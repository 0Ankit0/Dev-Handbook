# %% [markdown]
# # **Chapter 7: Communication Protocols & Data Formats**
#
# In a distributed system, every request crosses a network boundary. The choice of *how* services talk to each other — and *what shape* that data takes — affects latency, developer experience, coupling, and scalability.
#
# ---
#
# ## **7.1 Synchronous vs. Asynchronous Communication**
#
# Before choosing a protocol, decide whether the caller *waits* for a response or *fires and forgets*.
#
# | Style | Caller blocks? | Use when |
# |-------|---------------|----------|
# | Synchronous (HTTP, gRPC) | Yes | Immediate answer needed (login, read API) |
# | Asynchronous (queues, events) | No | Work can happen later (email, analytics) |
#
# **Key trade-off**: Synchronous calls are simpler to reason about but create temporal coupling — if the downstream service is slow or down, the caller blocks or fails.
#
# ---
#
# ## **7.2 REST (Representational State Transfer)**
#
# **REST** is an architectural style built on HTTP. It is the dominant style for public APIs because HTTP is universally supported and JSON is human-readable.
#
# ### **Core Constraints**
#
# 1. **Stateless**: Each request carries all the information the server needs. No session state is stored between requests.
# 2. **Uniform interface**: Resources are identified by URLs; actions are expressed via HTTP verbs.
# 3. **Client-server separation**: UI and storage concerns are decoupled.
# 4. **Cacheable**: Responses declare whether they can be cached.
#
# ### **HTTP Verbs and their Semantics**
#
# | Verb | Meaning | Idempotent? | Safe? |
# |------|---------|-------------|-------|
# | GET | Read a resource | Yes | Yes |
# | POST | Create / trigger action | No | No |
# | PUT | Replace entire resource | Yes | No |
# | PATCH | Partial update | No | No |
# | DELETE | Remove resource | Yes | No |
#
# **Idempotent** means calling the same request multiple times produces the same result. This matters for retry logic — safe to retry a `PUT` after a timeout, dangerous to retry a `POST` (may create duplicates).
#
# ### **REST Request/Response Flow**
#
# The following diagram shows a typical REST call. Notice that the client includes authentication in the header and that the server responds with a standard status code:
#
# ```text
# Client                              Server
#   │                                   │
#   │  GET /v1/users/42                 │
#   │  Accept: application/json         │
#   │  Authorization: Bearer <token>    │
#   │──────────────────────────────────▶│
#   │                                   │  Look up user 42 in DB
#   │  HTTP/1.1 200 OK                  │
#   │  Content-Type: application/json   │
#   │  {"id":42, "name":"Alice"}        │
#   │◀──────────────────────────────────│
# ```
#
# ### **REST Best Practices**
#
# - Use nouns for resources, not verbs: `/orders` not `/getOrders`
# - Use plural resource names: `/users/42` not `/user/42`
# - Return meaningful HTTP status codes: `200 OK`, `201 Created`, `400 Bad Request`, `404 Not Found`, `429 Too Many Requests`
# - Version your API: `/v1/users` so you can evolve without breaking clients

# %%
# REST API with Flask — demonstrates resource naming, status codes, idempotency
from flask import Flask, request, jsonify, abort

app = Flask(__name__)
users = {1: {'id': 1, 'name': 'Alice', 'email': 'alice@example.com'}}

@app.route('/v1/users/<int:user_id>', methods=['GET'])
def get_user(user_id):
    """Idempotent and safe: same result every call."""
    user = users.get(user_id)
    if not user:
        abort(404, description=f'User {user_id} not found')
    return jsonify(user), 200

@app.route('/v1/users', methods=['POST'])
def create_user():
    """Not idempotent: creates a NEW user on each call."""
    data = request.get_json()
    if not data or 'name' not in data:
        abort(400, description='name is required')
    new_id = max(users) + 1
    users[new_id] = {'id': new_id, **data}
    return jsonify(users[new_id]), 201  # 201 Created, not 200

@app.route('/v1/users/<int:user_id>', methods=['DELETE'])
def delete_user(user_id):
    """Idempotent: deleting twice has the same effect as deleting once."""
    users.pop(user_id, None)
    return '', 204  # 204 No Content

# %% [markdown]
# ---
#
# ## **7.3 GraphQL**
#
# **GraphQL** is a query language for APIs developed by Facebook (Meta) in 2012. Instead of many REST endpoints each returning a fixed data shape, GraphQL exposes a *single endpoint* where clients specify exactly the fields they need.
#
# ### **The Problem GraphQL Solves**
#
# With REST you often face:
# - **Over-fetching**: The endpoint returns 30 fields but the client only needs 3.
# - **Under-fetching / N+1**: One endpoint is not enough, so the client makes 3 sequential requests.
#
# The diagram below contrasts the two approaches for loading a user profile page:
#
# ```text
# REST: Multiple round-trips for a profile page
# ──────────────────────────────────────────────────
#   Request 1: GET /users/42           → name, email
#   Request 2: GET /users/42/posts     → post IDs
#   Request 3: GET /posts/7/comments   → comment count
#   3 network round-trips
#
# GraphQL: One query, one response
# ──────────────────────────────────────────────────
#   POST /graphql
#   {
#     user(id: 42) {
#       name
#       email
#       posts(last: 5) { title commentCount }
#     }
#   }
#   → Exactly the fields requested, in 1 round-trip
# ```
#
# ### **When to Use GraphQL**
#
# ✅ Mobile apps where minimizing bandwidth matters
# ✅ Multiple frontends (web, iOS, Android) with different data needs
# ✅ Aggregating data from multiple services in one call
# ❌ Simple CRUD APIs where REST is perfectly adequate
# ❌ Teams unfamiliar with schema-first design

# %% [markdown]
# ---
#
# ## **7.4 gRPC (Google Remote Procedure Call)**
#
# **gRPC** is a high-performance RPC framework that uses **Protocol Buffers** for serialization and **HTTP/2** as the transport.
#
# ### **How gRPC Differs from REST**
#
# | Aspect | REST / JSON | gRPC / Protobuf |
# |--------|-------------|------------------|
# | Protocol | HTTP/1.1 | HTTP/2 |
# | Payload format | Text (JSON) | Binary (protobuf) |
# | Schema | Optional (OpenAPI) | Required (.proto file) |
# | Speed | Moderate | ~5–10× faster serialization |
# | Streaming | No | Bidirectional streaming |
# | Browser support | Universal | Limited (needs grpc-web) |
#
# ### **gRPC Communication Patterns**
#
# gRPC supports four call types, shown here. The bidirectional streaming pattern is particularly powerful for real-time use cases like live dashboards and game servers:
#
# ```text
# ┌───────────────────────────────────────────────────────────────┐
# │                 gRPC Communication Patterns                   │
# ├───────────────────────────────────────────────────────────────┤
# │                                                               │
# │  1. Unary (like a REST call)                                  │
# │     Client ──── Request ────▶ Server                         │
# │     Client ◀─── Response ─── Server                         │
# │                                                               │
# │  2. Server Streaming (e.g., live updates)                     │
# │     Client ──── Request ────▶ Server                         │
# │     Client ◀─── Response 1 ── Server                        │
# │     Client ◀─── Response 2 ── Server                        │
# │     Client ◀─── Response N ── Server (stream ends)          │
# │                                                               │
# │  3. Client Streaming (e.g., uploading log chunks)             │
# │     Client ──── Request 1 ──▶ Server                         │
# │     Client ──── Request N ──▶ Server                         │
# │     Client ◀─── Response ─── Server (after all chunks)      │
# │                                                               │
# │  4. Bidirectional Streaming (e.g., chat, telemetry)           │
# │     Client ◀─────────────────▶ Server  (simultaneous)       │
# │                                                               │
# └───────────────────────────────────────────────────────────────┘
# ```
#
# ### **When to Use gRPC**
#
# ✅ Internal service-to-service communication where latency matters
# ✅ Polyglot environments (protobuf generates client code in 10+ languages)
# ✅ Streaming data between services
# ❌ Public APIs consumed by browsers
# ❌ Teams that need quick iteration without schema management overhead

# %% [markdown]
# ---
#
# ## **7.5 WebSockets and Server-Sent Events (SSE)**
#
# HTTP is fundamentally request-response: the client asks, the server answers. For real-time applications — live scores, collaborative editing, chat — you need the server to *push* data without the client polling.
#
# ### **WebSockets**
#
# A **WebSocket** establishes a persistent, full-duplex (bidirectional) TCP connection. After an HTTP upgrade handshake, both sides can send messages at any time without a request/response cycle:
#
# ```text
# WebSocket Connection Lifecycle
#
# Client                                     Server
#   │  GET /ws   HTTP/1.1                       │
#   │  Upgrade: websocket                       │
#   │──────────────────────────────────────────▶│
#   │  101 Switching Protocols                  │
#   │◀──────────────────────────────────────────│
#   │                                           │
#   │  [Persistent TCP connection established]  │
#   │                                           │
#   │  {"type":"chat","msg":"Hello"}            │
#   │──────────────────────────────────────────▶│
#   │                 {"type":"msg","from":"Bob"}│
#   │◀──────────────────────────────────────────│  (server pushes)
# ```
#
# **Use WebSockets for**: Chat, live collaboration, multiplayer games, real-time trading.
#
# ### **Server-Sent Events (SSE)**
#
# **SSE** is simpler — the server pushes a stream of events over a plain HTTP connection, but only one direction (server → client). The browser handles reconnection automatically.
#
# | | WebSocket | SSE |
# |-|-----------|-----|
# | Direction | Bidirectional | Server → Client only |
# | Protocol | Upgraded TCP | Plain HTTP |
# | Reconnection | Manual | Automatic |
# | Use case | Chat, games | Notifications, live feeds, build logs |
#
# **Rule of thumb**: Use SSE for simple one-way push (news feeds, progress bars, build logs). Use WebSockets when the client also sends real-time data back.

# %% [markdown]
# ---
#
# ## **7.6 Data Serialization Formats**
#
# The *format* of transmitted data affects payload size, serialization speed, schema enforcement, and human-readability.
#
# ### **JSON vs. Protocol Buffers: Size Comparison**
#
# The diagram below illustrates how the same data occupies very different sizes depending on format — a critical consideration at billions of requests per day:
#
# ```text
# Same data: JSON vs protobuf wire size
#
# JSON (82 bytes — human readable):
#   {"id": 42, "name": "Alice", "email": "alice@example.com"}
#
# Protobuf (28 bytes — binary, not human readable):
#   \x08\x2a\x12\x05Alice\x1a\x11alice@example.com
#   └── ~65% smaller than JSON
#
# At 1 billion requests/day:
#   JSON:     82 GB of payload/day
#   Protobuf: 28 GB of payload/day
#   Savings:  54 GB/day — significant bandwidth and CDN cost reduction
# ```
#
# ### **Format Comparison**
#
# | Format | Schema? | Binary? | Human readable? | Best for |
# |--------|---------|---------|-----------------|----------|
# | JSON | No | No | ✅ | Public APIs, config |
# | Protocol Buffers | Yes (.proto) | Yes | ❌ | gRPC, high-throughput internal APIs |
# | MessagePack | No | Yes | ❌ | Drop-in binary JSON replacement |
# | Apache Avro | Yes (.avsc) | Yes | ❌ | Kafka messages, data pipelines |
# | XML | No | No | ✅ | Legacy SOAP, document exchange |
#
# **Decision guide**: Start with JSON. Switch to protobuf or Avro when bandwidth or serialization latency becomes a measurable bottleneck.

# %%
import json
import time

# Demonstrate JSON serialization performance
user = {'id': 42, 'name': 'Alice', 'email': 'alice@example.com', 'age': 30}
json_bytes = json.dumps(user).encode('utf-8')

print(f'JSON payload: {json_bytes}')
print(f'JSON size:    {len(json_bytes)} bytes')
print()

iterations = 200_000
start = time.perf_counter()
for _ in range(iterations):
    json.dumps(user)
ser_time = time.perf_counter() - start

start = time.perf_counter()
for _ in range(iterations):
    json.loads(json_bytes)
parse_time = time.perf_counter() - start

print(f'JSON serialize: {ser_time*1000:.1f}ms for {iterations:,} operations')
print(f'JSON parse:     {parse_time*1000:.1f}ms for {iterations:,} operations')
print()
print('For protobuf benchmarks, install: pip install protobuf')
print('Expected: protobuf ~5x faster, ~60% smaller for structured records')

# %% [markdown]
# ---
#
# ## **7.7 Choosing the Right Protocol**
#
# The decision tree below captures the most common scenarios. There is no universally "best" choice — REST dominates public APIs for simplicity and ubiquity, gRPC wins for internal microservice meshes, and GraphQL shines for product APIs serving multiple frontends with different data needs.
#
# ```text
# Who consumes the API?
#         │
#         ├─▶ External / browser / public
#         │         │
#         │         ├─▶ Simple CRUD           → REST + JSON
#         │         ├─▶ Complex/flexible queries → GraphQL
#         │         └─▶ Real-time push         → WebSockets or SSE
#         │
#         └─▶ Internal service-to-service
#                   │
#                   ├─▶ Need max throughput/low latency → gRPC + protobuf
#                   ├─▶ Need streaming               → gRPC streaming
#                   └─▶ Small team, simplicity first  → REST + JSON (fine!)
# ```
#
# ### **Key Takeaways**
#
# - **REST** is the safe default for new public APIs.
# - **GraphQL** pays off when multiple clients have diverging data needs.
# - **gRPC** is the right tool for high-throughput internal communication.
# - **WebSockets** are the go-to for real-time bidirectional communication.
# - **Protobuf** is worth the schema overhead when bandwidth or CPU is constrained.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../2. The_building_blocks/6. load_balancing_and_traffic_management.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='8. distributed_data_management.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
