# %% [markdown]
# # Part V: Advanced Topics and Modern Analysis
#
# ## Chapter 18: Special Situations and Corporate Actions
#
# **Chapter Objective:** Understand how rights issues, bonuses, mergers, IPOs, and other corporate actions change the economics of a NEPSE investment.
#
# **NEPSE Focus:** Read every corporate action through its dilution effect, cash requirement, timeline, and likely impact on sentiment and valuation in Nepal.
#
# ![Chapter 18: Special Situations and Corporate Actions NEPSE visual](../images/chapter_18_nepse_visual.svg)
#
# Use the chapter visual as a memory map: start with market context, connect it to company evidence, then convert that evidence into a disciplined decision.
#
# **Visual anchors for this chapter**
# - 18.1 Mergers and Acquisitions (M&A) and Takeovers
# - 18.2 Rights Issues, Placings, and Share Buybacks
# - 18.3 Initial Public Offerings (IPOs) and New Issues
# - 18.4 Demergers and Spin-Offs

# %% [markdown]
# ### 18.1 Mergers and Acquisitions (M&A) and Takeovers
#
# Corporate actions can change both value and risk even when the headline looks attractive. The important question is what happens to dilution, cash needs, control, payout capacity, and timeline once a rights issue, merger, or other event is announced.
#
# **NEPSE example:** Apply this idea to a rights-heavy hydropower company and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 18.2 Rights Issues, Placings, and Share Buybacks
#
# This section explains how ownership is divided inside NEPSE-listed companies, where public shareholders, promoters, and sometimes strategic investors can have very different stakes and incentives. For a Nepali investor, the key habit is to check float, promoter holding, dividend history, and disclosure quality before assuming the quoted price reflects deep liquidity.
#
# **NEPSE example:** Apply this idea to a rights-heavy hydropower company and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 18.3 Initial Public Offerings (IPOs) and New Issues
#
# Corporate actions can change both value and risk even when the headline looks attractive. The important question is what happens to dilution, cash needs, control, payout capacity, and timeline once a rights issue, merger, or other event is announced.
#
# **NEPSE example:** Apply this idea to a rights-heavy hydropower company and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 18.4 Demergers and Spin-Offs
#
# Corporate actions can change both value and risk even when the headline looks attractive. The important question is what happens to dilution, cash needs, control, payout capacity, and timeline once a rights issue, merger, or other event is announced.
#
# **NEPSE example:** Apply this idea to a rights-heavy hydropower company and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 18.5 Bankruptcies and Distressed Investing
#
# Corporate actions can change both value and risk even when the headline looks attractive. The important question is what happens to dilution, cash needs, control, payout capacity, and timeline once a rights issue, merger, or other event is announced.
#
# **NEPSE example:** Apply this idea to a rights-heavy hydropower company and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 18.6 Special Situations Checklist
#
# A good investment process turns scattered observations into rules you can repeat. On NEPSE, that means deciding in advance what would make you buy more, hold patiently, trim, or exit instead of improvising after each daily move.
#
# **NEPSE example:** Apply this idea to a rights-heavy hydropower company and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ## Chapter Summary
#
# Keep the chapter grounded in NEPSE realities: read disclosures carefully, respect liquidity, compare within sector, and let evidence drive the decision instead of copying foreign-market assumptions.
#
# **Key points to retain**
# - 18.1 Mergers and Acquisitions (M&A) and Takeovers
# - 18.2 Rights Issues, Placings, and Share Buybacks
# - 18.3 Initial Public Offerings (IPOs) and New Issues
# - 18.4 Demergers and Spin-Offs
#
# **Exercises**
# 1. Review one NEPSE-listed company related to this chapter and note the single strongest supporting fact and the single biggest unanswered risk.
# 2. Compare the concept from this chapter across two NEPSE counters in the same sector and write down what changed your confidence level.
# 3. Create a one-page note that explains how you would use this chapter’s ideas before entering your next NEPSE trade or investment.

# %% [markdown]
# ## Resources for this chapter
#
# - [SEBON issue approvals and notices](https://www.sebon.gov.np/)
# - [NEPSE company action announcements](https://www.nepalstock.com/)
# - [CDSC allotment and demat notices](https://cdsc.com.np/)
# - [ShareSansar IPO and rights section](https://www.sharesansar.com/)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='17. behavioral_finance_the_investors_psychology.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='19. sentiment_analysis_and_big_data.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
