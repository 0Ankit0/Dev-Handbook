# %% [markdown]
# # Part V: Advanced Topics and Modern Analysis
#
# ## Chapter 20: Portfolio Management and Risk
#
# **Chapter Objective:** Build and evaluate a NEPSE portfolio using diversification, position sizing, risk control, and performance review.
#
# **NEPSE Focus:** Treat liquidity, sector concentration, rights issues, cash deployment pace, and exit discipline as core portfolio management concerns in Nepal.
#
# ![Chapter 20: Portfolio Management and Risk NEPSE visual](../images/chapter_20_nepse_visual.svg)
#
# Use the chapter visual as a memory map: start with market context, connect it to company evidence, then convert that evidence into a disciplined decision.
#
# **Visual anchors for this chapter**
# - 20.1 The Principles of Portfolio Construction
# - 20.2 Asset Allocation Strategies
# - 20.3 The Importance of Diversification
# - 20.4 Modern Portfolio Theory: The Efficient Frontier

# %% [markdown]
# ### 20.1 The Principles of Portfolio Construction
#
# A good investment process turns scattered observations into rules you can repeat. On NEPSE, that means deciding in advance what would make you buy more, hold patiently, trim, or exit instead of improvising after each daily move.
#
# **NEPSE example:** Apply this idea to a diversified four-sector NEPSE portfolio and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 20.2 Asset Allocation Strategies
#
# This section keeps the discussion anchored to NEPSE so the concept is easier to remember and easier to use in a real Nepali investing workflow.
#
# **NEPSE example:** Apply this idea to a diversified four-sector NEPSE portfolio and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 20.3 The Importance of Diversification
#
# Technical analysis studies price, volume, and behavior to judge whether demand is strengthening or weakening. In NEPSE, technical tools work best when you focus on liquid counters, respect turnover confirmation, and avoid treating every thinly traded move as a reliable signal.
#
# **NEPSE example:** Apply this idea to a diversified four-sector NEPSE portfolio and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 20.4 Modern Portfolio Theory: The Efficient Frontier
#
# A good investment process turns scattered observations into rules you can repeat. On NEPSE, that means deciding in advance what would make you buy more, hold patiently, trim, or exit instead of improvising after each daily move.
#
# **NEPSE example:** Apply this idea to a diversified four-sector NEPSE portfolio and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 20.5 Implementing Stop-Losses and Hedging
#
# This section keeps the discussion anchored to NEPSE so the concept is easier to remember and easier to use in a real Nepali investing workflow.
#
# **NEPSE example:** Apply this idea to a diversified four-sector NEPSE portfolio and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 20.6 Evaluating Investment Performance
#
# This section keeps the discussion anchored to NEPSE so the concept is easier to remember and easier to use in a real Nepali investing workflow.
#
# **NEPSE example:** Apply this idea to a diversified four-sector NEPSE portfolio and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ## Chapter Summary
#
# Keep the chapter grounded in NEPSE realities: read disclosures carefully, respect liquidity, compare within sector, and let evidence drive the decision instead of copying foreign-market assumptions.
#
# **Key points to retain**
# - 20.1 The Principles of Portfolio Construction
# - 20.2 Asset Allocation Strategies
# - 20.3 The Importance of Diversification
# - 20.4 Modern Portfolio Theory: The Efficient Frontier
#
# **Exercises**
# 1. Review one NEPSE-listed company related to this chapter and note the single strongest supporting fact and the single biggest unanswered risk.
# 2. Compare the concept from this chapter across two NEPSE counters in the same sector and write down what changed your confidence level.
# 3. Create a one-page note that explains how you would use this chapter’s ideas before entering your next NEPSE trade or investment.

# %% [markdown]
# ## Resources for this chapter
#
# - [NEPSE sector and index data](https://www.nepalstock.com/)
# - [ShareSansar portfolio tracking pages](https://www.sharesansar.com/)
# - [Merolagani watchlist and portfolio tools](https://merolagani.com/)
# - [NRB macro updates for portfolio context](https://www.nrb.org.np/)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='19. sentiment_analysis_and_big_data.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../6. putting_it_all_together/21. a_step_by_step_walkthrough_analyzing_a_real_company.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
