# %% [markdown]
# # Part V: Advanced Topics and Modern Analysis
#
# ## Chapter 19: Sentiment Analysis and Big Data
#
# **Chapter Objective:** Combine newsflow, sentiment, and alternative data to improve NEPSE analysis without letting noise dominate the investment process.
#
# **NEPSE Focus:** Use local news, broker chatter, turnover spikes, AGM commentary, and promoter activity as sentiment inputs while keeping a disciplined filter.
#
# ![Chapter 19: Sentiment Analysis and Big Data NEPSE visual](../images/chapter_19_nepse_visual.svg)
#
# Use the chapter visual as a memory map: start with market context, connect it to company evidence, then convert that evidence into a disciplined decision.
#
# **Visual anchors for this chapter**
# - 19.1 What is Sentiment Analysis?
# - 19.2 Analyzing News and Social Media Sentiment
# - 19.3 Tracking Insider Trading Activity
# - 19.4 Analyzing Analyst Ratings and Their Effectiveness

# %% [markdown]
# ### 19.1 What is Sentiment Analysis?
#
# Sentiment is useful only when it is filtered through evidence. For NEPSE investors, the most practical signals come from disclosure timing, turnover spikes, investor attention, and whether news is actually changing earnings expectations or merely accelerating noise.
#
# **NEPSE example:** Apply this idea to a mid-cap driven by news and turnover and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 19.2 Analyzing News and Social Media Sentiment
#
# Sentiment is useful only when it is filtered through evidence. For NEPSE investors, the most practical signals come from disclosure timing, turnover spikes, investor attention, and whether news is actually changing earnings expectations or merely accelerating noise.
#
# **NEPSE example:** Apply this idea to a mid-cap driven by news and turnover and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 19.3 Tracking Insider Trading Activity
#
# Sentiment is useful only when it is filtered through evidence. For NEPSE investors, the most practical signals come from disclosure timing, turnover spikes, investor attention, and whether news is actually changing earnings expectations or merely accelerating noise.
#
# **NEPSE example:** Apply this idea to a mid-cap driven by news and turnover and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 19.4 Analyzing Analyst Ratings and Their Effectiveness
#
# Sentiment is useful only when it is filtered through evidence. For NEPSE investors, the most practical signals come from disclosure timing, turnover spikes, investor attention, and whether news is actually changing earnings expectations or merely accelerating noise.
#
# **NEPSE example:** Apply this idea to a mid-cap driven by news and turnover and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 19.5 Alternative Data and Big Data in Investing
#
# Sentiment is useful only when it is filtered through evidence. For NEPSE investors, the most practical signals come from disclosure timing, turnover spikes, investor attention, and whether news is actually changing earnings expectations or merely accelerating noise.
#
# **NEPSE example:** Apply this idea to a mid-cap driven by news and turnover and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 19.6 Integrating Sentiment into Investment Decisions
#
# A good investment process turns scattered observations into rules you can repeat. On NEPSE, that means deciding in advance what would make you buy more, hold patiently, trim, or exit instead of improvising after each daily move.
#
# **NEPSE example:** Apply this idea to a mid-cap driven by news and turnover and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ## Chapter Summary
#
# Keep the chapter grounded in NEPSE realities: read disclosures carefully, respect liquidity, compare within sector, and let evidence drive the decision instead of copying foreign-market assumptions.
#
# **Key points to retain**
# - 19.1 What is Sentiment Analysis?
# - 19.2 Analyzing News and Social Media Sentiment
# - 19.3 Tracking Insider Trading Activity
# - 19.4 Analyzing Analyst Ratings and Their Effectiveness
#
# **Exercises**
# 1. Review one NEPSE-listed company related to this chapter and note the single strongest supporting fact and the single biggest unanswered risk.
# 2. Compare the concept from this chapter across two NEPSE counters in the same sector and write down what changed your confidence level.
# 3. Create a one-page note that explains how you would use this chapter’s ideas before entering your next NEPSE trade or investment.

# %% [markdown]
# ## Resources for this chapter
#
# - [NEPSE announcements and disclosures](https://www.nepalstock.com/)
# - [ShareSansar news archive](https://www.sharesansar.com/)
# - [Merolagani market news](https://merolagani.com/)
# - [SEBON insider transaction disclosures](https://www.sebon.gov.np/)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='18. special_situations_and_corporate_actions.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='20. portfolio_management_and_risk.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
