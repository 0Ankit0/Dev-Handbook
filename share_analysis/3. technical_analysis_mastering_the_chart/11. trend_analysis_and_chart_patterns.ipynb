# %% [markdown]
# # Part III: Technical Analysis – Mastering the Chart
#
# ## Chapter 11: Trend Analysis and Chart Patterns
#
# **Chapter Objective:** Read NEPSE charts using trend, support, resistance, and pattern logic that respects the market’s liquidity profile and trader behavior.
#
# **NEPSE Focus:** Pay close attention to breakout confirmation, turnover quality, circuit-driven moves, and the reliability of patterns in thinly traded counters.
#
# ![Chapter 11: Trend Analysis and Chart Patterns NEPSE visual](../images/chapter_11_nepse_visual.svg)
#
# Use the chapter visual as a memory map: start with market context, connect it to company evidence, then convert that evidence into a disciplined decision.
#
# **Visual anchors for this chapter**
# - 11.1 Identifying Trends: Uptrends, Downtrends, and Sideways Markets
# - 11.2 Support and Resistance: The Bedrock of Technicals
# - 11.3 Drawing Trendlines and Channel Lines
# - 11.4 Classical Reversal Patterns

# %% [markdown]
# ### 11.1 Identifying Trends: Uptrends, Downtrends, and Sideways Markets
#
# Technical analysis studies price, volume, and behavior to judge whether demand is strengthening or weakening. In NEPSE, technical tools work best when you focus on liquid counters, respect turnover confirmation, and avoid treating every thinly traded move as a reliable signal.
#
# **NEPSE example:** Apply this idea to a liquid NEPSE banking or manufacturing counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 11.2 Support and Resistance: The Bedrock of Technicals
#
# Technical analysis studies price, volume, and behavior to judge whether demand is strengthening or weakening. In NEPSE, technical tools work best when you focus on liquid counters, respect turnover confirmation, and avoid treating every thinly traded move as a reliable signal.
#
# **NEPSE example:** Apply this idea to a liquid NEPSE banking or manufacturing counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 11.3 Drawing Trendlines and Channel Lines
#
# Technical analysis studies price, volume, and behavior to judge whether demand is strengthening or weakening. In NEPSE, technical tools work best when you focus on liquid counters, respect turnover confirmation, and avoid treating every thinly traded move as a reliable signal.
#
# **NEPSE example:** Apply this idea to a liquid NEPSE banking or manufacturing counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 11.4 Classical Reversal Patterns
#
# This section keeps the discussion anchored to NEPSE so the concept is easier to remember and easier to use in a real Nepali investing workflow.
#
# **NEPSE example:** Apply this idea to a liquid NEPSE banking or manufacturing counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 11.5 Classical Continuation Patterns
#
# This section keeps the discussion anchored to NEPSE so the concept is easier to remember and easier to use in a real Nepali investing workflow.
#
# **NEPSE example:** Apply this idea to a liquid NEPSE banking or manufacturing counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 11.6 Volume Confirmation
#
# Technical analysis studies price, volume, and behavior to judge whether demand is strengthening or weakening. In NEPSE, technical tools work best when you focus on liquid counters, respect turnover confirmation, and avoid treating every thinly traded move as a reliable signal.
#
# **NEPSE example:** Apply this idea to a liquid NEPSE banking or manufacturing counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 11.7 Practical Application: A Step‑by‑Step Chart Analysis
#
# Technical analysis studies price, volume, and behavior to judge whether demand is strengthening or weakening. In NEPSE, technical tools work best when you focus on liquid counters, respect turnover confirmation, and avoid treating every thinly traded move as a reliable signal.
#
# **NEPSE example:** Apply this idea to a liquid NEPSE banking or manufacturing counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ## Chapter Summary
#
# Keep the chapter grounded in NEPSE realities: read disclosures carefully, respect liquidity, compare within sector, and let evidence drive the decision instead of copying foreign-market assumptions.
#
# **Key points to retain**
# - 11.1 Identifying Trends: Uptrends, Downtrends, and Sideways Markets
# - 11.2 Support and Resistance: The Bedrock of Technicals
# - 11.3 Drawing Trendlines and Channel Lines
# - 11.4 Classical Reversal Patterns
#
# **Exercises**
# 1. Review one NEPSE-listed company related to this chapter and note the single strongest supporting fact and the single biggest unanswered risk.
# 2. Compare the concept from this chapter across two NEPSE counters in the same sector and write down what changed your confidence level.
# 3. Create a one-page note that explains how you would use this chapter’s ideas before entering your next NEPSE trade or investment.

# %% [markdown]
# ## Resources for this chapter
#
# - [NEPSE Alpha trend and pattern tools](https://nepsealpha.com/)
# - [NEPSE historical price data](https://www.nepalstock.com/)
# - [ShareSansar company chart pages](https://www.sharesansar.com/)
# - [Merolagani live market pages](https://merolagani.com/)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='10. the_philosophy_of_technical_analysis.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='12. technical_indicators_and_oscillators.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
