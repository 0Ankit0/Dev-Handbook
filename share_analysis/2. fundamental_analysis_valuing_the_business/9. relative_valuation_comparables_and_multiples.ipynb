# %% [markdown]
# # Part II: Fundamental Analysis – Valuing the Business
#
# ## Chapter 9: Relative Valuation – Comparables and Multiples
#
# **Chapter Objective:** Learn to value a stock relative to comparable NEPSE peers using multiples that make sense for the local market and sector structure.
#
# **NEPSE Focus:** Choose peer groups carefully because NEPSE has a smaller universe, sector concentration, and large differences in free float, promoter holding, and liquidity.
#
# ![Chapter 9: Relative Valuation – Comparables and Multiples NEPSE visual](../images/chapter_09_nepse_visual.svg)
#
# Use the chapter visual as a memory map: start with market context, connect it to company evidence, then convert that evidence into a disciplined decision.
#
# **Visual anchors for this chapter**
# - 9.1 The Philosophy of Relative Valuation
# - 9.2 Price Multiples
# - 9.3 Enterprise Value Multiples
# - 9.4 The PEG Ratio for Growth Companies

# %% [markdown]
# ### 9.1 The Philosophy of Relative Valuation
#
# Valuation converts business expectations into a disciplined estimate of worth. Because NEPSE companies often operate in a smaller market with lower analyst coverage, you should use conservative assumptions and insist on a margin of safety before trusting a model output.
#
# **NEPSE example:** Apply this idea to NABIL and similar banks and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 9.2 Price Multiples
#
# Relative valuation is especially useful when you need a market-based sense check for a NEPSE idea. The challenge is choosing truly comparable peers, because sectors can be small and liquidity differences can distort apparently simple multiple comparisons.
#
# **NEPSE example:** Apply this idea to NABIL and similar banks and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 9.3 Enterprise Value Multiples
#
# Relative valuation is especially useful when you need a market-based sense check for a NEPSE idea. The challenge is choosing truly comparable peers, because sectors can be small and liquidity differences can distort apparently simple multiple comparisons.
#
# **NEPSE example:** Apply this idea to NABIL and similar banks and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 9.4 The PEG Ratio for Growth Companies
#
# Ratios turn raw statements into a clearer signal by showing whether management is converting sales or assets into sustainable shareholder value. The most useful habit on NEPSE is to compare each ratio with sector norms and with the company’s own multi-year trend rather than reading one number in isolation.
#
# **NEPSE example:** Apply this idea to NABIL and similar banks and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 9.5 When to Use Which Multiple
#
# This section keeps the discussion anchored to NEPSE so the concept is easier to remember and easier to use in a real Nepali investing workflow.
#
# **NEPSE example:** Apply this idea to NABIL and similar banks and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 9.6 Building a Comparable Company Analysis (Comps)
#
# This section keeps the discussion anchored to NEPSE so the concept is easier to remember and easier to use in a real Nepali investing workflow.
#
# **NEPSE example:** Apply this idea to NABIL and similar banks and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 9.7 Forward vs. Trailing Multiples
#
# Relative valuation is especially useful when you need a market-based sense check for a NEPSE idea. The challenge is choosing truly comparable peers, because sectors can be small and liquidity differences can distort apparently simple multiple comparisons.
#
# **NEPSE example:** Apply this idea to NABIL and similar banks and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 9.8 Limitations of Relative Valuation
#
# Valuation converts business expectations into a disciplined estimate of worth. Because NEPSE companies often operate in a smaller market with lower analyst coverage, you should use conservative assumptions and insist on a margin of safety before trusting a model output.
#
# **NEPSE example:** Apply this idea to NABIL and similar banks and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ## Chapter Summary
#
# Keep the chapter grounded in NEPSE realities: read disclosures carefully, respect liquidity, compare within sector, and let evidence drive the decision instead of copying foreign-market assumptions.
#
# **Key points to retain**
# - 9.1 The Philosophy of Relative Valuation
# - 9.2 Price Multiples
# - 9.3 Enterprise Value Multiples
# - 9.4 The PEG Ratio for Growth Companies
#
# **Exercises**
# 1. Review one NEPSE-listed company related to this chapter and note the single strongest supporting fact and the single biggest unanswered risk.
# 2. Compare the concept from this chapter across two NEPSE counters in the same sector and write down what changed your confidence level.
# 3. Create a one-page note that explains how you would use this chapter’s ideas before entering your next NEPSE trade or investment.

# %% [markdown]
# ## Resources for this chapter
#
# - [NEPSE sector company lists](https://www.nepalstock.com/)
# - [ShareSansar peer comparison tools](https://www.sharesansar.com/)
# - [Merolagani valuation snapshots](https://merolagani.com/)
# - [Company annual reports](https://www.nepalstock.com/)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='8. intrinsic_valuation_building_the_models.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../3. technical_analysis_mastering_the_chart/10. the_philosophy_of_technical_analysis.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
