# %% [markdown]
# # Part I: Laying the Foundation – The Investor's Toolkit
#
# ## Chapter 2: Core Concepts of Risk and Return
#
# **Chapter Objective:** Understand risk and return through the lens of liquidity, concentration, sector cycles, and opportunity cost inside the Nepali equity market.
#
# **NEPSE Focus:** Frame volatility around real NEPSE behavior such as thin order books, policy-sensitive sectors, dividend expectations, and sudden sentiment swings in banking and hydropower counters.
#
# ![Chapter 2: Core Concepts of Risk and Return NEPSE visual](../images/chapter_02_nepse_visual.svg)
#
# Use the chapter visual as a memory map: start with market context, connect it to company evidence, then convert that evidence into a disciplined decision.
#
# **Visual anchors for this chapter**
# - 2.1 Defining Investment Risk: More Than Just "Losing Money"
# - 2.2 The Historical Trade-Off Between Risk and Return
# - 2.3 An Introduction to Market Cycles: Boom, Bust, and Bubbles
# - 2.4 The Concept of Opportunity Cost

# %% [markdown]
# ### 2.1 Defining Investment Risk: More Than Just "Losing Money"
#
# On NEPSE, risk is not just a falling price; it is also the risk of poor liquidity, delayed exits, concentrated sector exposure, and policy-sensitive earnings. A disciplined investor therefore studies both price swings and the business reasons behind those swings before deciding position size.
#
# **NEPSE example:** Apply this idea to the NEPSE Index and a liquid banking counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 2.2 The Historical Trade-Off Between Risk and Return
#
# On NEPSE, risk is not just a falling price; it is also the risk of poor liquidity, delayed exits, concentrated sector exposure, and policy-sensitive earnings. A disciplined investor therefore studies both price swings and the business reasons behind those swings before deciding position size.
#
# **NEPSE example:** Apply this idea to the NEPSE Index and a liquid banking counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 2.3 An Introduction to Market Cycles: Boom, Bust, and Bubbles
#
# NEPSE cycles often amplify because sentiment spreads quickly, free float is limited, and many investors anchor to recent highs. The smart habit is to read each cycle through earnings support, liquidity support, and policy support rather than through headline excitement alone.
#
# **NEPSE example:** Apply this idea to the NEPSE Index and a liquid banking counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 2.4 The Concept of Opportunity Cost
#
# Return should always be judged against the amount of uncertainty, holding time, and alternative uses of capital available in Nepal. Comparing an equity idea with bank deposits, bonds, or a better-priced listed alternative helps you avoid confusing excitement with real reward.
#
# **NEPSE example:** Apply this idea to the NEPSE Index and a liquid banking counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 2.5 Quantifying Risk: Volatility, Beta, and Downside Risk
#
# On NEPSE, risk is not just a falling price; it is also the risk of poor liquidity, delayed exits, concentrated sector exposure, and policy-sensitive earnings. A disciplined investor therefore studies both price swings and the business reasons behind those swings before deciding position size.
#
# **NEPSE example:** Apply this idea to the NEPSE Index and a liquid banking counter and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ## Chapter Summary
#
# Keep the chapter grounded in NEPSE realities: read disclosures carefully, respect liquidity, compare within sector, and let evidence drive the decision instead of copying foreign-market assumptions.
#
# **Key points to retain**
# - 2.1 Defining Investment Risk: More Than Just "Losing Money"
# - 2.2 The Historical Trade-Off Between Risk and Return
# - 2.3 An Introduction to Market Cycles: Boom, Bust, and Bubbles
# - 2.4 The Concept of Opportunity Cost
#
# **Exercises**
# 1. Review one NEPSE-listed company related to this chapter and note the single strongest supporting fact and the single biggest unanswered risk.
# 2. Compare the concept from this chapter across two NEPSE counters in the same sector and write down what changed your confidence level.
# 3. Create a one-page note that explains how you would use this chapter’s ideas before entering your next NEPSE trade or investment.

# %% [markdown]
# ## Resources for this chapter
#
# - [NEPSE index and turnover history](https://www.nepalstock.com/market-summary)
# - [Nepal Rastra Bank reports](https://www.nrb.org.np/)
# - [Ministry of Finance economic survey](https://www.mof.gov.np/)
# - [Merolagani market stats](https://merolagani.com/)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='1. understanding_the_stock_market_landscape.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='3. the_two_pillars_of_analysis_fundamental_vs_technical.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
