# %% [markdown]
# # Part I: Laying the Foundation – The Investor's Toolkit
#
# ## Chapter 1: Understanding the Stock Market Landscape
#
# **Chapter Objective:** Build a practical NEPSE-first understanding of what a share represents, how trades move through the market, and how listed shares compare with other investment options available to Nepali investors.
#
# **NEPSE Focus:** Use NEPSE, SEBON, CDSC, broker accounts, and common local counters such as NTC, NABIL, and HIDCL as the default reference points instead of foreign exchanges.
#
# ![Chapter 1: Understanding the Stock Market Landscape NEPSE visual](../images/chapter_01_nepse_visual.svg)
#
# Use the chapter visual as a memory map: start with market context, connect it to company evidence, then convert that evidence into a disciplined decision.
#
# **Visual anchors for this chapter**
# - 1.1 What are Shares? Ordinary Shares, Promoter Shares, and Public Float in Nepal
# - 1.2 How Securities Are Traded: From Exchanges to Order Types
# - 1.3 Market Participants and Market Makers
# - 1.4 An Overview of Investment Alternatives: Stocks, Bonds, ETFs, and Funds

# %% [markdown]
# ### 1.1 What are Shares? Ordinary Shares, Promoter Shares, and Public Float in Nepal
#
# This section explains how ownership is divided inside NEPSE-listed companies, where public shareholders, promoters, and sometimes strategic investors can have very different stakes and incentives. For a Nepali investor, the key habit is to check float, promoter holding, dividend history, and disclosure quality before assuming the quoted price reflects deep liquidity.
#
# **NEPSE example:** Apply this idea to NTC and NABIL and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 1.2 How Securities Are Traded: From Exchanges to Order Types
#
# In NEPSE, execution quality is shaped by broker routing, limited depth in many counters, and the difference between a price you see on screen and the price you can actually fill. Understanding how orders meet, how spreads widen, and how settlement works through CDSC makes you far more realistic about entry and exit planning.
#
# **NEPSE example:** Apply this idea to NTC and NABIL and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 1.3 Market Participants and Market Makers
#
# The Nepali market is influenced by retail investors, institutions, promoters, mutual funds, and active traders whose behavior shows up in turnover and delivery patterns. Rather than assuming a deep two-sided market at all times, treat every trade as an interaction between liquidity, conviction, and timing.
#
# **NEPSE example:** Apply this idea to NTC and NABIL and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ### 1.4 An Overview of Investment Alternatives: Stocks, Bonds, ETFs, and Funds
#
# Shares compete with fixed deposits, government bonds, mutual funds, debentures, and real-estate decisions in the local investor mind. The practical question is not whether equities are always superior, but when their higher return potential justifies the additional volatility and liquidity risk.
#
# **NEPSE example:** Apply this idea to NTC and NABIL and ask what the market is pricing correctly, what may still be misunderstood, and what evidence would change your view.
#
# - Focus on the local disclosure, liquidity, and sector context before drawing a conclusion.
# - Prefer a simple repeatable checklist over a prediction-heavy story.
# - Revisit the idea after new NEPSE notices, quarterly numbers, or turnover shifts appear.

# %% [markdown]
# ## Chapter Summary
#
# Keep the chapter grounded in NEPSE realities: read disclosures carefully, respect liquidity, compare within sector, and let evidence drive the decision instead of copying foreign-market assumptions.
#
# **Key points to retain**
# - 1.1 What are Shares? Ordinary Shares, Promoter Shares, and Public Float in Nepal
# - 1.2 How Securities Are Traded: From Exchanges to Order Types
# - 1.3 Market Participants and Market Makers
# - 1.4 An Overview of Investment Alternatives: Stocks, Bonds, ETFs, and Funds
#
# **Exercises**
# 1. Review one NEPSE-listed company related to this chapter and note the single strongest supporting fact and the single biggest unanswered risk.
# 2. Compare the concept from this chapter across two NEPSE counters in the same sector and write down what changed your confidence level.
# 3. Create a one-page note that explains how you would use this chapter’s ideas before entering your next NEPSE trade or investment.

# %% [markdown]
# ## Resources for this chapter
#
# - [NEPSE market information](https://www.nepalstock.com/)
# - [SEBON investor education and disclosures](https://www.sebon.gov.np/)
# - [CDSC account and settlement guides](https://cdsc.com.np/)
# - [ShareSansar market overview](https://www.sharesansar.com/)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <span style='color:gray; font-size:1.05em;'>Previous</span>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='2. core_concepts_of_risk_and_return.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
