# %% [markdown]
# # Chapter 14: How PostgreSQL Executes Queries

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='14. how_postgres_executes_queries.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='15. index_fundamentals.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
