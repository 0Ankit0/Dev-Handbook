# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../1.%20Foundations/4.%20core_concepts_you_must_get_right_early.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='6.%20creating_tables_and_constraints.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 5: Data Types Done Right
#
# Choosing the wrong data type is one of the most expensive database design mistakes. Type changes require table rewrites, index rebuilds, and application refactoring. Get types right the first time — every row added after a wrong choice increases the cost of fixing it.

# %% [markdown]
# ## The Big Picture
#
# Think of data types as contracts. When you declare `price NUMERIC(19,4)`, you make a contract with every application and reporting tool that touches that column: 'this value will always be an exact decimal with up to 4 fractional digits.' Breaking that contract later cascades into application bugs and reporting inaccuracies.
#
# The most important principle: **choose the most specific type that correctly models your domain**. A product price is not a `FLOAT` — floating point arithmetic cannot represent 0.10 exactly (try `0.1 + 0.2 == 0.3` in Python: it returns `False`). An email is not a `CHAR(255)` — padding wastes space and breaks equality comparisons. A timestamp without a timezone is not a point in time — it is an ambiguous local clock reading.
#
# PostgreSQL's type system goes far beyond standard SQL. Beyond integers and text, it offers `UUID`, `JSONB`, `INET`, range types (`TSTZRANGE`, `DATERANGE`), `BOOLEAN`, composite types, and domain types. Each has query operators and index support designed specifically for that type. A phone number stored as `TEXT` cannot use `inet` operators. A date range stored as two separate `DATE` columns cannot use the `&&` overlap check with a GiST index.
#
# The decisions in this chapter affect every query written against your schema for the life of the application.

# %% [markdown]
# ## Core Concepts
#
# ### Integer Types
# `SMALLINT` (2 bytes, ±32K), `INTEGER` (4 bytes, ±2B), `BIGINT` (8 bytes, ±9.2 quintillion). Use `BIGINT` for primary keys. `INTEGER` PKs overflow at 2 billion rows — closer than you think.
#
# ### Exact vs Approximate Numerics
# `NUMERIC(precision, scale)` stores exact decimals — mandatory for financial calculations. `REAL` and `DOUBLE PRECISION` use IEEE 754 floating point — correct for scientific measurements, never for money.
#
# ### Text Types
# `TEXT` and `VARCHAR` are identical in PostgreSQL storage and performance. Use `TEXT` everywhere; add length constraints via `CHECK` constraints. `CHAR(n)` pads with spaces — almost never appropriate.
#
# ### Temporal Types
# `TIMESTAMPTZ` (with time zone) is the standard for events — stores UTC, displays in session timezone. `TIMESTAMP` (without zone) is a wall-clock reading without context. Always set `timezone = 'UTC'` in `postgresql.conf`.
#
# ### Specialized Types
# `UUID` for globally unique identifiers. `JSONB` for semi-structured data with GIN indexing. `BOOLEAN` for flags (not `SMALLINT`). `INET`/`CIDR` for IP addresses. Range types (`TSTZRANGE`, `DATERANGE`) for time intervals with overlap detection.

# %% [markdown]
# ## Key SQL Syntax
#
# ```sql
# -- Integer primary key
# user_id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY
#
# -- Exact money
# price_cents BIGINT NOT NULL CHECK (price_cents >= 0)
# price_exact NUMERIC(19,4) NOT NULL CHECK (price_exact >= 0)
#
# -- Text with validation
# email TEXT NOT NULL CHECK (email ~* '^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\\.[A-Za-z]{2,}$')
# slug  TEXT NOT NULL CHECK (slug ~ '^[a-z0-9-]+$')
#
# -- Timestamps
# occurred_at TIMESTAMPTZ NOT NULL DEFAULT NOW()
# birth_date  DATE NOT NULL CHECK (birth_date < CURRENT_DATE)
#
# -- Specialized
# doc_id      UUID NOT NULL DEFAULT gen_random_uuid()
# metadata    JSONB
# ip_addr     INET
# period      TSTZRANGE
#
# -- JSONB query with GIN index
# CREATE INDEX ON documents USING GIN (metadata);
# SELECT * FROM documents WHERE metadata @> '{"status": "published"}';
# ```

# %%
# Data type selection guide

type_guide = [
    ('Primary Keys',
     'BIGINT GENERATED ALWAYS AS IDENTITY',
     'SERIAL (legacy), INTEGER (overflow), UUID as PK (index fragmentation)',
     'BIGINT handles 9.2 quintillion rows; IDENTITY is SQL standard'),
    ('Financial Amounts',
     'BIGINT (cents) or NUMERIC(19,4)',
     'FLOAT, DOUBLE PRECISION, MONEY',
     '0.1 + 0.2 != 0.3 in floating point — never for money'),
    ('Text Data',
     'TEXT with CHECK constraints',
     'CHAR(n) (pads with spaces), VARCHAR(n) (use CHECK instead)',
     'TEXT and VARCHAR are identical storage; CHECK gives better errors'),
    ('Events/Logs',
     'TIMESTAMPTZ NOT NULL DEFAULT NOW()',
     'TIMESTAMP (no timezone), BIGINT (Unix epoch — unreadable)',
     'TIMESTAMPTZ stores UTC, displays in session zone — never ambiguous'),
    ('Boolean Flags',
     'BOOLEAN NOT NULL DEFAULT FALSE',
     'SMALLINT (0/1), CHAR(1) (Y/N), TEXT (\'true\')',
     'BOOLEAN is self-documenting with IS TRUE / IS FALSE operators'),
    ('IP Addresses',
     'INET or CIDR',
     'TEXT (loses subnet operators), BIGINT (IPv6 overflow)',
     'INET supports <<= (subnet containment) and >> operators natively'),
    ('Semi-structured Data',
     'JSONB (binary, indexed, queryable)',
     'JSON (text, not indexable), TEXT (no operators)',
     'JSONB supports GIN indexes, -> operators, jsonb_path_query()'),
]

print('=== Data Type Selection Guide ===')
print()
for category, recommended, avoid, reason in type_guide:
    print(f'  {category}')
    print(f'    Use:    {recommended}')
    print(f'    Avoid:  {avoid}')
    print(f'    Why:    {reason}')
    print()

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 1: The Money Problem — Why Floating Point Fails
#
# This is the most important data type lesson. Financial calculations with `FLOAT` accumulate errors invisibly. A customer's balance might show `$99.99999999` instead of `$100.00` — or worse, round the wrong way on taxes, failing an audit years later.

# %%
# Demonstrating floating point precision failures

from decimal import Decimal

print('=== Floating Point Precision Problem ===')
print()
a, b = 0.1, 0.2
result = a + b
print(f'  0.1 + 0.2 = {result}')
print(f'  0.1 + 0.2 == 0.3 is {result == 0.3}')
print()

# Accumulation error (simulate 100 line items at $0.10)
total = sum(0.1 for _ in range(100))
print(f'  Sum of 0.1 x 100 times:')
print(f'    Expected: {100 * 0.1:.10f}')
print(f'    Got:      {total:.10f}')
print(f'    Error:    {abs(total - 100 * 0.1):.2e}')
print()

print('=== Correct Approaches ===')
print()

# Approach 1: Integer cents
cents_a, cents_b = 10, 20  # $0.10 and $0.20 as cents
cents_sum = cents_a + cents_b
print(f'  Integer cents: {cents_a} + {cents_b} = {cents_sum} cents = ${cents_sum/100:.2f}')

# Approach 2: Decimal
d_sum = Decimal('0.10') + Decimal('0.20')
print(f'  Decimal: 0.10 + 0.20 = {d_sum} (exact)')
print(f'  Decimal == 0.30: {d_sum == Decimal("0.30")}')
print()

print('=== PostgreSQL DDL ===')
approaches = [
    ('BIGINT cents', 'price_cents BIGINT NOT NULL CHECK (price_cents >= 0)', 'Fastest, no precision issues'),
    ('NUMERIC',      'price NUMERIC(19,4) NOT NULL CHECK (price >= 0)',       'Exact decimal arithmetic'),
    ('FLOAT (wrong)','price DOUBLE PRECISION',                                'WRONG — accumulates rounding errors'),
    ('MONEY (wrong)','price MONEY',                                           'WRONG — locale-dependent, limited operators'),
]
for label, ddl, note in approaches:
    marker = 'x' if 'WRONG' in note else 'v'
    print(f'  [{marker}] {label}: {ddl}')
    print(f'       {note}')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 2: The Timestamp Timezone Trap
#
# The `TIMESTAMP` vs `TIMESTAMPTZ` distinction causes more production bugs than almost any other data type decision. Everything works perfectly until your team spans timezones, or your server is moved to a different region.

# %%
# TIMESTAMPTZ vs TIMESTAMP behaviour illustrated

class TimestampTZ:
    def __init__(self, utc_value):
        self.utc = utc_value
    def display(self, tz):
        offsets = {
            'UTC': '+00:00', 'America/New_York': '-05:00',
            'Asia/Tokyo': '+09:00', 'Europe/London': '+00:00',
        }
        return f'{self.utc}{offsets.get(tz, "+00:00")} ({tz})'

class Timestamp:
    def __init__(self, value):
        self.value = value
    def display(self, tz):
        return f'{self.value} (timezone unknown — ambiguous!)'

ts_with_tz = TimestampTZ('2024-03-15 17:00:00')  # noon NYC = 17:00 UTC
ts_without_tz = Timestamp('2024-03-15 12:00:00')  # just '12:00'

print('Scenario: Noon New York time inserted as 2024-03-15 12:00:00')
print()
for session_tz in ['UTC', 'America/New_York', 'Asia/Tokyo', 'Europe/London']:
    print(f'  Session TZ: {session_tz}')
    print(f'    TIMESTAMPTZ: {ts_with_tz.display(session_tz)}')
    print(f'    TIMESTAMP:   {ts_without_tz.display(session_tz)}')
    print()

print('=== Best Practices ===')
rules = [
    ('postgresql.conf',  "timezone = 'UTC'"),
    ('Every connection', "SET TIME ZONE 'UTC'"),
    ('Schema',           'ALL event columns: TIMESTAMPTZ NOT NULL DEFAULT NOW()'),
    ('Display',          'Convert to local time in the frontend, never in DB'),
    ('Exception',        "TIMESTAMP only for 'meeting at 9 AM local time' — future local events"),
]
for context, rule in rules:
    print(f'  {context:<18} {rule}')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 3: Specialized Types — JSONB, UUID, and Range Types
#
# PostgreSQL's specialized types are not just storage formats — each comes with operators, indexes, and query capabilities that would require dozens of columns to replicate using basic types.

# %%
# Specialized PostgreSQL types and their operators

print('=== JSONB Operators ===')
jsonb_ops = [
    ('->', 'col -> \'key\'', 'Extract field as JSON'),
    ('->>', 'col ->> \'key\'', 'Extract field as TEXT'),
    ('@>', 'col @> \'{"k":"v"}\'', 'Contains (GIN indexed)'),
    ('?',  'col ? \'key\'', 'Key exists (GIN indexed)'),
    ('#>', 'col #> \'{a,b}\'', 'Extract nested path as JSON'),
]
for op, example, desc in jsonb_ops:
    print(f'  {op:<5} {example:<30} {desc}')
print()
print('  Index: CREATE INDEX ON docs USING GIN (metadata);')
print('  Query: SELECT * FROM docs WHERE metadata @> \'{"published":true}\';')

print()
print('=== UUID Patterns ===')
uuid_patterns = [
    ('External ID',  'order_uuid UUID DEFAULT gen_random_uuid()', 'Non-enumerable external identifier'),
    ('Internal PK',  'order_id BIGINT GENERATED ALWAYS AS IDENTITY', 'Fast internal joins'),
    ('Hybrid (best)','Both columns on same table', 'Internal speed + external security'),
]
for pattern, ddl, use_case in uuid_patterns:
    print(f'  {pattern:<16} {ddl}')
    print(f'  {"":16} -> {use_case}')

print()
print('=== Range Type Operators ===')
range_ops = [
    ('@>',  'period @> NOW()', 'Contains a point (is now within the range?)'),
    ('&&',  'a && b', 'Overlap (do two ranges share any time?)'),
    ('<@',  'point <@ range', 'Element is contained by range'),
    ('-|-', 'a -|- b', 'Adjacent (do the ranges share an endpoint?)'),
]
for op, example, desc in range_ops:
    print(f'  {op:<5} {example:<25} {desc}')
print()
print('  Exclusion constraint (no overlapping bookings):')
print('  EXCLUDE USING GIST (room_id WITH =, period WITH &&)')

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# 1. **What if you store money as `DOUBLE PRECISION`?** Run `SELECT 0.1::DOUBLE PRECISION + 0.2::DOUBLE PRECISION = 0.3::DOUBLE PRECISION;` — it returns `false`. Imagine 1 million tax calculations silently rounding the wrong way.
#
# 2. **What if you use `TIMESTAMP` and change your server timezone?** Insert a row with `NOW()`. Change `SET TIME ZONE 'Asia/Tokyo'` and re-read. With `TIMESTAMPTZ`, the moment is the same but the display changes correctly. With `TIMESTAMP`, you cannot tell which timezone the value was written in.
#
# 3. **What if you store JSON as `TEXT` vs `JSONB`?** Try `SELECT '{"name":"alice"}'::TEXT @> '{"name":"alice"}'` — it fails. `JSONB` gets operators (`@>`, `?`, `#>`) and GIN index support. `TEXT` gets string functions only.

# %%
# Experiment: Comparing money storage approaches

from decimal import Decimal

print('=== Money Storage Comparison: 1000 items at $19.99 each ===')
print()

expected = 1000 * 1999  # 19990 cents

# Float approach (wrong)
float_total = sum(19.99 for _ in range(1000))
float_error = abs(float_total - 19990) / 100
print(f'  FLOAT:    ${float_total:.6f}  (error: ${float_error:.8f})')

# Integer cents (correct)
cents_total = sum(1999 for _ in range(1000))
print(f'  BIGINT:   ${cents_total / 100:.6f}  (exact, error: $0.00000000)')

# Decimal (correct)
d_total = sum(Decimal('19.99') for _ in range(1000))
d_error = abs(float(d_total) - 19990) / 100
print(f'  NUMERIC:  ${float(d_total):.6f}  (error: ${d_error:.8f})')
print()

print('=== DDL Recommendation ===')
print('  -- For prices, always use one of:')
print('  price_cents BIGINT NOT NULL CHECK (price_cents >= 0)  -- recommended for most apps')
print('  price NUMERIC(19,4) NOT NULL CHECK (price >= 0)       -- when fractional cents needed')
print()
print('  -- NEVER:')
print('  price DOUBLE PRECISION  -- floating point error')
print('  price MONEY             -- locale-dependent, deprecated')

# %% [markdown]
# ## Real-World Project Link
#
# **Mini project:** Design a type-safe e-commerce product catalog schema.
#
# Requirements:
# - `product` table: UUID external ID, BIGINT internal PK, name (TEXT with length check), price in cents (BIGINT), weight_grams (INTEGER), in_stock (BOOLEAN), metadata (JSONB)
# - `price_history` table tracking changes with `TIMESTAMPTZ` and exact `NUMERIC(19,4)` values
# - A generated column converting `price_cents` to dollars as `NUMERIC(10,2)`
# - A `discount` table with `TSTZRANGE` and an exclusion constraint preventing overlapping discounts
#
# Write the complete DDL and include a comment for each type choice explaining why that type was selected.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### What you learned
# - `BIGINT GENERATED ALWAYS AS IDENTITY` for PKs — never `SERIAL` or `INTEGER`
# - `NUMERIC(19,4)` or `BIGINT` cents for money — never `FLOAT`, never `MONEY`
# - `TEXT` for strings with `CHECK` constraints; `CHAR(n)` is rarely correct
# - `TIMESTAMPTZ` for events; `TIMESTAMP` only for abstract wall-clock times
# - `JSONB` (not `JSON`) for semi-structured data — GIN index support
# - Range types (`TSTZRANGE`, `DATERANGE`) for overlap detection with GiST indexes
#
# ### Cheat sheet
# ```sql
# -- Primary key
# id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY
#
# -- Money
# price_cents BIGINT NOT NULL CHECK (price_cents >= 0)
# price       NUMERIC(19,4) NOT NULL CHECK (price >= 0)
#
# -- Text
# email TEXT NOT NULL CHECK (email ~* '^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\\.[A-Za-z]{2,}$')
#
# -- Timestamps
# created_at TIMESTAMPTZ NOT NULL DEFAULT NOW()
# birth_date DATE NOT NULL CHECK (birth_date < CURRENT_DATE)
#
# -- Specialized
# external_id UUID NOT NULL DEFAULT gen_random_uuid()
# attributes  JSONB
# ip_address  INET
# active_period TSTZRANGE
#
# -- JSONB query
# SELECT * FROM products WHERE attributes @> '{"color": "red"}';
# ```

# %% [markdown]
# ## Practice Prompts
#
# 1. Run `SELECT 0.1::FLOAT + 0.2::FLOAT = 0.3::FLOAT;` in PostgreSQL. What does it return? Why? What type would you use for financial calculations?
# 2. What is the difference between `TIMESTAMPTZ` and `TIMESTAMP`? Write a scenario where using `TIMESTAMP` causes a production bug.
# 3. Why is `CHAR(n)` almost never the right choice? What storage difference exists between `CHAR(255)` and `TEXT` for a 5-character value?
# 4. Describe three specialized PostgreSQL types beyond standard SQL. For each, explain what query capability it enables that `TEXT` or `INTEGER` would not.
# 5. Design the DDL for a `product_price` table recording price history with exact values and correct timezone-aware timestamps. Explain each type choice.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../1.%20Foundations/4.%20core_concepts_you_must_get_right_early.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='6.%20creating_tables_and_constraints.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
