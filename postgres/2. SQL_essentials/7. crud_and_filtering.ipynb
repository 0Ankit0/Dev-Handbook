# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='6.%20creating_tables_and_constraints.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='8.%20joins_aggregation_and_set_logic.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 7: CRUD Operations and Filtering
#
# Mastering Create, Read, Update, and Delete operations is fundamental to PostgreSQL proficiency. This chapter covers industry-standard patterns for safe, performant data manipulation — from atomic upserts to safe batch updates and pagination that actually scales.

# %% [markdown]
# ## The Big Picture
#
# Think of CRUD operations as recipes. You can cook an omelette correctly or you can cook it in a way that poisons everyone at the table. The SQL compiles either way. The difference between correct and dangerous SQL is rarely obvious from syntax alone.
#
# `UPDATE users SET status = 'deleted';` is valid SQL. It also deletes every user in the table if you forgot the `WHERE` clause. `DELETE FROM orders;` runs in milliseconds and destroys years of business data. These mistakes happen to experienced engineers under pressure.
#
# The `RETURNING` clause is one of PostgreSQL's most valuable CRUD features. It eliminates the need for a second query after an insert to retrieve generated IDs, eliminates race conditions between insert and select, and enables atomic 'write and confirm' patterns in a single round trip.
#
# Large bulk updates deserve special attention. Updating millions of rows in a single transaction generates a massive WAL (Write-Ahead Log) entry, causes replication lag, prevents autovacuum from reclaiming dead tuples until the transaction commits, and holds locks for extended periods. The industry standard is to batch large mutations into smaller transactions.

# %% [markdown]
# ## Core Concepts
#
# ### RETURNING Clause
# Returns column values from modified rows without a second query. Essential for getting auto-generated IDs, defaults, and computed values after `INSERT`, `UPDATE`, or `DELETE`.
#
# ### ON CONFLICT (Upsert)
# Handles unique constraint violations atomically: `ON CONFLICT (col) DO UPDATE SET ...`. The `EXCLUDED` pseudo-table refers to the row that failed to insert. Combine with `WHERE` to make updates conditional.
#
# ### Batch Updates
# Large updates should use `LIMIT`-based batching to avoid long-running transactions. Use `ctid` (physical row address) for efficient batch targeting without re-scanning.
#
# ### Soft Deletes
# Instead of hard deleting rows, set `deleted_at = NOW()` and filter with `WHERE deleted_at IS NULL`. Preserves history, enables undo, simplifies auditing.
#
# ### Filtering Best Practices
# Use `IS DISTINCT FROM` instead of `!=` when NULLs are possible. Use `EXISTS` instead of `IN` for subquery filtering (more efficient planner handling). Use `LIMIT ... OFFSET` only for small datasets; use keyset pagination for large result sets.

# %% [markdown]
# ## Key SQL Syntax
#
# ```sql
# -- INSERT with RETURNING
# INSERT INTO users (email, full_name)
# VALUES ('alice@example.com', 'Alice Smith')
# RETURNING user_id, created_at;
#
# -- Upsert (insert or update)
# INSERT INTO users (email, full_name, updated_at)
# VALUES ('alice@example.com', 'Alice Updated', NOW())
# ON CONFLICT (email)
# DO UPDATE SET
#     full_name  = EXCLUDED.full_name,
#     updated_at = EXCLUDED.updated_at
# RETURNING user_id;
#
# -- Safe batch update
# UPDATE large_table SET status = 'archived'
# WHERE ctid IN (
#     SELECT ctid FROM large_table
#     WHERE status != 'archived' AND created_at < '2023-01-01'
#     LIMIT 1000
# );
#
# -- Keyset pagination (scalable)
# SELECT * FROM orders
# WHERE order_id > :last_seen_id
# ORDER BY order_id
# LIMIT 50;
# ```

# %%
# CRUD operation patterns illustrated

print('=== INSERT Patterns ===')
print()

insert_patterns = {
    'Basic (anti-pattern)': (
        'INSERT INTO users (email) VALUES (\"alice@example.com\");\n'
        '-- Requires separate query to get user_id (race condition risk)'
    ),
    'With RETURNING (standard)': (
        'INSERT INTO users (email, full_name)\n'
        'VALUES (\"alice@example.com\", \"Alice Smith\")\n'
        'RETURNING user_id, created_at;\n'
        '-- One round trip: insert and get ID atomically'
    ),
    'Bulk insert': (
        'INSERT INTO users (email, full_name) VALUES\n'
        '    (\"user1@example.com\", \"User One\"),\n'
        '    (\"user2@example.com\", \"User Two\"),\n'
        '    (\"user3@example.com\", \"User Three\")\n'
        'RETURNING user_id, email;'
    ),
    'Upsert': (
        'INSERT INTO users (email, full_name, updated_at)\n'
        'VALUES (\"alice@example.com\", \"Alice Updated\", NOW())\n'
        'ON CONFLICT (email) DO UPDATE SET\n'
        '    full_name = EXCLUDED.full_name,\n'
        '    updated_at = EXCLUDED.updated_at\n'
        'RETURNING user_id, (xmax = 0) AS was_inserted;'
    ),
}

for pattern, sql in insert_patterns.items():
    print(f'  -- {pattern}')
    print(f'  {sql}')
    print()

print('=== xmax Trick: Detect Insert vs Update in RETURNING ===')
print('  xmax = 0  -> row was inserted (no previous version)')
print('  xmax > 0  -> row was updated (previous version exists)')
print('  Use (xmax = 0) AS was_inserted in RETURNING clause')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 1: Batch Updates — Avoiding the Long Transaction Trap
#
# Updating millions of rows in one transaction is a classic production mistake. It causes replication lag, prevents autovacuum, holds locks, and generates WAL so large that recovery from a failed migration takes hours.

# %%
# Batch update strategy — safe large-table modifications

naive_update = '''
-- ANTI-PATTERN: One giant update
UPDATE large_table
SET status = 'archived'
WHERE created_at < '2023-01-01';
-- Problems:
--  1. Locks table for the entire operation (minutes for millions of rows)
--  2. Generates massive WAL -> replication lag on replicas
--  3. autovacuum cannot reclaim dead tuples until COMMIT
--  4. If cancelled, full rollback (equally slow)
'''

safe_batch_update = '''
-- INDUSTRY STANDARD: Batch update with LIMIT
DO $$
DECLARE
    rows_updated INTEGER;
    batch_count  INTEGER := 0;
BEGIN
    LOOP
        UPDATE large_table
        SET status = 'archived'
        WHERE ctid IN (
            SELECT ctid
            FROM large_table
            WHERE status != 'archived'
              AND created_at < '2023-01-01'
            LIMIT 1000
        );

        GET DIAGNOSTICS rows_updated = ROW_COUNT;
        EXIT WHEN rows_updated = 0;

        batch_count := batch_count + 1;
        COMMIT;                        -- Release locks, allow vacuum
        PERFORM pg_sleep(0.05);        -- Brief pause for other queries
    END LOOP;
    RAISE NOTICE 'Done. Batches: %', batch_count;
END $$;
'''

print('=== Naive (dangerous) ===')
print(naive_update)
print('=== Safe Batch Update ===')
print(safe_batch_update)

print('=== ctid Explanation ===')
print('  ctid = physical row location (block_number, offset_in_block)')
print('  Fastest way to target a specific row — no index needed')
print('  Warning: ctid changes after VACUUM FULL — do not store long-term')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 2: Scalable Pagination — Keyset vs OFFSET
#
# `LIMIT N OFFSET M` is deceptively simple and performs terribly at scale. With 1 million rows, `OFFSET 999950` forces PostgreSQL to read and discard 999,950 rows to deliver the last 50. Keyset pagination does this in microseconds.

# %%
# Pagination strategies comparison

offset_pagination = '''
-- OFFSET pagination (simple but slow at scale)
SELECT order_id, customer_id, total_cents, created_at
FROM order
ORDER BY created_at DESC, order_id DESC
LIMIT 50 OFFSET :page_offset;
-- OFFSET 0    -> first 50 rows    (fast)
-- OFFSET 1000 -> rows 1001-1050   (reads 1050, discards 1000)
-- OFFSET 10M  -> rows 10M-10M+50  (reads 10M rows!)
'''

keyset_pagination = '''
-- KEYSET pagination (fast at any scale)
-- Page 1 (no cursor)
SELECT order_id, customer_id, total_cents, created_at
FROM order
ORDER BY created_at DESC, order_id DESC
LIMIT 50;

-- Page 2+ (use values from last row of previous page as cursor)
SELECT order_id, customer_id, total_cents, created_at
FROM order
WHERE (created_at, order_id) < (:last_created_at, :last_order_id)
ORDER BY created_at DESC, order_id DESC
LIMIT 50;
-- Uses index on (created_at, order_id) -> O(log n) regardless of offset
'''

comparison = [
    ('OFFSET 0',       'Reads 50 rows',      'Reads 50 rows',      'Same'),
    ('OFFSET 1,000',   'Reads 1,050 rows',   'Reads 50 rows',      'Keyset 21x faster'),
    ('OFFSET 100,000', 'Reads 100,050 rows',  'Reads 50 rows',      'Keyset 2001x faster'),
    ('OFFSET 10M',     'Reads 10M+ rows',     'Reads 50 rows',      'Keyset 200,000x faster'),
]

print('=== Pagination Strategy Comparison ===')
print(f'{"Page position":<20} {"OFFSET cost":<25} {"Keyset cost":<15} {"Difference"}')
print('-' * 80)
for pos, offset_cost, keyset_cost, diff in comparison:
    print(f'{pos:<20} {offset_cost:<25} {keyset_cost:<15} {diff}')

print()
print('=== When to use OFFSET ===')
print('  Small datasets (< 10,000 rows total)')
print('  Reporting/admin pages where users never go past page 10')
print('  When cursor-based state is impractical to maintain')

print('=== Required index for keyset pagination ===')
print('  CREATE INDEX order_pagination_idx ON order (created_at DESC, order_id DESC);')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 3: Soft Deletes and Safe Filtering Patterns
#
# Soft deletes preserve data history, enable undo functionality, and prevent orphan reference issues. Combined with partial indexes, they maintain query performance on active data.

# %%
# Soft delete patterns and safe filtering

soft_delete_schema = '''
-- Soft delete schema pattern
CREATE TABLE user (
    user_id    BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
    email      TEXT NOT NULL,
    status     TEXT NOT NULL DEFAULT 'active',
    created_at TIMESTAMPTZ NOT NULL DEFAULT NOW(),
    deleted_at TIMESTAMPTZ,  -- NULL = active, NOT NULL = soft-deleted

    CONSTRAINT user_email_unique UNIQUE (email)
    -- Note: unique constraint applies even to deleted users
    -- Use partial unique index to allow re-registration:
);

-- Allow email reuse after soft-delete
CREATE UNIQUE INDEX user_active_email_ukey
ON user (email)
WHERE deleted_at IS NULL;
'''

soft_delete_queries = {
    'Soft delete': 'UPDATE user SET deleted_at = NOW() WHERE user_id = :id;',
    'Restore': 'UPDATE user SET deleted_at = NULL WHERE user_id = :id;',
    'List active': 'SELECT * FROM user WHERE deleted_at IS NULL;',
    'List deleted': 'SELECT * FROM user WHERE deleted_at IS NOT NULL;',
    'Hard purge (after retention)': (
        'DELETE FROM user\n'
        'WHERE deleted_at < NOW() - INTERVAL \'90 days\';'
    ),
}

safe_filter_patterns = [
    ('= vs IS DISTINCT FROM',
     'WHERE col != val',
     'WHERE col IS DISTINCT FROM val',
     '!= returns NULL (excluded) when col is NULL'),
    ('IN vs EXISTS',
     'WHERE id IN (SELECT id FROM ...)',
     'WHERE EXISTS (SELECT 1 FROM ... WHERE ...)',
     'EXISTS short-circuits; IN may not use index on subquery'),
    ('LIKE vs ILIKE',
     'WHERE email LIKE \'%@gmail.com\'',
     'WHERE email ILIKE \'%@gmail.com\'',
     'ILIKE is case-insensitive; consider citext column instead'),
]

print('=== Soft Delete Schema ===')
print(soft_delete_schema)
print('=== Soft Delete Operations ===')
for op, sql in soft_delete_queries.items():
    print(f'  {op}: {sql}')
print()
print('=== Safe Filter Patterns ===')
for pattern, avoid, prefer, reason in safe_filter_patterns:
    print(f'  {pattern}:')
    print(f'    Avoid:  {avoid}')
    print(f'    Prefer: {prefer}')
    print(f'    Why:    {reason}')
    print()

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# 1. **What if you run `UPDATE users SET status = 'deleted';` without a WHERE clause?** This updates every row in the table. Test safe patterns: always run `SELECT COUNT(*)` with the same `WHERE` clause before executing a large `UPDATE` or `DELETE`.
#
# 2. **What if you paginate with `OFFSET 100000` on a 1M-row table?** Run `EXPLAIN (ANALYZE, BUFFERS)` on both OFFSET and keyset queries. The OFFSET version shows a sequential scan reading 100,050 rows; the keyset version shows an index scan reading exactly 50.
#
# 3. **What if you use `ON CONFLICT DO NOTHING` vs `ON CONFLICT DO UPDATE`?** Try inserting a duplicate row with both options and use `RETURNING` with `xmax` to observe: DO NOTHING returns no rows on conflict; DO UPDATE returns the updated row.

# %%
# Experiment: Safe update checklist simulation

def safe_update_checklist(table, where_clause, set_clause, estimated_rows):
    print(f'=== Safe Update Checklist for {table} ===')
    print(f'  Target: UPDATE {table} SET {set_clause} WHERE {where_clause}')
    print(f'  Estimated affected rows: {estimated_rows:,}')
    print()

    steps = [
        ('1. Count first',
         f'SELECT COUNT(*) FROM {table} WHERE {where_clause};',
         'Verify row count before destructive operation'),
        ('2. Test in transaction',
         f'BEGIN; UPDATE {table} SET {set_clause} WHERE {where_clause}; ROLLBACK;',
         'Confirm it runs without error before committing'),
        ('3. Batch if large',
         'Use LIMIT 1000 + COMMIT loop' if estimated_rows > 10000 else 'Single UPDATE is fine',
         'Avoid long transactions for large updates'),
        ('4. Schedule off-peak',
         'Plan for maintenance window' if estimated_rows > 100000 else 'Any time is fine',
         'Minimise impact on production traffic'),
        ('5. Monitor replication lag',
         'SELECT pg_wal_lsn_diff(pg_current_wal_lsn(), sent_lsn) FROM pg_stat_replication;',
         'Large updates generate WAL that creates replica lag'),
    ]

    for step_name, action, reason in steps:
        print(f'  {step_name}')
        print(f'    Action: {action}')
        print(f'    Why:    {reason}')
        print()

safe_update_checklist(
    table='user',
    where_clause="status = 'inactive' AND last_login < NOW() - INTERVAL '2 years'",
    set_clause='deleted_at = NOW()',
    estimated_rows=150000
)

# %% [markdown]
# ## Real-World Project Link
#
# **Mini project:** Build a robust user registration and login tracking system.
#
# Requirements:
# - `user` table with soft delete (no hard deletes)
# - `login_attempt` table recording every attempt (email, success, ip_address, attempted_at)
# - An upsert procedure: `INSERT INTO user ... ON CONFLICT (email) DO UPDATE` that updates `last_login_at` on successful authentication
# - A query returning users who have not logged in for 90 days (keyset-paginated)
# - A batch soft-delete operation for users inactive for 2+ years
#
# Focus on using `RETURNING`, `ON CONFLICT`, and batch processing patterns from this chapter.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### What you learned
# - `RETURNING` clause eliminates round trips for getting generated IDs and defaults
# - `ON CONFLICT ... DO UPDATE` enables atomic upserts; `EXCLUDED` references the failed row
# - Batch updates with `LIMIT + COMMIT` loop avoid long-transaction problems
# - Keyset pagination scales to any dataset size; OFFSET pagination breaks at scale
# - Soft deletes with partial unique indexes preserve history and allow email reuse
#
# ### Cheat sheet
# ```sql
# -- INSERT with RETURNING
# INSERT INTO users (email) VALUES ('a@b.com') RETURNING user_id, created_at;
#
# -- Upsert
# INSERT INTO users (email, name, updated_at) VALUES ('a@b.com', 'A', NOW())
# ON CONFLICT (email) DO UPDATE
# SET name = EXCLUDED.name, updated_at = EXCLUDED.updated_at
# RETURNING user_id, (xmax = 0) AS was_inserted;
#
# -- Batch update (1000 rows at a time)
# UPDATE t SET col = val WHERE ctid IN
#     (SELECT ctid FROM t WHERE condition LIMIT 1000);
#
# -- Keyset pagination
# SELECT * FROM orders
# WHERE order_id > :last_id ORDER BY order_id LIMIT 50;
#
# -- Soft delete
# UPDATE user SET deleted_at = NOW() WHERE user_id = :id;
# SELECT * FROM user WHERE deleted_at IS NULL;  -- Active only
# ```

# %% [markdown]
# ## Practice Prompts
#
# 1. What is the `EXCLUDED` pseudo-table in an `ON CONFLICT ... DO UPDATE` statement? Write an upsert that only updates a row if the new email is different from the existing one.
# 2. Explain why `LIMIT N OFFSET M` pagination is O(M+N) in cost. Rewrite the following OFFSET query as a keyset query: `SELECT * FROM events ORDER BY created_at DESC LIMIT 20 OFFSET 500;`
# 3. What does `(xmax = 0)` indicate in a `RETURNING` clause? How is this useful for upserts?
# 4. Write a batch soft-delete procedure that marks users as deleted in batches of 500, committing after each batch, for all users inactive for more than 1 year.
# 5. Why is `IS DISTINCT FROM` sometimes preferable to `!=`? Give an example where `!=` produces incorrect results when NULLs are involved.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='6.%20creating_tables_and_constraints.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='8.%20joins_aggregation_and_set_logic.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
