# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='5.%20data_types_done_right.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='7.%20crud_and_filtering.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 6: Creating Tables and Constraints
#
# Table creation is the foundation everything else depends on. Poor primary key choices, missing constraints, and wrong foreign key behaviour cascade into application bugs, performance issues, and maintenance nightmares. This chapter establishes the industry-standard patterns you will use for every table you create.

# %% [markdown]
# ## The Big Picture
#
# Think of table design as drafting a legal contract. The schema is the contract between your database and every application that touches it. A constraint is a clause that cannot be violated — ever. When you add `CHECK (price_cents >= 0)`, you are writing a guarantee that no bug in any application layer can store a negative price.
#
# The database is your last line of defence against application bugs. Application code has tests that sometimes miss edge cases. The database has constraints that never miss. A row that violates a constraint is rejected regardless of how it got there.
#
# Primary key strategy is the most consequential table design decision. It affects storage size (8 bytes for BIGINT vs 16 for UUID), index performance (sequential vs random insertion), API security (enumerable IDs vs UUIDs), and join efficiency. The decision is nearly impossible to reverse without a full table rewrite.
#
# Foreign key cascade behaviour is equally consequential. `ON DELETE CASCADE` is powerful and dangerous — it silently deletes child rows when a parent is deleted. `ON DELETE RESTRICT` is safe and explicit — it forces the caller to handle the relationship. Always choose based on business logic, not convenience.

# %% [markdown]
# ## Core Concepts
#
# ### Primary Key Strategies
# Three options: **surrogate BIGINT** (best for most tables — compact, fast, sequential), **natural key** (use only when the business key is immutable, compact, and stable), **UUID** (for external-facing IDs or distributed systems). Hybrid: BIGINT internally, UUID externally.
#
# ### `GENERATED ALWAYS AS IDENTITY` vs `SERIAL`
# `SERIAL` is syntactic sugar for a sequence with a DEFAULT — not SQL standard, allows accidental ID override. `GENERATED ALWAYS AS IDENTITY` is SQL standard, explicitly prevents manual ID insertion (requires `OVERRIDING SYSTEM VALUE`), and has cleaner DDL.
#
# ### Foreign Key Cascade Behaviours
# `RESTRICT` / `NO ACTION`: prevent parent delete if children exist (safest default). `CASCADE`: automatically delete/update children (use only when children cannot exist without parent). `SET NULL`: set FK to NULL on parent delete (for optional relationships). `SET DEFAULT`: reset FK to default value on parent delete.
#
# ### CHECK Constraints
# Enforce business rules at the database level: value ranges, enum-like validation, cross-column rules, format patterns. Name them explicitly for clear error messages.
#
# ### Generated Columns
# Computed columns stored persistently (`STORED`) — automatically updated on `INSERT`/`UPDATE`. Useful for denormalised display values, computed metrics, and search optimisation.

# %% [markdown]
# ## Key SQL Syntax
#
# ```sql
# -- Modern primary key
# user_id BIGINT GENERATED ALWAYS AS IDENTITY
#     (START WITH 1000000 INCREMENT BY 1) PRIMARY KEY
#
# -- UUID external ID + BIGINT internal ID (hybrid)
# order_id   BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
# order_uuid UUID NOT NULL DEFAULT gen_random_uuid() UNIQUE
#
# -- Foreign key with explicit cascade
# CONSTRAINT orders_customer_fk
#     FOREIGN KEY (customer_id) REFERENCES customer(customer_id)
#     ON DELETE RESTRICT ON UPDATE CASCADE
#
# -- Named CHECK constraint
# CONSTRAINT products_price_check CHECK (price_cents > 0)
# CONSTRAINT orders_status_check  CHECK (status IN ('pending','paid','shipped','cancelled'))
#
# -- Generated column
# price_dollars NUMERIC(10,2) GENERATED ALWAYS AS (price_cents / 100.0) STORED
# ```

# %%
# Primary key strategies comparison

pk_strategies = {
    'BIGINT IDENTITY (recommended)': {
        'ddl': 'id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY',
        'storage_bytes': 8,
        'pros': ['Compact (8B)', 'Sequential insertion (no fragmentation)', 'SQL standard', 'Fast joins'],
        'cons': ['Enumerable (expose UUID externally for security)', 'Cluster-local uniqueness'],
        'use_for': 'Most entity tables (users, orders, products)',
    },
    'SERIAL (legacy)': {
        'ddl': 'id SERIAL PRIMARY KEY',
        'storage_bytes': 4,
        'pros': ['Simple syntax', 'Widely understood'],
        'cons': ['Not SQL standard', '4-byte INTEGER overflows at 2B rows',
                 'Allows accidental manual ID insertion'],
        'use_for': 'Avoid for new tables — use BIGINT IDENTITY',
    },
    'UUID (external)': {
        'ddl': 'id UUID DEFAULT gen_random_uuid() PRIMARY KEY',
        'storage_bytes': 16,
        'pros': ['Globally unique', 'Non-enumerable', 'Safe for distributed systems'],
        'cons': ['16 bytes (2x BIGINT)', 'Random insertion fragments B-tree index'],
        'use_for': 'Only as external ID; use BIGINT internally',
    },
    'Hybrid BIGINT+UUID (best of both)': {
        'ddl': 'id BIGINT IDENTITY + external_id UUID DEFAULT gen_random_uuid()',
        'storage_bytes': 24,
        'pros': ['Fast internal joins (BIGINT)', 'Secure external API (UUID)',
                 'Non-enumerable URLs'],
        'cons': ['Extra column', 'Slightly more complex schema'],
        'use_for': 'Customer-facing tables where IDs appear in URLs/APIs',
    },
}

print('=== Primary Key Strategy Comparison ===')
for strategy, info in pk_strategies.items():
    print(f'  {strategy}')
    print(f'    DDL:    {info["ddl"]}')
    print(f'    Bytes:  {info["storage_bytes"]} bytes per row')
    print(f'    Pros:   {info["pros"]}')
    print(f'    Cons:   {info["cons"]}')
    print(f'    Use:    {info["use_for"]}')
    print()

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 1: A Complete Production-Ready Table
#
# This example shows a complete `order` table incorporating all the patterns from this chapter: hybrid PK, explicit FKs, named constraints, generated column, and audit timestamps.

# %%
# Complete production-ready table DDL

order_ddl = '''
CREATE TABLE order (
    -- Internal surrogate key (fast joins)
    order_id        BIGINT GENERATED ALWAYS AS IDENTITY
                        (START WITH 1000000) PRIMARY KEY,

    -- External UUID (non-enumerable for API/URL use)
    order_uuid      UUID NOT NULL DEFAULT gen_random_uuid(),

    -- Foreign key to customer
    customer_id     BIGINT NOT NULL,

    -- Business fields
    status          TEXT NOT NULL DEFAULT 'pending',
    subtotal_cents  BIGINT NOT NULL,
    tax_cents       BIGINT NOT NULL DEFAULT 0,
    total_cents     BIGINT GENERATED ALWAYS AS
                        (subtotal_cents + tax_cents) STORED,

    -- Audit timestamps
    created_at      TIMESTAMPTZ NOT NULL DEFAULT NOW(),
    updated_at      TIMESTAMPTZ NOT NULL DEFAULT NOW(),
    completed_at    TIMESTAMPTZ,

    -- Named constraints
    CONSTRAINT order_uuid_unique
        UNIQUE (order_uuid),

    CONSTRAINT order_customer_fk
        FOREIGN KEY (customer_id)
        REFERENCES customer(customer_id)
        ON DELETE RESTRICT ON UPDATE CASCADE,

    CONSTRAINT order_status_check
        CHECK (status IN ('pending','paid','shipped','delivered','cancelled')),

    CONSTRAINT order_subtotal_positive
        CHECK (subtotal_cents > 0),

    CONSTRAINT order_tax_non_negative
        CHECK (tax_cents >= 0),

    CONSTRAINT order_completed_requires_paid
        CHECK (completed_at IS NULL OR status IN ('delivered','cancelled'))
);

-- Index the foreign key (PostgreSQL does NOT auto-index FKs)
CREATE INDEX order_customer_id_idx ON order (customer_id);

-- Index for status-based queries (common filter)
CREATE INDEX order_status_idx ON order (status) WHERE status != 'delivered';
'''

print('=== Production-Ready Table DDL ===')
print(order_ddl)

design_decisions = [
    ('BIGINT + UUID hybrid', 'Fast joins internally, secure non-enumerable URLs externally'),
    ('GENERATED column',     'total_cents auto-computed, never stale, never inconsistent'),
    ('Named constraints',    'Error messages are human-readable, not opaque auto-names'),
    ('START WITH 1000000',   'Reserves IDs below 1M for test/seed data'),
    ('RESTRICT on FK',       'Prevents accidental customer deletion with open orders'),
    ('Partial index',        'Smaller index — only active orders, not historical delivered rows'),
]
print('=== Design Decision Rationale ===')
for decision, rationale in design_decisions:
    print(f'  {decision:<30} {rationale}')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 2: Foreign Key Cascade Behaviour in Detail
#
# Choosing the wrong `ON DELETE` behaviour is a silent data integrity time bomb. `CASCADE` feels convenient until it silently deletes 10,000 rows because a parent was deleted.

# %%
# Foreign key cascade behaviour comparison

cascade_behaviours = {
    'RESTRICT': {
        'on_delete': 'Prevents parent deletion if children exist (checked immediately)',
        'on_update': 'Prevents parent PK update if children exist',
        'use_when': 'Most tables — explicit error forces caller to clean up first',
        'example': 'DELETE customer WHERE id=1 -> ERROR if orders exist',
        'safety': 'Safest — no silent side effects',
    },
    'NO ACTION': {
        'on_delete': 'Same as RESTRICT but checked at end of statement (allows deferred)',
        'on_update': 'Same as RESTRICT but deferred',
        'use_when': 'Same as RESTRICT; use when deferred constraint checking needed',
        'example': 'Allows circular FK inserts within a transaction',
        'safety': 'Safe — default if not specified',
    },
    'CASCADE': {
        'on_delete': 'Automatically deletes child rows when parent is deleted',
        'on_update': 'Automatically updates child FK when parent PK changes',
        'use_when': 'Children cannot exist without parent (order_item -> order)',
        'example': 'DELETE order WHERE id=1 -> deletes all order_items too',
        'safety': 'Dangerous — silent mass delete; use only when logically correct',
    },
    'SET NULL': {
        'on_delete': 'Sets FK column to NULL when parent is deleted',
        'on_update': 'Sets FK to NULL when parent PK changes',
        'use_when': 'Optional relationship — child can exist without parent',
        'example': 'DELETE manager -> employees.manager_id becomes NULL',
        'safety': 'Safe — preserves child rows, nullable FK required',
    },
    'SET DEFAULT': {
        'on_delete': 'Resets FK column to its DEFAULT value',
        'on_update': 'Resets FK to DEFAULT on parent PK change',
        'use_when': 'Reassign to a catch-all parent (e.g., unassigned category)',
        'example': 'DELETE category -> products reassigned to category_id=1 (Uncategorized)',
        'safety': 'Safe — requires a valid default parent to exist',
    },
}

print('=== FK Cascade Behaviour Reference ===')
for behaviour, info in cascade_behaviours.items():
    safety_icon = 'CAUTION' if behaviour == 'CASCADE' else 'OK    '
    print(f'  [{safety_icon}] {behaviour}')
    print(f'    On delete: {info["on_delete"]}')
    print(f'    Use when:  {info["use_when"]}')
    print(f'    Example:   {info["example"]}')
    print()

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 3: CHECK Constraints — Enforcing Business Rules
#
# CHECK constraints are the most underused PostgreSQL feature. Every business rule that can be expressed as a boolean condition should be a named CHECK constraint. They are faster than application validation and impossible to bypass.

# %%
# CHECK constraint patterns for common business rules

check_patterns = {
    'Enum-like values': (
        "CONSTRAINT order_status_check\n"
        "    CHECK (status IN ('pending','paid','shipped','delivered','cancelled'))"
    ),
    'Positive amounts': (
        "CONSTRAINT product_price_positive\n"
        "    CHECK (price_cents > 0)"
    ),
    'Date ordering': (
        "CONSTRAINT event_dates_ordered\n"
        "    CHECK (end_date IS NULL OR end_date > start_date)"
    ),
    'Email format': (
        "CONSTRAINT user_email_format\n"
        "    CHECK (email ~* '^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\\\\.[A-Za-z]{2,}$')"
    ),
    'Cross-column rule': (
        "CONSTRAINT order_completed_requires_paid\n"
        "    CHECK (completed_at IS NULL OR status IN ('delivered','cancelled'))"
    ),
    'Percentage range': (
        "CONSTRAINT discount_pct_range\n"
        "    CHECK (discount_pct BETWEEN 0 AND 100)"
    ),
    'Slug format': (
        "CONSTRAINT article_slug_format\n"
        "    CHECK (slug ~ '^[a-z0-9][a-z0-9-]*[a-z0-9]$' AND LENGTH(slug) BETWEEN 3 AND 100)"
    ),
    'Lowercase enforcement': (
        "CONSTRAINT user_email_lowercase\n"
        "    CHECK (email = LOWER(email))"
    ),
}

print('=== CHECK Constraint Patterns ===')
for name, ddl in check_patterns.items():
    print(f'  -- {name}')
    print(f'  {ddl}')
    print()

print('=== Why Name Constraints? ===')
print('  Auto-named:  "orders_total_cents_check" — opaque, changes on rebuild')
print('  Explicitly:  "order_price_positive" — self-documenting in error messages')
print()
print('  Error message without explicit name:')
print('    ERROR: new row for relation "orders" violates check constraint "orders_total_cents_check"')
print('  Error message with explicit name:')
print('    ERROR: new row for relation "order" violates check constraint "order_price_positive"')

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# 1. **What if you use `ON DELETE CASCADE` everywhere?** Delete a customer and watch all their orders, all order items, all reviews, and all shipment records disappear silently. Try `ON DELETE RESTRICT` first and see the error — it forces you to think about the business logic.
#
# 2. **What if you use `SERIAL` instead of `GENERATED ALWAYS AS IDENTITY`?** Try `INSERT INTO serial_table (id, name) VALUES (5, 'test')` — it succeeds silently. With `GENERATED ALWAYS AS IDENTITY`, the same insert fails with 'cannot insert into column "id"' — a safety guarantee.
#
# 3. **What if you skip naming constraints?** PostgreSQL auto-generates names like `orders_total_check`. Drop and recreate the table, and the auto-generated name changes. This breaks migration scripts that reference the constraint name. Always name constraints explicitly.

# %%
# Experiment: Constraint violation error messages

def simulate_constraint_check(table, row, constraints):
    violations = []
    for name, check_fn, message in constraints:
        try:
            if not check_fn(row):
                violations.append((name, message))
        except Exception as e:
            violations.append((name, str(e)))
    return violations

order_constraints = [
    ('order_status_check',
     lambda r: r.get('status') in ('pending','paid','shipped','delivered','cancelled'),
     "value 'invalid_status' violates check constraint"),
    ('order_price_positive',
     lambda r: r.get('subtotal_cents', 0) > 0,
     "value 0 violates check constraint (price must be positive)"),
    ('order_customer_fk',
     lambda r: r.get('customer_id') is not None and r.get('customer_id') > 0,
     "insert or update violates foreign key constraint"),
]

test_rows = [
    {'status': 'paid',        'subtotal_cents': 1999, 'customer_id': 1},   # valid
    {'status': 'processing',  'subtotal_cents': 1999, 'customer_id': 1},   # bad status
    {'status': 'pending',     'subtotal_cents': 0,    'customer_id': 1},   # zero amount
    {'status': 'pending',     'subtotal_cents': 500,  'customer_id': None},# null FK
]

print('=== Constraint Check Simulation ===')
for row in test_rows:
    violations = simulate_constraint_check('order', row, order_constraints)
    status = 'OK' if not violations else 'FAIL'
    print(f'  [{status}] {row}')
    for name, msg in violations:
        print(f'        ERROR [{name}]: {msg}')

# %% [markdown]
# ## Real-World Project Link
#
# **Mini project:** Design a multi-tenant SaaS schema with proper constraints.
#
# Tables: `organisation`, `user` (belongs to organisation), `project` (belongs to org), `project_member` (junction table, user + project with role).
#
# Requirements:
# - All tables use `BIGINT GENERATED ALWAYS AS IDENTITY` + `UUID` external ID
# - `user.email` is unique per organisation (not globally) — use a partial unique index
# - `project_member.role` must be one of `'owner'`, `'editor'`, `'viewer'`
# - Every table has `created_at` and `updated_at TIMESTAMPTZ`
# - All FK constraints are named and have explicit `ON DELETE` behaviour
# - A CHECK ensures every project has at least one `owner` (enforced via trigger or application logic)
#
# Write the full DDL and justify each design decision in SQL comments.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### What you learned
# - `BIGINT GENERATED ALWAYS AS IDENTITY` is the modern primary key standard
# - Hybrid BIGINT+UUID is the best of both worlds for customer-facing tables
# - `ON DELETE RESTRICT` is the safe default; `CASCADE` only when logically mandatory
# - Named CHECK constraints enforce business rules at the DB level with clear error messages
# - Generated columns auto-compute derived values that can never be stale
#
# ### Cheat sheet
# ```sql
# -- Modern PK
# id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1000000) PRIMARY KEY
#
# -- Hybrid PK
# id          BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
# external_id UUID NOT NULL DEFAULT gen_random_uuid() UNIQUE
#
# -- Named FK
# CONSTRAINT order_customer_fk
#     FOREIGN KEY (customer_id) REFERENCES customer(customer_id)
#     ON DELETE RESTRICT ON UPDATE CASCADE
#
# -- Named CHECK
# CONSTRAINT order_status_check
#     CHECK (status IN ('pending','paid','shipped','cancelled'))
#
# -- Generated column
# total_cents BIGINT GENERATED ALWAYS AS (subtotal + tax) STORED
#
# -- Always index FK columns
# CREATE INDEX order_customer_id_idx ON order (customer_id);
# ```

# %% [markdown]
# ## Practice Prompts
#
# 1. What is the difference between `GENERATED ALWAYS AS IDENTITY` and `SERIAL`? Why is the newer syntax safer?
# 2. You have a `comment` table that belongs to a `post`. If the post is deleted, should comments be deleted too (`CASCADE`) or should the delete fail (`RESTRICT`)? Justify your answer.
# 3. Write a CHECK constraint that ensures a `discount` table's `valid_from` is always before `valid_to` and `discount_pct` is between 1 and 99.
# 4. When would you use a natural key instead of a surrogate key? Give two examples of appropriate natural keys and explain why they qualify.
# 5. PostgreSQL does not auto-index foreign key columns. Why not? What command would you run to find all unindexed FK columns in the `app` schema?

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='5.%20data_types_done_right.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='7.%20crud_and_filtering.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
