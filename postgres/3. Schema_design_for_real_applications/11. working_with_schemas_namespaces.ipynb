# %% [markdown]
# # Chapter 11: Working with Schemas (Namespaces)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='11. working_with_schemas.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='12. views_and_materialized_views.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
