# %% [markdown]
# # Chapter 13: Partitioning (Declarative)

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='13. partitioning.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../4. Indexing_and_query_performance/14. how_postgres_executes_queries.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
