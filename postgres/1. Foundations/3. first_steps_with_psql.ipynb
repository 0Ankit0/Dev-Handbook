# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='2.%20installing_postgresql.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='4.%20core_concepts_you_must_get_right_early.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 3: First Steps with `psql`
#
# `psql` is PostgreSQL's official command-line client and the industry standard for database interaction. Whether you are debugging a production incident at 3 AM or writing your first migration, `psql` is the tool that will always be there.

# %% [markdown]
# ## The Big Picture
#
# Think of `psql` as the cockpit of a commercial airliner. GUI tools are like autopilot — convenient for routine flights, but when something goes wrong, a pilot who only knows autopilot is helpless. `psql` gives you direct access to every dial and lever in PostgreSQL.
#
# Unlike GUI tools that abstract implementation details, `psql` provides direct access to the wire protocol, system statistics, and administrative functions. It is the only tool guaranteed to be present on every PostgreSQL server, making it non-negotiable for production debugging, automation scripts, and emergency recovery.
#
# The most important mindset shift: `psql` is not just a query runner. It is a full scripting environment with variables, conditionals, output formatting, file I/O, and shell integration. Teams that master `psql` scripting write migration scripts, monitoring checks, and data exports that run identically in CI, staging, and production.
#
# Connection security is the first `psql` skill to master. Never hardcode passwords. Use `.pgpass` files or connection service files for credentials. Always specify `sslmode=require` for remote connections.

# %% [markdown]
# ## Core Concepts
#
# ### Connection Parameters and Precedence
# `psql` accepts connection parameters via flags, URI, environment variables, service file, or `.pgpass`. Precedence (highest to lowest): command-line flags → URI → env vars (`PGHOST`, `PGUSER`, etc.) → `~/.pg_service.conf` → `~/.pgpass` → compiled defaults.
#
# ### Meta-Commands (Backslash Commands)
# Meta-commands start with `\` and are processed by `psql` itself before SQL reaches the server. Key commands: `\d table` (describe), `\dt` (list tables), `\l` (list databases), `\c db` (connect), `\timing` (show execution time), `\x` (expanded output), `\copy` (client-side file I/O).
#
# ### Secure Credential Management
# Use `~/.pgpass` (chmod 600) for password storage: `hostname:port:database:username:password`. Use `~/.pg_service.conf` for named connection profiles. Never use `PGPASSWORD` environment variable in scripts.
#
# ### Scripting and Automation
# `-v ON_ERROR_STOP=1` exits on first error (essential for migrations). `-1` wraps the session in a transaction. `-X` ignores `.psqlrc` for reproducible scripts. `\gset` captures query results into variables.
#
# ### Output Formatting
# `\pset format csv` for pipeline output, `\x auto` for human-readable wide rows, `\timing on` for performance measurement, `\pset null '[NULL]'` to make NULL values visible.

# %% [markdown]
# ## Key SQL Syntax
#
# ```bash
# # Connect with URI (preferred for scripts)
# psql "postgresql://appuser:secret@localhost:5432/appdb?sslmode=require&application_name=myapp"
#
# # Single command, quiet output
# psql -U appuser -d appdb -Atc "SELECT count(*) FROM users"
#
# # Execute file, exit on first error, single transaction
# psql -U appuser -d appdb -v ON_ERROR_STOP=1 -1 -f migration.sql
# ```
#
# ```sql
# -- Essential meta-commands
# \timing on              -- Show execution time
# \x auto                 -- Expanded display for wide rows
# \pset null '[NULL]'     -- Show NULLs clearly
# \d+ users               -- Full table description with indexes
# \conninfo               -- Show current connection details
# \watch 2                -- Re-run last query every 2 seconds
# ```

# %%
# psql meta-commands and their SQL equivalents

meta_commands = {
    '\\l':    ('SELECT datname, pg_encoding_to_char(encoding) FROM pg_database;', 'List databases'),
    '\\dt':   ('SELECT schemaname, tablename FROM pg_tables;', 'List tables'),
    '\\di':   ('SELECT indexname, tablename FROM pg_indexes;', 'List indexes'),
    '\\du':   ('SELECT rolname, rolsuper, rolcanlogin FROM pg_roles;', 'List roles'),
    '\\dx':   ('SELECT extname, extversion FROM pg_extension;', 'List extensions'),
    '\\dn':   ('SELECT nspname FROM pg_namespace WHERE nspname NOT LIKE \'pg_%\';', 'List schemas'),
}

print('=== psql Meta-Commands and SQL Equivalents ===')
print()
print(f'{"Meta-cmd":<10} {"Description":<25} SQL equivalent (simplified)')
print('-' * 75)
for cmd, (sql, desc) in meta_commands.items():
    print(f'{cmd:<10} {desc:<25} {sql[:40]}...')

print()
print('=== Connection Security Best Practices ===')
security_rules = [
    ('Never use',  'PGPASSWORD env var — appears in process list'),
    ('Never use',  'Plaintext passwords in scripts committed to version control'),
    ('Always use', '~/.pgpass (chmod 600) for automated scripts'),
    ('Always use', 'sslmode=require for remote connections'),
    ('Prefer',     '~/.pg_service.conf for named team connection profiles'),
]
for action, rule in security_rules:
    marker = 'x' if action == 'Never use' else 'v'
    print(f'  [{marker}] {action}: {rule}')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 1: Secure `.pgpass` and Service File Configuration
#
# These two files are the backbone of safe, scriptable PostgreSQL access. `.pgpass` stores credentials locally (never committed). `pg_service.conf` stores connection profiles (safe to commit — no passwords).

# %%
# .pgpass and pg_service.conf setup

pgpass_lines = [
    '# ~/.pgpass — chmod 600 REQUIRED',
    '# Format: hostname:port:database:username:password',
    'localhost:5432:appdb:appuser:devpassword',
    'prod.db.company.com:5432:appdb:appuser:prodpassword',
    '*:5432:monitoring:monitor_ro:readonlypass',
]

pg_service_sections = [
    ('[dev]', {'host': 'localhost', 'port': '5432', 'dbname': 'appdb', 'user': 'appuser'}),
    ('[prod]', {'host': 'prod.db.company.com', 'port': '5432', 'dbname': 'appdb',
                'user': 'appuser', 'sslmode': 'require'}),
    ('[monitoring]', {'host': 'prod.db.company.com', 'port': '5432', 'dbname': 'postgres',
                      'user': 'monitor_ro', 'sslmode': 'require',
                      'application_name': 'grafana_monitor'}),
]

print('=== ~/.pgpass ===')
for line in pgpass_lines:
    print(f'  {line}')
print()
print('Setup commands:')
print('  touch ~/.pgpass && chmod 600 ~/.pgpass')
print()
print('=== ~/.pg_service.conf ===')
for section, params in pg_service_sections:
    print(f'  {section}')
    for k, v in params.items():
        print(f'    {k}={v}')
    print()
print('Usage:')
print('  psql "service=dev"     # connect to dev')
print('  psql "service=prod"    # connect to prod')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 2: Migration Scripts — The `-v ON_ERROR_STOP=1 -1` Pattern
#
# The combination of `ON_ERROR_STOP=1` and `-1` (single-transaction) is the industry standard for safe, atomic database migrations. Without it, a partially-applied migration leaves the schema in an inconsistent state that may be impossible to recover without a restore.

# %%
# Migration script safety patterns

migration_script = '''
-- Run with: psql -v ON_ERROR_STOP=1 -1 -X -q -f this_migration.sql

-- 1. Guard: confirm we are on the right database
DO $guard$
BEGIN
    IF current_database() NOT IN (\'appdb\', \'appdb_staging\') THEN
        RAISE EXCEPTION \'Wrong database: %\', current_database();
    END IF;
END $guard$;

-- 2. Create new table
CREATE TABLE user_preferences (
    preference_id  BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
    user_id        BIGINT NOT NULL REFERENCES users(user_id) ON DELETE CASCADE,
    key            TEXT NOT NULL,
    value          JSONB,
    created_at     TIMESTAMPTZ NOT NULL DEFAULT NOW(),
    CONSTRAINT user_preferences_user_key_unique UNIQUE (user_id, key)
);

-- 3. Index for efficient user lookups
CREATE INDEX user_preferences_user_id_idx ON user_preferences (user_id);
'''

automation_flags = {
    '-v ON_ERROR_STOP=1': 'Exit code 3 on first SQL error (default: continue)',
    '-1 (--single-transaction)': 'Entire script is one atomic transaction',
    '-X (--no-psqlrc)': 'Ignore ~/.psqlrc for reproducible CI behaviour',
    '-q (--quiet)': 'Suppress welcome banner for cleaner CI logs',
    '-t (--tuples-only)': 'No headers or row counts (for pipeline output)',
    '-v key=value': 'Pass variable; accessible as :key in SQL',
}

print('=== Safe Migration Invocation ===')
print('  psql -v ON_ERROR_STOP=1 -1 -X -q -f migration.sql "service=prod"')
print()
print('=== Critical psql Automation Flags ===')
for flag, description in automation_flags.items():
    print(f'  {flag}')
    print(f'    {description}')
    print()
print('=== Migration Script Pattern (excerpt) ===')
print(migration_script[:400] + '...')

# %% [markdown]
# ## Deep Dive with Examples
#
# ### Example 3: Real-Time Performance Monitoring in `psql`
#
# `psql` combined with `pg_stat_*` views provides a complete monitoring toolkit without installing any external tools. The `\watch N` command turns any query into a live dashboard that refreshes every N seconds.

# %%
# Performance monitoring queries

monitoring_queries = {
    'Active long-running queries': '''
SELECT pid, now() - query_start AS duration,
       state, wait_event_type, left(query, 80) AS query
FROM pg_stat_activity
WHERE state = 'active'
  AND now() - query_start > interval '5 seconds'
ORDER BY query_start;''',

    'Lock conflicts': '''
SELECT blocked.pid AS blocked_pid, blocked.usename AS blocked_user,
       blocker.pid AS blocker_pid, blocker.usename AS blocker_user,
       left(blocked.query, 60) AS blocked_query
FROM pg_stat_activity blocked
JOIN pg_stat_activity blocker ON blocker.pid = ANY(pg_blocking_pids(blocked.pid))
WHERE cardinality(pg_blocking_pids(blocked.pid)) > 0;''',

    'Top 10 tables by size': '''
SELECT schemaname, tablename,
       pg_size_pretty(pg_total_relation_size(schemaname||\'.\'||tablename)) AS total_size
FROM pg_tables
WHERE schemaname NOT IN (\'pg_catalog\', \'information_schema\')
ORDER BY pg_total_relation_size(schemaname||\'.\'||tablename) DESC
LIMIT 10;''',
}

print('=== Production Monitoring Queries ===')
for title, query in monitoring_queries.items():
    print(f'-- {title}')
    print(query.strip())
    print()

print('=== Using \\watch for Live Monitoring ===')
print('  # In psql:')
print('  SELECT pid, state, wait_event, left(query,60) FROM pg_stat_activity WHERE state=\'active\';')
print('  \\watch 2   -- refresh every 2 seconds, Ctrl+C to stop')

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# 1. **What if you forget `-v ON_ERROR_STOP=1`?** Test it: `echo "SELECT 1/0;" | psql appdb; echo "Exit: $?"` — psql exits 0 (success) despite the division-by-zero error. With `-v ON_ERROR_STOP=1`, it exits 3. This is why missing migrations silently succeed in CI without this flag.
#
# 2. **What if you use `COPY` instead of `\copy`?** `COPY` reads from the server's filesystem and requires superuser. `\copy` reads from the client machine, works for any user, and is safe in scripts. Try both: `COPY users TO '/tmp/users.csv' CSV HEADER;` (server) vs `\copy users TO '/tmp/users.csv' CSV HEADER` (client).
#
# 3. **What if you add `\timing on` to `~/.psqlrc`?** Every query shows its execution time during development, surfacing slow queries before they reach production.

# %%
# Experiment: Simulating ON_ERROR_STOP behaviour

def simulate_migration(statements, stop_on_error=True):
    print(f'  ON_ERROR_STOP={stop_on_error}')
    for i, stmt in enumerate(statements, 1):
        is_error = 'ERROR' in stmt
        status = 'ERROR' if is_error else 'OK'
        print(f'  Step {i} [{status}]: {stmt[:55]}')
        if is_error and stop_on_error:
            print(f'          Stopping — exit code 3')
            return False
    return True

statements = [
    'CREATE TABLE orders (id BIGINT PRIMARY KEY, amount NUMERIC);',
    'INSERT INTO nonexistent_table VALUES (1);  -- ERROR',
    'CREATE INDEX orders_amount_idx ON orders(amount);',
    'COMMIT;',
]

print('=== With ON_ERROR_STOP=1 (recommended) ===')
simulate_migration(statements, stop_on_error=True)
print()
print('=== Without ON_ERROR_STOP (dangerous default) ===')
simulate_migration(statements, stop_on_error=False)
print()
print('Lesson: Always use -v ON_ERROR_STOP=1 -1 for migrations.')

# %% [markdown]
# ## Real-World Project Link
#
# **Mini project:** Write a `psql` health-check script for a PostgreSQL server.
#
# The script should:
# 1. Accept the target database via a `-v` flag
# 2. Verify server version is >= 14
# 3. Report the 5 largest tables with their sizes
# 4. Report any queries running longer than 30 seconds
# 5. Report any lock conflicts
# 6. Exit with code 0 if all checks pass, code 1 if warnings found
#
# Use `-v ON_ERROR_STOP=1 -X` flags, format output with `\pset format aligned`, and add `\timing on`. This script will become your production go-to tool for database health assessment.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### What you learned
# - `psql` is irreplaceable — always available, scriptable, and precise
# - Use `.pgpass` (chmod 600) and service files for secure credential management
# - `-v ON_ERROR_STOP=1 -1` is mandatory for safe migration scripts
# - Meta-commands (`\dt`, `\d+`, `\timing`, `\x auto`) replace most GUI exploration needs
# - `pg_stat_activity`, `pg_locks`, and `pg_tables` are your real-time monitoring tools
#
# ### Cheat sheet
# ```bash
# # Connect with service file
# psql "service=prod"
#
# # Run migration safely
# psql -v ON_ERROR_STOP=1 -1 -X -q -f migration.sql "service=prod"
#
# # Quick count
# psql -Atc "SELECT count(*) FROM users" "service=prod"
# ```
#
# ```sql
# -- Session setup
# \timing on
# \x auto
# \pset null '[NULL]'
#
# -- Schema inspection
# \d+ users          -- Full description with indexes
# \di+ orders*       -- All indexes matching pattern
#
# -- Capture query result into variable
# SELECT max(user_id) FROM users \gset max_
# \echo :max_user_id
# ```

# %% [markdown]
# ## Practice Prompts
#
# 1. What is the difference between `COPY` and `\copy` in `psql`? When would you use each?
# 2. A migration script fails halfway without `ON_ERROR_STOP=1`. What state is the database in, and how do you recover?
# 3. Write the `~/.pgpass` entry format and explain what happens if file permissions are not `600`.
# 4. What does `\gset` do? Write a psql script that captures the maximum `user_id` and uses it in a subsequent query.
# 5. Name three `pg_stat_*` views and describe what operational question each one answers.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='2.%20installing_postgresql.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='4.%20core_concepts_you_must_get_right_early.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
