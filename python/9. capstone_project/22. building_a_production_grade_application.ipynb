# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../8. devops_deployment_and_future_proofing/21. performance_optimization.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <span style='color:gray; font-size:1.05em;'>You've reached the end! 🎓</span>
# </div>

# %% [markdown]
# # Chapter 22: Capstone Project — Building a Production-Grade Task Manager API
#
# > *"The whole is greater than the sum of its parts."* — Aristotle
#
# Welcome to the finish line. 🎉
#
# This chapter is different from every other chapter in this handbook. We are not learning one new concept in isolation. We are **assembling everything** — every idea, pattern, and tool from the previous 21 chapters — into a single, real, deployable application called **TaskFlow**.
#
# By the end of this chapter you will have:
# - Built a full REST API with user authentication, CRUD operations, and access control
# - Written a 12-test test suite covering every endpoint
# - Packaged the project with Poetry and Docker
# - Deployed it to a free cloud host
#
# You can show this project in a portfolio, extend it with new features, and use it as a template for every future API you build.
#
# Let’s build something you’re proud of.
#
# > ❓ **What problem does Docker solve?** "It works on my machine." Docker packages your app *and* its exact environment (OS libraries, Python version, config) into a container image that runs identically on any machine or cloud provider.

# %% [markdown]
# ## 🌍 The Big Picture: Real Software in the Wild
#
# Imagine your first week as a backend engineer at a startup. The product manager hands you this requirement:
#
# > *"Build a task management API so our team can track work across projects. Users log in, create tasks, mark them done, and nobody can see anyone else’s tasks."*
#
# This is not a toy example. Teams at Asana, Trello, Linear, and Notion solve this exact problem — at massive scale — but the **core architecture** is identical to what you’re about to build.
#
# By the time you finish, you’ll understand exactly how all the pieces fit together:
#
# ```
# Browser / Mobile App
#        ↓
#    HTTP Request  (GET /tasks/, POST /users/login, …)
#        ↓
# ┌───────────────────────────┐
# │   FastAPI App (routes.py)         │  ← receives + validates request
# │   Pydantic (schemas.py)           │  ← validates JSON shape
# │   Auth middleware (auth.py)       │  ← verifies JWT token
# │   SQLAlchemy session (database.py)│  ← talks to the database
# └───────────────────────────┘
#        ↓
# SQLite / PostgreSQL database
#        ↓
#    JSON Response back to client
# ```
#
# > ❓ **Why use an ORM instead of raw SQL?** An ORM (Object-Relational Mapper) lets you work with database rows as Python objects, so you write Python instead of SQL strings. It also prevents SQL injection by default and makes switching databases straightforward later.

# %% [markdown]
# ## 🧠 Core Concepts: Why a Capstone Project?
#
# Learning programming in isolation — like learning individual musical notes — is necessary but not sufficient. You also need to play the full song.
#
# A capstone project matters for three reasons:
#
# **1. Integration** — Real systems are not made of independent modules. They are woven together. A bug in your authentication affects your task routes. Your database schema shapes your API response format. Understanding these dependencies is a professional skill.
#
# **2. Decision-making** — In isolated exercises, the "right" tool is given to you. In a real project, you must choose: *Which framework? Which database? How do I structure my code?* This chapter walks through those decisions explicitly.
#
# **3. Confidence** — There is a specific, deep confidence that comes from having built something end-to-end. After this chapter, when someone asks "can you build a REST API?", the honest answer is: "Yes. I’ve done it."
#
# > ❓ **What makes an API "RESTful"?** REST uses HTTP verbs semantically: `GET` reads, `POST` creates, `PUT`/`PATCH` updates, `DELETE` removes. Each URL represents a *resource* (e.g., `/users/42`), and the server keeps no state between requests.

# %% [markdown]
# ## 📋 Project Overview: TaskFlow
#
# If the wording here feels abstract at first, anchor it to the concrete job 📋 Project Overview: TaskFlow performs in a real system. That mental model makes the definitions easier to retain and easier to use later.
#
# ### What We’re Building
#
# **TaskFlow** is a REST API for a personal task manager. Here is the complete feature set:
#
# | Endpoint | Method | Description |
# |---|---|---|
# | `/users/register` | POST | Create an account |
# | `/users/login` | POST | Get a JWT access token |
# | `/users/me` | GET | View your own profile |
# | `/tasks/` | POST | Create a new task |
# | `/tasks/` | GET | List all your tasks (filter by status) |
# | `/tasks/{id}` | GET | View a single task |
# | `/tasks/{id}` | PUT | Update a task |
# | `/tasks/{id}/complete` | PATCH | Mark a task as done |
# | `/tasks/{id}` | DELETE | Delete a task |
#
# ### The Tech Stack — Every Layer Mapped to a Chapter
#
# Architecture material sounds bigger than it is if you read it only as terminology. Start by identifying the responsibility of each part and the reason those responsibilities are separated; the structure usually becomes much clearer from there.
#
# ```
# ┌─────────────────────────────────────────────────────┐
# │           TaskFlow Architecture                  │
# ├─────────────────────────────────────────────────────┤
# │  HTTP Layer:       FastAPI (Ch 15)                │
# │  Validation:       Pydantic (Ch 15)               │
# │  Authentication:   JWT + bcrypt (builds on Ch 14) │
# │  Database ORM:     SQLAlchemy (Ch 16)             │
# │  Database:         SQLite → PostgreSQL (Ch 16)    │
# │  Error Handling:   Custom exceptions (Ch 9)       │
# │  Testing:          pytest + TestClient (Ch 10)    │
# │  Config:           python-dotenv / .env (Ch 20)   │
# │  Packaging:        Poetry + pyproject.toml (Ch19) │
# │  Deployment:       Docker + docker-compose (Ch 20)│
# └─────────────────────────────────────────────────────┘
# ```
# ### Project File Structure
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```
# taskflow/
# ├── app/
# │   ├── __init__.py
# │   ├── main.py          ← FastAPI app + startup
# │   ├── config.py        ← Settings from .env
# │   ├── database.py      ← SQLAlchemy engine & session
# │   ├── models.py        ← Database table definitions
# │   ├── schemas.py       ← Pydantic request/response models
# │   ├── auth.py          ← JWT creation & verification
# │   └── routers/
# │       ├── __init__.py
# │       ├── users.py     ← /users routes
# │       └── tasks.py     ← /tasks routes
# ├── tests/
# │   ├── __init__.py
# │   ├── conftest.py      ← Shared test fixtures
# │   ├── test_users.py
# │   └── test_tasks.py
# ├── .env.example
# ├── .gitignore
# ├── Dockerfile
# ├── docker-compose.yml
# └── pyproject.toml
# ```
#
# We’ll build this file by file, explaining every decision as we go.

# %% [markdown]
# ## 🛠️ Step 1: Setting Up the Project
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ### Initialize with Poetry
#
# We use Poetry (Chapter 19) to manage dependencies. It creates a reproducible virtual environment and locks every dependency version so the project works identically on every machine.
#
# ```bash
# # Create the project directory
# mkdir taskflow && cd taskflow
#
# # Initialize Poetry (interactive prompts for name, description, etc.)
# poetry init --name taskflow --description "A production-grade task manager API" --python "^3.11" --no-interaction
#
# # Add runtime dependencies
# poetry add fastapi "uvicorn[standard]" sqlalchemy pydantic pydantic-settings \
#            "python-jose[cryptography]" "passlib[bcrypt]" python-dotenv python-multipart
#
# # Add development-only dependencies (not included in production Docker image)
# poetry add --group dev pytest httpx pytest-asyncio
#
# # Activate the virtual environment
# poetry shell
# ```
#
# ### pyproject.toml (generated by Poetry)
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```toml
# [tool.poetry]
# name = "taskflow"
# version = "0.1.0"
# description = "A production-grade task manager API"
# authors = ["Your Name <you@example.com>"]
#
# [tool.poetry.dependencies]
# python = "^3.11"
# fastapi = "*"
# uvicorn = {extras = ["standard"], version = "*"}
# sqlalchemy = "*"
# pydantic = "*"
# pydantic-settings = "*"
# python-jose = {extras = ["cryptography"], version = "*"}
# passlib = {extras = ["bcrypt"], version = "*"}
# python-dotenv = "*"
# python-multipart = "*"
#
# [tool.poetry.group.dev.dependencies]
# pytest = "*"
# httpx = "*"
# pytest-asyncio = "*"
#
# [build-system]
# requires = ["poetry-core"]
# build-backend = "poetry.core.masonry.api"
# ```
# ### Environment Variables (.env)
#
# We never hard-code secrets in source code. Environment variables (Chapter 20) keep secrets out of version control.
#
# ```bash
# # .env.example  ← Commit this (it’s a template with no real secrets)
# DATABASE_URL=sqlite:///./taskflow.db
# SECRET_KEY=change-this-to-a-long-random-string-in-production
# ALGORITHM=HS256
# ACCESS_TOKEN_EXPIRE_MINUTES=30
# ```
#
# ```bash
# # Set up your real .env:
# cp .env.example .env
#
# # Generate a real secret key:
# python3 -c "import secrets; print(secrets.token_hex(32))"
# # Copy the output into .env as SECRET_KEY
#
# # ALWAYS add .env to .gitignore:
# echo ".env" >> .gitignore
# ```
#
# > 🚨 **Never commit a `.env` file.** It contains your secret key. Anyone with this key can forge authentication tokens for your entire user base.
#
# > ❓ **Why not install packages globally?** Installing globally means every project on your machine shares the same package versions. When two projects need different versions of the same library, one breaks. A virtual environment gives each project its own isolated package space so they can never conflict.

# %% [markdown]
# ## ⚙️ Step 2: Configuration — `config.py`
#
# Setup steps are easier to remember when you know what each one unlocks. Read this section as a map from each command, option, or file to the problem it solves, so later errors are easier to diagnose instead of feeling random.
#
# `pydantic-settings` reads `.env` files and validates every value. This is much safer than `os.getenv()` because it raises a clear error at startup if a required variable is missing — rather than failing mysteriously at 3am when a user first hits the missing feature.
#
# ```python
# # app/config.py
# from pydantic_settings import BaseSettings
#
# class Settings(BaseSettings):
#     """Application configuration. Values are loaded from environment variables
#     (or a .env file). Pydantic validates the types automatically."""
#     DATABASE_URL: str = "sqlite:///./taskflow.db"
#     SECRET_KEY: str = "change-me-please"
#     ALGORITHM: str = "HS256"
#     ACCESS_TOKEN_EXPIRE_MINUTES: int = 30
#
#     class Config:
#         env_file = ".env"
#         env_file_encoding = "utf-8"
#
# # A single module-level instance.
# # Python modules are cached, so this is created exactly ONCE
# # and the same object is shared everywhere it’s imported.
# settings = Settings()
# ```
#
# > **Why a single `settings` instance?** Python caches module imports. Every `from app.config import settings` returns the **same object**. Configuration is loaded once at startup, not on every request.

# %% [markdown]
# ## 🗄️ Step 3: The Database Layer
#
# A useful beginner mental model here is to separate the shape of the data from the operations performed on it. Once you know what is being represented and who depends on that representation, the rules become easier to predict.
#
# The database layer has two files: `database.py` (how we connect to the DB) and `models.py` (what tables exist).
# ### `database.py` — Connection Setup
#
# A beginner usually learns this material faster by connecting each setup step to its purpose rather than treating it as a checklist. Keep asking what each piece enables and what would fail if you skipped it.
#
# ```python
# # app/database.py
# from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker, DeclarativeBase
# from app.config import settings
#
# # The engine is the core interface to the database.
# # connect_args is only needed for SQLite (prevents threading issues).
# engine = create_engine(
#     settings.DATABASE_URL,
#     connect_args={"check_same_thread": False}
# )
#
# # SessionLocal is a factory that creates new database sessions.
# SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
#
# # All our models will inherit from this Base class.
# class Base(DeclarativeBase):
#     pass
#
# def get_db():
#     """
#     FastAPI dependency that provides a database session per request.
#
#     The 'yield' makes this a generator. FastAPI:
#     1. Calls get_db(), runs up to 'yield', gives the session to the route
#     2. Route runs, uses the session
#     3. FastAPI resumes after 'yield', runs db.close() — even if the route raised an error
#
#     This prevents database connection leaks.
#     """
#     db = SessionLocal()
#     try:
#         yield db
#     finally:
#         db.close()
# ```
#
# ### `models.py` — Database Table Definitions
#
# SQLAlchemy models (Chapter 16) are Python classes where each attribute becomes a database column.
#
# ```python
# # app/models.py
# from datetime import datetime
# from sqlalchemy import Column, Integer, String, Boolean, DateTime, ForeignKey, Enum
# from sqlalchemy.orm import relationship
# from app.database import Base
# import enum
#
#
# class TaskStatus(str, enum.Enum):
#     """The possible lifecycle states of a task."""
#     PENDING = "pending"
#     IN_PROGRESS = "in_progress"
#     DONE = "done"
#
#
# class User(Base):
#     """Represents a registered user."""
#     __tablename__ = "users"
#
#     id              = Column(Integer, primary_key=True, index=True)
#     email           = Column(String, unique=True, index=True, nullable=False)
#     username        = Column(String, unique=True, index=True, nullable=False)
#     hashed_password = Column(String, nullable=False)   # NEVER store plain-text passwords
#     is_active       = Column(Boolean, default=True)
#     created_at      = Column(DateTime, default=datetime.utcnow)
#
#     # One-to-many: one User owns many Tasks
#     # cascade="all, delete-orphan" means: if the User is deleted, delete their Tasks too
#     tasks = relationship("Task", back_populates="owner", cascade="all, delete-orphan")
#
#
# class Task(Base):
#     """Represents a single task belonging to a user."""
#     __tablename__ = "tasks"
#
#     id          = Column(Integer, primary_key=True, index=True)
#     title       = Column(String, nullable=False)
#     description = Column(String, default="")
#     status      = Column(Enum(TaskStatus), default=TaskStatus.PENDING, nullable=False)
#     due_date    = Column(DateTime, nullable=True)
#     created_at  = Column(DateTime, default=datetime.utcnow)
#     updated_at  = Column(DateTime, default=datetime.utcnow, onupdate=datetime.utcnow)
#
#     owner_id = Column(Integer, ForeignKey("users.id"), nullable=False)
#     owner    = relationship("User", back_populates="tasks")
# ```
#
# #### Design decisions explained
#
# Production-oriented material makes more sense when you see it as reliability work. The tools and steps here exist to make behavior repeatable, observable, and safer to change.
#
# | Decision | Reason |
# |---|---|
# | `unique=True` on email | Two accounts with the same email causes confusion and security issues |
# | `index=True` on email & username | The DB creates a B-tree index — lookups are O(log n) instead of O(n) |
# | Column named `hashed_password` | A reminder — in the code and the DB — that we never store raw passwords |
# | `cascade="all, delete-orphan"` | Prevents "orphaned" tasks with no owner after user deletion |
# | `onupdate=datetime.utcnow` | SQLAlchemy automatically sets this when the row is updated |

# %% [markdown]
# ## ✅ Step 4: The Schema Layer — `schemas.py`
#
# Pydantic schemas (Chapter 15) define the **shape of JSON** flowing in and out of the API. They are **separate** from SQLAlchemy models:
#
# - **SQLAlchemy model** = blueprint for a database row
# - **Pydantic schema** = blueprint for a JSON payload
#
# Why separate? Because what the user *sends* is different from what the database *stores*, and different again from what the API *returns*.
#
# ```python
# # app/schemas.py
# from datetime import datetime
# from typing import Optional
# from pydantic import BaseModel, EmailStr, Field
# from app.models import TaskStatus
#
#
# # ─── User Schemas ──────────────────────────────────────────
#
# class UserCreate(BaseModel):
#     """Fields the client sends to register. EmailStr validates the format."""
#     email:    EmailStr
#     username: str = Field(min_length=3, max_length=50)
#     password: str = Field(min_length=8)
#
# class UserResponse(BaseModel):
#     """Fields returned after creating/fetching a user. No password field!"""
#     id:         int
#     email:      EmailStr
#     username:   str
#     is_active:  bool
#     created_at: datetime
#
#     class Config:
#         from_attributes = True  # Allow Pydantic to read SQLAlchemy model attributes
#
# class UserLogin(BaseModel):
#     """Credentials needed to log in."""
#     username: str
#     password: str
#
#
# # ─── Token Schemas ─────────────────────────────────────────
#
# class Token(BaseModel):
#     """JWT token returned after a successful login."""
#     access_token: str
#     token_type:   str = "bearer"
#
# class TokenData(BaseModel):
#     """The decoded content of a JWT token."""
#     username: Optional[str] = None
#
#
# # ─── Task Schemas ──────────────────────────────────────────
#
# class TaskCreate(BaseModel):
#     """Fields the client sends to create a task.
#     Note: owner_id is NOT here — it’s taken from the JWT token server-side."""
#     title:       str = Field(min_length=1, max_length=200)
#     description: str = Field(default="", max_length=2000)
#     due_date:    Optional[datetime] = None
#
# class TaskUpdate(BaseModel):
#     """All fields are Optional — only send what you want to change."""
#     title:       Optional[str]        = Field(None, min_length=1, max_length=200)
#     description: Optional[str]        = Field(None, max_length=2000)
#     status:      Optional[TaskStatus] = None
#     due_date:    Optional[datetime]   = None
#
# class TaskResponse(BaseModel):
#     """Full task data returned by the API."""
#     id:          int
#     title:       str
#     description: str
#     status:      TaskStatus
#     due_date:    Optional[datetime]
#     owner_id:    int
#     created_at:  datetime
#     updated_at:  datetime
#
#     class Config:
#         from_attributes = True
# ```
#
# #### Why not just use one schema for everything?
#
# A useful beginner mental model here is to separate the shape of the data from the operations performed on it. Once you know what is being represented and who depends on that representation, the rules become easier to predict.
#
# Consider `owner_id`. In `TaskCreate`, the user should **not** be able to set this — it would be a security hole (a user could create tasks owned by someone else). In `TaskResponse`, we **do** include it so the client knows who owns the task. Separate schemas give us precise control over each flow.

# %% [markdown]
# ## 🔐 Step 5: Authentication — `auth.py`
#
# Security topics become much easier to follow when you separate the threat from the defense. As you read, keep asking what can go wrong, what protection addresses it, and what assumption that protection depends on.
#
# ### The Hotel Key Card Analogy
#
# A JWT (JSON Web Token) works exactly like a hotel key card:
#
# 1. **Check in (login)**: You prove your identity. The hotel gives you a key card.
# 2. **Open doors (access endpoints)**: Every time you open a door, the lock verifies your card — *without* calling the front desk. It verifies the card cryptographically.
# 3. **Check out (token expires)**: After a set time, the card stops working. Log in again to get a new one.
#
# This is called **stateless authentication** — the server doesn’t need to remember you between requests. Your token is your proof of identity.
#
# ### `auth.py` — The Full Implementation
#
# Security topics become much easier to follow when you separate the threat from the defense. As you read, keep asking what can go wrong, what protection addresses it, and what assumption that protection depends on.
#
# ```python
# # app/auth.py
# from datetime import datetime, timedelta
# from typing import Optional
#
# from fastapi import Depends, HTTPException, status
# from fastapi.security import OAuth2PasswordBearer
# from jose import JWTError, jwt
# from passlib.context import CryptContext
# from sqlalchemy.orm import Session
#
# from app import models
# from app.database import get_db
# from app.config import settings
#
# # ── Password Hashing ─────────────────────────────────────────────
#
# # bcrypt is the industry standard for password hashing.
# # It’s intentionally slow (unlike MD5/SHA256) to resist brute-force attacks.
# pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")
#
# def hash_password(password: str) -> str:
#     """Convert a plain-text password into a bcrypt hash for storage."""
#     return pwd_context.hash(password)
#
# def verify_password(plain: str, hashed: str) -> bool:
#     """Check if plain-text matches the stored hash. Never compare plain passwords!"""
#     return pwd_context.verify(plain, hashed)
#
# # ── JWT Token Logic ────────────────────────────────────────────
#
# # Tells FastAPI: "look for a Bearer token in the Authorization header"
# oauth2_scheme = OAuth2PasswordBearer(tokenUrl="/users/login")
#
# def create_access_token(data: dict, expires_delta: Optional[timedelta] = None) -> str:
#     """Create a signed JWT token embedding the given data."""
#     payload = data.copy()
#     expire  = datetime.utcnow() + (
#         expires_delta or timedelta(minutes=settings.ACCESS_TOKEN_EXPIRE_MINUTES)
#     )
#     payload["exp"] = expire   # 'exp' is the standard JWT expiry claim
#     return jwt.encode(payload, settings.SECRET_KEY, algorithm=settings.ALGORITHM)
#
# # ── Dependency: Get Authenticated User ───────────────────────────
#
# def get_current_user(
#     token: str          = Depends(oauth2_scheme),
#     db:    Session      = Depends(get_db)
# ) -> models.User:
#     """
#     FastAPI dependency: decode the JWT and return the current User object.
#     Raises HTTP 401 if the token is missing, expired, or tampered with.
#     """
#     credentials_exception = HTTPException(
#         status_code=status.HTTP_401_UNAUTHORIZED,
#         detail="Could not validate credentials",
#         headers={"WWW-Authenticate": "Bearer"},
#     )
#     try:
#         payload  = jwt.decode(token, settings.SECRET_KEY, algorithms=[settings.ALGORITHM])
#         username: str = payload.get("sub")   # 'sub' = subject (standard JWT claim)
#         if username is None:
#             raise credentials_exception
#     except JWTError:
#         raise credentials_exception
#
#     user = db.query(models.User).filter(models.User.username == username).first()
#     if user is None:
#         raise credentials_exception
#     return user
#
# def get_active_user(current_user: models.User = Depends(get_current_user)) -> models.User:
#     """Dependency that additionally requires the account to be active."""
#     if not current_user.is_active:
#         raise HTTPException(status_code=400, detail="Inactive user account")
#     return current_user
# ```
#
# ### What Does a JWT Actually Look Like?
#
# A beginner-friendly way to approach this section is to pair each risk with the mechanism meant to reduce it. That keeps the advice grounded and helps you see why the defaults matter.
#
# ```
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9
# .eyJzdWIiOiJhbGljZSIsImV4cCI6MTcwMDAwMDAwMH0
# .kHSBZlLSvGTCdxKn5QY4LwnvTj6a8e9EkxF_C_placeholder
# ```
#
# Three base64-encoded sections, separated by dots:
#
# 1. **Header** — `{"alg": "HS256", "typ": "JWT"}`
# 2. **Payload** — `{"sub": "alice", "exp": 1700000000}`
# 3. **Signature** — `HMACSHA256(header + "." + payload, SECRET_KEY)`
#
# The signature is the magic. **Only the server knows `SECRET_KEY`**, so the signature can’t be forged. When a client returns a token, the server recomputes the expected signature and compares. No database lookup needed.

# %% [markdown]
# ### Live Demo: JWT in Action
#
# Let’s see JWT work in a notebook cell. We’ll create a token, decode it, and watch it reject tampered or expired tokens.

# %%
# Install jose if not already available
try:
    from jose import jwt, JWTError
except ImportError:
    import subprocess
    subprocess.run(["pip", "install", "python-jose[cryptography]", "-q"], check=True)
    from jose import jwt, JWTError

from datetime import datetime, timedelta

SECRET_KEY = "demo-key-never-use-in-production"
ALGORITHM  = "HS256"

def make_token(username: str, minutes: int = 30) -> str:
    payload = {"sub": username, "exp": datetime.utcnow() + timedelta(minutes=minutes)}
    return jwt.encode(payload, SECRET_KEY, algorithm=ALGORITHM)

# ── Case 1: Valid token ────────────────────────────────────────────────────────
print("Case 1: Valid token")
token   = make_token("alice")
payload = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
print(f"  ✓ Decoded successfully. User: '{payload['sub']}'")
print(f"  Token (first 60 chars): {token[:60]}...")

# ── Case 2: Expired token ─────────────────────────────────────────────────────
print("
Case 2: Expired token (expired 5 minutes ago)")
old_token = make_token("alice", minutes=-5)
try:
    jwt.decode(old_token, SECRET_KEY, algorithms=[ALGORITHM])
except JWTError as e:
    print(f"  ✗ Rejected: {e}")

# ── Case 3: Tampered token ────────────────────────────────────────────────────
print("
Case 3: Tampered token (signature replaced)")
parts    = token.split(".")
tampered = parts[0] + "." + parts[1] + ".FAKESIGNATURE"
try:
    jwt.decode(tampered, SECRET_KEY, algorithms=[ALGORITHM])
except JWTError as e:
    print(f"  ✗ Rejected: {e}")

# ── Case 4: Wrong secret key ──────────────────────────────────────────────────
print("
Case 4: Token verified with wrong secret key")
try:
    jwt.decode(token, "wrong-secret-key", algorithms=[ALGORITHM])
except JWTError as e:
    print(f"  ✗ Rejected: {e}")

print("
✅ JWT correctly handles all four cases.")

# %% [markdown]
# ### Live Demo: Pydantic Validation in Action
#
# Pydantic catches bad data at the API boundary — before it ever reaches the database.

# %%
try:
    from pydantic import BaseModel, Field, ValidationError
except ImportError:
    import subprocess
    subprocess.run(["pip", "install", "pydantic[email]", "-q"], check=True)
    from pydantic import BaseModel, Field, ValidationError

from typing import Optional
from datetime import datetime

class TaskCreate(BaseModel):
    title:       str            = Field(min_length=1, max_length=200)
    description: str            = Field(default="", max_length=2000)
    due_date:    Optional[datetime] = None

# ── Valid input ───────────────────────────────────────────────────────────────
print("Valid input:")
t = TaskCreate(title="Buy groceries", description="Milk, eggs, bread")
print(f"  ✓ {t.model_dump()}")

# ── Empty title (min_length=1 violated) ───────────────────────────────────────
print("
Empty title:")
try:
    TaskCreate(title="")
except ValidationError as e:
    for err in e.errors():
        print(f"  ✗ {err['loc']} → {err['msg']}")

# ── Missing required field ────────────────────────────────────────────────────
print("
Missing title entirely:")
try:
    TaskCreate(description="No title provided")
except ValidationError as e:
    for err in e.errors():
        print(f"  ✗ {err['loc']} → {err['msg']}")

# ── Wrong type ────────────────────────────────────────────────────────────────
print("
Wrong type for title (integer instead of string):")
try:
    TaskCreate(title=42)
except ValidationError as e:
    # Pydantic v2 coerces int to str, so this might actually pass!
    print(f"  (Pydantic coerced it to string: '{TaskCreate(title=42).title}')")

print("
✅ Pydantic validates data before it reaches any route handler.")

# %% [markdown]
# ## 🛣️ Step 6: The API Routes
#
# When a section introduces a boundary between systems, focus on the contract first: what information crosses the boundary, who is allowed to send it, and what the caller can safely assume in return.
#
# ### `routers/users.py` — Registration and Login
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```python
# # app/routers/users.py
# from fastapi import APIRouter, Depends, HTTPException, status
# from sqlalchemy.orm import Session
# from app import models, schemas, auth
# from app.database import get_db
#
# router = APIRouter(prefix="/users", tags=["users"])
#
#
# @router.post("/register", response_model=schemas.UserResponse, status_code=201)
# def register_user(user_data: schemas.UserCreate, db: Session = Depends(get_db)):
#     """Register a new user. Checks for duplicate email/username, hashes password."""
#     if db.query(models.User).filter(models.User.email == user_data.email).first():
#         raise HTTPException(status_code=400, detail="Email already registered")
#
#     if db.query(models.User).filter(models.User.username == user_data.username).first():
#         raise HTTPException(status_code=400, detail="Username already taken")
#
#     user = models.User(
#         email=user_data.email,
#         username=user_data.username,
#         hashed_password=auth.hash_password(user_data.password)
#     )
#     db.add(user)
#     db.commit()
#     db.refresh(user)   # reload from DB to get auto-generated id and created_at
#     return user
#
#
# @router.post("/login", response_model=schemas.Token)
# def login(user_data: schemas.UserLogin, db: Session = Depends(get_db)):
#     """Authenticate and return a JWT token."""
#     user = db.query(models.User).filter(
#         models.User.username == user_data.username
#     ).first()
#
#     # Generic error: never reveal WHICH field was wrong (prevents username enumeration)
#     if not user or not auth.verify_password(user_data.password, user.hashed_password):
#         raise HTTPException(
#             status_code=status.HTTP_401_UNAUTHORIZED,
#             detail="Incorrect username or password",
#             headers={"WWW-Authenticate": "Bearer"},
#         )
#
#     token = auth.create_access_token(data={"sub": user.username})
#     return {"access_token": token, "token_type": "bearer"}
#
#
# @router.get("/me", response_model=schemas.UserResponse)
# def get_profile(current_user: models.User = Depends(auth.get_active_user)):
#     """Return the profile of the currently authenticated user."""
#     return current_user
# ```
#
# > **Security note on login errors:** The message "Incorrect username or password" is intentionally generic. If we said "Username not found", an attacker could enumerate which usernames exist on the platform by trying different values. Generic errors reveal nothing useful.

# %% [markdown]
# ### `routers/tasks.py` — Full CRUD with Ownership Enforcement
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```python
# # app/routers/tasks.py
# from typing import List, Optional
# from fastapi import APIRouter, Depends, HTTPException, Query
# from sqlalchemy.orm import Session
# from app import models, schemas, auth
# from app.database import get_db
#
# router = APIRouter(prefix="/tasks", tags=["tasks"])
#
#
# @router.post("/", response_model=schemas.TaskResponse, status_code=201)
# def create_task(
#     task_data: schemas.TaskCreate,
#     db:           Session      = Depends(get_db),
#     current_user: models.User  = Depends(auth.get_active_user)
# ):
#     """Create a task owned by the current user. owner_id is set from the JWT, not from
#     the request body — users cannot create tasks on behalf of other users."""
#     task = models.Task(**task_data.model_dump(), owner_id=current_user.id)
#     db.add(task)
#     db.commit()
#     db.refresh(task)
#     return task
#
#
# @router.get("/", response_model=List[schemas.TaskResponse])
# def list_tasks(
#     status: Optional[models.TaskStatus] = Query(None),
#     db:           Session     = Depends(get_db),
#     current_user: models.User = Depends(auth.get_active_user)
# ):
#     """List the current user's tasks. Optionally filter: ?status=pending|in_progress|done"""
#     q = db.query(models.Task).filter(models.Task.owner_id == current_user.id)
#     if status:
#         q = q.filter(models.Task.status == status)
#     return q.order_by(models.Task.created_at.desc()).all()
#
#
# @router.get("/{task_id}", response_model=schemas.TaskResponse)
# def get_task(
#     task_id: int,
#     db:           Session     = Depends(get_db),
#     current_user: models.User = Depends(auth.get_active_user)
# ):
#     """Get a single task. Returns 404 whether the task doesn't exist OR belongs to
#     another user — we deliberately don't distinguish between these cases."""
#     task = db.query(models.Task).filter(
#         models.Task.id == task_id,
#         models.Task.owner_id == current_user.id   # ← ownership enforced here
#     ).first()
#     if not task:
#         raise HTTPException(status_code=404, detail="Task not found")
#     return task
#
#
# @router.put("/{task_id}", response_model=schemas.TaskResponse)
# def update_task(
#     task_id:   int,
#     task_data: schemas.TaskUpdate,
#     db:           Session     = Depends(get_db),
#     current_user: models.User = Depends(auth.get_active_user)
# ):
#     """Update a task. Only fields included in the request are changed."""
#     task = db.query(models.Task).filter(
#         models.Task.id == task_id,
#         models.Task.owner_id == current_user.id
#     ).first()
#     if not task:
#         raise HTTPException(status_code=404, detail="Task not found")
#
#     # exclude_unset=True: only update fields the client actually sent
#     # Without this, every un-sent field would be set to None
#     for field, value in task_data.model_dump(exclude_unset=True).items():
#         setattr(task, field, value)
#
#     db.commit()
#     db.refresh(task)
#     return task
#
#
# @router.patch("/{task_id}/complete", response_model=schemas.TaskResponse)
# def complete_task(
#     task_id: int,
#     db:           Session     = Depends(get_db),
#     current_user: models.User = Depends(auth.get_active_user)
# ):
#     """Convenience endpoint: mark a task as done in one call."""
#     task = db.query(models.Task).filter(
#         models.Task.id == task_id,
#         models.Task.owner_id == current_user.id
#     ).first()
#     if not task:
#         raise HTTPException(status_code=404, detail="Task not found")
#
#     task.status = models.TaskStatus.DONE
#     db.commit()
#     db.refresh(task)
#     return task
#
#
# @router.delete("/{task_id}", status_code=204)
# def delete_task(
#     task_id: int,
#     db:           Session     = Depends(get_db),
#     current_user: models.User = Depends(auth.get_active_user)
# ):
#     """Delete a task. Returns 204 No Content (standard for successful deletions)."""
#     task = db.query(models.Task).filter(
#         models.Task.id == task_id,
#         models.Task.owner_id == current_user.id
#     ).first()
#     if not task:
#         raise HTTPException(status_code=404, detail="Task not found")
#
#     db.delete(task)
#     db.commit()
#     # No return — 204 means "success, nothing to return"
# ```

# %% [markdown]
# ### `main.py` — Assembling the Application
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```python
# # app/main.py
# from fastapi import FastAPI
# from fastapi.middleware.cors import CORSMiddleware
# from app.database import engine, Base
# from app.routers import users, tasks
#
# # Create all DB tables on startup.
# # (In production, use Alembic migrations instead — see Deep Dive section.)
# Base.metadata.create_all(bind=engine)
#
# app = FastAPI(
#     title="TaskFlow API",
#     description="A production-grade task manager REST API",
#     version="1.0.0",
#     docs_url="/docs",     # Interactive Swagger UI
#     redoc_url="/redoc",   # ReDoc documentation
# )
#
# # Allow browser frontends to call this API.
# # Replace "*" with your frontend domain in production.
# app.add_middleware(
#     CORSMiddleware,
#     allow_origins=["*"],
#     allow_credentials=True,
#     allow_methods=["*"],
#     allow_headers=["*"],
# )
#
# app.include_router(users.router)
# app.include_router(tasks.router)
#
#
# @app.get("/", tags=["health"])
# def root():
#     """Health check endpoint. Used by load balancers and uptime monitors."""
#     return {"status": "healthy", "service": "TaskFlow API", "version": "1.0.0"}
# ```
#
# Once this is running, FastAPI **automatically generates** interactive API docs at `http://localhost:8000/docs`. You can try every endpoint directly in the browser — no Postman needed.

# %% [markdown]
# ## 🧪 Step 7: Writing Tests
#
# Treat this section as a feedback loop: define an expectation, exercise the behavior, compare the result, and use the difference to learn. That framing keeps testing ideas concrete instead of procedural.
#
# > *"Untested code is broken code waiting to be discovered."*
#
# Tests are not optional for production software (Chapter 10). They catch bugs before users do, document expected behavior, and give you confidence to change code without fear of breaking things.
# ### `tests/conftest.py` — Shared Fixtures
#
# Treat this section as a feedback loop: define an expectation, exercise the behavior, compare the result, and use the difference to learn. That framing keeps testing ideas concrete instead of procedural.
#
# ```python
# # tests/conftest.py
# import pytest
# from fastapi.testclient import TestClient
# from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker
#
# from app.main import app
# from app.database import Base, get_db
#
# # Separate SQLite database just for tests — never touches your real data
# TEST_DATABASE_URL = "sqlite:///./test_taskflow.db"
# test_engine = create_engine(TEST_DATABASE_URL, connect_args={"check_same_thread": False})
# TestingSession = sessionmaker(autocommit=False, autoflush=False, bind=test_engine)
#
#
# @pytest.fixture(scope="function")
# def db_session():
#     """
#     Provide a fresh, empty database for each individual test.
#     Creates all tables before the test, drops them after.
#     This ensures tests can NEVER affect each other.
#     """
#     Base.metadata.create_all(bind=test_engine)
#     session = TestingSession()
#     try:
#         yield session
#     finally:
#         session.close()
#         Base.metadata.drop_all(bind=test_engine)
#
#
# @pytest.fixture(scope="function")
# def client(db_session):
#     """
#     FastAPI TestClient that uses the test database.
#
#     We OVERRIDE the get_db dependency so the app uses our test session
#     instead of the real database. The routes don't know the difference.
#     This is FastAPI's dependency injection system working perfectly.
#     """
#     def override_get_db():
#         yield db_session
#
#     app.dependency_overrides[get_db] = override_get_db
#     with TestClient(app) as c:
#         yield c
#     app.dependency_overrides.clear()
# ```

# %% [markdown]
# ### `tests/test_users.py`
#
# Testing concepts stick better when you remember the purpose behind each step: create evidence that the behavior you care about still works, and learn quickly when it stops working.
#
# ```python
# # tests/test_users.py
#
# def test_register_success(client):
#     response = client.post("/users/register", json={
#         "email": "alice@example.com",
#         "username": "alice",
#         "password": "securepass123"
#     })
#     assert response.status_code == 201
#     data = response.json()
#     assert data["username"] == "alice"
#     assert data["email"] == "alice@example.com"
#     assert "password" not in data            # password MUST NEVER appear in a response
#     assert "hashed_password" not in data
#
#
# def test_register_duplicate_email(client):
#     payload = {"email": "bob@example.com", "username": "bob", "password": "password123"}
#     client.post("/users/register", json=payload)
#     response = client.post("/users/register", json={**payload, "username": "bob2"})
#     assert response.status_code == 400
#
#
# def test_login_success(client):
#     client.post("/users/register", json={
#         "email": "carol@example.com", "username": "carol", "password": "mypassword99"
#     })
#     response = client.post("/users/login", json={"username": "carol", "password": "mypassword99"})
#     assert response.status_code == 200
#     assert "access_token" in response.json()
#     assert response.json()["token_type"] == "bearer"
#
#
# def test_login_wrong_password(client):
#     client.post("/users/register", json={
#         "email": "dave@example.com", "username": "dave", "password": "correcthorse"
#     })
#     response = client.post("/users/login", json={"username": "dave", "password": "wrongpassword"})
#     assert response.status_code == 401
#
#
# def test_get_me_authenticated(client):
#     client.post("/users/register", json={
#         "email": "eve@example.com", "username": "eve", "password": "evepass123"
#     })
#     token = client.post("/users/login", json={"username": "eve", "password": "evepass123"}).json()["access_token"]
#     response = client.get("/users/me", headers={"Authorization": f"Bearer {token}"})
#     assert response.status_code == 200
#     assert response.json()["username"] == "eve"
#
#
# def test_get_me_unauthenticated(client):
#     response = client.get("/users/me")
#     assert response.status_code == 401   # No token → must be rejected
# ```

# %% [markdown]
# ### `tests/test_tasks.py`
#
# Treat this section as a feedback loop: define an expectation, exercise the behavior, compare the result, and use the difference to learn. That framing keeps testing ideas concrete instead of procedural.
#
# ```python
# # tests/test_tasks.py
# import pytest
#
#
# @pytest.fixture
# def auth_client(client):
#     """Register a user, log in, and return (client, auth_headers).
#     This fixture removes boilerplate from every task test."""
#     client.post("/users/register", json={
#         "email": "taskuser@example.com",
#         "username": "taskuser",
#         "password": "taskpass123"
#     })
#     token = client.post("/users/login", json={
#         "username": "taskuser", "password": "taskpass123"
#     }).json()["access_token"]
#     return client, {"Authorization": f"Bearer {token}"}
#
#
# def test_create_task(auth_client):
#     client, headers = auth_client
#     response = client.post("/tasks/", json={"title": "Write tests", "description": "Cover all routes"}, headers=headers)
#     assert response.status_code == 201
#     data = response.json()
#     assert data["title"] == "Write tests"
#     assert data["status"] == "pending"       # default status
#
#
# def test_list_tasks(auth_client):
#     client, headers = auth_client
#     client.post("/tasks/", json={"title": "Task A"}, headers=headers)
#     client.post("/tasks/", json={"title": "Task B"}, headers=headers)
#     response = client.get("/tasks/", headers=headers)
#     assert response.status_code == 200
#     assert len(response.json()) == 2
#
#
# def test_filter_by_status(auth_client):
#     client, headers = auth_client
#     r = client.post("/tasks/", json={"title": "Task 1"}, headers=headers)
#     client.post("/tasks/", json={"title": "Task 2"}, headers=headers)
#     client.patch(f"/tasks/{r.json()['id']}/complete", headers=headers)
#
#     assert len(client.get("/tasks/?status=done", headers=headers).json()) == 1
#     assert len(client.get("/tasks/?status=pending", headers=headers).json()) == 1
#
#
# def test_update_task(auth_client):
#     client, headers = auth_client
#     task_id = client.post("/tasks/", json={"title": "Old title"}, headers=headers).json()["id"]
#     response = client.put(f"/tasks/{task_id}", json={"title": "New title"}, headers=headers)
#     assert response.status_code == 200
#     assert response.json()["title"] == "New title"
#
#
# def test_complete_task(auth_client):
#     client, headers = auth_client
#     task_id = client.post("/tasks/", json={"title": "Finish me"}, headers=headers).json()["id"]
#     response = client.patch(f"/tasks/{task_id}/complete", headers=headers)
#     assert response.status_code == 200
#     assert response.json()["status"] == "done"
#
#
# def test_delete_task(auth_client):
#     client, headers = auth_client
#     task_id = client.post("/tasks/", json={"title": "To delete"}, headers=headers).json()["id"]
#     assert client.delete(f"/tasks/{task_id}", headers=headers).status_code == 204
#     assert client.get(f"/tasks/{task_id}", headers=headers).status_code == 404
#
#
# def test_ownership_enforced(client):
#     """SECURITY TEST: User B cannot read, update, or delete User A's tasks."""
#     # Create user A with a task
#     client.post("/users/register", json={"email":"a@x.com","username":"user_a","password":"aaaa1234"})
#     tok_a = client.post("/users/login", json={"username":"user_a","password":"aaaa1234"}).json()["access_token"]
#     h_a   = {"Authorization": f"Bearer {tok_a}"}
#     task  = client.post("/tasks/", json={"title": "A's secret task"}, headers=h_a).json()
#
#     # Create user B
#     client.post("/users/register", json={"email":"b@x.com","username":"user_b","password":"bbbb1234"})
#     tok_b = client.post("/users/login", json={"username":"user_b","password":"bbbb1234"}).json()["access_token"]
#     h_b   = {"Authorization": f"Bearer {tok_b}"}
#
#     # User B tries to access, update, and delete user A's task
#     assert client.get(f"/tasks/{task['id']}", headers=h_b).status_code == 404
#     assert client.put(f"/tasks/{task['id']}", json={"title":"hacked"}, headers=h_b).status_code == 404
#     assert client.delete(f"/tasks/{task['id']}", headers=h_b).status_code == 404
# ```
#
# The `test_ownership_enforced` test is the most important. It checks for **horizontal privilege escalation** — one user accessing another's data. This class of bug appears in real production systems and causes data breaches.

# %% [markdown]
# ## 🐳 Step 8: Dockerization
#
# Docker (Chapter 20) packages the application and **all its dependencies** into a container that runs identically everywhere: your laptop, a colleague’s machine, a cloud server.
#
# ### `Dockerfile`
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```dockerfile
# # Dockerfile
#
# # Start from official Python 3.11 slim (smaller than full image)
# FROM python:3.11-slim
#
# WORKDIR /app
#
# # Install Poetry
# RUN pip install poetry==1.7.1
#
# # Copy dependency manifests FIRST.
# # Docker builds in layers. If these files haven't changed, Docker skips
# # reinstalling dependencies on the next build — saving minutes per build.
# COPY pyproject.toml poetry.lock* ./
#
# # Install production dependencies only (no test tools in the image)
# RUN poetry config virtualenvs.create false \
#     && poetry install --only main --no-interaction --no-ansi
#
# # Now copy the application code
# COPY . .
#
# EXPOSE 8000
#
# # Start the ASGI server
# CMD ["uvicorn", "app.main:app", "--host", "0.0.0.0", "--port", "8000"]
# ```
#
# ### `docker-compose.yml`
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```yaml
# # docker-compose.yml
# version: "3.9"
#
# services:
#   api:
#     build: .
#     ports:
#       - "8000:8000"
#     environment:
#       - DATABASE_URL=sqlite:///./taskflow.db
#       - SECRET_KEY=${SECRET_KEY}
#       - ALGORITHM=HS256
#       - ACCESS_TOKEN_EXPIRE_MINUTES=30
#     volumes:
#       - .:/app                          # mount local code — enables hot reload
#     command: uvicorn app.main:app --host 0.0.0.0 --port 8000 --reload
# ```
#
# ### `.dockerignore`
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```
# __pycache__/
# *.pyc
# .env
# .pytest_cache/
# *.egg-info/
# dist/
# .git/
# tests/
# ```
# ### Running with Docker
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```bash
# # Build the image and start the container
# docker-compose up --build
#
# # Run in background
# docker-compose up -d
#
# # View logs
# docker-compose logs -f
#
# # Stop
# docker-compose down
# ```
#
# > **Upgrading to PostgreSQL** is one environment variable change:
# > Add a `db` service to `docker-compose.yml` and set `DATABASE_URL=postgresql://user:pass@db:5432/taskflow`. Your Python code doesn’t change at all — that’s the ORM abstraction paying off.

# %% [markdown]
# ## ▶️ Step 9: Running the Complete Application
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ### Start locally
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```bash
# # Install dependencies
# poetry install
#
# # Configure environment
# cp .env.example .env
# # Edit .env — set SECRET_KEY to a real random string:
# python3 -c "import secrets; print(secrets.token_hex(32))"
#
# # Start the server with hot-reload (great for development)
# poetry run uvicorn app.main:app --reload
#
# # Server is live at:   http://localhost:8000
# # Swagger UI at:       http://localhost:8000/docs
# # ReDoc docs at:       http://localhost:8000/redoc
# ```
#
# ### Run the test suite
#
# Treat this section as a feedback loop: define an expectation, exercise the behavior, compare the result, and use the difference to learn. That framing keeps testing ideas concrete instead of procedural.
#
# ```bash
# poetry run pytest -v
# # Expected output:
# # tests/test_users.py::test_register_success PASSED
# # tests/test_users.py::test_register_duplicate_email PASSED
# # tests/test_users.py::test_login_success PASSED
# # tests/test_users.py::test_login_wrong_password PASSED
# # tests/test_users.py::test_get_me_authenticated PASSED
# # tests/test_users.py::test_get_me_unauthenticated PASSED
# # tests/test_tasks.py::test_create_task PASSED
# # tests/test_tasks.py::test_list_tasks PASSED
# # tests/test_tasks.py::test_filter_by_status PASSED
# # tests/test_tasks.py::test_update_task PASSED
# # tests/test_tasks.py::test_complete_task PASSED
# # tests/test_tasks.py::test_delete_task PASSED
# # tests/test_tasks.py::test_ownership_enforced PASSED
# #
# # ======= 13 passed in 1.2s =======
# ```
#
# ### Try the API with curl
#
# API and integration material becomes easier when you treat it as agreement design rather than just endpoint syntax. Watch the shape of the data, the guarantees around it, and the failure cases.
#
# ```bash
# # Register
# curl -X POST http://localhost:8000/users/register \
#   -H "Content-Type: application/json" \
#   -d '{"email":"me@example.com","username":"alice","password":"secret123"}'
#
# # Login and capture the token
# TOKEN=$(curl -s -X POST http://localhost:8000/users/login \
#   -H "Content-Type: application/json" \
#   -d '{"username":"alice","password":"secret123"}' \
#   | python3 -c "import sys,json; print(json.load(sys.stdin)['access_token'])")
#
# # Create a task
# curl -X POST http://localhost:8000/tasks/ \
#   -H "Authorization: Bearer $TOKEN" \
#   -H "Content-Type: application/json" \
#   -d '{"title":"My first task","description":"Created via curl!"}'
#
# # List tasks
# curl http://localhost:8000/tasks/ -H "Authorization: Bearer $TOKEN"
#
# # List only done tasks
# curl "http://localhost:8000/tasks/?status=done" -H "Authorization: Bearer $TOKEN"
# ```

# %% [markdown]
# ## 🗺️ The Full Concept Map
#
# Every file in TaskFlow maps to concepts from this handbook. Here is the complete picture:
#
# ```
# ┌────────────────────────────────────────────────────────────────┐
# │  File / Component          Chapters Used                       │
# ├────────────────────────────────────────────────────────────────┤
# │  All Python syntax         Ch 1–4 (Fundamentals)                │
# │  TaskStatus Enum           Ch 6 (Advanced Python — Enums)       │
# │  Type hints everywhere     Ch 6 (Advanced Python — Type Hints) │
# │  @router.get decorators    Ch 6 (Advanced Python — Decorators) │
# │  yield in get_db()         Ch 6 (Advanced Python — Generators) │
# │  with TestClient()         Ch 6 (Advanced Python — Context Mgr)│
# │  User / Task classes       Ch 5 (Object-Oriented Programming)  │
# │  HTTPException handling    Ch 9 (Error Handling)               │
# │  pytest + fixtures         Ch 10 (Testing)                     │
# │  FastAPI framework         Ch 15 (Web Development)             │
# │  Pydantic schemas          Ch 15 (Web Development)             │
# │  SQLAlchemy ORM            Ch 16 (Databases)                   │
# │  Poetry / pyproject.toml  Ch 19 (Packaging)                   │
# │  Docker / .env config      Ch 20 (DevOps & Deployment)         │
# │  JWT / bcrypt (auth.py)    NEW — built on Ch 14–15 foundations  │
# └────────────────────────────────────────────────────────────────┘
# ```
#
# Every concept you studied had a purpose. You’ve been building toward this all along.

# %% [markdown]
# ## 🔬 Deep Dive: Key Architectural Decisions
#
# The important beginner shift here is moving from “it works on my machine” to “it behaves predictably in a real environment.” Each step matters because it reduces surprises when the software runs elsewhere.
#
# ### JWT vs Session Authentication
#
# These are the two most common approaches to web authentication. Understanding the tradeoff is a professional skill.
#
# | | **JWT (stateless)** | **Session-based (stateful)** |
# |---|---|---|
# | **How it works** | Server issues a signed token; client sends it on every request | Server stores session ID; client sends cookie |
# | **Server storage** | None — token is self-contained | Session must be stored (memory, Redis, DB) |
# | **Verification** | Cryptographic — no DB lookup needed | DB/cache lookup on every request |
# | **Scalability** | ✅ Any server can verify any token | ❌ Need sticky sessions or shared session store |
# | **Revocation** | ❌ Hard — valid until expiry | ✅ Easy — delete from session store |
# | **Best for** | REST APIs, microservices, mobile apps | Traditional server-rendered web apps |
#
# **When to choose sessions over JWT:**
#
# If you need *immediate* revocation (e.g., "suspend this account right now" or "log out all devices"), sessions win. With JWT you must wait up to 30 minutes (the expiry) for old tokens to become invalid. The workaround is a JWT blocklist — a Redis set of revoked token IDs — but that reintroduces statefulness.
#
# **JWT security rules:**
# 1. Keep the expiry short (15–30 min). Use refresh tokens for persistent sessions.
# 2. Store tokens in `HttpOnly` cookies if possible — not `localStorage` (XSS risk).
# 3. Never put sensitive data in the payload. The payload is base64-encoded, **not encrypted**. Anyone can decode it (try [jwt.io](https://jwt.io)).

# %% [markdown]
# ### SQLite vs PostgreSQL for Production
#
# We used SQLite because it requires zero infrastructure. Here’s the honest comparison:
#
# | | **SQLite** | **PostgreSQL** |
# |---|---|---|
# | **Setup** | ✅ Zero config — just a file | Requires a server process |
# | **Concurrent writes** | ❌ File-level locking | ✅ Row-level MVCC concurrency |
# | **Horizontal scale** | ❌ Single file, single machine | ✅ Replicas, read scaling |
# | **Features** | Basic SQL | JSON columns, full-text search, extensions |
# | **Managed hosting** | N/A | Neon, Supabase, RDS (all have free tiers) |
# | **Migration complexity** | Simple (just change DATABASE_URL) | Simple (just change DATABASE_URL!) |
#
# **When to upgrade to PostgreSQL:**
# - Your app gets real users (SQLite handles ~100k reads/sec but limited concurrent writes)
# - You need multiple workers/servers
# - You want database-level features: full-text search, JSON columns, advanced indexes
#
# **How to switch (seriously, it’s this simple):**
# ```bash
# # 1. Add the driver
# poetry add psycopg2-binary
#
# # 2. Update .env
# DATABASE_URL=postgresql://user:password@localhost:5432/taskflow
#
# # That’s it. SQLAlchemy handles the rest.
# ```
#
# ### Database Migrations: Alembic
#
# We used `Base.metadata.create_all()` for simplicity. In production, use **Alembic** for schema migrations.
#
# **Why?** `create_all()` creates tables but *cannot alter existing ones*. If you add a `priority` column to `Task` later, `create_all()` silently does nothing on an existing database. Alembic generates versioned migration scripts that safely alter the schema with rollback support.
#
# ```bash
# poetry add alembic
# alembic init migrations
#
# # After changing models.py:
# alembic revision --autogenerate -m "add priority column"
# alembic upgrade head      # apply migration
# alembic downgrade -1      # roll back one step
# ```

# %% [markdown]
# ### In-Memory vs File-Based Test Database
#
# Our tests used a file-based SQLite DB (`test_taskflow.db`). There’s an even simpler option:
#
# ```python
# # Option A: File-based (what we used)
# TEST_DATABASE_URL = "sqlite:///./test_taskflow.db"
#
# # Option B: In-memory (faster, no cleanup needed)
# TEST_DATABASE_URL = "sqlite:///:memory:"
# ```
#
# | | **File-based** | **In-memory** |
# |---|---|---|
# | **Speed** | Fast | ✅ Fastest (no disk I/O) |
# | **Isolation** | Needs `drop_all` / `create_all` per test | ✅ Each connection is a clean DB |
# | **Parallel tests** | Risk of collisions | ✅ Fully isolated |
# | **Debuggability** | ✅ Can inspect with DB browser | Vanishes after the test |
#
# For most projects, in-memory databases make the test suite noticeably faster and simpler. The tradeoff is that you can’t inspect the test DB if something goes wrong.

# %% [markdown]
# ## 🧪 What If? — Extension Challenges
#
# You have a working, production-grade API. Here are challenges to push TaskFlow further.
#
# ---
#
# ### 🟡 Challenge 1: Task Priorities (Beginner)
#
# **What if tasks had priorities — high, medium, low?**
#
# 1. Add a `Priority` enum to `models.py` (like `TaskStatus`)
# 2. Add a `priority` column to the `Task` model (default: `medium`)
# 3. Add `priority` to `TaskCreate` and `TaskResponse` schemas
# 4. Filter tasks by priority: `GET /tasks/?priority=high`
# 5. Write a test: creating a task with `priority="high"` stores and returns that priority
#
# *Practises: models, schemas, query filtering*
#
# ---
#
# ### 🟠 Challenge 2: Task Tags (Intermediate)
#
# **What if tasks could have multiple tags (e.g., "work", "personal", "urgent")?**
#
# This requires a **many-to-many relationship**: one task has many tags, one tag applies to many tasks.
#
# 1. Create a `Tag` model with a name field
# 2. Create a `task_tags` association table (`ForeignKey` to both `tasks.id` and `tags.id`)
# 3. Add `relationship("Tag", secondary=task_tags)` to `Task`
# 4. Update `TaskCreate` to accept a `tags: list[str]` field
# 5. Write tests for creating a task with tags
#
# *Practises: SQLAlchemy relationships, many-to-many, schema design*
#
# ---
#
# ### 🔴 Challenge 3: Scale to 10,000 Users (Advanced)
#
# **What if TaskFlow needed to handle 10,000 concurrent users?**
#
# 1. **Switch to PostgreSQL** — SQLite can’t handle concurrent writes at scale
# 2. **Add async support** — use `asyncpg` and `async def` route handlers with `await`
# 3. **Connection pooling** — configure SQLAlchemy’s `pool_size=20, max_overflow=10`
# 4. **Redis caching** — cache `GET /tasks/` for 30 seconds per user in Redis
# 5. **Load testing** — use `locust` to simulate 10k users and find bottlenecks
# 6. **Multiple workers** — `uvicorn app.main:app --workers 4`
#
# *Practises: async Python, caching, performance optimization (Ch 21), architecture*
#
# ---
#
# ### 🟣 Bonus: Add a Frontend
#
# The API already has CORS enabled. Build a React or Vue.js frontend that:
# 1. Shows a login form that exchanges credentials for a JWT
# 2. Stores the JWT in a cookie and includes it on every request
# 3. Displays the task list and lets users create/complete/delete tasks
#
# Deploy the frontend to Vercel or Netlify (free). You now have a full-stack application.

# %% [markdown]
# ## 🚀 Deployment: Share TaskFlow with the World
#
# Whenever a process has several stages, beginners benefit from tracing the handoff between them. Follow the order carefully and notice what information each step receives, transforms, and passes on.
#
# ### Option A: Railway (Recommended — Easiest)
#
# [Railway](https://railway.app) detects your Dockerfile and deploys automatically. Free tier available.
#
# ```bash
# # 1. Push your code to GitHub
# git init && git add . && git commit -m "Initial TaskFlow implementation"
# git remote add origin https://github.com/yourusername/taskflow.git
# git push -u origin main
#
# # 2. Go to railway.app → New Project → Deploy from GitHub repo
# # 3. Select your repository — Railway detects the Dockerfile automatically
# # 4. Add environment variables in the Railway dashboard:
# #      SECRET_KEY  = (generate with: python3 -c "import secrets; print(secrets.token_hex(32))")
# #      DATABASE_URL = sqlite:///./taskflow.db   (or a Railway PostgreSQL URL)
# # 5. Deploy — your API is live in ~2 minutes
# ```
#
# ### Option B: Render
#
# [Render](https://render.com) is another excellent free-tier option.
#
# ```yaml
# # render.yaml  (place in project root)
# services:
#   - type: web
#     name: taskflow-api
#     runtime: docker
#     dockerfilePath: ./Dockerfile
#     envVars:
#       - key: SECRET_KEY
#         generateValue: true   # Render generates a random value automatically
#       - key: DATABASE_URL
#         value: sqlite:///./taskflow.db
# ```
#
# Push to GitHub, connect the repo in Render’s dashboard, and you’re live.
#
# ### Production Checklist
#
# Before your API serves real users, verify every item:
#
# - [ ] `SECRET_KEY` is a cryptographically random 32+ byte string (not "change-me")
# - [ ] `.env` is in `.gitignore` and has **never** been committed
# - [ ] Auto-reload (`--reload`) is OFF in production
# - [ ] CORS `allow_origins` lists specific domains, not `"*"`
# - [ ] HTTPS is enforced (Railway and Render handle this automatically)
# - [ ] Token expiry is reasonably short (15–30 minutes)
# - [ ] Rate limiting is configured on the login endpoint
# - [ ] Alembic is set up for future schema migrations
# - [ ] Application logs are shipped to a logging service

# %% [markdown]
# ## 📋 Final Summary: Everything You’ve Learned
#
# ### The Complete Python Handbook — All 22 Chapters
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# | # | Chapter | Core Skill Gained |
# |---|---|---|
# | 1 | **Python Fundamentals** | Variables, data types, operators, control flow |
# | 2 | **Strings & Text Processing** | String methods, f-strings, regular expressions |
# | 3 | **Data Structures** | Lists, dicts, sets, tuples — and when to use each |
# | 4 | **Functions** | Defining functions, arguments, scope, recursion |
# | 5 | **Object-Oriented Programming** | Classes, inheritance, encapsulation, polymorphism |
# | 6 | **Advanced Python** | Decorators, generators, context managers, type hints |
# | 7 | **Functional Programming** | map, filter, reduce, lambda, list comprehensions |
# | 8 | **Modules & Packages** | Organizing code, imports, the standard library |
# | 9 | **Error Handling** | try/except, custom exceptions, defensive programming |
# | 10 | **Testing** | pytest, fixtures, test-driven development |
# | 11 | **File I/O** | Reading, writing, CSV, JSON, binary files |
# | 12 | **Concurrency** | Threading, multiprocessing, asyncio |
# | 13 | **Standard Library Deep Dive** | datetime, collections, itertools, pathlib |
# | 14 | **Working with APIs** | requests, REST, authentication, rate limiting |
# | 15 | **Web Development with FastAPI** | REST APIs, routing, Pydantic, dependency injection |
# | 16 | **Databases with SQLAlchemy** | ORM, models, queries, relationships, sessions |
# | 17 | **Data Science Fundamentals** | NumPy, Pandas, data manipulation |
# | 18 | **Data Visualization** | Matplotlib, Seaborn, insightful charts |
# | 19 | **Packaging & Distribution** | Poetry, pyproject.toml, publishing to PyPI |
# | 20 | **DevOps & Deployment** | Docker, docker-compose, environment variables, CI/CD |
# | 21 | **Performance Optimization** | Profiling, caching, async, algorithmic improvements |
# | 22 | **Capstone Project** | 🏆 **TaskFlow — a real, deployed, production-grade API** |
#
# ---
# ### A Word to You
#
# You started this handbook knowing little about Python. You may have struggled with Chapter 1 syntax, felt confused by Chapter 5 inheritance, or hit a wall with Chapter 12 async.
#
# But you kept going.
#
# And here, in Chapter 22, you have:
# - Built a REST API from scratch with real authentication
# - Written a test suite that covers security edge cases
# - Packaged the application with Poetry and Docker
# - Deployed it to the internet for anyone to use
#
# That is not a small thing. Most people who "want to learn programming" never build anything real. You built and deployed a production-grade application.
#
# **You are now a Python developer. Not a beginner. A developer.**
#
# The gap between what you knew on page 1 and what you know now is extraordinary. Be proud of it.

# %% [markdown]
# ## 💪 Next Steps: Where Do You Go From Here?
#
# The end of this handbook is the end of the beginning. Here are the highest-value paths forward:
#
# ---
#
# ### 🔹 Deepen Your Python
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - **Fluent Python** by Luciano Ramalho — the definitive advanced Python book
# - **Metaclasses, descriptors, `__slots__`** — Python’s deepest features
# - **CPython internals** — understand the GIL, memory management, bytecode
#
# ---
# ### 🔹 System Design
#
# This is what separates junior from senior engineers.
#
# - *Designing Data-Intensive Applications* by Martin Kleppmann — the best technical book of the decade
# - Topics: load balancers, caches, message queues, database sharding, microservices
# - Practice: [system-design-primer](https://github.com/donnemartin/system-design-primer) on GitHub
#
# ---
#
# ### 🔹 Cloud Architecture
#
# Architecture material sounds bigger than it is if you read it only as terminology. Start by identifying the responsibility of each part and the reason those responsibilities are separated; the structure usually becomes much clearer from there.
#
# - **AWS / GCP / Azure** — AWS Cloud Practitioner certification is a great start
# - **Kubernetes** — container orchestration for production scale
# - **Terraform** — infrastructure as code
#
# ---
# ### 🔹 Machine Learning & AI
#
# Python is the dominant ML language. Your skills transfer directly.
#
# 1. NumPy + Pandas (you already know these from Ch 17)
# 2. Scikit-learn — classical ML: regression, classification, clustering
# 3. PyTorch or TensorFlow — neural networks
# 4. Build a project using a real model (image classification, text generation, prediction)
#
# ---
#
# ### 🔹 Contribute to Open Source
#
# The fastest way to grow as an engineer is to read and contribute to code written by experts.
#
# 1. Find a project you use (FastAPI, Pydantic, SQLAlchemy, pytest, httpx)
# 2. Read the "good first issue" label on their GitHub
# 3. Fix a bug, improve docs, or add a test
# 4. Submit a pull request
#
# You'll learn more from one week of contributing than from months of tutorials.
#
# ---
#
# ### 🔹 Build More Projects
#
# Projects are your portfolio. Some ideas that directly use your new skills:
#
# | Idea | Skills |
# |---|---|
# | Personal finance tracker | FastAPI + SQLAlchemy + charts |
# | URL shortener (like bit.ly) | FastAPI + Redis + Docker |
# | Weather dashboard | APIs + Pandas + Matplotlib |
# | CLI tool for your workflow | argparse + File I/O + packaging |
# | Real-time chat | WebSockets + async + deployment |
#
# ---
#
# ### One Final Thought
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# > *"The best time to plant a tree was 20 years ago. The second best time is now."*
#
# You’ve planted your tree. Keep watering it. Build things. Break things. Fix things. Share what you build.
#
# The Python community is one of the most welcoming in all of tech. The `#python` channels on Discord, r/Python, local meetups, PyCon — these are full of people who genuinely want to help you grow.
#
# Go build something. The world is waiting.
#
# 🐍 Happy coding.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../8. devops_deployment_and_future_proofing/21. performance_optimization.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <span style='color:gray; font-size:1.05em;'>You've reached the end! 🎓</span>
# </div>

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../8. devops_deployment_and_future_proofing/21. performance_optimization.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <span style='color:gray; font-size:1.05em;'>Next</span>
# </div>
