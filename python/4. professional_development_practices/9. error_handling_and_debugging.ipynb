# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='8.%20code_style_and_quality.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 8: Code Style</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='10.%20testing_and_quality_assurance.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 10: Testing →</a>
# </div>
#
# ---

# %% [markdown]
# # Chapter 9: Error Handling and Debugging
# ## When Things Go Wrong — And They Will!
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ---

# %% [markdown]
# ## 🌍 The Big Picture
#
# Every program crashes eventually. The question is: **does it crash gracefully** with a helpful message, or does it **explode** with a cryptic wall of red text that leaves users confused and developers panicked?
#
# ```
# # What the user should NOT see:
# Traceback (most recent call last):
#   File "app.py", line 47, in process_data
#     result = data["user"]["profile"]["age"]
# KeyError: 'profile'
#
# # What they SHOULD see:
# Error: User profile data is missing.
# Please log out and log back in. If the problem persists, contact support@example.com
# ```
#
# Error handling is the difference between a **professional application** and a **fragile script**.
#
# > 💡 **Real-world impact:** A bank's payment service has no error handling. A network hiccup causes a lookup to fail. The unhandled exception crashes the entire service. 50,000 customers can't access their accounts. A single `try/except` block could have fallen back to a cached response and served users without interruption.
#
# ---

# %% [markdown]
# ## 🧠 Core Concepts: The "Why"
#
# The easiest way to read this section is to keep one plain-language question in view: what is The "Why" actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### What is an Exception?
#
# When Python encounters something it can't handle — dividing by zero, accessing a missing key, opening a nonexistent file — it **raises an exception**.
#
# > 🙋 **Analogy:** Exceptions are Python's way of raising its hand and saying "I can't do this!" A well-written program listens for these raised hands and responds thoughtfully.
#
# An unhandled exception **terminates your program** immediately. A handled exception lets you:
# - Show the user a meaningful message
# - Try an alternative approach
# - Log the error for debugging later
# - Clean up resources before exiting
#
# ### The Two Philosophies
#
# Python programmers prefer **EAFP** over **LBYL**:
#
# | Style | Name | Approach |
# |-------|------|----------|
# | **LBYL** | Look Before You Leap | Check all conditions BEFORE attempting |
# | **EAFP** | Easier to Ask Forgiveness | Attempt first, handle exceptions if they occur |
#
# Python's design and community strongly prefer **EAFP** — we'll see why shortly.
#
# ---

# %% [markdown]
# ## 📖 Syntax & First Usage: Reading a Traceback
#
# Before handling exceptions, you need to **read** them. This is one of the most important skills in Python.
#
# > 🔑 **Key insight:** Always read tracebacks from **BOTTOM to TOP**. The bottom tells you WHAT went wrong. The top tells you WHERE it started.

# %%
# Let us generate a real traceback and read it together

def get_user_age(user_data):
    return user_data["profile"]["age"]

def process_user(user_id):
    users = {
        1: {"name": "Alice", "profile": {"age": 30}},
        2: {"name": "Bob"},   # Bob has no "profile" key!
    }
    user = users[user_id]
    return get_user_age(user)

# Catch it and show how to read it
try:
    age = process_user(2)
except KeyError as e:
    print("=" * 55)
    print("HOW TO READ A TRACEBACK")
    print("=" * 55)
    print()
    print("Traceback (most recent call last):")
    print('  File "app.py", line 15, in <module>')
    print('    age = process_user(2)              <- call chain entry point')
    print('  File "app.py", line 12, in process_user')
    print('    return get_user_age(user)          <- led here')
    print('  File "app.py", line 4, in get_user_age')
    print('    return user_data["profile"]["age"] <- EXACT LINE THAT FAILED')
    print(f'KeyError: {e}                         <- WHAT failed (read first!)')
    print()
    print("Reading order:")
    print("  1. BOTTOM: KeyError: 'profile' -> a dict lookup failed")
    print("  2. ONE LINE UP: user_data['profile']['age'] -> the exact code")
    print("  3. UPWARD: get_user_age -> process_user -> main code")
    print("  4. YOUR CODE starts where you see your filename")

# %% [markdown]
# ## 🔴 Common Built-In Exceptions
#
# Python has dozens of built-in exceptions. Here are the ones you'll encounter most often:

# %%
print("=" * 55)
print("THE 6 MOST COMMON PYTHON EXCEPTIONS")
print("=" * 55)

# 1. TypeError
print("
1. TypeError — wrong type for an operation")
try:
    result = "age: " + 25   # Can't concatenate str and int
except TypeError as e:
    print(f"   Error: {e}")
    print("   Fix:   f'age: {25}'  or  'age: ' + str(25)")

# 2. ValueError
print("
2. ValueError — right type, wrong value")
try:
    number = int("hello")   # "hello" cannot become an int
except ValueError as e:
    print(f"   Error: {e}")
    print("   Fix:   validate before converting")

# 3. KeyError
print("
3. KeyError — dictionary key does not exist")
try:
    config = {"host": "localhost"}
    port = config["port"]
except KeyError as e:
    print(f"   Error: {e}")
    print("   Fix:   config.get('port', 8080)  or  if 'port' in config")

# 4. IndexError
print("
4. IndexError — list index out of range")
try:
    items = ["apple", "banana"]
    third = items[2]    # Only indices 0 and 1 exist
except IndexError as e:
    print(f"   Error: {e}")
    print("   Fix:   check len(items) > 2 first")

# 5. AttributeError
print("
5. AttributeError — object has no such attribute/method")
try:
    number = 42
    number.append(1)    # int has no .append() — lists do
except AttributeError as e:
    print(f"   Error: {e}")
    print("   Fix:   check type(number) — did you mean a list?")

# 6. FileNotFoundError
print("
6. FileNotFoundError — file or directory does not exist")
try:
    with open("nonexistent_file.txt") as f:
        content = f.read()
except FileNotFoundError as e:
    print(f"   Error: {e}")
    print("   Fix:   check if file exists with Path.exists()")

# %% [markdown]
# ## 🛡️ try / except — Your Safety Net
#
# The `try/except` block is Python's core error handling mechanism.
#
# ```python
# try:
#     # "Let me attempt this risky operation..."
#     risky_operation()
# except SomeException:
#     # "If it goes wrong, here is the backup plan..."
#     handle_the_error()
# ```
#
# > 🎯 **Analogy:** `try` is like attempting to drive across a bridge. `except` is your GPS saying "if the bridge is out, I'll reroute you."

# %%
# Basic try/except
def safe_divide(a, b):
    try:
        result = a / b
        return result
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")
        return None

print(safe_divide(10, 2))   # Works fine: 5.0
print(safe_divide(10, 0))   # Handled gracefully
print(safe_divide(7, 3))    # Works fine: 2.333...
print()

# Accessing an exception's message with "as e"
def parse_integer(text: str) -> int:
    """Convert a string to integer with a helpful error message."""
    try:
        return int(text)
    except ValueError as e:
        # "as e" gives us access to the exception object
        print(f"  Could not parse '{text}' as integer: {e}")
        return 0

print(parse_integer("42"))       # 42
print(parse_integer("3.14"))     # Helpful error, returns 0
print(parse_integer("hello"))    # Helpful error, returns 0

# %% [markdown]
# ## 🎯 Multiple except Clauses — Handling Different Errors Differently
#
# Different errors often need different responses. Use multiple `except` clauses:

# %%
import json

def load_config(filename: str) -> dict:
    """Load configuration from a JSON file with graceful fallbacks."""
    try:
        with open(filename) as f:
            data = json.load(f)
        return data

    except FileNotFoundError:
        # The file doesn't exist — use sensible defaults
        print(f"Config '{filename}' not found. Using defaults.")
        return {"host": "localhost", "port": 8080, "debug": False}

    except json.JSONDecodeError as e:
        # The file exists but isn't valid JSON — user must fix it
        print(f"Config file is corrupted (invalid JSON at line {e.lineno}): {e.msg}")
        print("Please fix or delete the config file and restart.")
        return None

    except PermissionError:
        # File exists but we can't read it — OS-level issue
        print(f"Permission denied reading '{filename}'.")
        print("Try running with elevated permissions.")
        return None

# Demo case 1: file not found (most common)
print("--- File not found ---")
config = load_config("nonexistent.json")
print(f"Config: {config}")
print()

# Demo case 2: invalid JSON
import tempfile, os
with tempfile.NamedTemporaryFile(mode="w", suffix=".json", delete=False) as f:
    f.write("{ this is not valid json }")
    tmp_path = f.name

print("--- Invalid JSON ---")
config = load_config(tmp_path)
os.unlink(tmp_path)

# %% [markdown]
# ## ✅ else and finally — The Complete try Block
#
# The full `try` statement has four possible clauses:
#
# ```python
# try:
#     # Attempt the operation
# except SomeError:
#     # Runs ONLY if an exception was raised
# else:
#     # Runs ONLY if NO exception occurred
# finally:
#     # ALWAYS runs — exception or not
# ```
#
# > 🎉 **`else`** — The success path. "The try worked — now do this bonus thing."
# >
# > 🧹 **`finally`** — The cleanup crew. "They show up whether the party went great or ended in disaster."

# %%
def read_user_file(filepath: str) -> str:
    """Read a file and return its contents, always closing the handle."""
    file_handle = None

    try:
        print(f"  Opening: {filepath}")
        file_handle = open(filepath, "r")
        content = file_handle.read()

    except FileNotFoundError:
        print(f"  File not found: {filepath}")
        return ""

    except PermissionError:
        print(f"  Permission denied: {filepath}")
        return ""

    else:
        # Only reaches here if NO exception occurred in try
        print(f"  Read successfully ({len(content)} bytes)")
        return content

    finally:
        # ALWAYS runs — perfect for resource cleanup
        if file_handle and not file_handle.closed:
            file_handle.close()
            print("  File handle closed (finally block)")

import tempfile
with tempfile.NamedTemporaryFile(mode="w", suffix=".txt", delete=False) as f:
    f.write("Hello from the file!")
    tmp_path = f.name

print("=== Test 1: File exists ===")
result = read_user_file(tmp_path)
print(f"  Content: '{result}'")

print()
print("=== Test 2: File missing ===")
result = read_user_file("/nonexistent/file.txt")
print(f"  Content: '{result}'")

import os
os.unlink(tmp_path)

# %%
# Visualizing the try/else/finally control flow

print("Flow demonstration:
")

for scenario in ["success", "failure"]:
    print(f"--- Scenario: {scenario} ---")
    try:
        if scenario == "failure":
            raise ValueError("Something went wrong!")
        print("  try:     Running... no error occurred")

    except ValueError as e:
        print(f"  except:  Caught: {e}")

    else:
        print("  else:    Runs because try had NO exception")

    finally:
        print("  finally: ALWAYS runs
")

# %% [markdown]
# ## 🚨 Raising Exceptions — Signaling Problems Yourself
#
# You can raise exceptions yourself when you detect invalid state or bad input.
#
# ```python
# raise ExceptionType("Descriptive message explaining what went wrong")
# ```

# %%
def set_age(age: int) -> None:
    """Set a user's age with full validation."""
    if not isinstance(age, int):
        raise TypeError(f"Age must be an integer, got {type(age).__name__}")
    if age < 0:
        raise ValueError(f"Age cannot be negative, got {age}")
    if age > 150:
        raise ValueError(f"Age {age} is not realistic (max 150)")
    print(f"  Age set to {age}")


# Test valid input
set_age(25)

# Test invalid inputs
test_cases = [
    ("25",  "string instead of int"),
    (-5,    "negative age"),
    (200,   "unrealistic age"),
]

for value, description in test_cases:
    try:
        set_age(value)
    except (TypeError, ValueError) as e:
        print(f"  {description}: {e}")

# %% [markdown]
# ## 🏗️ Custom Exceptions — Creating Your Own Error Types
#
# When built-in exceptions don't accurately describe your error, create your own. This makes error handling more precise and self-documenting.
#
# ```python
# class MyCustomError(ValueError):
#     pass    # The pass is enough — we inherit everything
# ```

# %%
# Custom exceptions for a user registration system

class RegistrationError(Exception):
    """Base exception for all registration-related errors."""
    pass

class InvalidEmailError(RegistrationError):
    """Raised when an email address format is invalid."""
    pass

class DuplicateUserError(RegistrationError):
    """Raised when trying to register an already-existing email."""

    def __init__(self, email: str):
        self.email = email
        super().__init__(f"User with email '{email}' already exists")

class WeakPasswordError(RegistrationError):
    """Raised when a password doesn't meet strength requirements."""

    def __init__(self, reason: str):
        super().__init__(f"Password too weak: {reason}")


def register_user(email: str, password: str) -> dict:
    """Register a new user account."""
    existing_users = {"alice@example.com", "bob@example.com"}

    if "@" not in email or "." not in email.split("@")[-1]:
        raise InvalidEmailError(f"'{email}' is not a valid email address")

    if email in existing_users:
        raise DuplicateUserError(email)

    if len(password) < 8:
        raise WeakPasswordError("must be at least 8 characters")
    if not any(c.isupper() for c in password):
        raise WeakPasswordError("must contain at least one uppercase letter")

    return {"id": 42, "email": email, "status": "active"}


# Test each scenario
test_cases = [
    ("not-an-email", "Password1!", "Bad email"),
    ("alice@example.com", "Password1!", "Duplicate email"),
    ("new@example.com", "weak", "Weak password"),
    ("new@example.com", "StrongPass1!", "Valid registration"),
]

for email, password, description in test_cases:
    print(f"
{description}:")
    try:
        user = register_user(email, password)
        print(f"  Registered: {user}")
    except InvalidEmailError as e:
        print(f"  Email error: {e}")
    except DuplicateUserError as e:
        print(f"  Duplicate (email attr: {e.email}): {e}")
    except WeakPasswordError as e:
        print(f"  Password: {e}")

# %% [markdown]
# ## 🆚 try/except vs. if/else — EAFP vs. LBYL
#
# There are two ways to handle potential errors. Python prefers **EAFP**:

# %%
# Scenario: Read a value from a deeply nested dictionary

data = {"user": {"profile": {"age": 30}}}

# LBYL — verbose, repetitive, easy to miss a case
def get_age_lbyl(data):
    if "user" in data:
        if "profile" in data["user"]:
            if "age" in data["user"]["profile"]:
                return data["user"]["profile"]["age"]
    return None

# EAFP — concise, handles ALL missing levels at once
def get_age_eafp(data):
    try:
        return data["user"]["profile"]["age"]
    except KeyError:
        return None

print("Full data:")
print("  LBYL:", get_age_lbyl(data))
print("  EAFP:", get_age_eafp(data))

incomplete = {"user": {}}
print("
Missing profile:")
print("  LBYL:", get_age_lbyl(incomplete))
print("  EAFP:", get_age_eafp(incomplete))

print()
print("Why EAFP wins:")
print("  - Less code, fewer bugs")
print("  - Handles ALL missing levels with one except")
print("  - In multi-threaded code, LBYL has race conditions (check then act)")
print("  - Python's stdlib is built around EAFP")

# %% [markdown]
# ## 🔍 Debugging Techniques — Finding and Fixing Bugs
#
# Even with good error handling, you'll need to debug your code. Three essential techniques:

# %%
# Technique 1: Strategic print() debugging
# Key: print CONTEXT, not just values

def find_discount(product_id: int, user_tier: str) -> float:
    products = {101: "laptop", 102: "mouse", 103: "keyboard"}
    discounts = {"gold": 0.20, "silver": 0.10, "bronze": 0.05}

    print(f"[DEBUG] find_discount: product_id={product_id}, tier={user_tier}")

    product = products.get(product_id)
    print(f"[DEBUG] Found product: {product}")

    discount = discounts.get(user_tier, 0)
    print(f"[DEBUG] Discount for '{user_tier}': {discount}")

    if product is None:
        print("[DEBUG] Product not found, returning 0")
        return 0.0

    return discount

print("--- Test 1: Valid ---")
result = find_discount(101, "gold")
print(f"Result: {result}")
print()
print("--- Test 2: Unknown product ---")
result = find_discount(999, "gold")
print(f"Result: {result}")

# %%
# Technique 2: breakpoint() — Python's built-in debugger (pdb)

print("breakpoint() usage:")
print()
print("  Add  breakpoint()  anywhere in your code.")
print("  When Python hits it, execution PAUSES.")
print("  You get a (Pdb) prompt where you can inspect state.")
print()
print("  Essential pdb commands:")
print("    n  (next)     - run the next line")
print("    s  (step)     - step INTO a function call")
print("    c  (continue) - run until next breakpoint")
print("    p expr        - print value of expression")
print("    l  (list)     - show source code around current line")
print("    w  (where)    - show the call stack")
print("    q  (quit)     - exit the debugger")
print()

example = """
def calculate_tax(income, rate):
    breakpoint()     # <-- Execution PAUSES here
    taxable = income * rate
    return round(taxable, 2)

tax = calculate_tax(50000, 0.22)
# At the (Pdb) prompt, type:
#   p income         # -> 50000
#   p rate           # -> 0.22
#   n                # run next line
#   p taxable        # -> 11000.0
#   c                # continue to finish
"""
print("Example code with breakpoint():")
print(example)

# %%
# Technique 3: logging — better than print for production code

import logging

logging.basicConfig(
    level=logging.DEBUG,
    format="%(levelname)s: %(message)s"
)
logger = logging.getLogger(__name__)

def process_order(order_id: int, items: list) -> dict:
    """Process an order and calculate the total."""
    logger.debug(f"Processing order {order_id} with {len(items)} items")

    if not items:
        logger.warning(f"Order {order_id} has no items!")
        return {"order_id": order_id, "total": 0, "status": "empty"}

    total = sum(item["price"] * item["quantity"] for item in items)
    logger.info(f"Order {order_id} total: ${total:.2f}")

    if total > 1000:
        logger.warning(f"Large order: ${total:.2f} — flagging for review")

    return {"order_id": order_id, "total": total, "status": "processed"}


order = process_order(1001, [
    {"name": "Laptop", "price": 999.99, "quantity": 1},
    {"name": "Mouse",  "price": 29.99,  "quantity": 2},
])
print(f"
Result: {order}")
print()
order2 = process_order(1002, [])
print(f"Result: {order2}")

# %% [markdown]
# ## 🧪 What If? Experimentation
#
# Let's explore the tricky edge cases in error handling:

# %%
# What If #1: Catching too broad an exception?

print("=== Danger of Broad Exception Catching ===
")

def dangerous_broad_catch():
    try:
        data = [1, 2, 3]
        result = data[10]   # IndexError — a real programming bug!
        return result
    except Exception:       # Catches EVERYTHING, including real bugs!
        print("  Something went wrong... (but you just hid a bug!)")
        return None

result = dangerous_broad_catch()
print(f"Result: {result}")
print("The IndexError is a PROGRAMMING MISTAKE — fix it, don't hide it.")
print()

# Best practices:
print("Better approaches:")

# Catch specific exceptions
def specific_catch():
    try:
        data = [1, 2, 3]
        return data[10]
    except IndexError:
        print("  Specific catch: IndexError handled, data too short")
        return None

specific_catch()

# Log and re-raise
def log_and_reraise():
    try:
        data = [1, 2, 3]
        return data[10]
    except Exception as e:
        print(f"  Logging: {type(e).__name__}: {e}")
        raise   # Re-raise the same exception — never swallow it silently

try:
    log_and_reraise()
except IndexError:
    print("  Caller handled the re-raised exception")

# %%
# What If #2: Raising an exception but never catching it?

print("=== Uncaught Exceptions ===
")

def validate_username(username: str) -> None:
    if len(username) < 3:
        raise ValueError(f"Username '{username}' too short (min 3 chars)")
    if not username.isalnum():
        raise ValueError(f"Username '{username}' must be alphanumeric")

# With handling — the caller catches it
print("With exception handling:")
try:
    validate_username("ab")
except ValueError as e:
    print(f"  Caught: {e}")

print()
print("Without handling:")
print("  Python prints the full traceback and EXITS the program.")
print("  In a web server -> the request fails with HTTP 500.")
print("  In a CLI script -> user sees red text, script stops.")
print()
print("  Rule: libraries let exceptions propagate (callers decide).")
print("  Rule: applications catch at the boundary (API handler / main).")

# %%
# What If #3: An exception is raised inside a finally block?

print("=== Exception in finally block ===
")

def careful_cleanup():
    print("  try: Starting operation...")
    try:
        raise ValueError("Primary operation failed")

    except ValueError as e:
        print(f"  except: Caught ValueError: {e}")
        raise   # Re-raise to propagate upward

    finally:
        print("  finally: Cleanup running...")
        # If we raised here it would REPLACE the original exception!
        # The ValueError would be lost and debugging becomes very hard.
        # NEVER raise in finally — just clean up quietly.
        # raise RuntimeError("Cleanup also failed!")  <- DON'T DO THIS

try:
    careful_cleanup()
except ValueError as e:
    print(f"  Caller: Original exception preserved: {e}")

print()
print("Rules for finally blocks:")
print("  DO:   close files, release locks, disconnect DBs")
print("  DO:   log that cleanup happened")
print("  NEVER: raise exceptions (swallows original error)")
print("  NEVER: use return (also swallows original exception!)")

# %% [markdown]
# ## 🚀 Real-World Project Link
#
# In our **File Processor project**, we'll use `try/except` to handle:
# - `FileNotFoundError` — gracefully report when input files are missing
# - `json.JSONDecodeError` — detect and report corrupted data files
# - `PermissionError` — alert users when output directories aren't writable
# - Custom `ProcessingError` exceptions to communicate domain-specific failures
#
# Robust error handling is what separates a script you run once from a tool you trust in production.
#
# ---

# %% [markdown]
# ## 📋 Chapter Summary & Cheat Sheet
#
# ### Key Takeaways
# - **Exceptions** signal "I can't do this" — don't fear them, handle them
# - **Read tracebacks bottom-to-top**: bottom = what failed, top = where it started
# - **Common exceptions**: `TypeError`, `ValueError`, `KeyError`, `IndexError`, `AttributeError`, `FileNotFoundError`
# - **`try/except/else/finally`**: try=attempt, except=fallback, else=success path, finally=always cleanup
# - **Raise exceptions** with `raise ValueError("message")` to communicate errors to callers
# - **Custom exceptions** make error handling precise and self-documenting
# - **EAFP** (try/except) is preferred over LBYL (if/check) in Python
# - **Don't catch too broadly** — specific exceptions first; log then re-raise if needed
# - **Debugging**: print() for quick checks, `breakpoint()` for interactive debugging, logging for production

# %%
# ==========================================
# CHAPTER 9 CHEAT SHEET
# ==========================================

# --- BASIC TRY/EXCEPT ---
try:
    result = 10 / 0
except ZeroDivisionError:
    result = None

# --- CATCH WITH INFO ---
try:
    int("abc")
except ValueError as e:
    print(f"Error: {e}")

# --- MULTIPLE EXCEPTIONS ---
try:
    value = int("hello")
except ValueError:
    print("Bad value")
except TypeError:
    print("Wrong type")

# --- FULL FORM ---
try:
    data = open("file.txt").read()
except FileNotFoundError:
    data = ""               # fallback
else:
    print("File read OK")   # only if no exception
finally:
    print("Always runs")    # cleanup

# --- RAISING ---
def set_age(age):
    if age < 0:
        raise ValueError(f"Age cannot be negative: {age}")

# --- CUSTOM EXCEPTIONS ---
class InsufficientFundsError(ValueError):
    def __init__(self, amount, balance):
        super().__init__(f"Need ${amount}, have ${balance}")
        self.shortfall = amount - balance

try:
    raise InsufficientFundsError(100, 50)
except InsufficientFundsError as e:
    print(f"Caught: {e}")
    print(f"Shortfall: ${e.shortfall}")

# --- EAFP (Python preferred) ---
def get_value(d, key, default=None):
    try:
        return d[key]
    except KeyError:
        return default

print(get_value({"x": 1}, "x"))      # 1
print(get_value({"x": 1}, "y", 0))   # 0

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='8.%20code_style_and_quality.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 8: Code Style</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='10.%20testing_and_quality_assurance.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 10: Testing →</a>
# </div>

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='8. code_style_and_quality.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='10. testing_and_quality_assurance.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
