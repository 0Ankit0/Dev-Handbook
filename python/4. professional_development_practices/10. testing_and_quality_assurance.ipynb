# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='9.%20error_handling_and_debugging.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 9: Error Handling</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../5.%20advanced_python_features/11.%20iterators_generators_and_decorators.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 11: Iterators & Generators →</a>
# </div>
#
# ---

# %% [markdown]
# # Chapter 10: Testing and Quality Assurance
# ## Proving Your Code Works
#
# ---

# %% [markdown]
# ## 🌍 The Big Picture
#
# Imagine a team of civil engineers building a bridge. They design it, construct it, and on opening day, trucks start driving over it.
#
# But they never load-tested it. Never put weight on it to see how it held up.
#
# Would you drive your car over that bridge?
#
# **Tests are the load tests for your code.** They let you make changes confidently, knowing that if something breaks, you'll be alerted immediately — before users see it.
#
# > 💡 **Real-world scenario:** You have a shopping cart module. It works perfectly. A teammate adds a 10% loyalty discount feature. It works too — but it accidentally changes how tax is calculated. Without tests, you ship both to production and customers get overcharged. With tests, the tax calculation test fails immediately, and you catch the bug before it ships.
# >
# > **Tests are your safety net for change.**
#
# ---

# %% [markdown]
# ## 🧠 Core Concepts: The "Why"
#
# ### Without vs. With Tests
#
# Testing concepts stick better when you remember the purpose behind each step: create evidence that the behavior you care about still works, and learn quickly when it stops working.
#
# | Without Tests | With Tests |
# |--------------|-----------|
# | Every change is scary | Refactor with confidence |
# | Bugs discovered by users in production | Bugs caught before shipping |
# | Manual testing before every release | Automated: one command, all verified |
# | "Does this still work?" | "All 247 tests passed ✅" |
# | Fear of changing legacy code | Tests document expected behavior |
# ### Tests as Living Documentation
#
# Tests are also **living documentation**. A test named `test_apply_discount_with_expired_coupon_returns_zero` tells you exactly what the function should do in that edge case — more precisely than any comment ever could.
#
# ### The Testing Pyramid
#
# The **Testing Pyramid** is a guideline for how many of each test type to write. Unit tests form the base — they're fast, isolated, and cheap to run. Integration tests verify how components talk to each other. End-to-end tests check the full user journey but are slow and expensive. Build a wide base of unit tests first.
#
# ```text
#         /\
#        /  \     <- End-to-end tests (few, slow, expensive)
#       /----\
#      /      \   <- Integration tests (test how parts work together)
#     /--------\
#    /          \ <- Unit tests (many, fast, cheap — our focus!)
# ```
#
# We'll focus on **unit tests** — the foundation everything else rests on.
#
# ---

# %% [markdown]
# ## 📖 Syntax & First Usage: What Are We Testing?
#
# Let's start with code we want to test. We'll build a simple calculator module and write tests for it.
#
# > 🔑 **The mental model:** For every function, ask: "What should this return? What edge cases exist? What should happen with bad input?" Each answer becomes a test.

# %%
# Our "production code" — the functions we want to test
# In a real project, this would live in: calculator.py

def add(a: float, b: float) -> float:
    """Return the sum of a and b."""
    return a + b

def subtract(a: float, b: float) -> float:
    """Return a minus b."""
    return a - b

def multiply(a: float, b: float) -> float:
    """Return the product of a and b."""
    return a * b

def divide(a: float, b: float) -> float:
    """Return a divided by b.

    Raises:
        ZeroDivisionError: If b is zero.
    """
    if b == 0:
        raise ZeroDivisionError("Cannot divide by zero")
    return a / b

def percentage(value: float, total: float) -> float:
    """Return value as a percentage of total.

    Raises:
        ZeroDivisionError: If total is zero.
        ValueError: If either argument is negative.
    """
    if total == 0:
        raise ZeroDivisionError("Total cannot be zero")
    if value < 0 or total < 0:
        raise ValueError("Values must be non-negative")
    return (value / total) * 100


# Quick sanity check
print(add(3, 4))            # 7
print(subtract(10, 3))      # 7
print(multiply(4, 5))       # 20
print(divide(15, 3))        # 5.0
print(percentage(25, 100))  # 25.0

# %% [markdown]
# ## 🧪 unittest — Python's Built-in Testing Framework
#
# Python ships with `unittest` in the standard library — no installation needed.
#
# ### Structure
#
# Every `unittest` test follows the **Arrange-Act-Assert** pattern: set up your inputs (Arrange), call the function under test (Act), then verify the result (Assert). Once you see that pattern in each test method, any `unittest` class becomes easy to read and extend.
#
# - Create a class that inherits from `unittest.TestCase`
# - Each test is a method starting with `test_`
# - Use `self.assert*` methods to check outcomes
# - Run with `python -m unittest test_file.py`
# ### Pattern
#
# Here is the basic template every `unittest` test class follows. The class name describes the component under test; each method name describes the exact behavior being verified:
#
# ```python
# class TestMyFunction(unittest.TestCase):
#     def test_some_behavior(self):
#         result = my_function(input)
#         self.assertEqual(result, expected_output)
# ```
#
# > ❓ **Why use classes instead of just functions?** Classes bundle related data (attributes) and behaviour (methods) into one unit. In large codebases this makes code easier to navigate, test, and reuse because each class has a single clear responsibility.

# %%
import unittest

# Calculator functions (defined above, repeated here for clarity)
def add(a, b): return a + b
def subtract(a, b): return a - b
def multiply(a, b): return a * b
def divide(a, b):
    if b == 0: raise ZeroDivisionError("Cannot divide by zero")
    return a / b
def percentage(value, total):
    if total == 0: raise ZeroDivisionError("Total cannot be zero")
    if value < 0 or total < 0: raise ValueError("Values must be non-negative")
    return (value / total) * 100


class TestCalculator(unittest.TestCase):
    """Test suite for the calculator module."""

    # --- add() tests ---
    def test_add_two_positive_numbers(self):
        result = add(3, 4)
        self.assertEqual(result, 7)

    def test_add_negative_numbers(self):
        self.assertEqual(add(-3, -4), -7)

    def test_add_zero_identity(self):
        """Adding zero should not change the value."""
        self.assertEqual(add(5, 0), 5)
        self.assertEqual(add(0, 5), 5)

    def test_add_floats(self):
        # Use assertAlmostEqual for floats — floating point is imprecise!
        self.assertAlmostEqual(add(1.1, 2.2), 3.3, places=10)

    # --- subtract() tests ---
    def test_subtract_positive_result(self):
        self.assertEqual(subtract(10, 3), 7)

    def test_subtract_to_negative(self):
        self.assertEqual(subtract(3, 10), -7)

    # --- multiply() tests ---
    def test_multiply_positive(self):
        self.assertEqual(multiply(4, 5), 20)

    def test_multiply_by_zero(self):
        self.assertEqual(multiply(100, 0), 0)

    def test_multiply_two_negatives_gives_positive(self):
        self.assertEqual(multiply(-3, -4), 12)

    # --- divide() tests ---
    def test_divide_evenly(self):
        self.assertEqual(divide(15, 3), 5.0)

    def test_divide_with_remainder(self):
        self.assertAlmostEqual(divide(10, 3), 3.33333, places=4)

    def test_divide_by_zero_raises_exception(self):
        """divide() must raise ZeroDivisionError when b is zero."""
        with self.assertRaises(ZeroDivisionError):
            divide(10, 0)

    # --- percentage() tests ---
    def test_percentage_basic(self):
        self.assertEqual(percentage(25, 100), 25.0)

    def test_percentage_zero_total_raises(self):
        with self.assertRaises(ZeroDivisionError):
            percentage(5, 0)

    def test_percentage_negative_raises(self):
        with self.assertRaises(ValueError):
            percentage(-5, 100)


# Run the tests
loader = unittest.TestLoader()
suite = loader.loadTestsFromTestCase(TestCalculator)
runner = unittest.TextTestRunner(verbosity=2)
result = runner.run(suite)

# %% [markdown]
# ### unittest Assertion Methods — Your Verification Toolkit
#
# Choosing the right assertion gives you a precise failure message. `assertEqual(result, 5)` reports `3 != 5` — you know immediately what went wrong. `assertTrue(result == 5)` only says `False is not true` — far less helpful. Always use the most specific assertion available:
#
# | Method | What it checks |
# |--------|---------------|
# | `assertEqual(a, b)` | `a == b` |
# | `assertNotEqual(a, b)` | `a != b` |
# | `assertTrue(x)` | `bool(x) is True` |
# | `assertFalse(x)` | `bool(x) is False` |
# | `assertIsNone(x)` | `x is None` |
# | `assertIsNotNone(x)` | `x is not None` |
# | `assertIn(a, b)` | `a in b` |
# | `assertRaises(Exc)` | Block raises that exception |
# | `assertAlmostEqual(a, b)` | Floats equal within tolerance |
# | `assertGreater(a, b)` | `a > b` |
# | `assertIsInstance(a, T)` | `isinstance(a, T)` |

# %%
class TestAssertionMethods(unittest.TestCase):

    def test_basic_equality(self):
        self.assertEqual(2 + 2, 4)
        self.assertNotEqual(2 + 2, 5)

    def test_boolean_assertions(self):
        self.assertTrue([1, 2, 3])    # Non-empty list is truthy
        self.assertFalse([])          # Empty list is falsy
        self.assertTrue(5 > 3)

    def test_membership(self):
        fruits = ["apple", "banana", "cherry"]
        self.assertIn("banana", fruits)
        self.assertNotIn("grape", fruits)

    def test_none_check(self):
        result = {"key": "value"}.get("nonexistent")
        self.assertIsNone(result)

    def test_float_comparison(self):
        # CRITICAL: NEVER use assertEqual for floats!
        # 0.1 + 0.2 is NOT 0.3 in floating point arithmetic
        self.assertNotEqual(0.1 + 0.2, 0.3)        # This PASSES (they differ!)
        self.assertAlmostEqual(0.1 + 0.2, 0.3, places=10)  # Correct approach

    def test_type_check(self):
        self.assertIsInstance(42, int)
        self.assertIsInstance("hello", str)
        self.assertIsInstance([1, 2], list)

    def test_exception_with_message(self):
        with self.assertRaises(ValueError) as ctx:
            int("abc")
        # Inspect the exception message
        self.assertIn("invalid literal", str(ctx.exception))


loader = unittest.TestLoader()
suite = loader.loadTestsFromTestCase(TestAssertionMethods)
runner = unittest.TextTestRunner(verbosity=2)
runner.run(suite)

# %% [markdown]
# ## ⚡ pytest — The Modern Testing Framework
#
# `pytest` is the industry-standard testing framework. It's preferred because:
# - **Simpler syntax** — just write functions, no class required
# - **Better failure output** — shows exact values that didn't match
# - **More powerful** — fixtures, parametrize, plugins ecosystem
# - **Uses plain `assert`** — no need to learn 20 different `assert*` methods
#
# ```bash
# pip install pytest
#
# # Run tests
# pytest test_calculator.py
# pytest test_calculator.py -v    # verbose output
# ```

# %%
# pytest style — same tests, dramatically less boilerplate

# In a real project: test_calculator.py
# from calculator import add, subtract, multiply, divide, percentage

# Re-define functions for this notebook
def add(a, b): return a + b
def subtract(a, b): return a - b
def multiply(a, b): return a * b
def divide(a, b):
    if b == 0: raise ZeroDivisionError("Cannot divide by zero")
    return a / b
def percentage(value, total):
    if total == 0: raise ZeroDivisionError("Total cannot be zero")
    if value < 0 or total < 0: raise ValueError("Values must be non-negative")
    return (value / total) * 100

# pytest tests: just functions with plain assert
def test_add_positive_numbers():
    assert add(3, 4) == 7

def test_add_negative():
    assert add(-3, -4) == -7

def test_add_zero_identity():
    assert add(5, 0) == 5
    assert add(0, 5) == 5

def test_subtract():
    assert subtract(10, 3) == 7
    assert subtract(3, 10) == -7

def test_multiply():
    assert multiply(4, 5) == 20
    assert multiply(100, 0) == 0

def test_divide_evenly():
    assert divide(15, 3) == 5.0

def test_divide_by_zero_raises():
    import pytest
    with pytest.raises(ZeroDivisionError):
        divide(10, 0)

def test_percentage_basic():
    assert percentage(25, 100) == 25.0

def test_percentage_zero_total():
    import pytest
    with pytest.raises(ZeroDivisionError):
        percentage(5, 0)

# Simulate running them (what pytest does automatically)
import traceback

tests = [
    test_add_positive_numbers, test_add_negative, test_add_zero_identity,
    test_subtract, test_multiply, test_divide_evenly,
    test_divide_by_zero_raises, test_percentage_basic, test_percentage_zero_total,
]

passed = failed = 0
for test in tests:
    try:
        test()
        print(f"  PASSED  {test.__name__}")
        passed += 1
    except Exception as e:
        print(f"  FAILED  {test.__name__}: {e}")
        failed += 1

print(f"
{passed} passed, {failed} failed")

# %% [markdown]
# ## 🆚 unittest vs. pytest — Side by Side
#
# Let's write the exact same test in both frameworks:

# %%
import unittest

# =====================================================
# unittest style
# =====================================================
class TestDivideUnittest(unittest.TestCase):
    def test_divide_by_zero(self):
        with self.assertRaises(ZeroDivisionError) as ctx:
            divide(10, 0)
        self.assertEqual(str(ctx.exception), "Cannot divide by zero")

    def test_divide_returns_float(self):
        result = divide(10, 4)
        self.assertEqual(result, 2.5)
        self.assertIsInstance(result, float)

    def test_negative_division(self):
        self.assertEqual(divide(-10, 2), -5.0)
        self.assertEqual(divide(10, -2), -5.0)
        self.assertEqual(divide(-10, -2), 5.0)

# =====================================================
# pytest style — same logic, less code
# =====================================================
import pytest

def test_divide_by_zero():
    with pytest.raises(ZeroDivisionError, match="Cannot divide by zero"):
        divide(10, 0)

def test_divide_returns_float():
    result = divide(10, 4)
    assert result == 2.5
    assert isinstance(result, float)

def test_negative_division():
    assert divide(-10, 2) == -5.0
    assert divide(10, -2) == -5.0
    assert divide(-10, -2) == 5.0

# Run both to show identical results
print("=== unittest ===")
loader = unittest.TestLoader()
suite = loader.loadTestsFromTestCase(TestDivideUnittest)
runner = unittest.TextTestRunner(verbosity=2)
runner.run(suite)

print("
=== pytest style (manual run) ===")
for test in [test_divide_by_zero, test_divide_returns_float, test_negative_division]:
    try:
        test()
        print(f"  PASSED  {test.__name__}")
    except Exception as e:
        print(f"  FAILED  {test.__name__}: {e}")

print("
Both give the same results. pytest wins on readability!")

# %% [markdown]
# ## 🔴→🟢🔵 Test-Driven Development (TDD)
#
# **TDD** = Write the test FIRST, then write the code that makes it pass.
#
# ### The Red-Green-Refactor Cycle
#
# Each phase has a strict purpose. **Red**: write a test for behavior that does not exist yet — it *must* fail, which confirms the test is actually checking something real. **Green**: write the *minimum* code to make the test pass (no more). **Refactor**: clean up the code while your passing tests prove nothing broke:
#
# ```text
# 🔴 RED       Write a failing test (the feature doesn't exist yet)
# 🟢 GREEN     Write the MINIMUM code to make it pass
# 🔵 REFACTOR  Clean up while keeping all tests green
# ```
# ### Why TDD?
#
# - Forces you to think about the interface BEFORE implementation
# - Every line you write is tested immediately
# - Natural documentation of expected behavior
# - Encourages small, focused functions

# %%
# TDD Walk-Through: Password Strength Checker

print("=== TDD: Password Strength Checker ===
")

# ============================================================
# STEP 1: RED — Write tests first (function does not exist yet)
# ============================================================

# Our requirements (written as tests before any code):
def test_too_short():
    assert is_strong_password("Ab1!") == False

def test_no_uppercase():
    assert is_strong_password("abcdef1!") == False

def test_no_digit():
    assert is_strong_password("Abcdefg!") == False

def test_no_special_char():
    assert is_strong_password("Abcdef12") == False

def test_valid_password():
    assert is_strong_password("Secure1!") == True

def test_another_valid():
    assert is_strong_password("MyP@ssw0rd") == True

# These tests currently FAIL because the function doesn't exist
print("Tests written. Now implementing the function...")
print()

# ============================================================
# STEP 2: GREEN — Write minimum code to make tests pass
# ============================================================

def is_strong_password(password: str) -> bool:
    """Return True if password meets all strength requirements."""
    if len(password) < 8:
        return False
    if not any(c.isupper() for c in password):
        return False
    if not any(c.isdigit() for c in password):
        return False
    if not any(c in "!@#$%^&*()_+-=[]{}|;:,.<>?" for c in password):
        return False
    return True

# Run the tests — should all pass now!
all_tests = [
    test_too_short, test_no_uppercase, test_no_digit,
    test_no_special_char, test_valid_password, test_another_valid,
]

all_passed = True
for test in all_tests:
    try:
        test()
        print(f"  [GREEN] {test.__name__}")
    except AssertionError:
        print(f"  [RED]   {test.__name__} FAILED")
        all_passed = False

print()
print("All green!" if all_passed else "Some tests still failing!")

# %%
# ============================================================
# STEP 3: REFACTOR — Clean up while keeping all tests green
# ============================================================

def is_strong_password(password: str) -> bool:
    """Return True if password meets all strength requirements.

    A strong password must:
    - Be at least 8 characters
    - Contain at least one uppercase letter
    - Contain at least one digit
    - Contain at least one special character (!@#$%^&* etc.)

    Args:
        password: The password string to evaluate.

    Returns:
        True if all requirements are met, False otherwise.
    """
    SPECIAL_CHARS = "!@#$%^&*()_+-=[]{}|;:,.<>?"
    MIN_LENGTH = 8

    checks = {
        "length":    len(password) >= MIN_LENGTH,
        "uppercase": any(c.isupper() for c in password),
        "digit":     any(c.isdigit() for c in password),
        "special":   any(c in SPECIAL_CHARS for c in password),
    }

    return all(checks.values())


# Re-run ALL tests to verify refactoring did not break anything
print("=== After Refactor: Re-running all tests ===
")

all_tests = [
    test_too_short, test_no_uppercase, test_no_digit,
    test_no_special_char, test_valid_password, test_another_valid,
]

for test in all_tests:
    try:
        test()
        print(f"  [GREEN] {test.__name__}")
    except AssertionError:
        print(f"  [RED]   {test.__name__} FAILED — refactoring broke something!")

print()
print("Refactored and all tests still green!")
print()

# Bonus: the checks dict enables useful diagnostic feedback
def password_feedback(password: str) -> dict:
    SPECIAL_CHARS = "!@#$%^&*()_+-=[]{}|;:,.<>?"
    return {
        "length >= 8":    len(password) >= 8,
        "has uppercase":  any(c.isupper() for c in password),
        "has digit":      any(c.isdigit() for c in password),
        "has special":    any(c in SPECIAL_CHARS for c in password),
    }

print("Feedback for 'weak':")
for k, v in password_feedback("weak").items():
    print(f"  {'OK' if v else 'FAIL'}  {k}")

print("
Feedback for 'Secure1!':")
for k, v in password_feedback("Secure1!").items():
    print(f"  {'OK' if v else 'FAIL'}  {k}")

# %% [markdown]
# ## 🔧 pytest Power Features: Parametrize and Fixtures
#
# Two features that dramatically reduce test code duplication:
#
# ### `@pytest.mark.parametrize` — Test Many Inputs at Once
# Instead of writing 10 separate test functions for 10 inputs, write one parametrized test that runs against all inputs automatically.
#
# ### Fixtures — Shared Setup Code
# Fixtures provide test data or objects that multiple tests need, eliminating repetitive setup.

# %%
# Demonstrating parametrize concept

# Without parametrize — repetitive and error-prone
def test_add_case_1(): assert add(3, 4) == 7
def test_add_case_2(): assert add(-3, 4) == 1
def test_add_case_3(): assert add(0, 0) == 0

# With @pytest.mark.parametrize — one function, many cases:
#
# @pytest.mark.parametrize("a, b, expected", [
#     (3,    4,    7),
#     (-3,   4,    1),
#     (0,    0,    0),
#     (100, -100,  0),
#     (0.5,  0.5,  1.0),
#     (1000, 1000, 2000),
# ])
# def test_add_parametrized(a, b, expected):
#     assert add(a, b) == expected

# Simulating what parametrize does behind the scenes:
parametrize_cases = [
    (3,    4,    7,    "positive + positive"),
    (-3,   4,    1,    "negative + positive"),
    (0,    0,    0,    "zero + zero"),
    (100, -100,  0,    "sum to zero"),
    (0.5,  0.5,  1.0,  "floats"),
]

print("Parametrized test run:")
for a, b, expected, description in parametrize_cases:
    result = add(a, b)
    status = "PASSED" if result == expected else "FAILED"
    print(f"  [{status}]  add({a}, {b}) == {expected}  ({description})")

print()
print("5 scenarios tested with one logical test function!")

# %%
# Demonstrating fixtures concept

# Without fixtures — setup code repeated in every test
import unittest

class TestCartNoFixture(unittest.TestCase):
    def test_add_item(self):
        cart = {"items": [], "total": 0.0}   # Setup repeated!
        cart["items"].append({"name": "Apple", "price": 0.99})
        cart["total"] += 0.99
        self.assertEqual(len(cart["items"]), 1)

    def test_total(self):
        cart = {"items": [], "total": 0.0}   # Setup repeated again!
        cart["items"].append({"name": "Apple", "price": 0.99})
        cart["total"] += 0.99
        self.assertAlmostEqual(cart["total"], 0.99, places=2)

# With pytest fixtures — defined once, injected automatically:
#
# @pytest.fixture
# def empty_cart():
#     return {"items": [], "total": 0.0}
#
# @pytest.fixture
# def cart_with_items(empty_cart):
#     for item in [{"name": "Apple", "price": 0.99}, {"name": "Banana", "price": 0.59}]:
#         empty_cart["items"].append(item)
#         empty_cart["total"] += item["price"]
#     return empty_cart
#
# def test_cart_has_two_items(cart_with_items):
#     assert len(cart_with_items["items"]) == 2
#
# def test_cart_total(cart_with_items):
#     assert round(cart_with_items["total"], 2) == 1.58

# Simulating fixture pattern:
def make_cart_with_items():
    """Factory function acting as a fixture."""
    cart = {"items": [], "total": 0.0}
    for item in [{"name": "Apple", "price": 0.99}, {"name": "Banana", "price": 0.59}]:
        cart["items"].append(item)
        cart["total"] += item["price"]
    return cart

print("Fixture simulation:")
cart = make_cart_with_items()
print(f"  Items: {len(cart['items'])}")
print(f"  Total: ${cart['total']:.2f}")

assert len(cart["items"]) == 2
assert round(cart["total"], 2) == 1.58
print("  Both assertions pass!")

# %% [markdown]
# ## 📊 Code Coverage — How Much of Your Code Is Tested?
#
# **Code coverage** measures what percentage of your code is actually executed during test runs. High coverage means fewer untested code paths, which means fewer surprise bugs.
#
# ```bash
# pip install pytest-cov
#
# # Generate coverage report in terminal
# pytest --cov=calculator test_calculator.py
#
# # Generate HTML report (open htmlcov/index.html)
# pytest --cov=calculator --cov-report=html test_calculator.py
# ```
#
# Sample coverage output:
# ```text
# ----------- coverage: python 3.11 -----------
# Name             Stmts   Miss  Cover
# ------------------------------------
# calculator.py       20      2    90%
# TOTAL               20      2    90%
# ```
#
# > 🎯 **100% coverage ≠ bug-free.** It means every line was executed — not every edge case was tested. Aim for **80%+** on critical business logic. Don't chase 100% at the expense of writing meaningful tests.

# %%
# Demonstrating coverage concepts with branch analysis

def classify_triangle(a: float, b: float, c: float) -> str:
    """Classify a triangle by its side lengths.

    Returns: "equilateral", "isosceles", "scalene", or "invalid"
    """
    if a <= 0 or b <= 0 or c <= 0:
        return "invalid"
    if a + b <= c or a + c <= b or b + c <= a:
        return "invalid"

    if a == b == c:
        return "equilateral"
    elif a == b or b == c or a == c:
        return "isosceles"
    else:
        return "scalene"


# Tests that achieve close to 100% branch coverage
test_cases = [
    (3, 3, 3,   "equilateral",   "all sides equal"),
    (3, 3, 4,   "isosceles",     "two sides equal"),
    (3, 4, 5,   "scalene",       "all sides different"),
    (0, 3, 3,   "invalid",       "zero side"),
    (-1, 3, 3,  "invalid",       "negative side"),
    (1, 2, 10,  "invalid",       "violates triangle inequality"),
]

print("Branch coverage test run:")
print(f"{'Input':<15} {'Expected':<15} {'Got':<15} Status")
print("-" * 60)
all_passed = True
for a, b, c, expected, desc in test_cases:
    got = classify_triangle(a, b, c)
    ok = got == expected
    if not ok: all_passed = False
    print(f"  ({a},{b},{c}) {desc:<20} {expected:<14} {got:<14} {'OK' if ok else 'FAIL'}")

print()
branches_covered = [
    "a<=0 or b<=0 or c<=0      (invalid: zero/negative side)",
    "a+b<=c or similar         (invalid: triangle inequality)",
    "a == b == c               (equilateral)",
    "a==b or b==c or a==c      (isosceles)",
    "else                      (scalene)",
]
print("Branches covered:")
for b in branches_covered:
    print(f"  [OK]  {b}")

# %% [markdown]
# ## 🧪 What If? Experimentation
#
# Let's explore tricky testing scenarios:

# %%
# What If #1: A test fails — how do you read the output?

def buggy_multiply(a, b):
    return a * b + 1    # Bug: accidentally adds 1!

print("=== Simulating a test failure ===
")

try:
    result = buggy_multiply(3, 4)
    assert result == 12, f"Expected 12, got {result}"
except AssertionError as e:
    print(f"AssertionError: {e}")
    print()
    print("What pytest would show:")
    print("  FAILED tests/test_calc.py::test_multiply")
    print("  __________________________________________")
    print()
    print("  def test_multiply():")
    print("      result = buggy_multiply(3, 4)")
    print(">     assert result == 12")
    print("  E   AssertionError: assert 13 == 12")
    print("  E   Expected 12, got 13")
    print()
    print("Reading the output:")
    print("  1. FAILED test name -> tells you WHICH test failed")
    print("  2. The > line       -> the exact assertion that failed")
    print("  3. E lines          -> the actual vs expected values")
    print("  4. These 3 pieces point you directly to the bug!")

# %%
# What If #2: Testing a function with randomness?

import random
from unittest.mock import patch

def roll_dice(sides: int = 6) -> int:
    """Simulate rolling a die with the given number of sides."""
    return random.randint(1, sides)

def is_critical_hit(roll: int, threshold: int = 20) -> bool:
    """Return True if the roll reaches or exceeds the threshold."""
    return roll >= threshold

print("=== Testing non-deterministic code ===
")

# Method 1: Mock random to return a controlled value
print("Method 1: Mock the random function")
with patch("random.randint", return_value=20):
    result = roll_dice(20)
    assert result == 20
    print(f"  Mocked roll: {result} — test is deterministic!")

# Method 2: Test the deterministic parts directly
print("
Method 2: Test what you CAN control")
assert is_critical_hit(20) == True
assert is_critical_hit(21) == True
assert is_critical_hit(19) == False
print("  Critical hit logic tested without any randomness!")

# Method 3: Statistical test (for range validation)
print("
Method 3: Statistical range test")
results = [roll_dice(6) for _ in range(1000)]
assert all(1 <= r <= 6 for r in results), "Got out-of-range roll!"
print(f"  1000 rolls: min={min(results)}, max={max(results)} — all in range 1-6")

print()
print("Key insight: mock external dependencies (random, APIs, databases)")
print("to make tests fast, deterministic, and independent.")

# %%
# What If #3: Code with no tests needs to be refactored?

print("=== Legacy Code: Safe Refactoring Approach ===
")

# You inherit this. It works, but no one knows exactly HOW.
def legacy_process(data):
    r = []
    for x in data:
        if x > 0:
            if x % 2 == 0:
                r.append(x * 2)
            else:
                r.append(x * 3)
        elif x < 0:
            r.append(abs(x))
    return r

# Step 1: Discover and document the behavior BEFORE touching anything
print("Step 1: Characterize existing behavior")
test_inputs = [[1, 2, 3, 4, -1, -2, 0], [10, -5, 7], []]
for inp in test_inputs:
    print(f"  Input: {inp!s:<25} -> Output: {legacy_process(inp)}")

# Step 2: Write "golden tests" that lock in current behavior
print("
Step 2: Write golden tests")
def test_positive_even_doubled():    assert legacy_process([2]) == [4]
def test_positive_odd_tripled():     assert legacy_process([3]) == [9]
def test_negative_to_absolute():     assert legacy_process([-5]) == [5]
def test_zero_excluded():            assert legacy_process([0]) == []
def test_mixed_input():              assert legacy_process([1, 2, -3, 0]) == [3, 4, 3]

tests = [test_positive_even_doubled, test_positive_odd_tripled,
         test_negative_to_absolute, test_zero_excluded, test_mixed_input]
for t in tests:
    try:
        t()
        print(f"  [OK] {t.__name__}")
    except AssertionError as e:
        print(f"  [FAIL] {t.__name__}: {e}")

print()
print("Step 3: Refactor freely — tests catch any regressions immediately!")
print("Safety net is in place. You can now improve the code with confidence.")

# %% [markdown]
# ## 🚀 Real-World Project Link
#
# In our **Calculator project**, we'll write a test suite that:
# - Verifies every arithmetic operation works correctly
# - Tests edge cases (zero division, negative numbers, floating-point precision)
# - Uses `@pytest.mark.parametrize` to test dozens of input combinations efficiently
# - Achieves 95%+ code coverage before the project is considered "done"
#
# When we share this project — on GitHub, in a team, or as an open-source package — the test suite is **proof the code works** and a **guide for contributors** who want to understand expected behavior.
#
# ---

# %% [markdown]
# ## 📋 Chapter Summary & Cheat Sheet
#
# ### Key Takeaways
# - **Tests are your safety net** — they let you change code confidently
# - **Unit tests** test one function in isolation — the foundation of a test suite
# - **`unittest`** is built into Python — `TestCase` class + `self.assert*` methods
# - **`pytest`** is the modern standard — functions + plain `assert`, better output
# - **TDD**: Write failing test 🔴 → make it pass 🟢 → clean up 🔵
# - **Parametrize** tests many inputs with one test function
# - **Fixtures** provide reusable, fresh setup — eliminate repetition
# - **Mock** random/external dependencies for deterministic tests
# - **Coverage** measures tested lines — aim for 80%+ on critical code
# - **Failing test** = valuable information — it tells you exactly where the bug is

# %%
# ==========================================
# CHAPTER 10 CHEAT SHEET
# ==========================================

import unittest

# --- PRODUCTION CODE ---
def multiply(a, b):
    return a * b

# --- UNITTEST STYLE ---
class TestMultiply(unittest.TestCase):
    def test_positive_numbers(self):
        self.assertEqual(multiply(3, 4), 12)

    def test_multiply_by_zero(self):
        self.assertEqual(multiply(5, 0), 0)

    def test_negative_numbers(self):
        self.assertEqual(multiply(-3, -4), 12)

    def test_returns_number(self):
        self.assertIsInstance(multiply(2, 3), int)

# --- PYTEST STYLE (simpler!) ---
def test_multiply_positive_pytest():
    assert multiply(3, 4) == 12

def test_multiply_zero_pytest():
    assert multiply(5, 0) == 0

# --- ASSERTION QUICK REFERENCE ---
# assertEqual(a, b)         ->  a == b
# assertNotEqual(a, b)      ->  a != b
# assertTrue(x)             ->  bool(x) is True
# assertFalse(x)            ->  bool(x) is False
# assertIsNone(x)           ->  x is None
# assertIn(a, b)            ->  a in b
# assertRaises(Exc)         ->  block raises Exc
# assertAlmostEqual(a, b)   ->  floats equal within tolerance

# --- TDD CYCLE ---
# 1. Write failing test (RED)
# 2. Write minimum code to pass (GREEN)
# 3. Refactor while keeping green (REFACTOR)

# --- RUNNING TESTS ---
# python -m unittest test_file.py
# pytest test_file.py
# pytest test_file.py -v                -> verbose
# pytest --cov=mymodule test_file.py   -> with coverage

loader = unittest.TestLoader()
suite = loader.loadTestsFromTestCase(TestMultiply)
runner = unittest.TextTestRunner(verbosity=2)
runner.run(suite)

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='9.%20error_handling_and_debugging.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 9: Error Handling</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../5.%20advanced_python_features/11.%20iterators_generators_and_decorators.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 11: Iterators & Generators →</a>
# </div>
