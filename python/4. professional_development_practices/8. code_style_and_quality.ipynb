# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../3.%20object_oriented_programming/7.%20advanced_oop_concepts.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 7: Advanced OOP</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='9.%20error_handling_and_debugging.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 9: Error Handling →</a>
# </div>
#
# ---

# %% [markdown]
# # Chapter 8: Code Style and Quality
# ## Writing Code That Others — and Future You — Can Read
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ---

# %% [markdown]
# ## 🌍 The Big Picture
#
# Imagine you receive a set of IKEA assembly instructions — but there are **no diagrams, no step numbers**, and all the text is crammed onto one continuous line with random abbreviations.
#
# Technically complete. Practically useless.
#
# Now imagine the **well-illustrated, step-by-step version** with clear labels, logical groupings, and helpful diagrams. Same furniture. Completely different experience.
#
# **That's the difference between poorly styled code and well-styled code.**
#
# > 💡 **Real-world story:** You wrote a script six months ago. Your manager asks you to add one feature. You open the file and stare. Variable names like `d`, `tmp2`, `x_final`. Functions 200 lines long. No comments, no structure. You spend 3 hours just *understanding* your own code before writing a single line.
# >
# > Good style is **a letter to future you** — and to every teammate who will ever touch your code.
#
# ---

# %% [markdown]
# ## 🧠 Core Concepts: The "Why"
#
# The easiest way to read this section is to keep one plain-language question in view: what is The "Why" actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### Why does code style matter?
#
# Code is **read far more often than it is written**. Studies suggest developers spend **10x more time reading code than writing it**.
#
# Style matters because:
#
# - 🤝 **Collaboration** — teammates can understand your code without asking you
# - 🐛 **Debugging** — well-structured code makes bugs easier to spot
# - 🔧 **Maintenance** — adding features to readable code is faster and safer
# - 💼 **Professionalism** — clean code signals engineering maturity
#
# ### The Analogy: Code as Communication
#
# Think of your code as a **newspaper article**:
# - The **headline** is your function/class name — clear and descriptive
# - The **first paragraph** is your docstring — summarizing what it does
# - The **body** is your logic — structured and easy to scan
# - **No one wants to read a wall of text** with no paragraphs
#
# ---

# %% [markdown]
# ## 📖 Syntax & First Usage: PEP 8 — Python's Style Bible
#
# **PEP 8** is Python's official style guide. It's not enforced by the interpreter, but it IS the universal convention used by virtually every Python project in the world.
#
# **PEP = Python Enhancement Proposal** — documents that propose changes or define standards for Python.
#
# Let's walk through the key rules one by one.

# %% [markdown]
# ### Rule 1: Naming Conventions
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# | What | Convention | Example |
# |------|-----------|---------|
# | Variables & functions | `snake_case` | `user_name`, `calculate_total()` |
# | Classes | `PascalCase` | `BankAccount`, `UserProfile` |
# | Constants | `UPPER_CASE` | `MAX_RETRIES`, `PI` |
# | Private attributes | `_leading_underscore` | `_internal_count` |
# | "Really private" | `__double_underscore` | `__secret` |

# %%
# ✅ Good naming — instantly readable
user_age = 25
MAX_LOGIN_ATTEMPTS = 3

def calculate_monthly_salary(annual_salary, tax_rate):
    return annual_salary * (1 - tax_rate) / 12

class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

# ❌ Bad naming — cryptic and confusing
ua = 25
mla = 3

def calc(s, t):
    return s * (1 - t) / 12

class BA:
    def __init__(self, o, b):
        self.o = o
        self.b = b

print("Both work identically — but only one is readable!")

# %% [markdown]
# ### Rule 2: Indentation — 4 Spaces (Not Tabs!)
#
# Python uses indentation to define code blocks. PEP 8 specifies **4 spaces** (not tabs, not 2 spaces).
#
# > 🔑 Most editors auto-convert Tab to 4 spaces. Always check your editor settings!

# %%
# ✅ Correct: 4 spaces per level
def greet(name):
    if name:
        print(f"Hello, {name}!")
    else:
        print("Hello, stranger!")

greet("Alice")
greet("")

# %% [markdown]
# ### Rule 3: Line Length — Maximum 79 Characters
#
# Why 79? Historical reasons (terminals were 80 chars wide), but also: **short lines are easier to read and allow side-by-side comparisons in code review tools**.
#
# For long expressions, break them up using parentheses:

# %%
# ❌ Too long — hard to read without scrolling
long_result = "some_very_long_variable_name" + "another_very_long_variable" + "yet_another_thing_here"

# ✅ Break it up using implicit line continuation inside parentheses
long_result = (
    "some_very_long_variable_name"
    + "another_very_long_variable"
    + "yet_another_thing_here"
)

# ✅ Long function calls — one argument per line for clarity
user_data = dict(
    name="Alice",
    age=30,
    email="alice@example.com",
    role="admin"
)
print(user_data)

# %% [markdown]
# ### Rule 4: Blank Lines — Breathing Room for Code
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - **2 blank lines** before and after top-level functions and classes
# - **1 blank line** between methods inside a class
# - Use blank lines to group related statements inside functions
#
# Blank lines signal "these things belong together" and "this is a new section."

# %%
# ✅ Proper spacing — count the blank lines!


def calculate_area(radius):
    return 3.14159 * radius ** 2


def calculate_circumference(radius):
    return 2 * 3.14159 * radius


class Circle:

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return calculate_area(self.radius)

    def circumference(self):
        return calculate_circumference(self.radius)


c = Circle(5)
print(f"Area:          {c.area():.2f}")
print(f"Circumference: {c.circumference():.2f}")

# %% [markdown]
# ### Rule 5: Spaces Around Operators and After Commas
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.

# %%
# ❌ Bad spacing — hard to parse visually
x=5
y=x+2
my_list=[1,2,3,4]
result=x*y+len(my_list)

# ✅ Good spacing — reads naturally
x = 5
y = x + 2
my_list = [1, 2, 3, 4]
result = x * y + len(my_list)

# ✅ Special case: no space around = in default arguments
def connect(host, port=8080, timeout=30):
    print(f"Connecting to {host}:{port} (timeout={timeout}s)")

connect("localhost")
connect("api.example.com", port=443)

# %% [markdown]
# ### Rule 6: Import Ordering
#
# Imports should be grouped in this order, with a blank line between groups:
# 1. **Standard library** (built into Python — no installation needed)
# 2. **Third-party packages** (installed with `pip`)
# 3. **Local/project modules** (your own files)
#
# Within each group, alphabetical order is preferred.

# %%
# ✅ Correct import ordering

# 1. Standard library
import os
import sys
from datetime import datetime
from pathlib import Path

# 2. Third-party (installed via pip)
# import numpy as np
# import pandas as pd
# import requests

# 3. Local modules
# from my_project import utils
# from my_project.models import User

print("Import ordering is enforced automatically by tools like 'isort'!")
print(f"Python version: {sys.version_info.major}.{sys.version_info.minor}")

# %% [markdown]
# ## 🔍 Deep Dive: Before vs. After PEP 8
#
# Let's look at a real transformation. **Same logic — dramatically different readability.**

# %%
# ❌ BEFORE: Written in a hurry, never cleaned up
# (This kind of code exists in real codebases everywhere)

def calcT(p,r,n,t):
    a=p*(1+r/n)**(n*t)
    i=a-p
    return a,i
x=1000
y=0.05
z=calcT(x,y,12,5)
print('amount:',z[0],'interest:',z[1])

# %%
# ✅ AFTER: PEP 8 compliant — same logic, dramatically more readable

MONTHS_PER_YEAR = 12


def calculate_compound_interest(
    principal: float,
    annual_rate: float,
    compounds_per_year: int,
    years: int
) -> tuple:
    """Calculate compound interest over a period of time.

    Args:
        principal: Initial investment amount in dollars.
        annual_rate: Annual interest rate as a decimal (e.g., 0.05 for 5%).
        compounds_per_year: Number of times interest compounds per year.
        years: Number of years the investment grows.

    Returns:
        A tuple of (final_amount, interest_earned).
    """
    final_amount = principal * (1 + annual_rate / compounds_per_year) ** (
        compounds_per_year * years
    )
    interest_earned = final_amount - principal
    return final_amount, interest_earned


initial_investment = 1_000.00   # Underscores in numbers improve readability!
interest_rate = 0.05

final_amount, interest_earned = calculate_compound_interest(
    principal=initial_investment,
    annual_rate=interest_rate,
    compounds_per_year=MONTHS_PER_YEAR,
    years=5
)

print(f"Initial investment: ${initial_investment:,.2f}")
print(f"Final amount:       ${final_amount:,.2f}")
print(f"Interest earned:    ${interest_earned:,.2f}")

# %% [markdown]
# ## 📝 Docstrings — Documentation Built Into Your Code
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# A **docstring** is a string literal that appears as the **first statement** in a module, function, class, or method. It becomes the object's `__doc__` attribute and powers the built-in `help()` function.
#
# > 💡 Think of a docstring as the **instruction manual** for your function — written once, readable forever.
# ### Google Style (Most Common in Modern Python)
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```python
# def function_name(param):
#     """One-line summary of what the function does.
#
#     Longer description if needed — explains context,
#     edge cases, or important behavior.
#
#     Args:
#         param: Description of the parameter.
#
#     Returns:
#         Description of what's returned.
#
#     Raises:
#         ValueError: When and why this is raised.
#
#     Examples:
#         >>> function_name(42)
#         84
#     """
# ```

# %%
# ❌ Without docstring — users must read the implementation to understand it
def process_temperature(temp, unit):
    if unit == "F":
        return (temp - 32) * 5 / 9
    elif unit == "C":
        return temp * 9 / 5 + 32
    else:
        raise ValueError("Unit must be 'F' or 'C'")


# ✅ With Google-style docstring — self-documenting
def convert_temperature(temperature: float, from_unit: str) -> float:
    """Convert temperature between Celsius and Fahrenheit.

    Args:
        temperature: The temperature value to convert.
        from_unit: The unit to convert FROM. Either "C" (Celsius)
                   or "F" (Fahrenheit).

    Returns:
        The converted temperature as a float.

    Raises:
        ValueError: If from_unit is not "C" or "F".

    Examples:
        >>> convert_temperature(100, "C")
        212.0
        >>> convert_temperature(32, "F")
        0.0
    """
    if from_unit == "C":
        return temperature * 9 / 5 + 32
    elif from_unit == "F":
        return (temperature - 32) * 5 / 9
    else:
        raise ValueError(f"Unit must be 'C' or 'F', got '{from_unit}'")


# The docstring powers help()!
help(convert_temperature)

# %%
# Docstrings work for classes too
class TemperatureConverter:
    """A utility class for temperature conversions.

    Supports Celsius <-> Fahrenheit conversions with
    configurable output precision.

    Attributes:
        precision: Number of decimal places for rounding results.

    Examples:
        >>> converter = TemperatureConverter(precision=1)
        >>> converter.celsius_to_fahrenheit(100)
        212.0
    """

    def __init__(self, precision: int = 2):
        """Initialize the converter with the specified precision.

        Args:
            precision: Decimal places to round to. Defaults to 2.
        """
        self.precision = precision

    def celsius_to_fahrenheit(self, celsius: float) -> float:
        """Convert Celsius to Fahrenheit."""
        result = celsius * 9 / 5 + 32
        return round(result, self.precision)

    def fahrenheit_to_celsius(self, fahrenheit: float) -> float:
        """Convert Fahrenheit to Celsius."""
        result = (fahrenheit - 32) * 5 / 9
        return round(result, self.precision)


converter = TemperatureConverter(precision=1)
print(f"100 C = {converter.celsius_to_fahrenheit(100)} F")
print(f"32  F = {converter.fahrenheit_to_celsius(32)} C")
print(f"37  C = {converter.celsius_to_fahrenheit(37)} F  (body temperature)")

# %% [markdown]
# ## 🏷️ Type Hints — Labels on Your Boxes
#
# **Type hints** let you annotate what types your function expects and returns. Python does **NOT** enforce them at runtime — they're for **humans and tooling** (IDEs, type checkers like `mypy`).
#
# > 🎁 **Analogy:** Imagine moving boxes. Without labels, you have to open every box to find what's inside. With labels (`KITCHEN`, `BOOKS`, `FRAGILE`), everything is clear at a glance. Type hints are labels for your code.
#
# ```python
# def function_name(param: type) -> return_type:
#     ...
# ```

# %%
# Basic type hints — the most common ones
def add(a: int, b: int) -> int:
    return a + b

def greet(name: str) -> str:
    return f"Hello, {name}!"

def is_adult(age: int) -> bool:
    return age >= 18

def get_average(numbers: list) -> float:
    return sum(numbers) / len(numbers) if numbers else 0.0

# Try them out
print(add(3, 4))                    # 7
print(greet("Alice"))               # Hello, Alice!
print(is_adult(20))                 # True
print(get_average([85, 92, 78]))    # 85.0

# Type hints do NOT enforce types at runtime — Python still runs this:
result = add("hello", "world")  # Works! But IDE and mypy will warn you.
print(result)  # "helloworld" — string concatenation instead of int addition

# %%
# More powerful type hints with the typing module
from typing import Optional, Union, List, Dict

def find_user(user_id: int) -> Optional[str]:
    """Return username if found, None otherwise.
    Optional[str] means the function returns str OR None.
    """
    users = {1: "alice", 2: "bob", 3: "charlie"}
    return users.get(user_id)

def parse_number(value: Union[int, str]) -> float:
    """Accept either int or str, always return float.
    Union[int, str] means the parameter can be int or str.
    """
    return float(value)

def get_top_scores(scores: List[int], n: int) -> List[int]:
    """Return the top n scores from the list."""
    return sorted(scores, reverse=True)[:n]

def word_count(text: str) -> Dict[str, int]:
    """Count occurrences of each word."""
    words = text.lower().split()
    return {word: words.count(word) for word in set(words)}

# Examples
print(find_user(1))            # "alice"
print(find_user(99))           # None — Optional makes this explicit
print(parse_number("3.14"))    # 3.14
print(parse_number(42))        # 42.0
print(get_top_scores([85, 92, 78, 95, 88], 3))
print(word_count("the cat sat on the mat"))

# %% [markdown]
# ## 💬 Comments — Explaining the "Why", Not the "What"
#
# Good comments explain **why** the code does something, not **what** it does (the code itself shows what).
#
# > 🔑 **Rule of thumb:** If you need a comment to explain WHAT the code does, consider renaming variables or extracting a function instead. Comments should explain WHY.

# %%
# ❌ Over-commented: comments just restate what the code does (useless noise)
count = 0               # set count to 0
count = count + 1       # add 1 to count
count = count + 1       # add 1 to count
result = count * 2      # multiply count by 2

# ❌ Magic numbers with no explanation
def calculate_score(raw_score):
    return raw_score * 0.85 + 15

# ✅ Well-named code with purposeful comments
def calculate_adjusted_score(raw_score: float) -> float:
    # Scale by 85% to normalize for above-average test difficulty,
    # then apply 15-point bonus per grading policy update Q3-2024.
    # See: internal-wiki/grading-policy-2024 for background.
    difficulty_scaling = 0.85
    policy_bonus = 15
    return raw_score * difficulty_scaling + policy_bonus

# ✅ Comment explains WHY, not what
def get_active_users(users):
    # Sort in Python (not in the DB query) because the ORM does not support
    # case-insensitive ordering on this legacy database version (ticket #1247).
    return sorted(
        [u for u in users if u.get("active")],
        key=lambda u: u["name"].lower()
    )

print(calculate_adjusted_score(80))   # 83.0
print(calculate_adjusted_score(60))   # 66.0

# %% [markdown]
# ## 🆚 Comments vs. Docstrings — When to Use Each
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# | Feature | Comments (`#`) | Docstrings (`"""...""""`) |
# |---------|---------------|------------------------|
# | **Purpose** | Explain WHY non-obvious decisions were made | Describe the public interface |
# | **Audience** | Developer reading source code | User calling the function |
# | **Appears in `help()`** | ❌ No | ✅ Yes |
# | **Where placed** | Inside code, next to tricky lines | First statement of function/class/module |
# | **Style** | Free-form | Structured (Google, NumPy, or reST) |
#
# **Simple rule:** If it's something the *caller* needs to know → docstring. If it's something the *implementer* needs to know → comment.

# %%
def process_payment(amount: float, currency: str = "USD") -> dict:
    """Process a payment and return a transaction record.

    This is the DOCSTRING — it describes the public contract.
    People who CALL this function read this in their IDE or via help().

    Args:
        amount: Payment amount in the given currency. Must be positive.
        currency: ISO 4217 currency code. Defaults to "USD".

    Returns:
        A dict with keys: "transaction_id", "status", "amount", "currency".

    Raises:
        ValueError: If amount is not positive.
    """
    if amount <= 0:
        raise ValueError(f"Amount must be positive, got {amount}")

    # COMMENTS below describe implementation choices for future maintainers.

    # Use integer arithmetic for currency to avoid floating-point errors.
    # $12.50 becomes 1250 cents internally, then converted back on output.
    amount_cents = round(amount * 100)

    # Transaction IDs use a random counter here for the demo.
    # In production this calls the payment gateway API to get a real ID.
    import random
    transaction_id = f"TXN-{random.randint(100000, 999999)}"

    return {
        "transaction_id": transaction_id,
        "status": "completed",
        "amount": amount_cents / 100,
        "currency": currency
    }

result = process_payment(29.99)
print(result)

# %% [markdown]
# ## 🛠️ Code Formatters and Linters — Automate the Boring Parts
#
# You don't have to memorize every PEP 8 rule. **Tools do it for you automatically.**
#
# ### Formatters — Auto-Fix Your Code
#
# If this section feels dense, pause and identify the data structure or model first. Most of the APIs here make more sense once you know what is being stored, queried, or transformed.
#
# | Tool | Notes |
# |------|-------|
# | **`black`** | "Uncompromising" — opinionated, zero config needed |
# | **`ruff format`** | Modern, Rust-based, extremely fast |
#
# ```bash
# pip install black ruff
#
# black my_script.py          # Format one file
# black .                     # Format entire project
# ruff format my_script.py    # Alternative
# ```
# ### Linters — Warn About Style Issues
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# | Tool | Notes |
# |------|-------|
# | **`flake8`** | Classic PEP 8 checker |
# | **`ruff check`** | Modern, fast, replaces flake8 |
# | **`mypy`** | Checks type hints |
#
# ```bash
# flake8 my_script.py          # Check for violations
# ruff check my_script.py      # Modern alternative
# mypy my_script.py            # Check type hints
# ```
#
# > 💡 **Pro tip:** Most professional teams run these in CI/CD pipelines — bad style never reaches the main codebase.

# %%
# What linters catch — simulating common warnings

# These would trigger linter warnings:

import os, sys      # E401: multiple imports on one line -> split them

x=5                 # E225: missing whitespace around operator

if x == None:       # E711: use "is None" not "== None"
    pass

y = 10              # W291: trailing whitespace (invisible but linter sees it)

# What they look like after "black" formats them:
import os
import sys

x = 5

if x is None:
    pass

y = 10

# Linter output looks like:
# my_script.py:3:10: E401 multiple imports on one line
# my_script.py:5:2: E225 missing whitespace around operator
# my_script.py:7:5: E711 comparison to None (use "is None")

print(f"x={x}, y={y} — clean code achieved!")

# %% [markdown]
# ## 🧪 What If? Experimentation
#
# Let's explore what happens when you break the rules:

# %%
# What If #1: Mixing tabs and spaces?

inconsistent_code = """
def mixed_indent():
    x = 1   # 4 spaces
\t  y = 2   # tab mixed with spaces
    return x + y
"""

# Python 3 is STRICT: mixing tabs and spaces raises TabError immediately
try:
    exec(inconsistent_code)
except TabError as e:
    print(f"TabError: {e}")
except IndentationError as e:
    print(f"IndentationError: {e}")

print()
print("Fix: Configure your editor to insert 4 spaces when you press Tab.")
print("In VS Code: Settings -> Editor: Insert Spaces = True, Tab Size = 4")

# %%
# What If #2: Variable names are too short?

# Real code — can you tell what this calculates?
def f(a, b, c, d):
    x = a * b
    y = c * d
    z = x + y
    return z / (a + c) if (a + c) != 0 else 0

print("Mystery function result:", f(10, 85, 20, 92))
print("What does it calculate? You must trace every variable to find out.")
print()

# Same function with descriptive names — instantly clear
def calculate_weighted_average(
    group1_count: int, group1_score: float,
    group2_count: int, group2_score: float
) -> float:
    """Calculate the weighted average score across two groups."""
    group1_total = group1_count * group1_score
    group2_total = group2_count * group2_score
    combined_total = group1_total + group2_total
    combined_count = group1_count + group2_count
    return combined_total / combined_count if combined_count != 0 else 0

result = calculate_weighted_average(10, 85, 20, 92)
print(f"Weighted average: {result:.1f}")
print("Now you know exactly what it does from the name alone!")

# %%
# What If #3: Skipping docstrings on a complex function?

# Without docstring: you MUST read the full implementation to use it
def process(data, t, m, inv=False):
    f = [x for x in data if (x > t) != inv]
    if m == "s":
        return sum(f)
    elif m == "a":
        return sum(f) / len(f) if f else 0
    elif m == "c":
        return len(f)
    return None

# 3 months later: what does "inv" do? What are valid "m" values?
# What does it return for unknown "m"? You MUST read the source.
print("Without docs:", process([1, 5, 3, 8, 2], 4, "c"))
print()

# With docstring: instantly clear
def filter_and_aggregate(
    data: list, threshold: float, mode: str, invert: bool = False
) -> float:
    """Filter a numeric list by threshold and aggregate the results.

    Args:
        data: List of numeric values.
        threshold: Values ABOVE this are kept (unless invert=True).
        mode: Aggregation: "s" for sum, "a" for average, "c" for count.
        invert: If True, keeps values BELOW threshold. Defaults to False.

    Returns:
        The aggregated result, or None for unrecognized mode.

    Examples:
        >>> filter_and_aggregate([1, 5, 3, 8, 2], 4, "c")
        2
    """
    filtered = [x for x in data if (x > threshold) != invert]
    if mode == "s": return sum(filtered)
    elif mode == "a": return sum(filtered) / len(filtered) if filtered else 0
    elif mode == "c": return len(filtered)
    return None

print("Count above 4:", filter_and_aggregate([1, 5, 3, 8, 2], 4, "c"))
print("Sum above 4:  ", filter_and_aggregate([1, 5, 3, 8, 2], 4, "s"))
print("Count below 4:", filter_and_aggregate([1, 5, 3, 8, 2], 4, "c", invert=True))

# %% [markdown]
# ## 🚀 Real-World Project Link
#
# In **every project** we build throughout this handbook — file processors, web scrapers, data analysis pipelines, REST APIs — we'll apply these standards from the very first line.
#
# Clean, well-documented code is the foundation of professional Python. When you submit code for review, open a pull request, or onboard a new teammate, style is what separates a **script that works today** from **code that lasts for years**.
#
# > 🏆 The professionals who write the most maintainable code aren't the ones who memorize every rule — they're the ones who run `black .` before every commit and write docstrings as they code, not as an afterthought.
#
# ---

# %% [markdown]
# ## 📋 Chapter Summary & Cheat Sheet
#
# ### Key Takeaways
#
# - **PEP 8** is Python's universal style convention — follow it to write readable, professional code
# - **Naming**: `snake_case` for variables/functions · `PascalCase` for classes · `UPPER_CASE` for constants
# - **Indentation**: Always 4 spaces — never tabs
# - **Line length**: Keep under 79 characters; use parentheses to break long lines
# - **Blank lines**: 2 between top-level definitions, 1 between methods
# - **Docstrings**: First statement of every function/class — powers `help()` and IDEs
# - **Type hints**: Document expected types; enable IDE warnings and `mypy` checking
# - **Comments**: Explain **WHY**, not what — avoid restating obvious code
# - **Formatters** (`black`, `ruff format`): Auto-fix style — run before every commit
# - **Linters** (`flake8`, `ruff check`): Warn about issues — integrate into your editor

# %%
# ==========================================
# CHAPTER 8 CHEAT SHEET
# ==========================================

# --- NAMING CONVENTIONS ---
MAX_CONNECTIONS = 100           # constant:  UPPER_CASE
user_name = "alice"             # variable:  snake_case

def calculate_total(price, tax_rate):   # function: snake_case
    pass

class ShoppingCart:             # class:     PascalCase
    pass

# --- SPACING ---
x = 5 + 3                      # spaces around operators
my_list = [1, 2, 3]            # spaces after commas
def func(a, b=10): pass        # no space around default =

# --- IMPORTS (in order) ---
import os                       # 1. stdlib
import sys
# import requests               # 2. third-party
# from myproject import utils   # 3. local

# --- DOCSTRING (Google Style) ---
def greet(name: str) -> str:
    """Return a greeting for the given name.

    Args:
        name: The person's name.

    Returns:
        A greeting string.
    """
    return f"Hello, {name}!"

# --- TYPE HINTS ---
from typing import Optional, List

def find(items: List[str], query: str) -> Optional[str]:
    return next((i for i in items if query in i), None)

# --- COMMENT RULES ---
# Explain WHY:
#   Use binary search — linear scan too slow on 1M+ records
# NOT what:
#   x = x + 1  (don't: "add 1 to x")

# --- TOOLS ---
# pip install black ruff flake8 mypy
# black .             -> auto-format
# ruff check .        -> lint
# mypy .              -> type check

print("Style check: PASS")
print(greet("World"))

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='../3.%20object_oriented_programming/7.%20advanced_oop_concepts.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 7: Advanced OOP</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='9.%20error_handling_and_debugging.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 9: Error Handling →</a>
# </div>
