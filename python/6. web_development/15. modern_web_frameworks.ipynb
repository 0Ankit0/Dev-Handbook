# %% [markdown]
# # Chapter 15: Modern Web Frameworks — Building Your Own Web Applications
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='14.%20web_basics_and_apis.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 14: Web Basics & APIs</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='16.%20databases_and_orm.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 16: Databases & ORM →</a>
# </div>
#
# ---
#
# > ❓ **Why use an ORM instead of raw SQL?** An ORM (Object-Relational Mapper) lets you work with database rows as Python objects, so you write Python instead of SQL strings. It also prevents SQL injection by default and makes switching databases straightforward later.

# %% [markdown]
# ## 🌍 The Big Picture
#
# So far, you've been a **consumer** of web services — sending requests to APIs that others built. Now it's time to be a **producer**.
#
# A **web framework** gives you the tools to build your own web application — pages, APIs, and everything in between — without building everything from scratch.
#
# **Think about what "building a web server from scratch" would mean:**
# - Parsing raw HTTP text from a socket
# - Routing `/users/1` to the right function
# - Serializing Python objects to JSON
# - Validating incoming request data
# - Handling errors and returning the right status codes
#
# A framework handles all of that for you. You focus on your application logic.
#
# **What you'll build by the end:** A fully functional To-Do REST API with Create, Read, Update, and Delete operations — the foundation of almost every real-world web application.
#
# > ❓ **Why use a framework's routing instead of `if url == '/': ...`?** A routing system matches URLs against patterns (including variables like `<int:id>`), dispatches to the right function, and handles edge cases like trailing slashes and HTTP method checks — without any boilerplate from you.

# %% [markdown]
# ## 🧠 Core Concepts: The "Why"
#
# The easiest way to read this section is to keep one plain-language question in view: what is The "Why" actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### What is a Web Framework?
#
# **Building a website without a framework** is like building a house starting from raw trees — you need to cut lumber, smelt nails, and blow glass for windows.
#
# **Using a web framework** is like having:
# - Pre-cut lumber (HTTP request/response handling)
# - Pre-made windows (authentication utilities)
# - Blueprints (routing patterns)
# - Power tools (automatic documentation generation)
#
# You still design and build the house, but you don't reinvent every component.
#
# ### Python Web Framework Landscape
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```
# Flask ──────────── Minimal, flexible, "batteries not included"
#                    Great for: small APIs, microservices, learning
#
# FastAPI ─────────── Modern, fast, type-hint driven, auto-docs
#                    Great for: production APIs, modern Python projects
#
# Django ──────────── Full-stack, "batteries included" (ORM, admin, auth)
#                    Great for: large applications, content sites
# ```
#
# In this chapter, we'll focus on **FastAPI** — Python's most modern framework — with a comparison to Flask.

# %% [markdown]
# ## ⚡ FastAPI — Python's Most Modern Web Framework
#
# API and integration material becomes easier when you treat it as agreement design rather than just endpoint syntax. Watch the shape of the data, the guarantees around it, and the failure cases.
#
# FastAPI's superpowers:
#
# 1. **Type hints drive everything** — declare what data you expect, FastAPI validates it automatically
# 2. **Automatic documentation** — visit `/docs` and get an interactive API explorer for free
# 3. **Blazing fast** — built on Starlette and Pydantic, comparable to Node.js in performance
# 4. **Automatic JSON serialization** — return a dict, get JSON
# 5. **Used in production** by Microsoft, Uber, Netflix, and many others
# ### Installation
#
# A beginner usually learns this material faster by connecting each setup step to its purpose rather than treating it as a checklist. Keep asking what each piece enables and what would fail if you skipped it.
#
# ```bash
# pip install fastapi uvicorn[standard]
# ```
#
# - `fastapi` — the framework itself
# - `uvicorn` — the **ASGI server** that runs your app (ASGI = Asynchronous Server Gateway Interface, the modern web standard)
#
# > ❓ **What does `pip install` actually do?** `pip` downloads the named package from PyPI (the Python Package Index), along with any packages it depends on, and places them inside your currently active environment.

# %% [markdown]
# ## 🔧 Syntax & First Usage: The "How"
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### Your First FastAPI Application
#
# In a real project, you'd save this as `main.py` and run:
# ```bash
# uvicorn main:app --reload
# ```
#
# Let's read every single line carefully:
#
# > ❓ **Why not just use the development server in production?** The dev server is single-threaded and has no hardening for public traffic. Gunicorn/Uvicorn spawn multiple worker processes to handle concurrent requests and include timeouts, graceful restarts, and proper error logging.

# %%
# Let's look at the anatomy of a minimal FastAPI app
# (We'll actually run it below using TestClient)

fastapi_hello_world = '''
from fastapi import FastAPI

# 1. Create the application instance
#    This is the central object that holds all your routes, middleware, etc.
app = FastAPI(
    title="My First API",
    description="Learning FastAPI step by step",
    version="0.1.0"
)

# 2. Define a route
#    @app.get("/") is a decorator that registers this function as the handler
#    for HTTP GET requests to the "/" path (the root URL)
@app.get("/")
def read_root():
    # 3. Return data
    #    FastAPI automatically converts this dict to JSON
    return {"message": "Hello, World!", "status": "running"}

# 4. A second route with a path parameter
@app.get("/greet/{name}")
def greet_user(name: str):   # {name} in the path becomes a typed parameter
    return {"greeting": f"Hello, {name}!", "name": name}
'''

print(fastapi_hello_world)
print("To run this:")
print("  1. Save as main.py")
print("  2. Run: uvicorn main:app --reload")
print("  3. Open: http://127.0.0.1:8000")
print("  4. Open: http://127.0.0.1:8000/docs  <-- THE MAGIC")

# %%
# FastAPI provides TestClient for testing without a live server
# This is what production test suites use too!

try:
    from fastapi import FastAPI
    from fastapi.testclient import TestClient
    print("FastAPI is available!")
except ImportError:
    print("FastAPI not installed. Run: pip install fastapi")
    print("You can still read all the code examples below.")

# %%
try:
    from fastapi import FastAPI
    from fastapi.testclient import TestClient

    # Define our first app
    app = FastAPI(title="Hello World API")

    @app.get("/")
    def read_root():
        return {"message": "Hello, World!", "framework": "FastAPI"}

    @app.get("/greet/{name}")
    def greet_user(name: str):
        return {"greeting": f"Hello, {name}!", "name": name}

    # Use TestClient to send real HTTP requests
    client = TestClient(app)

    # Test the root endpoint
    response = client.get("/")
    print("GET /  ->", response.status_code, response.json())

    # Test the greet endpoint with a path parameter
    response = client.get("/greet/Alice")
    print("GET /greet/Alice ->", response.status_code, response.json())

    response = client.get("/greet/World")
    print("GET /greet/World ->", response.status_code, response.json())

except ImportError:
    print("FastAPI not installed -- skipping live demo")

# %% [markdown]
# ### The Automatic Documentation
#
# This is one of FastAPI's most beloved features. When you run your app:
#
# - **`/docs`** → Interactive Swagger UI — click "Try it out" and call your API from the browser
# - **`/redoc`** → ReDoc documentation — clean, readable API reference
# - **`/openapi.json`** → The raw OpenAPI schema
#
# FastAPI generates all of this **automatically** from your type hints. You write the code; the docs write themselves.
#
# ```
# http://127.0.0.1:8000/docs
# ```

# %% [markdown]
# ## 🛣️ Routes and Path Operations
#
# Production-oriented material makes more sense when you see it as reliability work. The tools and steps here exist to make behavior repeatable, observable, and safer to change.
#
# ### Path Parameters
#
# Path parameters capture parts of the URL path:

# %%
try:
    from fastapi import FastAPI
    from fastapi.testclient import TestClient

    app = FastAPI()

    # Simple path parameter — FastAPI validates it's an integer!
    @app.get("/items/{item_id}")
    def get_item(item_id: int):
        return {"item_id": item_id, "name": f"Item number {item_id}"}

    # Multiple path parameters
    @app.get("/users/{user_id}/posts/{post_id}")
    def get_user_post(user_id: int, post_id: int):
        return {"user_id": user_id, "post_id": post_id,
                "content": f"Post {post_id} by user {user_id}"}

    client = TestClient(app)

    print("GET /items/42 ->")
    print(" ", client.get("/items/42").json())

    print("\nGET /items/abc -> (invalid: 'abc' is not an int)")
    resp = client.get("/items/abc")
    print(f"  Status: {resp.status_code}")
    print(f"  Error:  {resp.json()['detail'][0]['msg']}")

    print("\nGET /users/1/posts/5 ->")
    print(" ", client.get("/users/1/posts/5").json())

except ImportError:
    print("FastAPI not installed -- skipping")

# %%
try:
    from fastapi import FastAPI
    from fastapi.testclient import TestClient
    from typing import Optional

    app = FastAPI()

    # Query Parameters — NOT in the path, they become ?key=value in the URL
    @app.get("/items")
    def list_items(
        skip: int = 0,              # default value = optional parameter
        limit: int = 10,            # default 10
        category: Optional[str] = None   # None = truly optional
    ):
        all_items = [{"id": i, "name": f"Item {i}", "category": "general"} for i in range(1, 51)]
        if category:
            all_items = [item for item in all_items if item["category"] == category]
        return {
            "items": all_items[skip : skip + limit],
            "total": len(all_items),
            "skip": skip,
            "limit": limit
        }

    client = TestClient(app)

    print("GET /items ->")
    resp = client.get("/items")
    data = resp.json()
    print(f"  Total: {data['total']}, showing: {len(data['items'])}")

    print("\nGET /items?skip=5&limit=3 ->")
    resp = client.get("/items?skip=5&limit=3")
    data = resp.json()
    print(f"  Showing items: {[item['id'] for item in data['items']]}")

except ImportError:
    print("FastAPI not installed -- skipping")

# %% [markdown]
# ## 📦 Request and Response Models with Pydantic
#
# **Pydantic** is the data validation library that powers FastAPI. It lets you define the *shape* of your data using Python classes.
#
# > **Analogy:** Pydantic is like a **security guard checking IDs at the door**. When data arrives at your API, Pydantic checks that it has all required fields, that the types are correct, and that values meet any constraints. Invalid data is rejected automatically before it ever reaches your code.

# %%
try:
    from fastapi import FastAPI
    from fastapi.testclient import TestClient
    from pydantic import BaseModel
    from typing import Optional

    app = FastAPI()

    # Define a Pydantic model — describes the shape of incoming data
    class ItemCreate(BaseModel):
        name: str                          # required string
        price: float                       # required float
        description: Optional[str] = None  # optional string
        in_stock: bool = True              # optional bool, defaults to True

    @app.post("/items", status_code=201)
    def create_item(item: ItemCreate):     # FastAPI auto-parses & validates the body
        # If we get here, the data is already validated!
        return {
            "message": "Item created",
            "item": item.model_dump(),
            "id": 42
        }

    client = TestClient(app)

    # Valid request
    print("Valid data:")
    resp = client.post("/items", json={"name": "Python Book", "price": 39.99})
    print(f"  Status: {resp.status_code}")
    print(f"  Response: {resp.json()}")

    # Invalid — missing required field
    print("\nMissing 'price' field:")
    resp = client.post("/items", json={"name": "Incomplete Item"})
    print(f"  Status: {resp.status_code}")  # 422 Unprocessable Entity
    error = resp.json()
    print(f"  Error: {error['detail'][0]['msg']} (field: {error['detail'][0]['loc']})")

    # Invalid — wrong type
    print("\nWrong type for 'price':")
    resp = client.post("/items", json={"name": "Bad Item", "price": "not-a-number"})
    print(f"  Status: {resp.status_code}")
    print(f"  Error: {resp.json()['detail'][0]['msg']}")

except ImportError:
    print("FastAPI/Pydantic not installed -- skipping")

# %% [markdown]
# ## ⚔️ Deep Dive: FastAPI vs Flask
#
# Both are excellent Python web frameworks. Here's the same route in each:

# %%
# The SAME route — two frameworks

flask_code = '''
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route("/items", methods=["POST"])
def create_item():
    data = request.get_json()            # Manually parse JSON

    # Manual validation -- you must write this yourself
    if "name" not in data:
        return jsonify({"error": "name is required"}), 400
    if "price" not in data:
        return jsonify({"error": "price is required"}), 400
    if not isinstance(data["price"], (int, float)):
        return jsonify({"error": "price must be a number"}), 400

    return jsonify({"message": "created", "item": data}), 201
'''

fastapi_code = '''
from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI()

class Item(BaseModel):
    name: str
    price: float

@app.post("/items", status_code=201)
def create_item(item: Item):
    # Validation is AUTOMATIC -- if we get here, data is already valid
    return {"message": "created", "item": item.model_dump()}
'''

print("=" * 50)
print("FLASK -- explicit and manual")
print("=" * 50)
print(flask_code)

print("=" * 50)
print("FASTAPI -- declarative and automatic")
print("=" * 50)
print(fastapi_code)

# %%
# Feature comparison
features = [
    ("Validation",       "Manual",                   "Automatic (Pydantic)"),
    ("Documentation",    "External (flask-swagger)",  "Built-in (/docs)"),
    ("Type hints",       "Optional",                  "Required & central"),
    ("Performance",      "Good",                      "Excellent"),
    ("Learning curve",   "Very low",                  "Low-medium"),
    ("Maturity",         "Very mature (2010)",         "Modern (2018)"),
]

print(f"{'Feature':<20} {'Flask':<28} {'FastAPI'}")
print("-" * 70)
for feat, flask_val, fastapi_val in features:
    print(f"{feat:<20} {flask_val:<28} {fastapi_val}")

print()
print("Use Flask for tiny scripts/quick prototypes.")
print("Use FastAPI for any serious API project.")

# %% [markdown]
# ## 🏗️ Building a Complete To-Do REST API
#
# Let's build a fully functional REST API with all four CRUD operations:
#
# | Operation | HTTP Method | Path | Action |
# |-----------|-------------|------|--------|
# | **C**reate | POST | `/todos` | Create a new todo |
# | **R**ead | GET | `/todos` | List all todos |
# | **R**ead | GET | `/todos/{id}` | Get a specific todo |
# | **U**pdate | PUT | `/todos/{id}` | Update a todo |
# | **D**elete | DELETE | `/todos/{id}` | Delete a todo |
#
# We'll use an **in-memory list** for storage (no database yet — that's Chapter 16!).

# %%
try:
    from fastapi import FastAPI, HTTPException
    from fastapi.testclient import TestClient
    from pydantic import BaseModel
    from typing import Optional, List
    from datetime import datetime

    # ---- Models ----

    class TodoCreate(BaseModel):
        title: str
        description: Optional[str] = None
        completed: bool = False

    class TodoUpdate(BaseModel):
        title: Optional[str] = None
        description: Optional[str] = None
        completed: Optional[bool] = None

    class TodoResponse(BaseModel):
        id: int
        title: str
        description: Optional[str] = None
        completed: bool
        created_at: str

    # ---- In-memory "database" ----
    todos_db: List[dict] = []
    next_id: int = 1

    # ---- App ----
    app = FastAPI(title="To-Do API")

    @app.get("/todos", response_model=List[TodoResponse])
    def list_todos(completed: Optional[bool] = None):
        if completed is None:
            return todos_db
        return [t for t in todos_db if t["completed"] == completed]

    @app.get("/todos/{todo_id}", response_model=TodoResponse)
    def get_todo(todo_id: int):
        todo = next((t for t in todos_db if t["id"] == todo_id), None)
        if todo is None:
            raise HTTPException(status_code=404, detail=f"Todo {todo_id} not found")
        return todo

    @app.post("/todos", response_model=TodoResponse, status_code=201)
    def create_todo(todo: TodoCreate):
        global next_id
        new_todo = {
            "id": next_id,
            "title": todo.title,
            "description": todo.description,
            "completed": todo.completed,
            "created_at": datetime.now().isoformat()
        }
        todos_db.append(new_todo)
        next_id += 1
        return new_todo

    @app.put("/todos/{todo_id}", response_model=TodoResponse)
    def update_todo(todo_id: int, updates: TodoUpdate):
        todo = next((t for t in todos_db if t["id"] == todo_id), None)
        if todo is None:
            raise HTTPException(status_code=404, detail=f"Todo {todo_id} not found")
        update_data = updates.model_dump(exclude_unset=True)
        todo.update(update_data)
        return todo

    @app.delete("/todos/{todo_id}", status_code=204)
    def delete_todo(todo_id: int):
        global todos_db
        original_len = len(todos_db)
        todos_db = [t for t in todos_db if t["id"] != todo_id]
        if len(todos_db) == original_len:
            raise HTTPException(status_code=404, detail=f"Todo {todo_id} not found")
        return None

    print("To-Do API defined successfully!")
    print(f"Routes: {[r.path for r in app.routes if hasattr(r, 'path')]}")

except ImportError as e:
    print(f"Missing dependency: {e}")
    print("Run: pip install fastapi")

# %%
# Test every endpoint!

try:
    client = TestClient(app)

    print("=" * 50)
    print("1. CREATE three todos")
    print("=" * 50)
    t1 = client.post("/todos", json={"title": "Learn FastAPI"})
    t2 = client.post("/todos", json={"title": "Add a database", "description": "Connect to SQLite"})
    t3 = client.post("/todos", json={"title": "Deploy to cloud"})
    for r in [t1, t2, t3]:
        d = r.json()
        print(f"  [{d['id']}] {d['title']}")

    print("\n" + "=" * 50)
    print("2. LIST all todos")
    print("=" * 50)
    for todo in client.get("/todos").json():
        status = "done" if todo["completed"] else "pending"
        print(f"  [{todo['id']}] {todo['title']} ({status})")

    print("\n" + "=" * 50)
    print("3. GET a single todo")
    print("=" * 50)
    print("  Todo #1:", client.get("/todos/1").json())

    print("\n" + "=" * 50)
    print("4. UPDATE — mark as completed")
    print("=" * 50)
    resp = client.put("/todos/1", json={"completed": True})
    d = resp.json()
    print(f"  {d['title']} -> completed: {d['completed']}")

    print("\n" + "=" * 50)
    print("5. FILTER — only incomplete todos")
    print("=" * 50)
    for todo in client.get("/todos?completed=false").json():
        print(f"  [ ] [{todo['id']}] {todo['title']}")

    print("\n" + "=" * 50)
    print("6. DELETE todo #2")
    print("=" * 50)
    resp = client.delete("/todos/2")
    print(f"  Status: {resp.status_code} (204 = success)")

    print("\n" + "=" * 50)
    print("7. LIST after delete")
    print("=" * 50)
    for todo in client.get("/todos").json():
        marker = "[x]" if todo["completed"] else "[ ]"
        print(f"  {marker} [{todo['id']}] {todo['title']}")

    print("\n" + "=" * 50)
    print("8. GET non-existent todo -> 404")
    print("=" * 50)
    resp = client.get("/todos/999")
    print(f"  Status: {resp.status_code}")
    print(f"  Detail: {resp.json()['detail']}")

except NameError:
    print("Run the previous cell first to define the app!")

# %% [markdown]
# ## 🔒 Middleware and CORS
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ### What is Middleware?
#
# **Middleware** is code that runs on *every* request before it reaches your route handler. Think of it as airport security — every passenger (request) passes through regardless of their destination.
#
# Common uses: logging every request, authentication checks, adding headers to every response, request timing.
#
# ### CORS — Cross-Origin Resource Sharing
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# **CORS** is a browser security feature. By default, a web page at `https://myapp.com` **cannot** make API calls to `https://api.differentdomain.com`. CORS headers tell the browser: "It's okay, I allow requests from that origin."
#
# You need CORS when your **frontend and backend are on different domains** (very common in React/Vue + FastAPI setups).

# %%
try:
    from fastapi import FastAPI, Request
    from fastapi.middleware.cors import CORSMiddleware
    from fastapi.testclient import TestClient
    import time

    app_with_middleware = FastAPI()

    # CORS middleware — in production, replace "*" with your actual frontend URL
    app_with_middleware.add_middleware(
        CORSMiddleware,
        allow_origins=["*"],          # Allow all origins (dev only!)
        allow_credentials=True,
        allow_methods=["*"],          # GET, POST, PUT, DELETE, etc.
        allow_headers=["*"],
    )

    # Custom logging middleware
    @app_with_middleware.middleware("http")
    async def log_requests(request: Request, call_next):
        start = time.time()
        response = await call_next(request)
        duration = (time.time() - start) * 1000
        print(f"  [{response.status_code}] {request.method} {request.url.path} -- {duration:.1f}ms")
        return response

    @app_with_middleware.get("/hello")
    def hello():
        return {"message": "Hello with middleware!"}

    @app_with_middleware.get("/data")
    def get_data():
        return {"data": [1, 2, 3, 4, 5]}

    client_mw = TestClient(app_with_middleware)
    print("Making requests -- watch the middleware logs:")
    client_mw.get("/hello")
    client_mw.get("/data")
    client_mw.get("/missing")

except ImportError:
    print("FastAPI not installed -- skipping")

# %% [markdown]
# ## 🧪 What If? Experimentation
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### What If You Send Invalid Data to a Pydantic Endpoint?
#
# FastAPI automatically returns a detailed **422 Unprocessable Entity** response:

# %%
try:
    from fastapi import FastAPI
    from fastapi.testclient import TestClient
    from pydantic import BaseModel

    test_app = FastAPI()

    class StrictItem(BaseModel):
        name: str
        quantity: int    # Must be an integer
        price: float     # Must be a float/int

    @test_app.post("/items")
    def create(item: StrictItem):
        return item.model_dump()

    client = TestClient(test_app)

    # Case 1: Wrong type
    print("Sending quantity as a string:")
    resp = client.post("/items", json={"name": "Widget", "quantity": "lots", "price": 9.99})
    print(f"  Status: {resp.status_code}")
    for error in resp.json()["detail"]:
        print(f"  Field {error['loc']}: {error['msg']}")

    # Case 2: Missing required field
    print("\nMissing 'price' field:")
    resp = client.post("/items", json={"name": "Widget", "quantity": 5})
    print(f"  Status: {resp.status_code}")
    for error in resp.json()["detail"]:
        print(f"  Field {error['loc']}: {error['msg']}")

    # Case 3: Valid data
    print("\nValid data:")
    resp = client.post("/items", json={"name": "Widget", "quantity": 5, "price": 9.99})
    print(f"  Status: {resp.status_code}, Data: {resp.json()}")

    print()
    print("KEY INSIGHT: FastAPI handles validation errors automatically.")
    print("You never write 'if not isinstance(x, int)' again.")

except ImportError:
    print("FastAPI not installed -- skipping")

# %% [markdown]
# ### What If Two Routes Have the Same Path?
#
# FastAPI uses the **first matching route**. Order matters:

# %%
try:
    from fastapi import FastAPI
    from fastapi.testclient import TestClient

    # BAD ORDER: parameterized route before specific route
    app_bad_order = FastAPI()

    @app_bad_order.get("/items/{item_id}")   # This catches /items/featured too!
    def get_by_id(item_id: str):
        return {"route": "by-id", "item_id": item_id}

    @app_bad_order.get("/items/featured")    # This never matches!
    def get_featured():
        return {"route": "featured", "items": ["best seller"]}

    client_bad = TestClient(app_bad_order)
    print("BAD ORDER:")
    print("  GET /items/featured ->", client_bad.get("/items/featured").json())
    print("  'featured' was treated as an item_id!")

    # GOOD ORDER: specific routes before parameterized ones
    app_good_order = FastAPI()

    @app_good_order.get("/items/featured")   # Specific FIRST
    def get_featured_good():
        return {"route": "featured", "items": ["best seller"]}

    @app_good_order.get("/items/{item_id}")  # General SECOND
    def get_by_id_good(item_id: str):
        return {"route": "by-id", "item_id": item_id}

    client_good = TestClient(app_good_order)
    print("\nGOOD ORDER:")
    print("  GET /items/featured ->", client_good.get("/items/featured").json())
    print("  GET /items/42      ->", client_good.get("/items/42").json())

    print()
    print("RULE: Always define specific routes BEFORE parameterized routes.")

except ImportError:
    print("FastAPI not installed -- skipping")

# %% [markdown]
# ### What If You Forget to Run uvicorn?
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```bash
# # WRONG — running the Python file directly doesn't start the server
# python main.py
#
# # CORRECT — use uvicorn to serve the app
# uvicorn main:app --reload
#
# # Syntax: uvicorn <filename_without_py>:<fastapi_variable> --reload
# # --reload = auto-restart when you save (development only!)
# ```
#
# **Common mistakes checklist:**
# - `uvicorn app:app` when your file is named `main.py` → use `uvicorn main:app`
# - `uvicorn main:application` when your variable is `app` → use `uvicorn main:app`
# - Running from the wrong directory → must be in the same folder as `main.py`
# - Forgetting `uvicorn` entirely and wondering why `python main.py` does nothing

# %% [markdown]
# ## 🚀 Real-World Project Link
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# > In our **REST API project**, we'll build a fully functional notes API: create, list, update, and delete notes, each with a title, content, and tags. The pattern you've built here with the To-Do API is exactly the same. The next chapter (Chapter 16) will connect this API to a **real SQLite database** using SQLAlchemy, replacing the in-memory list with persistent storage.

# %% [markdown]
# ## 📋 Chapter Summary & Cheat Sheet
#
# ### Key Concepts
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - A **web framework** handles HTTP parsing, routing, serialization — you focus on logic
# - **FastAPI** is modern, type-hint driven, with automatic validation and documentation
# - **Pydantic models** validate incoming data automatically
# - **Routes** map (URL + HTTP method) → Python function
# - **Path parameters** (`/items/{id}`) are captured from the URL
# - **Query parameters** (`/items?limit=10`) are optional filters
# - **Middleware** runs on every request (logging, auth, CORS)
# ### FastAPI Cheat Sheet
#
# When a section introduces a boundary between systems, focus on the contract first: what information crosses the boundary, who is allowed to send it, and what the caller can safely assume in return.
#
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# from typing import Optional, List
#
# app = FastAPI()
#
# class Item(BaseModel):
#     name: str
#     price: float
#     description: Optional[str] = None
#
# @app.get("/items")                         # List all
# def list_items(limit: int = 10): ...
#
# @app.get("/items/{item_id}")               # Get one
# def get_item(item_id: int): ...
#
# @app.post("/items", status_code=201)       # Create
# def create_item(item: Item): ...
#
# @app.put("/items/{item_id}")               # Update
# def update_item(item_id: int, item: Item): ...
#
# @app.delete("/items/{item_id}", status_code=204)  # Delete
# def delete_item(item_id: int): ...
# # Return 404
# raise HTTPException(status_code=404, detail="Not found")
#
# # Run:  uvicorn main:app --reload
# # Docs: http://127.0.0.1:8000/docs
# ```

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='14.%20web_basics_and_apis.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 14: Web Basics & APIs</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='16.%20databases_and_orm.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 16: Databases & ORM →</a>
# </div>
