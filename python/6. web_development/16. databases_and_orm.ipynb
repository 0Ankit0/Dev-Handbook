# %% [markdown]
# # Chapter 16: Databases and ORM — Making Your Data Permanent
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='15.%20modern_web_frameworks.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 15: Web Frameworks</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../7.%20data_science_and_automation/17.%20the_data_science_stack.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 17: Data Science →</a>
# </div>
#
# ---
#
# > ❓ **Why use an ORM instead of raw SQL?** An ORM (Object-Relational Mapper) lets you work with database rows as Python objects, so you write Python instead of SQL strings. It also prevents SQL injection by default and makes switching databases straightforward later.

# %% [markdown]
# ## 🌍 The Big Picture
#
# Our web app from Chapter 15 has a **fatal flaw**: restart the server, and **all the data disappears**. Every todo, every note, every user — gone. That in-memory list is as permanent as a sandcastle at high tide.
#
# A **database** is the solution — a persistent, organized storage system that survives server restarts, crashes, deployments, and time.
#
# **What you'll build by the end:**
# - Understand SQL and database fundamentals
# - Use Python's built-in `sqlite3` module for raw SQL
# - Master SQLAlchemy ORM for Pythonic database access
# - Connect a real SQLite database to the FastAPI app from Chapter 15
#
# **The Before and After:**
#
# | Before (Chapter 15) | After (This Chapter) |
# |---------------------|----------------------|
# | `todos_db = []` | SQLite database file |
# | Vanishes on restart | Persists forever |
# | Lives in RAM | Lives on disk |
# | No querying power | Full SQL query engine |

# %% [markdown]
# ## 🧠 Core Concepts: The "Why"
#
# The easiest way to read this section is to keep one plain-language question in view: what is The "Why" actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### What is a Database?
#
# A database is like a **spreadsheet on steroids**:
#
# | Spreadsheet | Database |
# |-------------|----------|
# | Sheets | Tables |
# | Column headers | Columns (with types!) |
# | Rows | Rows / Records |
# | Manual searching | SQL queries (instant, even for millions of rows) |
# | No relationships | Foreign keys link tables together |
# | One file, limited size | Can span terabytes |
#
# ### Types of Databases
#
# If this section feels dense, pause and identify the data structure or model first. Most of the APIs here make more sense once you know what is being stored, queried, or transformed.
#
# ```
# Relational (SQL) --- Data in tables with relationships
#     SQLite      -> single file, built into Python, perfect for learning
#     PostgreSQL  -> production powerhouse, open source
#     MySQL       -> widely used, especially in web applications
#
# Non-Relational  --- Flexible data structures
#     MongoDB     -> JSON-like documents
#     Redis       -> key-value, lightning fast, used for caching
# ```
#
# We'll use **SQLite** (comes built into Python!) and learn patterns that transfer directly to PostgreSQL.
#
# > ❓ **When should I *not* cache something?** Avoid caching data that must always be fresh (account balances, real-time prices), per-user private data in a shared cache, or responses containing secrets. Cache only public, slowly-changing data that's expensive to recompute.

# %% [markdown]
# ## 📊 SQL Basics — Just Enough to Understand What's Happening
#
# **SQL** (Structured Query Language) is the language you use to talk to relational databases:
#
# ```sql
# -- Create a table
# CREATE TABLE users (
#     id      INTEGER PRIMARY KEY,   -- unique identifier, auto-incremented
#     name    TEXT    NOT NULL,       -- required string
#     email   TEXT    UNIQUE,         -- must be unique across all rows
#     age     INTEGER
# );
#
# -- Insert a row
# INSERT INTO users (name, email, age) VALUES ('Alice', 'alice@example.com', 30);
#
# -- Query rows
# SELECT * FROM users;                             -- all rows, all columns
# SELECT name, email FROM users WHERE age > 25;   -- filtered
# SELECT * FROM users ORDER BY name LIMIT 10;     -- sorted, paginated
#
# -- Update a row
# UPDATE users SET age = 31 WHERE name = 'Alice';
#
# -- Delete a row
# DELETE FROM users WHERE id = 1;
# ```
#
# We'll see SQLAlchemy generate exactly this SQL — but you'll just write Python.

# %% [markdown]
# ## 🗄️ SQLite with Python's Built-in `sqlite3`
#
# Before using an ORM, let's see raw SQLite. This gives you an appreciation for what the ORM saves you from — and helps you understand what happens underneath.

# %%
import sqlite3

# sqlite3 is built into Python -- no pip install needed!
# ":memory:" creates a temporary in-RAM database (perfect for demos)
# In production: sqlite3.connect("myapp.db")

conn = sqlite3.connect(":memory:")
cursor = conn.cursor()  # Cursor is how you execute SQL

# Create a table
create_sql = (
    "CREATE TABLE IF NOT EXISTS users ("
    "  id    INTEGER PRIMARY KEY AUTOINCREMENT,"
    "  name  TEXT    NOT NULL,"
    "  email TEXT    UNIQUE NOT NULL,"
    "  age   INTEGER"
    ")"
)
cursor.execute(create_sql)
conn.commit()  # Save changes -- like Ctrl+S
print("Table 'users' created")

# Insert rows
cursor.execute("INSERT INTO users (name, email, age) VALUES (?, ?, ?)",
               ("Alice", "alice@example.com", 30))
cursor.execute("INSERT INTO users (name, email, age) VALUES (?, ?, ?)",
               ("Bob", "bob@example.com", 25))
cursor.executemany("INSERT INTO users (name, email, age) VALUES (?, ?, ?)", [
    ("Carol", "carol@example.com", 35),
    ("Dave",  "dave@example.com",  28),
])
conn.commit()
print("4 users inserted")

# Query
cursor.execute("SELECT * FROM users ORDER BY name")
rows = cursor.fetchall()

print("\nAll users:")
print(f"{'ID':<5} {'Name':<10} {'Email':<25} {'Age'}")
print("-" * 50)
for row in rows:
    print(f"{row[0]:<5} {row[1]:<10} {row[2]:<25} {row[3]}")

conn.close()

# %%
import sqlite3

conn = sqlite3.connect(":memory:")
conn.row_factory = sqlite3.Row  # Rows behave like dicts -- much better than tuple indices!

cursor = conn.cursor()
create_posts_sql = (
    "CREATE TABLE posts ("
    "  id        INTEGER PRIMARY KEY AUTOINCREMENT,"
    "  title     TEXT    NOT NULL,"
    "  content   TEXT,"
    "  user_id   INTEGER,"
    "  published INTEGER DEFAULT 0"
    ")"
)
cursor.execute(create_posts_sql)
cursor.executemany(
    "INSERT INTO posts (title, content, user_id, published) VALUES (?, ?, ?, ?)",
    [
        ("Intro to Python",  "Python is amazing!", 1, 1),
        ("FastAPI Guide",    "FastAPI is fast!",    1, 1),
        ("Draft post",       "Work in progress",    2, 0),
        ("SQLite Tips",      "Use row_factory!",    2, 1),
    ]
)
conn.commit()

# Access columns by name, not index
cursor.execute("SELECT * FROM posts WHERE published = 1")
for row in cursor.fetchall():
    print(f"[{row['id']}] {row['title']} (user {row['user_id']})")

print()
cursor.execute("SELECT title, content FROM posts WHERE user_id = ? AND published = 1", (1,))
print("User 1 published posts:")
for p in cursor.fetchall():
    print(f"  - {p['title']}: {p['content'][:30]}")

conn.close()

# %% [markdown]
# ## ⚔️ Deep Dive: Raw SQL vs SQLAlchemy ORM
#
# The same operations — both ways. This shows exactly what the ORM buys you:

# %%
print("=" * 55)
print("RAW SQL APPROACH")
print("=" * 55)

raw_sql_code = '''
import sqlite3

conn = sqlite3.connect("app.db")
cursor = conn.cursor()

# Insert user
cursor.execute(
    "INSERT INTO users (name, email) VALUES (?, ?)",
    ("Alice", "alice@example.com")
)
user_id = cursor.lastrowid   # Get the auto-generated ID

# Insert post
cursor.execute(
    "INSERT INTO posts (title, user_id) VALUES (?, ?)",
    ("My first post", user_id)
)
conn.commit()

# Fetch user posts
cursor.execute("SELECT p.title FROM posts p WHERE p.user_id = ?", (user_id,))
posts = cursor.fetchall()
'''
print(raw_sql_code)

print("=" * 55)
print("SQLALCHEMY ORM APPROACH")
print("=" * 55)

orm_code = '''
from sqlalchemy.orm import Session

# Insert user
user = User(name="Alice", email="alice@example.com")
session.add(user)
session.commit()
session.refresh(user)   # Load the auto-generated ID

# Insert post
post = Post(title="My first post", user_id=user.id)
session.add(post)
session.commit()

# Fetch user posts -- SQLAlchemy handles the JOIN for you!
posts = user.posts
'''
print(orm_code)

print("VERDICT:")
print("  Raw SQL  -> More control, visible SQL, verbose, SQL injection risk if not careful")
print("  ORM      -> Pythonic, safer, easier relationships, auto-generates SQL")
print("  Hybrid   -> Use ORM for most things, raw SQL for complex analytics queries")

# %% [markdown]
# ## 🔨 SQLAlchemy ORM — Python's Most Powerful Database Toolkit
#
# **SQLAlchemy** is the most widely used database library in the Python ecosystem.
#
# > **ORM = Object-Relational Mapper**: It translates between Python objects and database rows. You write Python classes; SQLAlchemy writes SQL.
#
# ```
# Your Python                SQLAlchemy                 Database
# -----------                ----------                 --------
# class User          ->     CREATE TABLE users
# User(name="Alice")  ->     INSERT INTO users ...
# session.query(User) ->     SELECT * FROM users
# ```
#
# ### Installation
#
# A beginner usually learns this material faster by connecting each setup step to its purpose rather than treating it as a checklist. Keep asking what each piece enables and what would fail if you skipped it.
#
# ```bash
# pip install sqlalchemy
# ```
#
# > ❓ **What does `pip install` actually do?** `pip` downloads the named package from PyPI (the Python Package Index), along with any packages it depends on, and places them inside your currently active environment.

# %%
try:
    import sqlalchemy
    print(f"SQLAlchemy {sqlalchemy.__version__} is available!")
except ImportError:
    print("Run: pip install sqlalchemy")

# %%
from sqlalchemy import create_engine, Column, Integer, String, Boolean, Text, ForeignKey
from sqlalchemy.orm import DeclarativeBase, relationship, Session

# Step 1: Create the engine -- the connection to the database
# "sqlite:///:memory:" = in-memory SQLite
# "sqlite:///myapp.db" = file-based SQLite (persists on disk)
# "postgresql://user:pass@localhost/dbname" = PostgreSQL
engine = create_engine("sqlite:///:memory:", echo=False)
print("Engine created")

# Step 2: Define the Base -- all models inherit from this
class Base(DeclarativeBase):
    pass

# Step 3: Define Models -- Python classes = database tables

class User(Base):
    __tablename__ = "users"      # Name of the SQL table

    id    = Column(Integer, primary_key=True, autoincrement=True)
    name  = Column(String(100), nullable=False)
    email = Column(String(200), unique=True, nullable=False)
    age   = Column(Integer)

    # Relationship: one user has many posts
    posts = relationship("Post", back_populates="author", cascade="all, delete-orphan")

    def __repr__(self):
        return f"<User id={self.id} name={self.name!r}>"

class Post(Base):
    __tablename__ = "posts"

    id        = Column(Integer, primary_key=True, autoincrement=True)
    title     = Column(String(200), nullable=False)
    content   = Column(Text)
    published = Column(Boolean, default=False)
    user_id   = Column(Integer, ForeignKey("users.id"), nullable=False)

    # Back-reference: access post.author to get the User object
    author = relationship("User", back_populates="posts")

    def __repr__(self):
        return f"<Post id={self.id} title={self.title!r}>"

# Step 4: Create the tables in the database
Base.metadata.create_all(engine)
print("Tables created:", list(Base.metadata.tables.keys()))

# %% [markdown]
# ### Sessions — The Shopping Cart Analogy
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# > A **session** is like a **shopping cart**. You add items, modify them, remove them — but nothing changes in the actual store until you **checkout** (`session.commit()`). If you change your mind, you can **empty the cart** (`session.rollback()`).

# %%
from sqlalchemy.orm import Session

# CRUD: CREATE
print("=== CREATE ===")

with Session(engine) as session:
    alice = User(name="Alice", email="alice@example.com", age=30)
    bob   = User(name="Bob",   email="bob@example.com",   age=25)
    carol = User(name="Carol", email="carol@example.com", age=35)

    session.add_all([alice, bob, carol])
    session.commit()

    session.refresh(alice)
    session.refresh(bob)

    print(f"Alice's auto-generated ID: {alice.id}")
    print(f"Bob's   auto-generated ID: {bob.id}")
    print(f"Carol's auto-generated ID: {carol.id}")

    session.add_all([
        Post(title="Learning Python",  content="It's amazing!", published=True,  user_id=alice.id),
        Post(title="FastAPI is great", content="So fast!",      published=True,  user_id=alice.id),
        Post(title="Draft post",       content="WIP...",         published=False, user_id=alice.id),
        Post(title="Hello World",      content="My first post",  published=True,  user_id=bob.id),
    ])
    session.commit()
    print("Posts created!")

# %%
from sqlalchemy import select
from sqlalchemy.orm import Session

# CRUD: READ
print("=== READ ===")

with Session(engine) as session:

    # Get all users
    all_users = session.execute(select(User)).scalars().all()
    print("All users:", all_users)

    # Get one user by primary key
    user = session.get(User, 1)
    print(f"\nUser with id=1: {user}")

    # Filter with WHERE
    young = session.execute(select(User).where(User.age < 32)).scalars().all()
    print(f"\nUsers under 32: {[u.name for u in young]}")

    # Order and limit
    first_two = session.execute(select(User).order_by(User.name).limit(2)).scalars().all()
    print(f"\nFirst 2 alphabetically: {[u.name for u in first_two]}")

    # .first() vs .one()
    # .first() -> returns first result or None (safe!)
    # .one()   -> raises error if 0 or more than 1 result
    found   = session.execute(select(User).where(User.name == "Alice")).scalars().first()
    missing = session.execute(select(User).where(User.name == "Nobody")).scalars().first()
    print(f"\nfirst() for Alice: {found}")
    print(f"first() for Nobody: {missing}")  # None -- no crash!

# %%
from sqlalchemy import select
from sqlalchemy.orm import Session

# CRUD: READ -- Relationships (the real power of ORM)
print("=== RELATIONSHIPS ===")

with Session(engine) as session:

    alice = session.execute(select(User).where(User.name == "Alice")).scalars().first()

    print(f"Posts by {alice.name}:")
    for post in alice.posts:   # SQLAlchemy handles the JOIN automatically!
        status = "Published" if post.published else "Draft"
        print(f"  [{status}] {post.title}")

    # Reverse: from post, get the author
    published = session.execute(select(Post).where(Post.published == True)).scalars().all()
    print("\nAll published posts with authors:")
    for post in published:
        print(f"  '{post.title}' by {post.author.name}")

# %%
from sqlalchemy import select
from sqlalchemy.orm import Session

# CRUD: UPDATE
print("=== UPDATE ===")

with Session(engine) as session:

    alice = session.execute(select(User).where(User.name == "Alice")).scalars().first()
    print(f"Before: {alice.name}, age={alice.age}")

    # Modify the object's attributes
    alice.age = 31
    alice.email = "alice.updated@example.com"
    session.commit()
    session.refresh(alice)

    print(f"After:  {alice.name}, age={alice.age}, email={alice.email}")

    # Publish all drafts
    drafts = session.execute(
        select(Post).where(Post.user_id == alice.id, Post.published == False)
    ).scalars().all()
    print(f"\nPublishing {len(drafts)} draft(s)...")
    for post in drafts:
        post.published = True
    session.commit()
    print("Done! All posts now published.")

# %%
from sqlalchemy import select
from sqlalchemy.orm import Session

# CRUD: DELETE
print("=== DELETE ===")

with Session(engine) as session:

    # Delete a specific post
    post = session.execute(select(Post).where(Post.title == "Draft post")).scalars().first()
    if post:
        session.delete(post)
        session.commit()
        print(f"Deleted post: '{post.title}'")

    remaining = session.execute(select(Post)).scalars().all()
    print(f"\nRemaining posts ({len(remaining)}):")
    for p in remaining:
        print(f"  [{p.id}] {p.title}")

    # Cascade delete: deleting a user deletes their posts too
    # (because we set cascade="all, delete-orphan" in the relationship)
    bob = session.execute(select(User).where(User.name == "Bob")).scalars().first()
    print(f"\nDeleting user Bob (and all his posts)...")
    session.delete(bob)
    session.commit()

    all_posts = session.execute(select(Post)).scalars().all()
    print(f"Posts remaining after Bob's deletion: {len(all_posts)}")

# %% [markdown]
# ## 🧪 What If? Experimentation
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### What If You Forget to `session.commit()`?
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.

# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.orm import DeclarativeBase, Session
from sqlalchemy import select

exp_engine = create_engine("sqlite:///:memory:")

class ExpBase(DeclarativeBase):
    pass

class Item(ExpBase):
    __tablename__ = "items"
    id   = Column(Integer, primary_key=True)
    name = Column(String)

ExpBase.metadata.create_all(exp_engine)

print("=== WITHOUT commit() ===")
with Session(exp_engine) as session:
    session.add(Item(name="Widget"))
    # session.commit() <-- MISSING!

    # Within the same session, we can see the item (it's in session state)
    items = session.execute(select(Item)).scalars().all()
    print(f"  Items in same session: {[i.name for i in items]}")
    # When 'with' block ends, changes are ROLLED BACK automatically

# New session -- item is gone
with Session(exp_engine) as session:
    items = session.execute(select(Item)).scalars().all()
    print(f"  Items in NEW session: {items}")
    print("  Empty! The uncommitted data was lost.")

print("\n=== WITH commit() ===")
with Session(exp_engine) as session:
    session.add(Item(name="Widget"))
    session.commit()   # Saves permanently

with Session(exp_engine) as session:
    items = session.execute(select(Item)).scalars().all()
    print(f"  Items in NEW session: {[i.name for i in items]}")
    print("  Item persisted!")

print()
print("KEY INSIGHT: Always commit() after changes you want to keep.")

# %% [markdown]
# ### What If You Query for Something That Doesn't Exist?
#
# If this section feels dense, pause and identify the data structure or model first. Most of the APIs here make more sense once you know what is being stored, queried, or transformed.

# %%
from sqlalchemy import select
from sqlalchemy.orm import Session

print("=== .first() vs .one() vs session.get() ===")

with Session(engine) as session:

    # .first() -- safe, returns None if not found
    print("--- .first() ---")
    found   = session.execute(select(User).where(User.name == "Alice")).scalars().first()
    missing = session.execute(select(User).where(User.name == "Zelda")).scalars().first()
    print(f"  Alice:  {found}")
    print(f"  Zelda:  {missing}")  # None -- no crash!
    if missing is None:
        print("  -> Handle gracefully when None")

    print()

    # .one() -- raises an error if 0 or 2+ results
    print("--- .one() -- raises if not exactly one ---")
    try:
        result = session.execute(select(User).where(User.name == "Zelda")).scalars().one()
    except Exception as e:
        print(f"  Exception: {type(e).__name__}: {e}")

    print()

    # session.get() -- best for primary key lookups
    print("--- session.get() -- best for PK lookups ---")
    by_pk    = session.get(User, 1)
    not_pk   = session.get(User, 9999)
    print(f"  get(User, 1):    {by_pk}")
    print(f"  get(User, 9999): {not_pk}")

    print()
    print("RULE: Use .first() or session.get() unless you know exactly one result exists.")

# %% [markdown]
# ### What If You Change a Model Column Without a Migration?
#
# A useful beginner mental model here is to separate the shape of the data from the operations performed on it. Once you know what is being represented and who depends on that representation, the rules become easier to predict.

# %%
print("=== The Schema Drift Problem ===")
print()
print("Your app.db already exists with:")
print("  CREATE TABLE users (id INTEGER, name TEXT, email TEXT)")
print()
print("You update your Python model:")
print("  class User(Base):")
print("      id        = Column(Integer, primary_key=True)")
print("      name      = Column(String)")
print("      email     = Column(String)")
print("      phone     = Column(String)               # NEW COLUMN")
print("      is_active = Column(Boolean, default=True) # NEW COLUMN")
print()
print("PROBLEM: Base.metadata.create_all(engine) does NOT alter existing tables.")
print("It only creates tables that don't exist yet.")
print("Your database and your model are now OUT OF SYNC.")
print()
print("SOLUTION: Database migrations with Alembic")
print()
print("  pip install alembic")
print("  alembic init alembic")
print("  alembic revision --autogenerate -m 'add phone and is_active to users'")
print("  alembic upgrade head")
print()
print("Alembic tracks every schema change like Git tracks code.")
print("Each change is a 'migration' that can be applied or rolled back.")

# %% [markdown]
# ## 📦 Alembic — Database Migrations (Brief Overview)
#
# As your application evolves, your database schema changes. **Alembic** is the migration tool for SQLAlchemy — it tracks every change like Git tracks code.
#
# ```bash
# # Install
# pip install alembic
#
# # Initialize (creates alembic/ directory and alembic.ini)
# alembic init alembic
#
# # Configure alembic/env.py to point to your models
# # (set target_metadata = Base.metadata)
#
# # Auto-generate a migration from your model changes
# alembic revision --autogenerate -m "add phone column to users"
#
# # Apply the migration to the database
# alembic upgrade head
#
# # Rollback one migration
# alembic downgrade -1
#
# # See migration history
# alembic history
# ```
#
# **Why migrations matter in production:**
# - You can't just `DROP TABLE` — that destroys real user data
# - Migrations apply changes incrementally: add a column, rename a column, add an index
# - Every team member runs `alembic upgrade head` to sync their database
# - Bad migrations can be rolled back without losing data

# %% [markdown]
# ## 🔗 Connecting SQLAlchemy to FastAPI
#
# Now let's replace the in-memory list from Chapter 15 with a real SQLite database. This is the standard pattern used in production FastAPI applications:

# %%
try:
    from fastapi import FastAPI, HTTPException, Depends
    from fastapi.testclient import TestClient
    from pydantic import BaseModel
    from sqlalchemy import create_engine, Column, Integer, String, Boolean
    from sqlalchemy.orm import DeclarativeBase, Session
    from sqlalchemy import select
    from typing import Optional, List, Generator

    # ---- Database setup ----
    DB_ENGINE = create_engine("sqlite:///:memory:", echo=False)

    class DBBase(DeclarativeBase):
        pass

    class TodoDB(DBBase):
        """SQLAlchemy model -- maps to the 'todos' table"""
        __tablename__ = "todos"
        id          = Column(Integer, primary_key=True, autoincrement=True)
        title       = Column(String(200), nullable=False)
        description = Column(String(500))
        completed   = Column(Boolean, default=False)

    DBBase.metadata.create_all(DB_ENGINE)

    # ---- Pydantic models (API data shapes) ----
    class TodoCreate(BaseModel):
        title: str
        description: Optional[str] = None
        completed: bool = False

    class TodoResponse(BaseModel):
        id: int
        title: str
        description: Optional[str] = None
        completed: bool

        class Config:
            from_attributes = True  # Allow ORM objects to be serialized

    # ---- Dependency injection -- the FastAPI way to share a DB session ----
    def get_db() -> Generator:
        """Yield a database session for each request. Always closes after."""
        with Session(DB_ENGINE) as session:
            yield session

    # ---- FastAPI App ----
    todo_app = FastAPI(title="Persistent Todo API")

    @todo_app.get("/todos", response_model=List[TodoResponse])
    def list_todos(completed: Optional[bool] = None, db: Session = Depends(get_db)):
        query = select(TodoDB)
        if completed is not None:
            query = query.where(TodoDB.completed == completed)
        return db.execute(query).scalars().all()

    @todo_app.get("/todos/{todo_id}", response_model=TodoResponse)
    def get_todo(todo_id: int, db: Session = Depends(get_db)):
        todo = db.get(TodoDB, todo_id)
        if todo is None:
            raise HTTPException(status_code=404, detail=f"Todo {todo_id} not found")
        return todo

    @todo_app.post("/todos", response_model=TodoResponse, status_code=201)
    def create_todo(todo_data: TodoCreate, db: Session = Depends(get_db)):
        todo = TodoDB(title=todo_data.title,
                      description=todo_data.description,
                      completed=todo_data.completed)
        db.add(todo)
        db.commit()
        db.refresh(todo)
        return todo

    @todo_app.put("/todos/{todo_id}", response_model=TodoResponse)
    def update_todo(todo_id: int, updates: TodoCreate, db: Session = Depends(get_db)):
        todo = db.get(TodoDB, todo_id)
        if todo is None:
            raise HTTPException(status_code=404, detail=f"Todo {todo_id} not found")
        todo.title       = updates.title
        todo.description = updates.description
        todo.completed   = updates.completed
        db.commit()
        db.refresh(todo)
        return todo

    @todo_app.delete("/todos/{todo_id}", status_code=204)
    def delete_todo(todo_id: int, db: Session = Depends(get_db)):
        todo = db.get(TodoDB, todo_id)
        if todo is None:
            raise HTTPException(status_code=404, detail=f"Todo {todo_id} not found")
        db.delete(todo)
        db.commit()
        return None

    print("Persistent Todo API (FastAPI + SQLAlchemy) defined!")

except ImportError as e:
    print(f"Missing dependency: {e}")
    print("Run: pip install fastapi sqlalchemy")

# %%
# Test the fully integrated API

try:
    client = TestClient(todo_app)

    print("=" * 50)
    print("1. CREATE todos (data goes to SQLite!)")
    print("=" * 50)
    r1 = client.post("/todos", json={"title": "Learn SQLAlchemy"})
    r2 = client.post("/todos", json={"title": "Connect to FastAPI", "description": "Use Depends()"})
    r3 = client.post("/todos", json={"title": "Deploy to production"})
    for r in [r1, r2, r3]:
        d = r.json()
        print(f"  [{d['id']}] {d['title']}")

    print("\n" + "=" * 50)
    print("2. LIST all todos from database")
    print("=" * 50)
    for todo in client.get("/todos").json():
        marker = "[x]" if todo["completed"] else "[ ]"
        print(f"  {marker} [{todo['id']}] {todo['title']}")

    print("\n" + "=" * 50)
    print("3. UPDATE -- mark first todo as completed")
    print("=" * 50)
    resp = client.put("/todos/1", json={"title": "Learn SQLAlchemy", "completed": True})
    d = resp.json()
    print(f"  {d['title']} -> completed: {d['completed']}")

    print("\n" + "=" * 50)
    print("4. FILTER -- only incomplete todos")
    print("=" * 50)
    for todo in client.get("/todos?completed=false").json():
        print(f"  [ ] [{todo['id']}] {todo['title']}")

    print("\n" + "=" * 50)
    print("5. DELETE -- remove a todo")
    print("=" * 50)
    resp = client.delete("/todos/2")
    print(f"  Delete status: {resp.status_code} (204 = success)")

    print("\n" + "=" * 50)
    print("6. Final state")
    print("=" * 50)
    for todo in client.get("/todos").json():
        marker = "[x]" if todo["completed"] else "[ ]"
        print(f"  {marker} [{todo['id']}] {todo['title']}")

    print()
    print("All data lives in SQLite, not in-memory Python!")
    print("With a file-based engine (sqlite:///app.db), data persists across restarts.")

except NameError:
    print("Run the previous cell first!")

# %% [markdown]
# ## 🚀 Real-World Project Link
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# > In our **Notes API project**, we'll replace the in-memory storage from Chapter 15 with a **SQLite database** using SQLAlchemy. Notes will have a title, content, and tags. We'll add a `/notes/search?q=keyword` endpoint that queries the database with a `LIKE` filter — something impossible with a plain Python list. The full pattern — FastAPI + Pydantic + SQLAlchemy + SQLite — is the same stack used in countless production Python web applications.

# %% [markdown]
# ## 📋 Chapter Summary & Cheat Sheet
#
# ### Key Concepts
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - **Databases** provide persistent, queryable storage that survives server restarts
# - **SQLite** is a serverless, file-based database built into Python
# - **SQLAlchemy** is Python's ORM: write Python classes, get SQL for free
# - **Sessions** are transaction contexts — add/modify, then commit to save
# - **Relationships** (`relationship()`) handle JOINs for you automatically
# - **Alembic** manages schema migrations as your models evolve
# ### SQLAlchemy ORM Cheat Sheet
#
# A useful beginner mental model here is to separate the shape of the data from the operations performed on it. Once you know what is being represented and who depends on that representation, the rules become easier to predict.
#
# ```python
# from sqlalchemy import create_engine, Column, Integer, String, Boolean, ForeignKey
# from sqlalchemy.orm import DeclarativeBase, Session, relationship
# from sqlalchemy import select
#
# engine = create_engine("sqlite:///myapp.db")
#
# class Base(DeclarativeBase): pass
#
# class User(Base):
#     __tablename__ = "users"
#     id    = Column(Integer, primary_key=True)
#     name  = Column(String, nullable=False)
#     posts = relationship("Post", back_populates="author")
#
# class Post(Base):
#     __tablename__ = "posts"
#     id      = Column(Integer, primary_key=True)
#     title   = Column(String)
#     user_id = Column(Integer, ForeignKey("users.id"))
#     author  = relationship("User", back_populates="posts")
#
# Base.metadata.create_all(engine)
#
# with Session(engine) as session:
#     # CREATE
#     user = User(name="Alice")
#     session.add(user)
#     session.commit()
#     session.refresh(user)      # Load auto-generated ID
#
#     # READ
#     all_users = session.execute(select(User)).scalars().all()
#     one       = session.get(User, 1)          # by primary key -> None if not found
#     found     = session.execute(
#                     select(User).where(User.name == "Alice")
#                 ).scalars().first()           # None if not found
#
#     # UPDATE
#     user.name = "Alice Smith"
#     session.commit()
#
#     # DELETE
#     session.delete(user)
#     session.commit()
# # FastAPI + SQLAlchemy pattern:
# def get_db():
#     with Session(engine) as session:
#         yield session
#
# @app.get("/items")
# def list_items(db: Session = Depends(get_db)):
#     return db.execute(select(Item)).scalars().all()
# ```

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='15.%20modern_web_frameworks.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 15: Web Frameworks</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../7.%20data_science_and_automation/17.%20the_data_science_stack.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 17: Data Science →</a>
# </div>

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='15. modern_web_frameworks.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../7. data_science_and_automation/17. the_data_science_stack.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
