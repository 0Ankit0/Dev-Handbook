# %% [markdown]
# # Chapter 14: Web Basics and APIs — How the Internet Works with Python
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../5.%20advanced_python_features/13.%20concurrency_and_parallelism.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 13: Concurrency</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='15.%20modern_web_frameworks.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 15: Web Frameworks →</a>
# </div>
#
# ---

# %% [markdown]
# ## 🌍 The Big Picture
#
# Every time you open a web page, search Google, or use a mobile app, your device is **sending requests over the internet and receiving responses**. Behind every weather widget, map, stock ticker, and social media feed is an API being called — often thousands of times per second.
#
# Python can participate in this conversation from both sides:
# - 🔍 **Sending requests** to web services (APIs) to fetch or submit data
# - 🏗️ **Building web services** of your own (covered in Chapter 15)
#
# In this chapter, you'll go from "I have no idea how a website works" to "I can fetch live data from the internet using Python" in a single session.
#
# **What you'll build by the end:** A Python script that fetches live data from a public API, processes the JSON response, handles errors gracefully, and displays formatted results.

# %% [markdown]
# ## 🧠 Core Concepts: The "Why"
#
# ### The Client-Server Model
#
# Every web interaction involves two roles:
#
# - **Client** — the one making requests (your browser, your Python script, a mobile app)
# - **Server** — the one responding (the machine hosting the website or API)
#
# **The Restaurant Analogy 🍽️**
#
# > You (the **client**) walk into a restaurant (the **server**) and place an order (the **request**). The kitchen prepares your meal and sends it back to your table (the **response**).
#
# The waiter in this analogy is **HTTP** — the protocol that defines how requests and responses are formatted and delivered.
#
# ### HTTP — HyperText Transfer Protocol
#
# HTTP is the language of the web. When your browser loads `https://example.com`, it's really sending an HTTP message that says:
#
# ```yaml
# GET /index.html HTTP/1.1
# Host: example.com
# ```
#
# And the server responds:
#
# ```text
# HTTP/1.1 200 OK
# Content-Type: text/html
# ...the actual HTML...
# ```

# %% [markdown]
# ### HTTP Methods — The "What Are You Doing?" of Requests
#
# Every HTTP request has a **method** (also called a *verb*) that describes what you want to do:
#
# | Method | Meaning | Restaurant Analogy |
# |--------|---------|-------------------|
# | **GET** | Retrieve data | "Can I see the menu?" |
# | **POST** | Send/create new data | "I'd like to order a burger" |
# | **PUT** | Update existing data | "Actually, make that a veggie burger" |
# | **DELETE** | Remove data | "Cancel my order" |
#
# You'll use GET and POST most of the time.

# %% [markdown]
# ### HTTP Status Codes — The Server's Reaction
#
# Status codes are 3-digit numbers in every HTTP response that tell you what happened:
#
# | Code | Meaning | Analogy |
# |------|---------|---------|
# | **200 OK** | Success! | "Here's your meal 🍔" |
# | **201 Created** | New resource created | "Your order is in the system ✅" |
# | **400 Bad Request** | You sent bad data | "I can't understand your order 🤔" |
# | **401 Unauthorized** | Not logged in | "Members only — show your card 🪪" |
# | **403 Forbidden** | Logged in but not allowed | "You don't have permission for that 🚫" |
# | **404 Not Found** | Resource doesn't exist | "We don't serve that dish 🤷" |
# | **429 Too Many Requests** | Rate limited | "You've ordered too much, slow down ⏱️" |
# | **500 Internal Server Error** | Server crashed | "The kitchen is on fire 🔥" |
#
# Codes starting with **2xx** = success. **4xx** = your fault. **5xx** = their fault.

# %% [markdown]
# ## 🔧 Syntax & First Usage: The "How"
#
# Sending an HTTP request from Python takes just a few lines. The `requests` library handles all the low-level details — connection management, encoding, redirects — so you can focus on what URL to call and what to do with the response.
#
# ### Installing and Importing `requests`
#
# `requests` is Python's friendliest library for making HTTP calls. It's not in the standard library, so you'd normally install it first:
#
# ```bash
# pip install requests
# ```
#
# In this notebook, we'll import it and use it immediately. Every part is explained inline.

# %%
# The requests library is Python's go-to for HTTP calls
# If you get an ImportError, run: pip install requests
import requests

# Let's make our very first web request!
# JSONPlaceholder is a free, fake REST API perfect for learning
url = "https://jsonplaceholder.typicode.com/posts/1"

# requests.get() sends an HTTP GET request to the URL
# It returns a Response object containing everything the server sent back
response = requests.get(url)

# Let's inspect what we got back
print("Status code:", response.status_code)   # Was the request successful?
print("Content type:", response.headers["Content-Type"])  # What type of data?
print("Response size:", len(response.text), "characters")

# %% [markdown]
# ### Dissecting the Response Object
#
# The `response` object is your window into everything the server sent back.

# %%
import requests

response = requests.get("https://jsonplaceholder.typicode.com/posts/1")

# .status_code — the HTTP status code (integer)
print("Status Code:", response.status_code)        # 200 means success

# .ok — a convenient boolean: True if status_code < 400
print("Is OK?:", response.ok)

# .text — the response body as a raw string
print("\nRaw Text (first 200 chars):")
print(response.text[:200])

# .json() — parse the response body as JSON -> returns a Python dict or list
print("\nParsed as Python dict:")
data = response.json()
print(type(data))
print(data)

# %%
import requests

# Once we have a Python dict, we can work with it like any other dict
response = requests.get("https://jsonplaceholder.typicode.com/posts/1")
post = response.json()

print("Post ID:   ", post["id"])
print("User ID:   ", post["userId"])
print("Title:     ", post["title"])
print("Body:      ", post["body"][:80], "...")

# Check if a key exists safely with .get()
print("Author:    ", post.get("author", "No author field in this API"))

# %% [markdown]
# ## 🌐 APIs — Application Programming Interfaces
#
# ### The Waiter Analogy
#
# > An **API** (Application Programming Interface) is like a waiter in a restaurant. You don't go directly into the kitchen (the server's internal systems). Instead, you tell the waiter (the API) what you want, the waiter communicates with the kitchen, and brings back what you ordered.
#
# APIs define:
# - **What you can ask for** (available endpoints like `/posts`, `/users`)
# - **How to ask** (GET, POST, etc.)
# - **What format to use** (usually JSON)
# - **What you'll get back** (the structure of the response)
# ### REST APIs
#
# **REST** (Representational State Transfer) is the most common API style. RESTful APIs follow these conventions:
# - Resources are **nouns** in the URL: `/users`, `/posts`, `/products`
# - HTTP methods define the **action**: GET to read, POST to create, etc.
# - Responses are usually **JSON**
#
# ### JSONPlaceholder — Our Learning API
#
# For this chapter, we'll use **JSONPlaceholder** (`https://jsonplaceholder.typicode.com`), a free fake REST API for learning. No sign-up, no API key required.

# %%
import requests

BASE_URL = "https://jsonplaceholder.typicode.com"

# GET all posts — fetches a list of resources
response = requests.get(f"{BASE_URL}/posts")
posts = response.json()

print(f"Total posts: {len(posts)}")
print("\nFirst 3 posts:")
for post in posts[:3]:
    print(f"  [{post['id']}] {post['title'][:55]}...")

# %%
import requests

BASE_URL = "https://jsonplaceholder.typicode.com"

# GET a single resource — fetch just post #5
response = requests.get(f"{BASE_URL}/posts/5")
print("Status:", response.status_code)
print("Post #5:", response.json())

# %%
import requests

BASE_URL = "https://jsonplaceholder.typicode.com"

# Query Parameters — filter results with ?key=value in the URL
# requests handles this cleanly with the params= argument

response = requests.get(
    f"{BASE_URL}/posts",
    params={"userId": 1}  # Only get posts by user 1
)

posts_by_user1 = response.json()
print(f"Posts by user 1: {len(posts_by_user1)}")
print("\nTitles:")
for post in posts_by_user1:
    print(f"  - {post['title'][:60]}")

print("\nActual URL sent:", response.url)

# %% [markdown]
# ## 📤 Sending Data with POST
#
# GET requests *retrieve* data. POST requests *send* data to create something new.

# %%
import requests

BASE_URL = "https://jsonplaceholder.typicode.com"

new_post = {
    "title": "My First API Post",
    "body": "This is the content of my post, sent from Python!",
    "userId": 1
}

# json= auto-serializes the dict AND sets Content-Type: application/json
response = requests.post(f"{BASE_URL}/posts", json=new_post)

print("Status code:", response.status_code)  # 201 = Created
print("\nServer's response:")
created = response.json()
print(created)
print("\nNew post ID assigned by server:", created["id"])

# %% [markdown]
# ## ⚔️ Deep Dive: GET vs POST
#
# | Feature | `requests.get()` | `requests.post()` |
# |---------|-----------------|------------------|
# | **Purpose** | Retrieve data | Send/create data |
# | **Data location** | URL query params | Request body |
# | **Bookmarkable?** | Yes (it's just a URL) | No |
# | **Idempotent?** | Yes (safe to repeat) | No (creates duplicates) |
# | **Common use** | Fetch a list, get one item | Submit a form, create a record |
#
# ```python
# # GET — data goes in the URL
# requests.get("https://api.example.com/search?q=python&limit=10")
#
# # POST — data goes in the body (invisible in the URL)
# requests.post("https://api.example.com/users",
#               json={"name": "Alice", "email": "alice@example.com"})
# ```

# %% [markdown]
# ## 🔐 Headers and Authentication
#
# HTTP **headers** are metadata attached to requests and responses.
#
# Common headers you'll send:
# - `Content-Type: application/json` — "I'm sending JSON" (requests sets this automatically)
# - `Authorization: Bearer TOKEN` — "Here's my API token"
# - `Accept: application/json` — "Please respond in JSON"

# %%
import requests

# Simulating an authenticated request
# (JSONPlaceholder doesn't check this, but the pattern is correct)

headers = {
    "Authorization": "Bearer my-secret-api-token-here",
    "Accept": "application/json",
    "User-Agent": "MyPythonApp/1.0"
}

response = requests.get(
    "https://jsonplaceholder.typicode.com/posts/1",
    headers=headers
)

print("Request headers sent:")
for key, value in response.request.headers.items():
    print(f"  {key}: {value}")

print("\nResponse received:", response.status_code)

# %% [markdown]
# ## 🛡️ Error Handling with APIs
#
# Never trust the network — here's how to handle errors like a professional:

# %%
import requests

# Method 1: Check status_code manually
response = requests.get("https://jsonplaceholder.typicode.com/posts/99999")

if response.status_code == 200:
    print("Success! Data:", response.json())
elif response.status_code == 404:
    print("Not found — that resource doesn't exist")
elif response.status_code == 500:
    print("Server error — their problem, not ours")
else:
    print(f"Unexpected status: {response.status_code}")

# %%
import requests

# Method 2: raise_for_status()
# Raises an HTTPError for any 4xx or 5xx status code

try:
    response = requests.get("https://jsonplaceholder.typicode.com/posts/99999")
    response.raise_for_status()
    data = response.json()
    print("Data:", data)
except requests.exceptions.HTTPError as e:
    print(f"HTTP error: {e}")
    print(f"Status code: {e.response.status_code}")

# %%
import requests

# Method 3: Full exception handling — covers ALL failure modes

def fetch_post(post_id):
    """Fetch a single post by ID, with comprehensive error handling."""
    url = f"https://jsonplaceholder.typicode.com/posts/{post_id}"
    try:
        response = requests.get(url, timeout=10)  # Always set a timeout!
        response.raise_for_status()
        return response.json()
    except requests.exceptions.Timeout:
        print("Request timed out")
        return None
    except requests.exceptions.ConnectionError:
        print("Connection error — check your internet connection")
        return None
    except requests.exceptions.HTTPError as e:
        print(f"HTTP {e.response.status_code} error: {e}")
        return None
    except requests.exceptions.RequestException as e:
        print(f"Something went wrong: {e}")
        return None

post = fetch_post(1)
if post:
    print(f"Got post: {post['title'][:50]}")

missing = fetch_post(999999)
print(f"\nMissing post result: {missing}")

# %% [markdown]
# ## 🔍 Parsing JSON Defensively
#
# APIs sometimes change their schema. Use `.get()` to access fields safely:

# %%
import requests

response = requests.get("https://jsonplaceholder.typicode.com/users/1")
user = response.json()

print("Raw user data:")
print(user)
print()

# FRAGILE (crashes if address is missing):
# print(user["address"]["city"])

# SAFE — use .get() at each level with fallback defaults
address = user.get("address", {})
city = address.get("city", "Unknown city")
geo = address.get("geo", {})
lat = geo.get("lat", "N/A")

print(f"User: {user.get('name', 'Unknown')}")
print(f"City: {city}")
print(f"Latitude: {lat}")
print(f"Company: {user.get('company', {}).get('name', 'No company')}")

# %% [markdown]
# ## 🧪 What If? Experimentation
#
# APIs fail in ways that are easy to predict — once you've seen them once. These scenarios cover the most common failure modes you'll encounter in real projects.
#
# ### What If the API is Down?

# %%
import requests

# Connecting to a server that doesn't exist
try:
    response = requests.get("https://this-domain-absolutely-does-not-exist-xyz99.com", timeout=5)
except requests.exceptions.ConnectionError as e:
    print("ConnectionError raised!")
    print("This happens when DNS lookup fails or the server is unreachable")
    print(f"Error type: {type(e).__name__}")
except requests.exceptions.Timeout:
    print("Timeout! The server took too long.")

print()
print("LESSON: Always wrap requests in try/except when the network is involved.")

# %% [markdown]
# ### What If You Hit a Rate Limit?
#
# Many APIs limit requests per minute/hour. They respond with **429 Too Many Requests**:

# %%
import requests
import time

def api_request_with_retry(url, max_retries=3):
    """Make an API request with automatic retry on rate limiting."""
    for attempt in range(1, max_retries + 1):
        response = requests.get(url)
        if response.status_code == 200:
            return response.json()
        elif response.status_code == 429:
            retry_after = int(response.headers.get("Retry-After", 60))
            print(f"Rate limited! Waiting {retry_after}s (attempt {attempt}/{max_retries})")
            time.sleep(retry_after)
        else:
            print(f"Error {response.status_code} on attempt {attempt}")
            break
    return None

result = api_request_with_retry("https://jsonplaceholder.typicode.com/posts/1")
print("Result:", result["title"] if result else "Failed")
print()
print("KEY INSIGHT: Check for 429 status code in API-heavy applications.")

# %% [markdown]
# ### What If the JSON Structure Changes?

# %%
def process_api_response(data):
    """Process user data safely regardless of which fields are present."""
    name  = data.get("name") or data.get("username") or "Anonymous"
    email = data.get("email", "not provided")
    city  = data.get("address", {}).get("city", "Unknown")
    tags  = data.get("tags", [])
    tag_str = ", ".join(tags) if isinstance(tags, list) else str(tags)
    return {"name": name, "email": email, "city": city, "tags": tag_str}

# Current API structure
current = {"name": "Alice", "email": "a@example.com", "address": {"city": "Wonderland"}, "tags": ["admin"]}
# Future structure — some fields renamed
future  = {"username": "alice42", "contact": "a@example.com", "location": "Wonderland"}

print("Current:", process_api_response(current))
print("Future: ", process_api_response(future))
print()
print("KEY INSIGHT: .get() with defaults makes your code resilient to API changes.")

# %% [markdown]
# ## 🏗️ Building a Complete API Consumer
#
# A robust API consumer separates **connection logic** (base URL, auth headers, timeout) from **business logic** (what to do with the data). Here's the pattern:
#
# 1. **Configure once** — set a `timeout`, `base_url`, and auth `headers` in one place
# 2. **One function per operation** — each function does one thing: fetch a list, get one item, create a record
# 3. **Handle errors at the boundary** — catch `requests` exceptions where the call is made, not scattered throughout your application
# 4. **Parse defensively** — use `.get('key', default)` so a schema change in the API doesn't crash your whole program
#
# > 💡 Using `requests.Session()` lets you share headers and connection pooling across multiple calls — more efficient than creating a new connection each time.

# %%
import requests

def get_user_summary(user_id):
    """Fetch a user and their posts, return a formatted summary."""
    base = "https://jsonplaceholder.typicode.com"

    try:
        user_resp = requests.get(f"{base}/users/{user_id}", timeout=10)
        user_resp.raise_for_status()
        user = user_resp.json()
    except requests.exceptions.RequestException as e:
        return f"Could not fetch user {user_id}: {e}"

    try:
        posts_resp = requests.get(f"{base}/posts", params={"userId": user_id}, timeout=10)
        posts_resp.raise_for_status()
        posts = posts_resp.json()
    except requests.exceptions.RequestException:
        posts = []  # Graceful degradation

    lines = [
        f"{'='*50}",
        f"User #{user.get('id')}: {user.get('name')}",
        f"{'='*50}",
        f"  Email:   {user.get('email')}",
        f"  Company: {user.get('company', {}).get('name')}",
        f"  City:    {user.get('address', {}).get('city')}",
        f"",
        f"  Posts ({len(posts)} total):",
    ]
    for post in posts[:3]:
        lines.append(f"    [{post['id']}] {post['title'][:55]}...")
    if len(posts) > 3:
        lines.append(f"    ... and {len(posts) - 3} more")

    return "\n".join(lines)

for uid in [1, 2]:
    print(get_user_summary(uid))
    print()

# %% [markdown]
# ## 🚀 Real-World Project Link
#
# > In our **Weather App project**, we'll use a public weather API (like OpenWeatherMap) to fetch current conditions and 5-day forecasts. The `requests` library, error handling patterns, and JSON parsing you've learned here are exactly what you'll need — pass your city name as a query parameter and display temperature, humidity, and conditions in a clean terminal output.

# %% [markdown]
# ## 📋 Chapter Summary & Cheat Sheet
#
# ### Key Concepts
#
# - **HTTP** is the protocol of the web: requests and responses
# - **Methods**: GET (read), POST (create), PUT (update), DELETE (remove)
# - **Status codes**: 2xx = success, 4xx = client error, 5xx = server error
# - **REST APIs** use URLs as resource names and HTTP methods as actions
# - **JSON** is the standard data format for web APIs
# ### Cheat Sheet
#
# ```python
# import requests
# # GET (retrieve)
# resp = requests.get("https://api.example.com/items",
#                     params={"limit": 10},
#                     headers={"Authorization": "Bearer TOKEN"},
#                     timeout=10)
#
# # POST (create)
# resp = requests.post("https://api.example.com/items",
#                      json={"name": "widget", "price": 9.99})
#
# # Inspect response
# resp.status_code    # 200, 404, 500, etc.
# resp.ok             # True if status < 400
# resp.text           # Raw string
# resp.json()         # Python dict/list
#
# # Error handling
# resp.raise_for_status()   # Raises HTTPError for 4xx/5xx
#
# try:
#     resp = requests.get(url, timeout=10)
#     resp.raise_for_status()
#     data = resp.json()
# except requests.exceptions.Timeout:        pass
# except requests.exceptions.ConnectionError: pass
# except requests.exceptions.HTTPError as e:  pass
#
# # Safe JSON access
# value  = data.get("key", "default")
# nested = data.get("outer", {}).get("inner", "fallback")
# ```

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='../5.%20advanced_python_features/13.%20concurrency_and_parallelism.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 13: Concurrency</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='15.%20modern_web_frameworks.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 15: Web Frameworks →</a>
# </div>
