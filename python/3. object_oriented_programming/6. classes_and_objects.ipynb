# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../2.%20data_structures_and_functions/5.%20functions_and_modular_programming.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 5: Functions</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='7.%20advanced_oop_concepts.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 7: Advanced OOP →</a>
# </div>
#
# ---

# %% [markdown]
# # Chapter 6: Classes and Objects — Modeling the Real World
#
# ---

# %% [markdown]
# ## 🌍 The Big Picture
#
# Imagine you're running a **dog shelter**. You have 50 dogs, each with a name, breed, and age.
#
# Without OOP, you'd write:
#
# ```python
# dog1_name = "Rex";   dog1_breed = "Labrador"; dog1_age = 3
# dog2_name = "Bella"; dog2_breed = "Poodle";   dog2_age = 5
# # ... 48 more sets of variables 😩
# ```
#
# What if you need a function to print every dog's info? What if you add a "weight" attribute? You'd update 50 variables.
#
# With a `Dog` **class**, you create **one template** and stamp out 50 dog objects in seconds. Change the template once — all dogs get the update.
#
# > **OOP (Object-Oriented Programming)** models real-world things — dogs, books, bank accounts — as **objects** that bundle *data* (attributes) and *behavior* (methods) together.
#
# This chapter teaches you to *think in objects*. By the end, you'll see Python programs as collections of interacting objects rather than long lists of instructions.

# %% [markdown]
# ---
#
# ## 🧠 Core Concepts: The "Why"
#
# The easiest way to read this section is to keep one plain-language question in view: what is The "Why" actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### The Blueprint Analogy
#
# Think of an **architect's blueprint** for a house:
#
# | Concept | Blueprint Analogy | Python |
# |---------|------------------|--------|
# | **Class** | The house plan (template) | `class Dog:` |
# | **Object / Instance** | An actual house built from the plan | `my_dog = Dog(...)` |
# | **Attribute** | A property of the house (color, size) | `self.name`, `self.breed` |
# | **Method** | A behavior (open door, switch lights) | `def bark(self):` |
#
# You can build **many houses** from one blueprint — each painted a different color, but sharing the same structure. That's exactly how classes and objects work.
#
# ### Why Not Just Use Dictionaries?
#
# You *could* represent a dog as `{"name": "Rex", "breed": "Labrador", "age": 3}`.
#
# But a class lets you:
# 1. **Attach behaviors** — methods like `bark()` or `celebrate_birthday()`
# 2. **Enforce structure** — every `Dog` *must* have `name`, `breed`, `age`
# 3. **Hide complexity** — internal workings stay private from outside code
# 4. **Build families** — `Puppy` inherits from `Dog` without repeating code
# 5. **Use Python protocols** — support `len()`, `+`, `in` on your objects
#
# Dictionaries hold *data*. Classes hold *data + behavior + rules + relationships*.
#
# > ❓ **Why split code into Blueprints?** A single file with hundreds of routes becomes unreadable. Blueprints group related routes (e.g., all auth routes) into pluggable mini-applications that you register on the main app — like separate chapters in a book.

# %% [markdown]
# ---
#
# ## ✏️ Syntax & First Usage: The "How"
#
# Let's build our first class, explaining every single part.

# %%
# ── Anatomy of a Class Definition ────────────────────────────────────────
#
#  class  ← keyword: "I'm defining a class"
#  Dog    ← class name (convention: CapitalCase / PascalCase)
#  :      ← colon starts the indented class body (like def, if, for)

class Dog:
    # __init__ is the CONSTRUCTOR (double underscores = "dunder method")
    # Python calls it automatically when you create a new Dog.
    # Its job: set up the object's initial state.
    #
    # self      ← ALWAYS the first parameter of any instance method.
    #             It's the object itself — Python passes it automatically.
    #             You never supply it yourself when calling methods.
    #
    # name, breed, age ← regular arguments YOU provide

    def __init__(self, name, breed, age):
        # self.name = name  means:
        # "Attach the value of 'name' to THIS object as an attribute."
        self.name  = name
        self.breed = breed
        self.age   = age

    # bark is an INSTANCE METHOD — a function that belongs to the class.
    # 'self' gives it access to the object's own data.
    def bark(self):
        print(f"{self.name} says: Woof! 🐶")


# ── Creating Objects (Instances) ──────────────────────────────────────────
# Dog("Rex", "Labrador", 3)  → Python creates a blank Dog object, then calls
# __init__(that_object, "Rex", "Labrador", 3) automatically.

my_dog  = Dog("Rex",   "Labrador", 3)
her_dog = Dog("Bella", "Poodle",   5)

# Dot notation accesses attributes:
print(my_dog.name)    # Rex
print(her_dog.breed)  # Poodle
print(my_dog.age)     # 3

# Calling a method — Python passes my_dog in as 'self' automatically:
my_dog.bark()
her_dog.bark()

# %% [markdown]
# ### 🔍 What Just Happened, Step by Step?
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```
# my_dog = Dog("Rex", "Labrador", 3)
# ```
#
# 1. Python creates a **blank Dog object** in memory.
# 2. Python calls `Dog.__init__(blank_object, "Rex", "Labrador", 3)`.
# 3. Inside `__init__`, `self` *is* the blank object.
# 4. `self.name = "Rex"` attaches `"Rex"` to that object as an attribute.
# 5. The fully initialized object is bound to the name `my_dog`.
#
# ```
# my_dog.bark()
# ```
#
# 6. Python finds `bark` in the `Dog` class.
# 7. Internally calls `Dog.bark(my_dog)` — passes `my_dog` as `self` automatically.
# 8. Inside `bark`, `self.name` accesses `my_dog.name`, which is `"Rex"`.
#
# The `.` (dot) operator is how you reach inside an object to access its attributes or call its methods.

# %% [markdown]
# ---
#
# ## 🔬 Deep Dive
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ### A Richer Class: Multiple Methods
#
# Let's give our `Dog` a few more meaningful behaviors.

# %%
class Dog:
    def __init__(self, name, breed, age, weight_kg):
        self.name      = name
        self.breed     = breed
        self.age       = age
        self.weight_kg = weight_kg
        self.tricks    = []    # each dog starts knowing no tricks

    def learn_trick(self, trick):
        self.tricks.append(trick)
        print(f"{self.name} learned '{trick}'! 🎉")

    def show_tricks(self):
        if not self.tricks:
            print(f"{self.name} doesn't know any tricks yet.")
        else:
            print(f"{self.name} knows: {', '.join(self.tricks)}")

    def celebrate_birthday(self):
        self.age += 1
        print(f"Happy birthday, {self.name}! You are now {self.age}. 🎂")

    def size_category(self):
        if self.weight_kg < 5:
            return "toy"
        elif self.weight_kg < 25:
            return "medium"
        else:
            return "large"

    def __str__(self):
        return f"{self.name} ({self.breed}, age {self.age}, {self.weight_kg}kg)"

    def __repr__(self):
        return f"Dog({self.name!r}, {self.breed!r}, {self.age}, {self.weight_kg})"


rex   = Dog("Rex",   "Labrador",  3, 30)
bella = Dog("Bella", "Chihuahua", 2, 3)

rex.learn_trick("sit")
rex.learn_trick("shake hands")
rex.learn_trick("roll over")
rex.show_tricks()

bella.show_tricks()           # no tricks yet
bella.celebrate_birthday()

print(rex)                    # Rex (Labrador, age 3, 30kg)
print(repr(rex))              # Dog('Rex', 'Labrador', 3, 30)
print(rex.size_category())    # large
print(bella.size_category())  # toy

# Each dog has an INDEPENDENT tricks list — they don't share it!
print("Rex's tricks:", rex.tricks)
print("Bella's tricks:", bella.tricks)

# %% [markdown]
# ---
#
# ### Instance Attributes vs Class Attributes
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# > **Instance attribute** — unique to each object. Rex has his own `name`; Bella has hers.
# >
# > **Class attribute** — shared by ALL objects of that class. Like a homeowner's association rule that applies to every house.
#
# Think of class attributes as *default settings* every instance starts with.

# %%
class Dog:
    # ── Class Attributes ───────────────────────────────────────────────────
    # Defined in the class body (outside any method).
    # Shared by ALL Dog instances unless overridden.
    species      = "Canis lupus familiaris"
    domesticated = True

    def __init__(self, name, breed, age):
        # ── Instance Attributes ────────────────────────────────────────────
        self.name  = name
        self.breed = breed
        self.age   = age


dog1 = Dog("Rex",   "Labrador", 3)
dog2 = Dog("Bella", "Poodle",   5)

# Both dogs share the class attribute:
print(dog1.species)                  # Canis lupus familiaris
print(dog2.species)                  # Canis lupus familiaris
print(dog1.species is dog2.species)  # True — same object in memory

# Access via the class itself (no instance needed):
print(Dog.domesticated)   # True

# Instance attributes are independent:
print(dog1.name)  # Rex
print(dog2.name)  # Bella

# Overriding on ONE instance creates an instance attribute that
# SHADOWS the class attribute for that object only:
dog1.species = "Wolfdog hybrid"
print(dog1.species)   # Wolfdog hybrid         (instance attr — shadow)
print(dog2.species)   # Canis lupus familiaris  (class attr — unchanged)
print(Dog.species)    # Canis lupus familiaris  (class itself — unchanged)

# Inspect which attributes live on the instance vs the class:
print("dog1's own attrs:", dog1.__dict__)
print("dog2's own attrs:", dog2.__dict__)

# %% [markdown]
# ---
#
# ### Practical Use of Class Attributes: Tracking Instances
#
# A common use-case: keep a count of how many objects have been created.

# %%
class Dog:
    total_dogs = 0      # class attribute — one shared counter

    def __init__(self, name, breed):
        self.name  = name
        self.breed = breed
        Dog.total_dogs += 1     # increment the CLASS counter

    def __repr__(self):
        return f"Dog({self.name!r}, {self.breed!r})"


print(f"Dogs in shelter: {Dog.total_dogs}")    # 0

d1 = Dog("Rex",   "Labrador")
d2 = Dog("Bella", "Poodle")
d3 = Dog("Max",   "Beagle")

print(f"Dogs in shelter: {Dog.total_dogs}")    # 3
for d in [d1, d2, d3]:
    print(f"  {d}")

# Class attribute is accessible on any instance too:
print(f"Counter via instance: {d1.total_dogs}")   # 3

# %% [markdown]
# ---
#
# ### Dunder Methods: Making Objects "Speak Python"
#
# **Dunder methods** (double underscore on each side) are Python's *hooks* that let your objects participate in built-in operations.
#
# | Method | Triggered by | Purpose |
# |--------|-------------|---------|
# | `__init__` | `Dog(...)` | Object construction |
# | `__str__` | `print(obj)`, `str(obj)` | Human-readable string |
# | `__repr__` | `repr(obj)`, REPL display | Developer-readable (should recreate object) |
# | `__eq__` | `obj1 == obj2` | Equality comparison |
# | `__lt__` | `obj1 < obj2` | Less-than (enables `sorted()`) |
# | `__len__` | `len(obj)` | Return a length |
#
# Without `__str__`, `print(my_dog)` shows `<__main__.Dog object at 0x10f3a2d50>` — not useful!

# %%
class Dog:
    def __init__(self, name, breed, age):
        self.name  = name
        self.breed = breed
        self.age   = age

    def __str__(self):
        return f"Dog(name='{self.name}', breed='{self.breed}', age={self.age})"

    def __repr__(self):
        return f"Dog({self.name!r}, {self.breed!r}, {self.age})"

    def __eq__(self, other):
        if not isinstance(other, Dog):
            return NotImplemented
        # Two dogs are "equal" if they have the same name and breed
        return self.name == other.name and self.breed == other.breed

    def __lt__(self, other):
        # Sort dogs youngest-first by default
        return self.age < other.age


dogs = [
    Dog("Rex",   "Labrador", 3),
    Dog("Bella", "Poodle",   5),
    Dog("Max",   "Beagle",   1),
]

print("--- __str__ (called by print) ---")
for d in dogs:
    print(d)

print("\n--- __repr__ ---")
print(repr(dogs[0]))

print("\n--- __eq__ ---")
rex_a = Dog("Rex", "Labrador", 3)
rex_b = Dog("Rex", "Labrador", 7)   # same name+breed, different age
print(rex_a == rex_b)   # True  — __eq__ checks name+breed only
print(rex_a is rex_b)   # False — they are different objects in memory

print("\n--- __lt__ enables sorted() ---")
sorted_dogs = sorted(dogs)   # uses __lt__ to compare
for d in sorted_dogs:
    print(f"  {d.name}: {d.age} years old")

# %% [markdown]
# ---
#
# ### Inheritance: "Is-A" Relationships
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# > **Inheritance** lets one class *extend* another, gaining all its attributes and methods for free.
# >
# > A `Puppy` IS a kind of `Dog` — it has everything a `Dog` has, plus puppy-specific things.
#
# This avoids repeating code. Instead of rewriting `name`/`breed`/`age` for `Puppy`, we *inherit* them from `Dog`.

# %%
# ── Parent class (also: base class, superclass) ───────────────────────────
class Dog:
    def __init__(self, name, breed, age):
        self.name  = name
        self.breed = breed
        self.age   = age

    def bark(self):
        return f"{self.name} says: Woof!"

    def describe(self):
        return f"I am {self.name}, a {self.age}-year-old {self.breed}."

    def __str__(self):
        return f"{self.name} ({self.breed}, age {self.age})"


# ── Child class (subclass) ─────────────────────────────────────────────────
# class Puppy(Dog):  ←  (Dog) means "inherit everything from Dog"
class Puppy(Dog):

    def __init__(self, name, breed):
        # super().__init__() calls the PARENT's __init__.
        # Always do this to set up the parent's attributes first!
        super().__init__(name, breed, age=0)    # puppies start at age 0
        self.is_vaccinated = False              # puppy-specific attribute

    # METHOD OVERRIDE: Puppy provides its own bark()
    # This REPLACES Dog's bark() for Puppy instances only.
    def bark(self):
        return f"{self.name} says: Yip yip! 🐾"

    def vaccinate(self):
        self.is_vaccinated = True
        print(f"{self.name} has been vaccinated! ✅")

    def describe(self):
        base = super().describe()   # call the parent's version first
        return base + f" (vaccinated: {self.is_vaccinated})"


adult = Dog("Rex",   "Labrador", 3)
pup   = Puppy("Max", "Beagle")

print(adult.bark())     # Woof!      ← Dog's bark
print(pup.bark())       # Yip yip!   ← Puppy's overridden bark

print(pup)              # Max (Beagle, age 0) ← inherited __str__
print(pup.name)         # Max                 ← inherited from Dog
print(pup.describe())   # includes vaccination status

pup.vaccinate()
print(pup.is_vaccinated)   # True
print(pup.describe())      # ... (vaccinated: True)

# isinstance() respects the whole inheritance chain:
print(isinstance(pup, Puppy))    # True
print(isinstance(pup, Dog))      # True  ← a Puppy IS a Dog
print(isinstance(adult, Puppy))  # False

# %% [markdown]
# ---
#
# ### ⚖️ Inheritance vs Composition — "Is-A" vs "Has-A"
#
# One of the most important design decisions in OOP:
#
# | Relationship | Pattern | Example |
# |-------------|---------|---------|
# | **Is-A** | Inheritance | A `GuideDog` IS a `Dog` |
# | **Has-A** | Composition | A `Dog` HAS an `Owner` |
#
# > **Rule of thumb:** prefer composition over inheritance when the relationship isn't clearly "is-a". Inheritance creates tight coupling; composition is more flexible and easier to change later.

# %%
# ── INHERITANCE (Is-A) ────────────────────────────────────────────────────
class Dog:
    def __init__(self, name, breed):
        self.name  = name
        self.breed = breed

    def bark(self):
        return f"{self.name}: Woof!"


class GuideDog(Dog):        # GuideDog IS-A Dog ✓
    def __init__(self, name, breed, handler_name):
        super().__init__(name, breed)
        self.handler_name = handler_name

    def guide(self):
        return f"{self.name} guides {self.handler_name} safely. 🦮"


# ── COMPOSITION (Has-A) ───────────────────────────────────────────────────
class Owner:
    def __init__(self, name, phone):
        self.name  = name
        self.phone = phone

    def __str__(self):
        return f"{self.name} ({self.phone})"


class Pet:
    def __init__(self, name, breed, owner):
        self.name  = name
        self.breed = breed
        self.owner = owner      # Pet HAS-AN Owner (composition) ✓

    def who_owns_me(self):
        return f"{self.name} belongs to {self.owner}"


# ── In action ─────────────────────────────────────────────────────────────
guide = GuideDog("Buddy", "Golden Retriever", "Alice")
print(guide.bark())    # Buddy: Woof!  ← inherited
print(guide.guide())   # Buddy guides Alice safely.

alice = Owner("Alice", "555-1234")
rex   = Pet("Rex", "Labrador", alice)
print(rex.who_owns_me())     # Rex belongs to Alice (555-1234)
print(rex.owner.phone)       # 555-1234

# Composition keeps objects in sync automatically:
alice.phone = "555-9999"
print(rex.owner.phone)       # 555-9999  ← updated because we hold a reference

# %% [markdown]
# ---
#
# ### Encapsulation: Controlling Access
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# > **Encapsulation** bundles data and the methods that operate on it together, and *hides internal details* from outside code.
#
# Python uses naming conventions to signal how "touchable" an attribute is:
#
# | Prefix | Example | Meaning |
# |--------|---------|---------|
# | (none) | `self.name` | **Public** — anyone can read/write |
# | Single `_` | `self._balance` | **Protected** — "please don't touch from outside" *(convention only)* |
# | Double `__` | `self.__pin` | **Private** — Python name-mangles it to make accidental access harder |
#
# > The single underscore is a *social convention* (like a "Staff Only" sign on a door). Double underscore adds a lock — but a determined programmer can still pick it.

# %%
class BankAccount:
    def __init__(self, owner, balance, pin):
        self.owner    = owner         # public — fine to access directly
        self._balance = balance       # "protected" — intended for internal use
        self.__pin    = pin           # "private" — name-mangled by Python

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be positive")
        self._balance += amount
        print(f"Deposited ${amount:.2f}. Balance: ${self._balance:.2f}")

    def withdraw(self, amount, pin):
        if pin != self.__pin:
            print("Wrong PIN! ❌")
            return
        if amount > self._balance:
            print("Insufficient funds! ❌")
            return
        self._balance -= amount
        print(f"Withdrew ${amount:.2f}. Balance: ${self._balance:.2f}")

    def get_balance(self, pin):
        if pin == self.__pin:
            return self._balance
        print("Wrong PIN! ❌")
        return None


acc = BankAccount("Alice", 1000, 1234)
acc.deposit(500)            # Deposited $500.00. Balance: $1500.00
acc.withdraw(200, 1234)     # Withdrew $200.00.  Balance: $1300.00
acc.withdraw(200, 9999)     # Wrong PIN! ❌

# Protected (_balance): accessible but convention says "use the methods"
print(acc._balance)         # 1300.0

# Private (__pin): name-mangled to _BankAccount__pin
try:
    print(acc.__pin)        # AttributeError!
except AttributeError as e:
    print(f"AttributeError: {e}")

# Technically reachable via mangled name — but never do this in real code:
print(acc._BankAccount__pin)    # 1234

# %% [markdown]
# ---
#
# ### Properties: Controlled Attribute Access
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# > The `@property` decorator lets you define a method that **behaves like an attribute**.
# > This gives you validation, transformation, and computed values — all without changing how callers use your class.
# #### ⚖️ Direct Attribute vs `@property`
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.

# %%
# ── WITHOUT @property ─────────────────────────────────────────────────────
class TemperatureNaive:
    def __init__(self, celsius):
        self.celsius = celsius      # No validation whatsoever!

t = TemperatureNaive(25)
t.celsius = -500                    # Physically impossible — Python lets it slide!
print(t.celsius)                    # -500  😬


# ── WITH @property ─────────────────────────────────────────────────────────
class Temperature:
    def __init__(self, celsius):
        self._celsius = celsius     # Store privately; property controls access

    # GETTER — runs when you READ  t.celsius
    @property
    def celsius(self):
        return self._celsius

    # SETTER — runs when you WRITE  t.celsius = value
    @celsius.setter
    def celsius(self, value):
        if value < -273.15:
            raise ValueError(f"{value}°C is below absolute zero!")
        self._celsius = value

    # COMPUTED, READ-ONLY property — derived from celsius; no setter
    @property
    def fahrenheit(self):
        return (self._celsius * 9/5) + 32

    @property
    def kelvin(self):
        return self._celsius + 273.15

    def __str__(self):
        return f"{self._celsius}°C / {self.fahrenheit}°F / {self.kelvin}K"


temp = Temperature(25)
print(temp)              # 25°C / 77.0°F / 298.15K
print(temp.celsius)      # 25     ← getter; looks like a plain attribute
print(temp.fahrenheit)   # 77.0   ← computed on the fly!

temp.celsius = 100       # setter called — valid input
print(temp)              # 100°C / 212.0°F / 373.15K

try:
    temp.celsius = -300  # setter called — invalid!
except ValueError as e:
    print(f"ValueError: {e}")

try:
    temp.fahrenheit = 32  # no setter → read-only!
except AttributeError as e:
    print(f"AttributeError: {e}")

# %% [markdown]
# ---
#
# ## 🧪 What If? Experimentation
#
# Let's break things *intentionally* to understand how Python responds.

# %%
# ── What If #1: Forgetting 'self' as the first parameter ─────────────────
# What happens if you define an instance method WITHOUT self?

class Broken:
    def greet(name):        # ← 'self' is missing!
        print(f"Hello, {name}")

b = Broken()
try:
    b.greet("Alice")        # Python tries to pass 'b' as first arg —
                            # the function receives it as 'name', leaving
                            # nothing for the "Alice" argument → TypeError!
except TypeError as e:
    print(f"TypeError: {e}")

# Interesting edge case: calling on the CLASS (not an instance) works,
# because no automatic 'self' is injected:
Broken.greet("Alice")       # Hello, Alice — but this is odd / unintended

# ── The Fix ───────────────────────────────────────────────────────────────
class Fixed:
    def greet(self, name):
        print(f"Hello, {name}")

Fixed().greet("Alice")       # Hello, Alice  ✅

# %%
# ── What If #2: Defining two classes with the same name ──────────────────

class Dog:
    def speak(self): return "Woof!"

# Redefining 'Dog' — Python just rebinds the name 'Dog' to the new class
class Dog:
    def speak(self): return "Bark bark!"

d = Dog()
print(d.speak())     # Bark bark!  ← second definition wins

# Python names are just labels pointing to objects.
# Redefining 'Dog' moves the label to the new class object.
# The first Dog class is gone if nothing else references it.
print(type(d))       # <class '__main__.Dog'>

print("Lesson: the last definition of any name always wins in Python.")

# %%
# ── What If #3: Accessing an attribute that was never set ────────────────

class Dog:
    def __init__(self, name):
        self.name = name
        # Forgot self.breed!

    def describe(self):
        return f"{self.name} is a {self.breed}"   # self.breed doesn't exist!

d = Dog("Rex")

try:
    print(d.describe())    # AttributeError — self.breed doesn't exist
except AttributeError as e:
    print(f"AttributeError: {e}")

try:
    print(d.breed)         # Same error on direct access
except AttributeError as e:
    print(f"AttributeError: {e}")

# ── Fix 1: Always initialize ALL attributes in __init__ ───────────────────
class DogV2:
    def __init__(self, name, breed=None):
        self.name  = name
        self.breed = breed    # default to None — never leave attributes unset!

d2 = DogV2("Rex")
print(d2.breed)              # None — no error!

# ── Fix 2: Use hasattr() to check before accessing ────────────────────────
print(hasattr(d2, "breed"))   # True (exists, just None)
print(hasattr(d2, "tricks"))  # False (never set)

# ── Fix 3: Use getattr() with a default value ─────────────────────────────
breed = getattr(d2, "breed", "Unknown")
print(f"Breed: {breed}")      # Breed: None

# %% [markdown]
# ---
#
# ### Multiple Levels of Inheritance
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# Inheritance chains can go deeper — a `Puppy` can extend `Dog` which extends `Animal`. Each level adds specialization.
#
# > **MRO (Method Resolution Order)** — when Python looks up a method, it walks up the chain: instance → child class → parent class → grandparent class → ... → `object` (the root of all Python classes).
# > You can inspect it with `ClassName.__mro__`.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def breathe(self):
        return f"{self.name} breathes air."

    def __str__(self):
        return f"{type(self).__name__}({self.name!r})"


class Dog(Animal):                 # Dog extends Animal
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

    def bark(self):
        return f"{self.name} says Woof!"


class Puppy(Dog):                  # Puppy extends Dog (which extends Animal)
    def __init__(self, name, breed):
        super().__init__(name, breed)
        self.is_vaccinated = False

    def bark(self):                # overrides Dog's bark
        return f"{self.name} says Yip!"


pup = Puppy("Max", "Beagle")

# Methods inherited from across the chain:
print(pup.bark())       # Yip!         ← Puppy's own version
print(pup.breathe())    # Max breathes air.  ← inherited from Animal
print(str(pup))         # Puppy('Max') ← inherited __str__ from Animal

# Inspect the full method resolution order:
print("MRO:", [c.__name__ for c in Puppy.__mro__])
# Puppy → Dog → Animal → object

# isinstance works all the way up the chain:
print(isinstance(pup, Puppy))    # True
print(isinstance(pup, Dog))      # True
print(isinstance(pup, Animal))   # True
print(isinstance(pup, object))   # True — EVERYTHING in Python inherits from object

# %% [markdown]
# ---
#
# ## 🚀 Real-World Project Link
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# In a **Library Management System**, we'll create a `Book` class with attributes (`title`, `author`, `isbn`) and methods (`checkout()`, `return_book()`), and a `Library` class that manages a collection of `Book` objects using **composition** (the Library *has* Books). Specialized items like `RareBook` use **inheritance** (it *is* a Book with extra handling restrictions). Every concept in this chapter — constructors, methods, `__str__`, inheritance, encapsulation, and properties — maps directly to that real system.
#
# ---

# %% [markdown]
# ### Putting It All Together: A Mini Shelter System
#
# Here's everything from this chapter working in harmony — a small but realistic shelter management example.

# %%
class Animal:
    total_in_shelter = 0           # class attribute — shared counter

    def __init__(self, name, species, age):
        self.name    = name
        self.species = species
        self._age    = age          # protected; exposed via property
        self.adopted = False
        Animal.total_in_shelter += 1

    @property
    def age(self):
        return self._age

    @age.setter
    def age(self, value):
        if value < 0:
            raise ValueError("Age cannot be negative")
        self._age = value

    def adopt(self, adopter_name):
        self.adopted = True
        print(f"{self.name} has been adopted by {adopter_name}! 🏠")
        Animal.total_in_shelter -= 1

    def __str__(self):
        status = "adopted" if self.adopted else "available"
        return f"{self.name} ({self.species}, age {self._age}) — {status}"

    def __repr__(self):
        return f"Animal({self.name!r}, {self.species!r}, {self._age})"

    def __eq__(self, other):
        if not isinstance(other, Animal):
            return NotImplemented
        return self.name == other.name and self.species == other.species


class Dog(Animal):                 # Dog IS-AN Animal
    def __init__(self, name, breed, age):
        super().__init__(name, species="Dog", age=age)
        self.breed = breed

    def bark(self):
        return f"{self.name} barks: Woof! 🐶"

    def __str__(self):
        return f"{self.name} the {self.breed} (age {self._age})"


class Cat(Animal):                 # Cat IS-AN Animal
    def __init__(self, name, indoor, age):
        super().__init__(name, species="Cat", age=age)
        self.indoor = indoor

    def meow(self):
        return f"{self.name} meows softly 🐱"


# ── Run the shelter ────────────────────────────────────────────────────────
shelter = [
    Dog("Rex",   "Labrador",  3),
    Dog("Max",   "Beagle",    1),
    Cat("Luna",  True,        4),
    Cat("Mochi", False,       2),
]

print(f"Animals in shelter: {Animal.total_in_shelter}\n")
for a in shelter:
    print(a)

print()
shelter[0].adopt("Alice")
print(f"Animals remaining: {Animal.total_in_shelter}")

# isinstance works across the hierarchy:
print(isinstance(shelter[0], Dog))     # True
print(isinstance(shelter[0], Animal))  # True
print(isinstance(shelter[2], Dog))     # False — it's a Cat

# %% [markdown]
# ---
#
# ## 📋 Chapter Summary & Cheat Sheet
#
# | Concept | Syntax | Purpose |
# |---------|--------|---------|
# | Define a class | `class Dog:` | Create a blueprint |
# | Constructor | `def __init__(self, ...)` | Initialize state on creation |
# | Instance attribute | `self.name = name` | Data unique to each object |
# | Class attribute | `species = "..."` (class body) | Data shared by all instances |
# | Create an object | `dog = Dog("Rex", "Lab", 3)` | Build an instance |
# | Call a method | `dog.bark()` | Trigger a behavior |
# | Human-readable | `def __str__(self)` | Called by `print()` |
# | Dev repr | `def __repr__(self)` | Called by `repr()` and REPL |
# | Equality | `def __eq__(self, other)` | Called by `==` |
# | Sorting | `def __lt__(self, other)` | Enables `sorted()` |
# | Inheritance | `class Puppy(Dog):` | Extend a parent class |
# | Call parent | `super().__init__(...)` | Run parent's constructor |
# | Override method | Redefine in child class | Replace parent behavior |
# | Protected attr | `self._balance` | Convention: internal use only |
# | Private attr | `self.__pin` | Name-mangled, harder to reach |
# | Property getter | `@property` | Controlled read access |
# | Property setter | `@name.setter` | Controlled write + validation |
# | Type check | `isinstance(obj, Class)` | Includes inheritance chain |
#
# ```python
# # ── Quick Reference ────────────────────────────────────────────────────────
# class Animal:
#     kingdom = "Animalia"                       # class attribute
#
#     def __init__(self, name, sound):
#         self.name  = name                      # instance attributes
#         self.sound = sound
#
#     def speak(self):
#         return f"{self.name} says {self.sound}"
#
#     def __str__(self):
#         return f"Animal({self.name!r})"
#
#
# class Dog(Animal):                             # inheritance
#     def __init__(self, name):
#         super().__init__(name, "Woof")         # call parent constructor
#
#     def speak(self):                           # method override
#         return f"{self.name} barks loudly!"
#
#     @property
#     def info(self):                            # computed property
#         return f"{self.name} ({self.kingdom})"
#
#
# d = Dog("Rex")
# print(d.speak())              # Rex barks loudly!
# print(d.kingdom)              # Animalia  (inherited class attr)
# print(d.info)                 # Rex (Animalia)
# print(isinstance(d, Animal))  # True
# ```

# %% [markdown]
# ---
#
# ## 💪 Practice Prompts
#
# **Challenge 1 — The Vehicle Class**
#
# Create a `Vehicle` class with attributes `make`, `model`, `year`, and `fuel_level` (0–100). Add:
# - `refuel(amount)` — adds fuel, caps at 100, raises `ValueError` for negative amounts
# - `drive(distance)` — reduces fuel by `distance * 0.1`; raises an error if not enough fuel
# - `__str__` and `__repr__` methods
#
# Then create an `ElectricVehicle` subclass that:
# - Tracks `battery_level` instead of `fuel_level`
# - Overrides `refuel()` with a `charge(amount)` method
# - Adds a `range_km` property (assume 6 km per 1% battery)
#
# ---
#
# **Challenge 2 — The Student Grade Book**
#
# Create a `Student` class with `name` and `grades` (a list). Add:
# - `add_grade(grade)` — validates the grade is between 0 and 100
# - `average` property — returns the average, or `0.0` if no grades exist
# - `__str__` — shows name and current average
# - `__lt__` — enables sorting by average
#
# Create 3 students, add various grades, and print them sorted by average (highest first using `sorted(..., reverse=True)`).
#
# ---
#
# **Challenge 3 — Bank Account with Inheritance**
#
# Build a `BankAccount` class with protected `_balance`, a `balance` property (read-only), and `deposit()`/`withdraw()` methods.
#
# Create a `SavingsAccount` subclass that:
# - Adds an `interest_rate` attribute (e.g., `0.05` for 5%)
# - Has `apply_interest()` that multiplies balance by `(1 + interest_rate)`
# - Overrides `withdraw()` to raise `ValueError` if balance would drop below $100 (minimum balance rule)
#
# ---

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='../2.%20data_structures_and_functions/5.%20functions_and_modular_programming.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 5: Functions</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='7.%20advanced_oop_concepts.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 7: Advanced OOP →</a>
# </div>
