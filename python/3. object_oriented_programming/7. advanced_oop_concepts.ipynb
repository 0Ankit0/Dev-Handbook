# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='6.%20classes_and_objects.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 6: Classes & Objects</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../4.%20professional_development_practices/8.%20code_style_and_quality.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 8: Code Style →</a>
# </div>
#
# ---

# %% [markdown]
# # Chapter 7: Advanced OOP — Taking Classes to the Next Level
#
# ---

# %% [markdown]
# ## 🌍 The Big Picture
#
# In Chapter 6 you learned to *build* with blueprints — creating classes, adding methods, inheriting behavior. That's the foundation.
#
# Chapter 7 teaches you to **build smarter**:
#
# | Chapter 6 | Chapter 7 |
# |-----------|-----------|
# | One class, one behavior | Same interface → different behaviors (polymorphism) |
# | Optional structure | Enforced structure (abstract classes) |
# | Writing `__init__` + `__repr__` over and over | Auto-generated with `@dataclass` |
# | Simple equality/addition | Custom operators via dunder methods |
# | Instance methods only | Class methods, static methods — different "scopes" |
#
# > By the end of this chapter, your classes won't just *work* — they'll feel like first-class Python citizens, behaving exactly like built-in types.

# %% [markdown]
# ---
#
# ## ✏️ Syntax & First Usage: Polymorphism
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ### Same Interface, Different Behavior
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# > **Polymorphism** (from Greek: "many forms") means you can call the *same method name* on different objects and each one responds in its own way.
#
# **Analogy:** A TV remote's **Play** button works on a TV, a stereo, and a DVD player. You press the same button — each device responds differently. You don't need to know *which* device it is; you just press Play.
#
# In Python, polymorphism lets you write code that works with *any* object that has a certain method — without caring about the exact type.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        # Base version — subclasses should override this
        raise NotImplementedError(f"{self.name} doesn't know how to speak!")


class Dog(Animal):
    def speak(self):
        return f"{self.name} says: Woof! 🐶"


class Cat(Animal):
    def speak(self):
        return f"{self.name} says: Meow! 🐱"


class Duck(Animal):
    def speak(self):
        return f"{self.name} says: Quack! 🦆"


# ── Polymorphism in action ─────────────────────────────────────────────────
animals = [
    Dog("Rex"),
    Cat("Luna"),
    Duck("Donald"),
    Dog("Buddy"),
]

# We call the SAME method on every animal.
# Each one responds differently — that's polymorphism!
for animal in animals:
    print(animal.speak())

print()
# A function that works with ANY animal that has a speak() method:
def make_noise(creature):
    print(creature.speak())

make_noise(Dog("Max"))    # Woof!
make_noise(Cat("Mochi"))  # Meow!
make_noise(Duck("Daffy")) # Quack!

# %% [markdown]
# ### Duck Typing: "If It Walks Like a Duck..."
#
# Python's polymorphism is even more flexible than most languages. You don't even need a common parent class — you just need the same *method name*. This is called **duck typing**.
#
# > "If it walks like a duck and quacks like a duck, it's a duck."
#
# Python doesn't check *what* an object is — it just tries to call the method. If it works, great!

# %%
# These classes share NO common parent — yet they all work the same way

class Robot:
    def speak(self):
        return "Beep boop! 🤖"

class Parrot:
    def speak(self):
        return "Polly wants a cracker! 🦜"

class Human:
    def speak(self):
        return "Hello, world! 👋"


# The same function works on all three — no shared parent needed!
speakers = [Robot(), Parrot(), Human()]

for speaker in speakers:
    print(speaker.speak())   # Python just calls speak() — it doesn't care about the type

# This is duck typing: "if it has a speak() method, it can be used here"
# Python only raises an error if the method doesn't exist.

# %% [markdown]
# ---
#
# ## 🧠 Core Concepts: Abstract Classes
#
# If the wording here feels abstract at first, anchor it to the concrete job Abstract Classes performs in a real system. That mental model makes the definitions easier to retain and easier to use later.
#
# ### Enforcing a "Contract"
#
# Production-oriented material makes more sense when you see it as reliability work. The tools and steps here exist to make behavior repeatable, observable, and safer to change.
#
# > An **abstract class** is a blueprint that *other blueprints must follow*. You can't build an object directly from it — it only serves as a template for subclasses.
#
# **Why would you want this?**
#
# Imagine you're building a geometry library. You have `Circle`, `Rectangle`, `Triangle`. Every shape *must* have an `area()` method — but there's no sensible generic `area()` for a "shape" in the abstract.
#
# An abstract class lets you say: "I don't know how to compute area for a generic Shape, but **every subclass must provide one**. If they don't, Python won't let them be instantiated."
#
# > This is a *contract* enforced by Python, not just a convention.
#
# > ❓ **Why split code into Blueprints?** A single file with hundreds of routes becomes unreadable. Blueprints group related routes (e.g., all auth routes) into pluggable mini-applications that you register on the main app — like separate chapters in a book.

# %%
from abc import ABC, abstractmethod
# ABC = Abstract Base Class (the "parent" for abstract classes)
# abstractmethod = decorator that marks a method as required

class Shape(ABC):           # inheriting from ABC makes this abstract
    def __init__(self, color="white"):
        self.color = color

    @abstractmethod
    def area(self):
        # No body — subclasses MUST implement this
        pass

    @abstractmethod
    def perimeter(self):
        pass

    # Regular (non-abstract) method — all shapes inherit this as-is
    def describe(self):
        return (f"A {self.color} {type(self).__name__} "
                f"with area={self.area():.2f} and perimeter={self.perimeter():.2f}")


class Circle(Shape):
    def __init__(self, radius, color="white"):
        super().__init__(color)
        self.radius = radius

    def area(self):
        import math
        return math.pi * self.radius ** 2

    def perimeter(self):
        import math
        return 2 * math.pi * self.radius


class Rectangle(Shape):
    def __init__(self, width, height, color="white"):
        super().__init__(color)
        self.width  = width
        self.height = height

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return 2 * (self.width + self.height)


# ── Using the concrete subclasses ─────────────────────────────────────────
c = Circle(5, "red")
r = Rectangle(4, 6, "blue")

print(c.describe())
print(r.describe())

# Polymorphism: same interface, different implementations
shapes = [Circle(3), Rectangle(2, 5), Circle(7)]
for s in shapes:
    print(f"Area: {s.area():.2f}")   # each uses its own formula

# %% [markdown]
# ---
#
# ### ⚖️ Abstract Class vs Regular Class
#
# What happens if you try to instantiate an abstract class or skip implementing an abstract method?

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass


# ── Attempt 1: Instantiate the abstract class directly ────────────────────
try:
    s = Shape()     # TypeError! Can't create a "generic shape"
except TypeError as e:
    print(f"TypeError: {e}")


# ── Attempt 2: Subclass that doesn't implement all abstract methods ────────
class BadTriangle(Shape):
    pass             # forgot to implement area()!

try:
    t = BadTriangle()   # TypeError! area() was not implemented
except TypeError as e:
    print(f"TypeError: {e}")


# ── The correct way: implement ALL abstract methods ────────────────────────
class Triangle(Shape):
    def __init__(self, base, height):
        self.base   = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height


t = Triangle(6, 4)
print(f"Triangle area: {t.area()}")   # 12.0  ✅


# ── Why is this USEFUL, not a bug? ────────────────────────────────────────
# Abstract classes act as contracts. If you're writing a plugin system,
# framework, or library, you can guarantee that any subclass the user
# provides will have the methods your code depends on.
# Without abstract methods, you'd only discover missing methods at runtime
# (possibly in production). With them, you find out immediately.
print("\nAbstract classes give you early, clear errors rather than late surprises.")

# %% [markdown]
# ---
#
# ## 🔬 Deep Dive: Multiple Inheritance
#
# Python allows a class to inherit from **more than one parent**:
#
# ```python
# class C(A, B):
#     pass
# ```
#
# This is powerful but can be confusing. The key question: if both `A` and `B` define a method with the same name, which one does `C` use?
#
# ### Method Resolution Order (MRO)
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# > Python uses the **MRO** (Method Resolution Order) — it reads the family tree **left to right, depth-first**.
# > For `class C(A, B)`: Python checks `C` first, then `A` (and all of A's parents), then `B`.
# > Inspect it with `C.__mro__`.

# %%
class Flyable:
    def move(self):
        return "I fly through the air! ✈️"

    def describe(self):
        return "I am flyable"


class Swimmable:
    def move(self):
        return "I swim through the water! 🏊"

    def describe(self):
        return "I am swimmable"


class Duck(Flyable, Swimmable):   # inherits from BOTH
    def quack(self):
        return "Quack! 🦆"


d = Duck()
print(d.quack())       # Quack!
print(d.move())        # "I fly through the air!" — Flyable wins (listed first)
print(d.describe())    # "I am flyable" — same reason

# Inspect the full MRO:
print("\nMRO:", [cls.__name__ for cls in Duck.__mro__])
# Duck → Flyable → Swimmable → object

# To explicitly call a specific parent's method:
print(Flyable.move(d))    # "I fly through the air!"
print(Swimmable.move(d))  # "I swim through the water!"

# Practical tip: use super() carefully in multiple inheritance —
# it follows the MRO, not just "the other parent":
class BetterDuck(Flyable, Swimmable):
    def move(self):
        fly  = Flyable.move(self)
        swim = Swimmable.move(self)
        return f"{fly} AND {swim}"

b = BetterDuck()
print(b.move())

# %% [markdown]
# ---
#
# ## 📦 Dataclasses: Less Boilerplate, Same Power
#
# If this section feels dense, pause and identify the data structure or model first. Most of the APIs here make more sense once you know what is being stored, queried, or transformed.
#
# ### The Problem: Tedious Boilerplate
#
# Every time you write a class that mainly holds data, you end up writing the same three methods over and over:
# - `__init__` to accept arguments and set attributes
# - `__repr__` so you can print the object helpfully
# - `__eq__` so you can compare two instances
#
# Python 3.7 introduced `@dataclass` — a decorator that **writes all of this for you**.

# %%
# ── WITHOUT @dataclass — lots of boilerplate ──────────────────────────────
class BookManual:
    def __init__(self, title, author, year, pages):
        self.title  = title
        self.author = author
        self.year   = year
        self.pages  = pages

    def __repr__(self):
        return f"Book(title={self.title!r}, author={self.author!r}, year={self.year}, pages={self.pages})"

    def __eq__(self, other):
        if not isinstance(other, BookManual):
            return NotImplemented
        return (self.title == other.title and
                self.author == other.author and
                self.year   == other.year)

b1 = BookManual("Python Crash Course", "Eric Matthes", 2023, 552)
b2 = BookManual("Python Crash Course", "Eric Matthes", 2023, 552)

print(b1)          # Book(title='Python Crash Course', ...)
print(b1 == b2)    # True


# ── WITH @dataclass — Python writes __init__, __repr__, __eq__ for you! ────
from dataclasses import dataclass

@dataclass
class Book:
    title:  str
    author: str
    year:   int
    pages:  int

b3 = Book("Python Crash Course", "Eric Matthes", 2023, 552)
b4 = Book("Python Crash Course", "Eric Matthes", 2023, 552)
b5 = Book("Fluent Python",       "Luciano Ramalho", 2022, 1012)

print(b3)          # Book(title='Python Crash Course', author='Eric Matthes', ...)
print(b3 == b4)    # True  — __eq__ auto-generated
print(b3 == b5)    # False

# You can still add your own methods!
@dataclass
class BookWithMethod:
    title:  str
    author: str
    year:   int
    pages:  int

    def is_long(self):
        return self.pages > 500

b6 = BookWithMethod("Python Crash Course", "Eric Matthes", 2023, 552)
print(b6.is_long())  # True

# %% [markdown]
# ---
#
# ### Dataclass Features: Defaults, Ordering, and Frozen
#
# `@dataclass` has several useful options:

# %%
from dataclasses import dataclass, field

# Default values — just use = as in a normal function parameter
@dataclass
class Config:
    host:    str  = "localhost"
    port:    int  = 8080
    debug:   bool = False
    tags:    list = field(default_factory=list)  # mutable defaults MUST use field()

c1 = Config()
c2 = Config(host="example.com", port=443, debug=True)
print(c1)  # Config(host='localhost', port=8080, debug=False, tags=[])
print(c2)  # Config(host='example.com', port=443, debug=True, tags=[])

# Mutable defaults: WHY do we need field(default_factory=list)?
# If you write  tags: list = []  all instances share the SAME list!
# field(default_factory=list) creates a NEW list for every instance.
c1.tags.append("web")
print(c1.tags)  # ['web']
print(c2.tags)  # []  ← c2 has its own independent list ✅


# order=True  — enables comparison operators (<, >, <=, >=) for sorting
@dataclass(order=True)
class Point:
    x: float
    y: float

points = [Point(3, 4), Point(1, 9), Point(2, 1)]
print(sorted(points))   # sorted by x first, then y (lexicographic)


# frozen=True  — makes the object immutable (like a tuple with named fields)
@dataclass(frozen=True)
class Coordinate:
    lat:  float
    lon:  float

coord = Coordinate(51.5, -0.1)
print(coord)

try:
    coord.lat = 52.0   # TypeError! frozen=True prevents mutation
except Exception as e:
    print(f"{type(e).__name__}: {e}")

# %% [markdown]
# ---
#
# ## 🪝 Dunder Methods Deep Dive
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# In Chapter 6 we saw `__init__`, `__str__`, `__repr__`, and `__eq__`. Now let's look at dunders that let your objects **behave like built-in Python types**.
#
# > **Analogy:** Dunder methods are Python's "hooks." When Python encounters `len(obj)`, it calls `obj.__len__()`. When it sees `item in obj`, it calls `obj.__contains__(item)`. When it sees `a + b`, it calls `a.__add__(b)`.
#
# If you implement these hooks, your objects integrate seamlessly with Python's syntax.

# %%
class ShoppingCart:
    def __init__(self):
        self._items = []    # list of (name, price) tuples

    def add(self, name, price):
        self._items.append((name, price))
        return self         # enables chaining: cart.add(...).add(...)

    # ── len(cart) ──────────────────────────────────────────────────────────
    def __len__(self):
        return len(self._items)

    # ── "milk" in cart ─────────────────────────────────────────────────────
    def __contains__(self, item_name):
        return any(name == item_name for name, _ in self._items)

    # ── cart1 + cart2  (merge two carts) ───────────────────────────────────
    def __add__(self, other):
        new_cart = ShoppingCart()
        new_cart._items = self._items + other._items
        return new_cart

    # ── for item in cart ───────────────────────────────────────────────────
    def __iter__(self):
        return iter(self._items)

    def total(self):
        return sum(price for _, price in self._items)

    def __str__(self):
        if not self._items:
            return "Empty cart"
        lines = [f"  {name}: ${price:.2f}" for name, price in self._items]
        return "Cart:\n" + "\n".join(lines) + f"\n  Total: ${self.total():.2f}"

    def __repr__(self):
        return f"ShoppingCart({self._items!r})"


# ── In action ─────────────────────────────────────────────────────────────
cart1 = ShoppingCart()
cart1.add("Milk",   2.99).add("Bread", 3.49).add("Eggs", 4.99)

cart2 = ShoppingCart()
cart2.add("Coffee", 8.99).add("Sugar", 1.99)

print(f"len(cart1) = {len(cart1)}")             # 3
print(f'"Milk" in cart1 = {"Milk" in cart1}')   # True
print(f'"Wine" in cart1 = {"Wine" in cart1}')   # False

# Iterating:
print("\nCart items:")
for name, price in cart1:
    print(f"  {name}: ${price}")

# Adding two carts:
combined = cart1 + cart2
print(f"\nCombined cart has {len(combined)} items")
print(combined)

# %% [markdown]
# ---
#
# ### ⚖️ `__eq__` vs `is` — Equality vs Identity
#
# Sections like this become clearer when you separate capabilities from tradeoffs. As you read, ask what each option is optimized for and what complexity you accept in exchange.
#
# | Operator | Checks | Uses dunder |
# |----------|--------|-------------|
# | `==` | Are the objects *equal in value*? | `__eq__` |
# | `is` | Are they the *exact same object* in memory? | (no dunder — checks `id()`) |
#
# By default (without `__eq__`), `==` falls back to `is` — so two different objects with the same data are NOT equal. Usually you want to override this.

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

# ── WITHOUT __eq__ ────────────────────────────────────────────────────────
p1 = Point(3, 4)
p2 = Point(3, 4)

print(p1 == p2)     # False! (default == checks identity, same as 'is')
print(p1 is p2)     # False  (different objects in memory)
print(p1 is p1)     # True   (same object)


# ── WITH __eq__ ───────────────────────────────────────────────────────────
class PointV2:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __eq__(self, other):
        if not isinstance(other, PointV2):
            return NotImplemented
        return self.x == other.x and self.y == other.y

    def __repr__(self):
        return f"Point({self.x}, {self.y})"


a = PointV2(3, 4)
b = PointV2(3, 4)
c = PointV2(1, 2)

print(a == b)    # True  — same x and y values
print(a == c)    # False — different values
print(a is b)    # False — still different objects in memory!

# Practical: this lets you use custom objects in sets and as dict keys
# (but you also need __hash__ for that — it's set to None when __eq__ is defined)
print(a == "not a point")   # NotImplemented → Python returns False gracefully

# %% [markdown]
# ---
#
# ## 🔧 Class Methods and Static Methods
#
# So far, all methods we've written are **instance methods** — they receive `self` and operate on a specific object.
#
# Python has two other kinds:
#
# | Type | Decorator | First param | Has access to |
# |------|-----------|-------------|---------------|
# | Instance method | (none) | `self` | Instance + class |
# | Class method | `@classmethod` | `cls` | Class only (not instance) |
# | Static method | `@staticmethod` | (none) | Neither instance nor class |
#
# ### Analogy
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - **Instance method** → A bank teller who handles YOUR account (knows you, knows the bank)
# - **Class method** → A bank manager who creates new accounts (knows the bank, not a specific account)
# - **Static method** → A calculator on the bank's website (uses bank branding, but doesn't touch accounts)

# %%
from datetime import datetime

class Dog:
    total = 0

    def __init__(self, name, breed, birth_year):
        self.name       = name
        self.breed      = breed
        self.birth_year = birth_year
        Dog.total += 1

    # ── @classmethod — "alternative constructor" / factory method ──────────
    # cls refers to the CLASS itself, not an instance.
    # Useful for creating objects from different data formats.
    @classmethod
    def from_age(cls, name, breed, age):
        birth_year = datetime.now().year - age
        return cls(name, breed, birth_year)   # cls(...) creates a new Dog

    @classmethod
    def count(cls):
        return f"Total dogs created: {cls.total}"

    # ── @staticmethod — utility function that lives in the class ───────────
    # No self or cls — it's just a regular function attached to the class.
    # Use when the logic is related to the class but doesn't need any class data.
    @staticmethod
    def is_valid_breed(breed):
        valid_breeds = {"Labrador", "Poodle", "Beagle", "Bulldog", "Husky"}
        return breed in valid_breeds

    def age(self):
        return datetime.now().year - self.birth_year

    def __repr__(self):
        return f"Dog({self.name!r}, {self.breed!r}, born {self.birth_year})"


# Instance method — needs an object
rex = Dog("Rex", "Labrador", 2021)
print(rex.age())        # current year - 2021

# Class method — no instance needed; called on the class directly
bella = Dog.from_age("Bella", "Poodle", 3)
print(bella)            # Dog('Bella', 'Poodle', born <year>)
print(Dog.count())      # Total dogs created: 2

# Static method — no instance or class state needed
print(Dog.is_valid_breed("Labrador"))   # True
print(Dog.is_valid_breed("Dragon"))     # False
# Can also be called on an instance, but calling on the class is clearer:
print(rex.is_valid_breed("Beagle"))     # True

# %% [markdown]
# ---
#
# ## 🧪 What If? Experimentation
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.

# %%
# ── What If #1: Not implementing all abstract methods ────────────────────
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

    @abstractmethod
    def stop_engine(self):
        pass


# Subclass that only implements ONE of the two required methods:
class IncompleteVehicle(Vehicle):
    def start_engine(self):
        return "Vroom!"
    # stop_engine() is missing!

try:
    v = IncompleteVehicle()   # TypeError! stop_engine not implemented
except TypeError as e:
    print(f"TypeError: {e}")


# Fix: implement ALL abstract methods
class Car(Vehicle):
    def start_engine(self):
        return "Car engine starts: Vroom! 🚗"

    def stop_engine(self):
        return "Car engine stops: Click."

c = Car()
print(c.start_engine())
print(c.stop_engine())
print(f"Is Car a Vehicle? {isinstance(c, Vehicle)}")   # True

# %%
# ── What If #2: Using @staticmethod but trying to access self ─────────────
class Calculator:
    def __init__(self, brand):
        self.brand = brand

    @staticmethod
    def add(a, b):
        # self is NOT available here — staticmethod has no self parameter
        # Trying to access self would raise a NameError
        return a + b

    def brand_add(self, a, b):
        # Regular instance method — self IS available
        return f"{self.brand}: {a} + {b} = {a + b}"


calc = Calculator("Casio")

# Static method works fine with arguments:
print(Calculator.add(3, 5))     # 8
print(calc.add(10, 20))         # 30 — can call on instance too, but odd

# Regular method has access to self:
print(calc.brand_add(3, 5))     # Casio: 3 + 5 = 8

# What if you try to reference self inside a staticmethod?
class BadStatic:
    def __init__(self, val):
        self.val = val

    @staticmethod
    def oops():
        try:
            return self.val    # NameError! 'self' is not defined here
        except NameError as e:
            return f"NameError: {e}"

b = BadStatic(42)
print(b.oops())   # NameError: name 'self' is not defined

# %%
# ── What If #3: Two parents with conflicting methods (MRO in action) ──────
class A:
    def hello(self):
        return "Hello from A"

class B:
    def hello(self):
        return "Hello from B"

class C(A, B):    # inherits from both — A listed first
    pass

class D(B, A):    # inherits from both — B listed first
    pass

c = C()
d = D()

print(c.hello())  # "Hello from A"  — A is first in C's MRO
print(d.hello())  # "Hello from B"  — B is first in D's MRO

# Inspect the MRO:
print("C MRO:", [cls.__name__ for cls in C.__mro__])  # C → A → B → object
print("D MRO:", [cls.__name__ for cls in D.__mro__])  # D → B → A → object

# The "diamond problem": what if A and B both inherit from a common base?
class Base:
    def hello(self):
        return "Hello from Base"

class X(Base):
    def hello(self):
        return "Hello from X"

class Y(Base):
    def hello(self):
        return "Hello from Y"

class Z(X, Y):   # diamond: Z → X → Y → Base
    pass

z = Z()
print(z.hello())  # "Hello from X"  — X comes before Y in MRO
print("Z MRO:", [cls.__name__ for cls in Z.__mro__])  # Z → X → Y → Base → object

# %% [markdown]
# ---
#
# ## 🏗️ Putting It All Together: A Library System
#
# Let's combine everything from Chapters 6 and 7 into a realistic mini-system.

# %% [markdown]
# ---
#
# ### Bonus: Mixins — Composable Behaviors via Multiple Inheritance
#
# A **mixin** is a class that provides a specific behavior you can "mix into" other classes. It's not meant to be instantiated on its own — it just adds capabilities.
#
# > Think of mixins like power strips: you plug in the behaviors you need.
#
# ```
# class LogMixin:      # adds logging behavior
# class SerializeMixin: # adds to_json / to_dict
# class ValidateMixin:  # adds validation
#
# class MyModel(ValidateMixin, SerializeMixin, LogMixin, BaseModel): ...
# ```
#
# This avoids deep inheritance trees while still sharing code.

# %%
import json
from datetime import datetime

class TimestampMixin:
    # Adds created_at / updated_at tracking to any class

    def __init_subclass__(cls, **kwargs):
        super().__init_subclass__(**kwargs)

    def set_timestamps(self):
        self.created_at = datetime.now().isoformat()
        self.updated_at = datetime.now().isoformat()

    def touch(self):
        self.updated_at = datetime.now().isoformat()


class SerializeMixin:
    # Adds to_dict() and to_json() to any class
    def to_dict(self):
        # Return all public attributes as a dict
        return {k: v for k, v in self.__dict__.items() if not k.startswith("_")}

    def to_json(self):
        return json.dumps(self.to_dict(), indent=2)


class LogMixin:
    # Adds a log() helper method
    def log(self, message):
        ts = datetime.now().strftime("%H:%M:%S")
        print(f"[{ts}] {type(self).__name__}: {message}")


# ── Mixing all three into a real class ────────────────────────────────────
class User(TimestampMixin, SerializeMixin, LogMixin):
    def __init__(self, username, email):
        self.username = username
        self.email    = email
        self.set_timestamps()   # from TimestampMixin

    def __repr__(self):
        return f"User({self.username!r}, {self.email!r})"


u = User("alice", "alice@example.com")
print(u)
u.log("User created successfully")       # from LogMixin
print(u.to_dict())                        # from SerializeMixin
print(u.to_json())                        # from SerializeMixin
u.touch()                                 # from TimestampMixin
print(f"Updated at: {u.updated_at}")

# %% [markdown]
# ---
#
# ## 🏗️ Putting It All Together: A Library System
#
# Let's combine everything from Chapters 6 and 7 into a realistic mini-system.

# %%
from abc import ABC, abstractmethod
from dataclasses import dataclass, field
from datetime import datetime, timedelta


# ── Abstract base — every library item must implement these ────────────────
class LibraryItem(ABC):
    @abstractmethod
    def checkout(self, borrower: str) -> str:
        pass

    @abstractmethod
    def return_item(self) -> str:
        pass

    @property
    @abstractmethod
    def is_available(self) -> bool:
        pass


# ── Book as a dataclass — minimal boilerplate ──────────────────────────────
@dataclass
class Book(LibraryItem):
    title:   str
    author:  str
    isbn:    str
    pages:   int = 0
    _borrower: str = field(default=None, init=False, repr=False)
    _due_date: object = field(default=None, init=False, repr=False)

    def checkout(self, borrower: str) -> str:
        if not self.is_available:
            return f"'{self.title}' is already checked out by {self._borrower}."
        self._borrower = borrower
        self._due_date = datetime.now() + timedelta(weeks=2)
        return f"'{self.title}' checked out to {borrower}. Due: {self._due_date.strftime('%Y-%m-%d')}"

    def return_item(self) -> str:
        if self.is_available:
            return f"'{self.title}' was not checked out."
        name = self._borrower
        self._borrower = None
        self._due_date = None
        return f"'{self.title}' returned by {name}. ✅"

    @property
    def is_available(self) -> bool:
        return self._borrower is None


# ── DVD — another concrete LibraryItem ────────────────────────────────────
@dataclass
class DVD(LibraryItem):
    title:    str
    director: str
    duration: int   # minutes
    _borrower: str = field(default=None, init=False, repr=False)

    def checkout(self, borrower: str) -> str:
        if not self.is_available:
            return f"DVD '{self.title}' is unavailable."
        self._borrower = borrower
        return f"DVD '{self.title}' checked out to {borrower}. Due in 1 week."

    def return_item(self) -> str:
        if self.is_available:
            return f"DVD '{self.title}' was not checked out."
        name = self._borrower
        self._borrower = None
        return f"DVD '{self.title}' returned by {name}. ✅"

    @property
    def is_available(self) -> bool:
        return self._borrower is None


# ── Library — manages a collection using composition ──────────────────────
class Library:
    def __init__(self, name: str):
        self.name  = name
        self._items: list[LibraryItem] = []

    def add_item(self, item: LibraryItem):
        self._items.append(item)

    def available_items(self):
        return [item for item in self._items if item.is_available]

    def __len__(self):
        return len(self._items)

    def __contains__(self, title: str):
        return any(item.title == title for item in self._items)

    def __str__(self):
        return f"Library '{self.name}' ({len(self)} items)"


# ── Demo ──────────────────────────────────────────────────────────────────
lib = Library("City Library")

lib.add_item(Book("Clean Code",     "Robert Martin",   "978-0132350884", 431))
lib.add_item(Book("Python Mastery", "Mark Lutz",        "978-1491912058", 1540))
lib.add_item(DVD("Monty Python",    "Terry Gilliam",    90))

print(lib)
print(f"Available: {len(lib.available_items())} items")
print(f"'Clean Code' in library: {'Clean Code' in lib}")

print()
book = lib._items[0]
print(book.checkout("Alice"))
print(book.checkout("Bob"))    # already checked out
print(f"Available now: {len(lib.available_items())} items")
print(book.return_item())
print(f"Available now: {len(lib.available_items())} items")

# %% [markdown]
# ---
#
# ## 🚀 Real-World Project Link
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# In our full **Library Management System**, we'll make `Book` a `@dataclass` and create an abstract `LibraryItem` class so that DVDs, Magazines, and AudioBooks *all* follow the same checkout/return interface. We'll add `@classmethod` factories for loading items from a database, and `@staticmethod` helpers for ISBN validation. Polymorphism means the checkout desk can handle any item type with the same code.
#
# ---

# %% [markdown]
# ## 📋 Chapter Summary & Cheat Sheet
#
# | Concept | Syntax | Purpose |
# |---------|--------|---------|
# | Polymorphism | Same method name on different classes | One interface, many behaviors |
# | Duck typing | Call a method; Python checks at runtime | No shared parent needed |
# | Abstract class | `class X(ABC):` | Enforce a contract on subclasses |
# | Abstract method | `@abstractmethod` | Subclasses MUST implement this |
# | Dataclass | `@dataclass` | Auto-generates `__init__`, `__repr__`, `__eq__` |
# | Dataclass defaults | `field(default_factory=list)` | Safe mutable defaults |
# | Ordered dataclass | `@dataclass(order=True)` | Adds `<`, `>`, `<=`, `>=` |
# | Frozen dataclass | `@dataclass(frozen=True)` | Makes instance immutable |
# | `__len__` | `len(obj)` | Object knows its own size |
# | `__contains__` | `item in obj` | Membership test |
# | `__add__` | `obj1 + obj2` | Addition / merging |
# | `__iter__` | `for x in obj` | Make object iterable |
# | `__eq__` | `obj1 == obj2` | Value equality |
# | `__lt__` | `obj1 < obj2` | Enables sorting |
# | `@classmethod` | `cls` as first param | Factory / alternative constructor |
# | `@staticmethod` | No `self` or `cls` | Utility function in class scope |
# | MRO | `ClassName.__mro__` | Method lookup order in inheritance |
#
# ```python
# # ── Quick Reference ────────────────────────────────────────────────────────
# from abc import ABC, abstractmethod
# from dataclasses import dataclass
#
# # Abstract class — enforces interface
# class Shape(ABC):
#     @abstractmethod
#     def area(self) -> float: ...
#
# class Circle(Shape):
#     def __init__(self, r): self.r = r
#     def area(self): return 3.14159 * self.r ** 2
#
# # Dataclass — minimal boilerplate
# @dataclass(order=True)
# class Point:
#     x: float
#     y: float
#
# # Dunder methods — behave like built-ins
# class Stack:
#     def __init__(self):       self._data = []
#     def push(self, x):        self._data.append(x)
#     def __len__(self):        return len(self._data)
#     def __contains__(self, x): return x in self._data
#     def __repr__(self):       return f"Stack({self._data!r})"
#
# # Class / static methods
# class Converter:
#     @classmethod
#     def from_string(cls, s):    # factory
#         return cls(float(s))
#     @staticmethod
#     def is_positive(n):         # utility
#         return n > 0
# ```

# %% [markdown]
# ---
#
# ## 💪 Practice Prompts
#
# **Challenge 1 — Shape Hierarchy with Abstract Class**
#
# Create an abstract `Shape` class with abstract methods `area()` and `perimeter()`, and a concrete `describe()` method.
#
# Implement three concrete subclasses: `Circle`, `Rectangle`, and `Triangle`.
#
# Add a `@staticmethod is_valid_radius(r)` to `Circle` that returns `True` if `r > 0`.
#
# Write a function `total_area(shapes)` that takes a list of any `Shape` objects and returns the sum of their areas — demonstrating polymorphism.
#
# ---
#
# **Challenge 2 — A Custom Collection**
#
# Build a `Playlist` class (like a music playlist) that supports:
# - `playlist.add("Song Name")` — add a song
# - `len(playlist)` — number of songs
# - `"Song Name" in playlist` — membership test
# - `playlist1 + playlist2` — merge two playlists
# - `for song in playlist` — iteration
# - `@classmethod from_list(cls, songs)` — create from an existing list
# - `@staticmethod is_valid_title(title)` — returns `True` if title is non-empty
#
# Make it a `@dataclass` if appropriate, or use `__init__`.
#
# ---
#
# **Challenge 3 — Employee Dataclass Hierarchy**
#
# Create a `@dataclass` called `Employee` with fields: `name`, `department`, `salary`. Add:
# - `@classmethod from_csv(cls, row)` that creates an `Employee` from a comma-separated string `"Alice,Engineering,90000"`
# - `give_raise(percent)` that increases salary by the given percentage
# - `__lt__` so employees can be sorted by salary
#
# Create a `Manager(Employee)` subclass with an extra `reports: list` field (default empty list). Override `give_raise()` to also apply a 10% bonus on top of the regular raise.
#
# Sort a list of mixed `Employee` and `Manager` objects by salary and print them.
#
# ---

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='6.%20classes_and_objects.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 6: Classes & Objects</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../4.%20professional_development_practices/8.%20code_style_and_quality.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 8: Code Style →</a>
# </div>

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='6. classes_and_objects.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../4. professional_development_practices/8. code_style_and_quality.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
