# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../7.%20data_science_and_automation/18.%20automation_and_scripting.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 18: Automation</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='20.%20containerization_and_deployment.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 20: Containerization →</a>
# </div>
#
# ---

# %% [markdown]
# # Chapter 19: Dependency Management — Keeping Your Projects Organized
#
# > *"It works on my machine!"* — Every developer, at least once.
#
# Welcome to one of the most practical chapters in this handbook. By the end, you'll never ship broken code because of a missing package again.

# %% [markdown]
# ## 1. 🌍 The Big Picture
#
# Imagine you've spent a week building a data analysis tool. It works perfectly on your laptop.
# You email the code to a colleague. They run it and get:
#
# ```
# ModuleNotFoundError: No module named 'pandas'
# ```
#
# They install pandas. Now they get:
#
# ```
# AttributeError: 'DataFrame' object has no attribute 'append'
# ```
#
# Why? Their pandas version is different from yours. `append()` was removed in pandas 2.0.
#
# **This is "dependency hell"** — and it's the #1 cause of "it works on my machine" bugs.
#
# **Dependency management** is the set of tools and practices that ensure:
# 1. Everyone working on your project uses the **exact same packages**
# 2. Different projects on the same machine **don't interfere with each other**
# 3. Your code can be **reproduced** months or years later
#
# This chapter teaches you to go from chaos → control.

# %% [markdown]
# ## 2. 🧠 Core Concepts: The "Why"
#
# The easiest way to read this section is to keep one plain-language question in view: what is The "Why" actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### What are Dependencies?
#
# A **dependency** is someone else's code that your code relies on. When you write:
#
# ```python
# import requests
# import pandas as pd
# import flask
# ```
#
# …`requests`, `pandas`, and `flask` are all dependencies.
#
# Python ships with a **standard library** (built-in modules like `os`, `json`, `math`).
# Everything else — things you install with `pip install` — are **third-party dependencies**.
#
# ### The Analogy: Cooking in a Shared Kitchen 🍳
#
# Imagine a kitchen shared by 10 chefs:
# - Chef A's recipe needs **Himalayan Pink Salt** (very specific!)
# - Chef B's recipe needs **Fine Sea Salt** (a different product!)
#
# If they share one salt shaker, someone's dish turns out wrong.
#
# **Virtual environments** give each chef their own pantry — their own separate set of ingredients.
#
# ### The Three Problems We're Solving
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# | Problem | Solution |
# |---------|----------|
# | Two projects need different versions of the same library | Virtual environments |
# | Colleague can't reproduce your setup | `requirements.txt` / lockfiles |
# | Manual dependency tracking is error-prone | Poetry (modern tooling) |
#
# > ❓ **What does `pip install` actually do?** `pip` downloads the named package from PyPI (the Python Package Index), along with any packages it depends on, and places them inside your currently active environment.

# %% [markdown]
# ## 3. 📦 pip — Python's Package Installer
#
# **pip** ("Pip Installs Packages") is the standard tool for installing Python packages.
# Think of it as an **App Store for Python** — there are 500,000+ packages on [PyPI](https://pypi.org)
# (the Python Package Index), covering everything from web frameworks to machine learning to game development.

# %%
# These are shell commands — run them in your terminal, not here.
# We display them so you can copy and reference them.

pip_commands = {
    'Install a package': 'pip install requests',
    'Install a specific version (pinned)': 'pip install requests==2.31.0',
    'Install minimum version': 'pip install requests>=2.28.0',
    'Install multiple packages': 'pip install requests flask sqlalchemy',
    'List installed packages': 'pip list',
    'Show package details': 'pip show requests',
    'Uninstall a package': 'pip uninstall requests',
    'Upgrade to latest': 'pip install --upgrade requests',
    'Check for conflicts': 'pip check',
    'Search for a package': 'pip index versions flask',
}

print('Common pip commands:')
print('-' * 55)
for desc, cmd in pip_commands.items():
    print(f'  {desc:<35} {cmd}')

# %% [markdown]
# ### Understanding Version Specifiers
#
# The important beginner shift here is moving from “it works on my machine” to “it behaves predictably in a real environment.” Each step matters because it reduces surprises when the software runs elsewhere.
#
# | Specifier | Meaning | Example |
# |-----------|---------|--------|
# | `==` | Exact version | `requests==2.31.0` |
# | `>=` | At least this version | `requests>=2.28.0` |
# | `<=` | At most this version | `requests<=3.0.0` |
# | `!=` | Anything except this | `requests!=2.30.0` |
# | `~=` | Compatible release | `requests~=2.31.0` (means `>=2.31.0, <3.0`) |
#
# The `~=` operator (**compatible release**) is a great middle ground:
# - More flexible than `==` (allows patch updates that fix bugs)
# - Safer than `>=` (won't jump to a major version that might break your code)
#
# For example, `~=2.31.0` means: "give me any 2.31.x version, but not 3.x"

# %%
# Let's see version specifiers in action (conceptual demo)

def check_compatibility(installed_version, specifier_str):
    """Simulate version checking — for educational purposes."""
    from packaging.specifiers import SpecifierSet
    from packaging.version import Version
    try:
        spec = SpecifierSet(specifier_str)
        v = Version(installed_version)
        return v in spec
    except Exception:
        return 'packaging not installed — showing conceptually'

# Showing what the specifiers MEAN conceptually
examples = [
    ('requests==2.31.0', ['2.31.0 ✅', '2.31.1 ❌', '2.30.0 ❌']),
    ('requests>=2.28.0', ['2.28.0 ✅', '2.31.0 ✅', '3.0.0 ✅', '2.27.9 ❌']),
    ('requests~=2.31.0', ['2.31.0 ✅', '2.31.9 ✅', '2.32.0 ✅', '3.0.0 ❌']),
    ('requests!=2.30.0', ['2.29.0 ✅', '2.31.0 ✅', '2.30.0 ❌']),
]

print('Version specifier compatibility:')
print('-' * 50)
for spec, versions in examples:
    print(f'  {spec:<25} matches: {versions}')

# %% [markdown]
# ### `pip freeze` — Taking a Snapshot
#
# `pip freeze` lists every installed package with its **exact version**.
# It's like taking a photograph of your current environment.
#
# ```bash
# $ pip freeze
# certifi==2024.2.2
# charset-normalizer==3.3.2
# idna==3.7
# requests==2.31.0
# urllib3==2.2.1
# ```
#
# Notice that `pip freeze` shows **more packages than you installed**.
# That's because `requests` depends on `certifi`, `urllib3`, etc.
# These are **transitive dependencies** — dependencies of your dependencies.
#
# ```bash
# # Save the snapshot to a file:
# pip freeze > requirements.txt
# ```

# %%
# Understanding transitive dependencies

print('When you install: pip install requests')
print()
print('pip actually installs:')
print('  requests==2.31.0        ← what you asked for')
print('  certifi==2024.2.2       ← requests needs this (SSL certificates)')
print('  charset-normalizer==3.3.2 ← requests needs this (text encoding)')
print('  idna==3.7               ← requests needs this (international domains)')
print('  urllib3==2.2.1          ← requests needs this (HTTP library)')
print()
print('These are TRANSITIVE dependencies.')
print('Your code only imported requests, but 5 packages were installed.')
print()
print('pip freeze captures ALL of them — ensuring perfect reproducibility.')

# %% [markdown]
# ## 4. 🔬 Virtual Environments — Isolated Project Sandboxes
#
# A beginner usually learns this material faster by connecting each setup step to its purpose rather than treating it as a checklist. Keep asking what each piece enables and what would fail if you skipped it.
#
# ### The Problem Without Virtual Environments
#
# Without virtual environments, all packages go into your **global Python installation**.
#
# ```
# Your Computer's Python (global)
# ├── requests 2.31.0   ← Project A needs this
# ├── requests 2.28.0   ← Project B needs this (CONFLICT!)
# ├── flask 3.0.0       ← Project A needs this
# └── flask 2.3.0       ← Project B needs this (CONFLICT!)
# ```
#
# Python can only have **one version** of each package globally.
# Whichever you installed last wins — and the other project breaks.
#
# ### The Solution: Virtual Environments
#
# A **virtual environment** is a self-contained directory with:
# - Its own Python interpreter
# - Its own copy of pip
# - Its own installed packages — completely isolated from everything else
#
# ```
# project-a/
# ├── .venv/              ← Virtual environment
# │   ├── bin/python      ← Project A's Python
# │   ├── bin/pip         ← Project A's pip
# │   └── lib/            ← Project A's packages (flask 3.0, requests 2.31)
# ├── main.py
# └── requirements.txt
#
# project-b/
# ├── .venv/              ← Separate virtual environment
# │   ├── bin/python      ← Project B's Python
# │   └── lib/            ← Project B's packages (flask 2.3, requests 2.28)
# ├── app.py
# └── requirements.txt
# ```
#
# No conflicts! Each project lives in its own bubble.

# %%
# Creating and using a virtual environment
# Run these commands in your terminal

steps = [
    ('1. Create the venv', 'python -m venv .venv'),
    ('2. Activate (macOS/Linux)', 'source .venv/bin/activate'),
    ('2. Activate (Windows CMD)', r'.venv\Scripts\activate.bat'),
    ('2. Activate (Windows PowerShell)', r'.venv\Scripts\Activate.ps1'),
    ('3. Verify activation', 'which python  # Should show .venv/bin/python'),
    ('4. Install packages', 'pip install requests flask'),
    ('5. Check what is installed', 'pip list'),
    ('6. Deactivate when done', 'deactivate'),
]

print('Virtual environment workflow:')
print('=' * 60)
for step, cmd in steps:
    print(f'  {step:<35} → {cmd}')

print()
print('How to tell if your venv is active:')
print('  ✅ Active:   (.venv) user@host:~/project$  ← prefix shows!')
print('  ❌ Inactive: user@host:~/project$           ← no prefix')

# %% [markdown]
# ### Before vs After Activating a Venv
#
# Sections like this become clearer when you separate capabilities from tradeoffs. As you read, ask what each option is optimized for and what complexity you accept in exchange.
#
# ```bash
# # BEFORE activation (global Python — bare minimum)
# $ pip list
# Package    Version
# ---------- -------
# pip        24.0
# setuptools 69.0.0
#
# # AFTER activation (.venv — your project's packages)
# (.venv) $ pip list
# Package            Version
# ------------------ -------
# blinker            1.8.2
# click              8.1.7
# flask              3.0.3
# itsdangerous       2.2.0
# Jinja2             3.1.4
# MarkupSafe         2.1.5
# requests           2.31.0
# Werkzeug           3.0.3
# ```
#
# **The venv only has what you installed.** No cross-project pollution.
#
# ### Where to Put Your Venv and What to Gitignore
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```
# ✅ Correct:  my_project/.venv/     ← inside the project, named .venv
# ❌ Wrong:    ~/shared-venv/         ← shared across projects
# ❌ Wrong:    my_project/myvenv/     ← non-standard name, harder to find
# ```
#
# Add `.venv/` to your `.gitignore`. You **never** commit the venv folder — it's huge,
# platform-specific, and fully recreatable from `requirements.txt`.

# %%
# A typical Python .gitignore

gitignore_content = """# Virtual environments
.venv/
venv/
env/

# Python bytecode
__pycache__/
*.py[cod]
*.pyo

# Secret configuration (CRITICAL!)
.env

# Build artifacts
dist/
build/
*.egg-info/

# Test cache
.pytest_cache/
.coverage
"""

print('Contents of a typical Python .gitignore:')
print(gitignore_content)

print('Key insight: commit the RECIPE (requirements.txt), not the RESULT (.venv)')
print('Just like you commit a recipe card, not the actual baked cake.')

# %% [markdown]
# ## 5. 📋 requirements.txt — Your Project's Ingredient List
#
# A `requirements.txt` file is a plain text file listing every package your project needs.
# It's the **standard** way to share your dependency list.
#
# Anyone can recreate your exact environment with one command:
#
# ```bash
# pip install -r requirements.txt
# # The -r flag means 'read requirements from this file'
# ```
#
# ### Generating requirements.txt
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```bash
# # After installing packages in your venv:
# pip freeze > requirements.txt
#
# # This creates:
# # flask==3.0.3
# # requests==2.31.0
# # sqlalchemy==2.0.29
# # ... (all transitive deps too)
# ```

# %%
# Different approaches to requirements.txt

styles = [
    (
        'PINNED — for production (maximum reproducibility)',
        ['flask==3.0.3', 'requests==2.31.0', 'sqlalchemy==2.0.29',
         'python-dotenv==1.0.1', 'gunicorn==22.0.0'],
        'Generated with: pip freeze > requirements.txt'
    ),
    (
        'COMPATIBLE RELEASE — for libraries you publish',
        ['flask~=3.0.3', 'requests~=2.31.0', 'sqlalchemy~=2.0.29'],
        'Allows patch updates (3.0.4 ok), blocks major changes (4.x blocked)'
    ),
    (
        'MINIMUM VERSION — for personal scripts (flexible, risky for teams)',
        ['flask>=3.0.0', 'requests>=2.28.0', 'sqlalchemy>=2.0.0'],
        'Gets latest compatible version — colleague might get different versions'
    ),
]

for style_name, packages, note in styles:
    print(f'Style: {style_name}')
    print(f'Note:  {note}')
    print('File contents:')
    for pkg in packages:
        print(f'  {pkg}')
    print()

# %% [markdown]
# ### ⚠️ The Risk of Unpinned Dependencies
#
# The important beginner shift here is moving from “it works on my machine” to “it behaves predictably in a real environment.” Each step matters because it reduces surprises when the software runs elsewhere.
#
# Here's a real scenario:
#
# 1. You write `pandas>=1.0.0` in your requirements.txt
# 2. Your code uses `df.append(other_df)` — perfectly valid in pandas 1.x
# 3. Six months later, a colleague installs your project
# 4. They get **pandas 2.0** (the latest) — because your specifier allowed it
# 5. pandas 2.0 **removed** `DataFrame.append()`
# 6. Their installation **crashes immediately**
#
# With `pandas==1.5.3` (pinned), this never happens.
# ### The Complete pip + venv Workflow
#
# Whenever a process has several stages, beginners benefit from tracing the handoff between them. Follow the order carefully and notice what information each step receives, transforms, and passes on.
#
# ```bash
# # --- Developer A (original author) ---
# mkdir weather-app && cd weather-app
# python -m venv .venv
# source .venv/bin/activate
# pip install requests python-dotenv
# # ... write code ...
# pip freeze > requirements.txt
# git add requirements.txt .gitignore
# git commit -m 'Add dependencies'
# git push
#
# # --- Developer B (colleague) ---
# git clone https://github.com/A/weather-app
# cd weather-app
# python -m venv .venv
# source .venv/bin/activate
# pip install -r requirements.txt
# # Identical environment! 🎉
# ```

# %% [markdown]
# ## 6. ⚙️ pyproject.toml — The Modern Standard
#
# Python recently standardized project configuration in `pyproject.toml`
# ([PEP 518](https://peps.python.org/pep-0518/) and [PEP 621](https://peps.python.org/pep-0621/)).
#
# Instead of multiple config files (`setup.py`, `setup.cfg`, `pytest.ini`, `.flake8`…),
# you get **one file** that configures everything:
#
# - Project metadata (name, version, description, authors)
# - Runtime dependencies
# - Dev dependencies
# - Build system configuration
# - Tool configurations (black, pytest, mypy, etc.)
#
# Even if you don't publish a package, `pyproject.toml` is where modern Python tools look for their settings.

# %%
# Full pyproject.toml example with annotations

pyproject_annotated = {
    '[tool.poetry]': '← Project identity',
    'name = "weather-app"': '← Package name (used when publishing)',
    'version = "0.1.0"': '← Semantic version: major.minor.patch',
    'description = "Fetch weather data"': '← Short description',
    'authors = ["You <you@email.com>"]': '← List of authors',
    'requires-python = ">=3.11"': '← Python version requirement',
    '': '',
    '[tool.poetry.dependencies]': '← Runtime dependencies (must be installed)',
    'python = "^3.11"': '← ^ means >=3.11, <4.0',
    'requests = "^2.31.0"': '← ^ means >=2.31.0, <3.0.0',
    'python-dotenv = "^1.0.1"': '← Load .env files',
    '  ': '',
    '[tool.poetry.group.dev.dependencies]': '← Dev-only (tests, linters)',
    'pytest = "^8.0.0"': '← Testing framework',
    'black = "^24.0.0"': '← Code formatter',
    '   ': '',
    '[build-system]': '← How to build/install the project',
    'requires = ["poetry-core"]': '← Build backend',
    '    ': '',
    '[tool.black]': '← black formatter settings (lives here!)',
    'line-length = 88': '← black will wrap at 88 chars',
}

print('pyproject.toml structure:')
print('=' * 60)
for line, annotation in pyproject_annotated.items():
    if annotation:
        print(f'  {line:<40} {annotation}')
    else:
        print(f'  {line}')

# %% [markdown]
# ## 7. 🎭 Poetry — Modern Dependency Management
#
# **Poetry** is the most popular modern Python dependency manager. It solves everything:
# virtual environments, adding/removing packages, resolving conflicts, and publishing.
#
# **Install Poetry** (once, on your machine):
# ```bash
# curl -sSL https://install.python-poetry.org | python3 -
# ```
#
# After installation, `poetry` is available in your terminal.

# %%
# Complete Poetry workflow

workflow = [
    ('=== STARTING A PROJECT ===', ''),
    ('New project with scaffold', 'poetry new weather-app'),
    ('Init in existing folder', 'cd weather-app && poetry init'),
    ('', ''),
    ('=== MANAGING DEPENDENCIES ===', ''),
    ('Add runtime dependency', 'poetry add requests'),
    ('Add multiple at once', 'poetry add flask sqlalchemy python-dotenv'),
    ('Add dev-only dependency', 'poetry add --group dev pytest black mypy'),
    ('Remove a dependency', 'poetry remove flask'),
    ('Update all packages', 'poetry update'),
    ('', ''),
    ('=== INSTALLING & RUNNING ===', ''),
    ('Install from poetry.lock', 'poetry install'),
    ('Activate the venv', 'poetry shell'),
    ('Run without activating', 'poetry run python main.py'),
    ('Run tests', 'poetry run pytest'),
    ('', ''),
    ('=== INSPECTING ===', ''),
    ('Show all packages', 'poetry show'),
    ('Show dependency tree', 'poetry show --tree'),
    ('Show current env info', 'poetry env info'),
]

print('Poetry command reference:')
for desc, cmd in workflow:
    if not cmd:
        print(f'  {desc}')
    else:
        print(f'    {desc:<35} → {cmd}')

# %% [markdown]
# ### The Lockfile: `poetry.lock`
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# When you run `poetry add` or `poetry install`, Poetry creates `poetry.lock`.
# This file captures the **exact version of every package** — including transitive dependencies.
#
# ```toml
# # poetry.lock (excerpt)
# [[package]]
# name = "flask"
# version = "3.0.3"
# description = "A simple framework for building complex web applications."
# content-hash = "sha256:abc123..."  # Even the hash is recorded!
#
# [[package]]
# name = "werkzeug"
# version = "3.0.3"        # Flask depends on this — also locked
# description = "The comprehensive WSGI web application library."
# ```
#
# **Commit `poetry.lock` to git.** When your teammate clones and runs `poetry install`,
# they get the **byte-for-byte identical environment** — even the hashes match.
#
# ```
# ✅ Commit:  pyproject.toml   poetry.lock
# ❌ Ignore:  .venv/           __pycache__/   .env
# ```

# %% [markdown]
# ## 8. ⚖️ vs: pip + requirements.txt vs Poetry
#
# Here's the same workflow in both approaches:

# %%
# Side-by-side comparison

comparison = [
    ('Task', 'pip + venv', 'Poetry'),
    ('-' * 38, '-' * 42, '-' * 40),
    ('Start a new project',
     'mkdir proj && cd proj',
     'poetry new proj'),
    ('Create isolated environment',
     'python -m venv .venv  (manual)',
     'Automatic! Poetry manages it'),
    ('Activate environment',
     'source .venv/bin/activate  (manual)',
     'poetry shell  (or implicit)'),
    ('Add a dependency',
     'pip install flask  (nothing saved!)',
     'poetry add flask  (saves to pyproject.toml)'),
    ('Save exact versions',
     'pip freeze > requirements.txt  (manual!)',
     'Automatic! poetry.lock always current'),
    ('Recreate environment',
     'pip install -r requirements.txt',
     'poetry install'),
    ('Separate dev dependencies',
     'Manage 2 files manually',
     'poetry add --group dev pytest'),
    ('Conflict detection',
     'Silent override (dangerous)',
     'Refuses + explains the conflict'),
    ('Publish to PyPI',
     'twine + setup.py  (extra tools)',
     'poetry publish  (built-in)'),
]

for row in comparison:
    print(f'  {row[0]:<38} {row[1]:<42} {row[2]}')

print()
print('Recommendation:')
print('  Learn pip + venv first to understand the fundamentals.')
print('  Use Poetry for any real project — it eliminates entire categories of bugs.')

# %% [markdown]
# ## 9. 😈 Understanding Dependency Hell
#
# **Dependency hell** is when two of your packages require **incompatible versions** of a shared library.
#
# ```
# Your project needs:
# ├── library-A 2.0  →  requires: requests >= 2.30.0
# └── library-B 1.5  →  requires: requests < 2.30.0
#
# 💥 CONFLICT: requests can't be both >= AND < 2.30.0 simultaneously
# ```
#
# This is more common than you'd think — especially in data science and ML.
# Here's how pip and Poetry handle it differently:

# %%
# pip vs Poetry — conflict handling demo

print('SCENARIO: Your project has requests==2.31.0 installed.')
print('You try to add old-api-client which needs requests==2.20.0.')
print()

print('pip behavior (without pip-tools):')
print('  $ pip install old-api-client')
print('  Collecting old-api-client')
print('  Collecting requests==2.20.0 (from old-api-client)')
print('  Successfully installed requests-2.20.0  ← SILENTLY DOWNGRADED!')
print()
print('  Your existing code that relied on requests 2.31 features just broke.')
print('  You will not know until you hit the failing code path at runtime.')
print()

print('Poetry behavior:')
print('  $ poetry add old-api-client')
print()
print('  Because old-api-client (0.1.0) requires requests (==2.20.0)')
print('  and my-project depends on requests (^2.31.0),')
print('  old-api-client is forbidden.')
print()
print('  Your pyproject.toml was NOT modified.')
print('  Your existing environment is completely safe.')
print('  You learn about the conflict BEFORE writing any code.')
print()
print('Resolution options:')
options = [
    'Find a newer version of old-api-client',
    'Find an alternative library without the conflict',
    'Use a separate virtual environment for the conflicting tool',
    'Pin to an older version of requests across your whole project',
]
for i, opt in enumerate(options, 1):
    print(f'  {i}. {opt}')

# %% [markdown]
# ## 10. 🧪 What If? Experimentation
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.

# %% [markdown]
# ### What If You Forget to Activate Your Venv?
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.

# %%
# What happens when you install without activating your venv

print('SCENARIO: Project has requests in .venv. You open a new terminal.')
print('You forget to activate. You run pip install numpy.')
print()
print('Where does numpy go?')
print('  → Your GLOBAL Python installation (~/.local/lib or /usr/local/lib)')
print()
print('Immediate consequence: None. It "works".')
print()
print('Delayed consequence (the trap):')
print('  1. You forget you installed numpy globally')
print('  2. Your code imports numpy — it works in your environment')
print('  3. You run pip freeze > requirements.txt  INSIDE the venv')
print('  4. numpy is NOT in requirements.txt  (it was global, not in venv!)')
print('  5. Colleague runs pip install -r requirements.txt')
print('  6. They get ModuleNotFoundError: No module named numpy')
print()
print('How to diagnose:')
print('  which python    # Should show path with .venv in it')
print('  which pip       # Same')
print('  python -c "import sys; print(sys.executable)"')
print()
print('Prevention:')
print('  - Check prompt for (.venv) prefix before every pip command')
print('  - Use Poetry: it always uses the right venv automatically')
print('  - Use VS Code: it detects .venv and shows it in the bottom bar')

# %% [markdown]
# ### What If You Delete Your Venv?
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.

# %%
# Accidentally deleted your .venv — now what?

print('SCENARIO: .venv is 450MB. Disk is full. You delete it.')
print('Did you lose your work?')
print()
print('ANSWER: Absolutely not! Here is why:')
print()
print('Your work lives in:')
print('  main.py           ← your code (untouched)')
print('  requirements.txt  ← your dependency list (untouched)')
print('  tests/            ← your tests (untouched)')
print()
print('Your venv contained only:')
print('  Binary packages   ← downloaded from PyPI (can be re-downloaded)')
print('  Python interpreter copy  ← can be recreated')
print()
print('Recovery:')
print()
print('  With pip:')
print('    python -m venv .venv')
print('    source .venv/bin/activate')
print('    pip install -r requirements.txt')
print('    # Identical environment restored in ~30 seconds')
print()
print('  With Poetry:')
print('    poetry install')
print('    # That is literally it.')
print()
print('The venv is to your project as a build artifact is to source code.')
print('You keep the source (requirements.txt), not the artifact (.venv).')

# %% [markdown]
# ### What If Two Packages Conflict? (Dependency Hell in Practice)
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.

# %%
# Real-world dependency conflict examples

conflicts = [
    {
        'name': 'TensorFlow + NumPy version mismatch',
        'description': 'tensorflow 2.12 requires numpy<1.24, but other ML libs need numpy>=1.24',
        'diagnosis': 'pip check  (shows all conflicts) + pip show numpy tensorflow',
        'poetry_advantage': 'Detects before install; suggests compatible combination',
    },
    {
        'name': 'boto3 + botocore tight coupling',
        'description': 'boto3 requires an exact minor version of botocore; upgrading one can break the other',
        'diagnosis': 'pip install --upgrade boto3 then check if botocore was downgraded',
        'poetry_advantage': 'Lockfile ensures they always stay at tested-together versions',
    },
    {
        'name': 'Django + Celery shared dependencies',
        'description': 'Both depend on kombu/billiard; upgrading Django can break Celery',
        'diagnosis': 'pip check after upgrade shows broken constraints',
        'poetry_advantage': 'Resolves compatible versions for BOTH before installing',
    },
]

for c in conflicts:
    print(f"Conflict: {c['name']}")
    print(f"  Problem:          {c['description']}")
    print(f"  How to diagnose:  {c['diagnosis']}")
    print(f"  Poetry advantage: {c['poetry_advantage']}")
    print()

# %% [markdown]
# ## 11. 🚀 Real-World Project Link
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# Every professional Python project uses virtual environments and dependency management.
# In our **Capstone project (Chapter 22)**, we'll use Poetry to manage a production FastAPI application with 10+ dependencies — including the web framework, database ORM, authentication library, background tasks, and testing tools. Poetry's automatic conflict resolution and `poetry.lock` ensure everyone on the team (and the deployment server) has an identical, reproducible environment.

# %% [markdown]
# ## 12. 📋 Chapter Summary & Cheat Sheet
#
# ### Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# - **Dependency**: External package your code imports (`import requests`)
# - **pip**: Python's package installer — the App Store for Python
# - **Virtual environment**: Isolated Python + packages per project (one `.venv` per project)
# - **requirements.txt**: Snapshot of packages for `pip install -r`
# - **pyproject.toml**: Modern single-file project configuration standard
# - **Lockfile**: Records exact version of every transitive dependency (`poetry.lock`)
# - **Poetry**: Modern tool combining venv + pip + lockfile + conflict resolution
# ### Quick Reference
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```bash
# # ── pip + venv (the classic approach) ──────────────────
# python -m venv .venv                  # Create virtual environment
# source .venv/bin/activate             # Activate (macOS/Linux)
# .venv\Scripts\activate               # Activate (Windows)
# pip install requests==2.31.0          # Install pinned version
# pip install -r requirements.txt       # Restore from snapshot
# pip freeze > requirements.txt         # Save snapshot
# pip check                             # Check for conflicts
# deactivate                            # Exit virtual environment
#
# # ── Poetry (the modern approach) ───────────────────────
# poetry new my-project                 # New project with scaffold
# poetry init                           # Init in existing folder
# poetry add flask                      # Add runtime dependency
# poetry add --group dev pytest         # Add dev-only dependency
# poetry install                        # Install from lockfile
# poetry shell                          # Activate venv
# poetry run python main.py             # Run without activating
# poetry update                         # Update packages
# poetry remove flask                   # Remove dependency
# poetry show --tree                    # Dependency tree
#
# # ── Version specifiers ──────────────────────────────────
# flask==3.0.3    # Exact — best for production
# flask~=3.0.3    # Compatible — >=3.0.3, <4.0
# flask>=3.0.0    # Minimum — flexible but risky
# flask           # Unpinned — avoid in team projects
# ```
#
# ### What to Commit to Git
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```
# ✅ Commit:  requirements.txt   pyproject.toml   poetry.lock
# ❌ Ignore:  .venv/   __pycache__/   *.pyc   .env
# ```

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='../7.%20data_science_and_automation/18.%20automation_and_scripting.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 18: Automation</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='20.%20containerization_and_deployment.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 20: Containerization →</a>
# </div>

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../7. data_science_and_automation/18. automation_and_scripting.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='20. containerization_and_deployment.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
