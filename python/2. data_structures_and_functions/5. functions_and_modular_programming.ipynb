# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='4.%20core_data_structures.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 4: Data Structures</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../3.%20object_oriented_programming/6.%20classes_and_objects.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 6: Classes & Objects →</a>
# </div>
#
# ---

# %% [markdown]
# # Chapter 5: Functions & Modular Programming — Writing Reusable Code
#
# > **What you'll learn:** How to package code into reusable **functions**, pass information in and out, control what variables are visible where, and organize code into **modules**.
#
# ---

# %% [markdown]
# ## 🌍 The Big Picture
#
# Imagine you make coffee every morning. You could write out the full procedure every single day:
#
# ```
# Day 1: boil water, add grounds, wait 4 minutes, pour into mug
# Day 2: boil water, add grounds, wait 4 minutes, pour into mug
# Day 3: ...and so on forever
# ```
#
# Or... you could write a **recipe** called `make_coffee()` once, and just *call* it whenever you need it.
#
# ```python
# def make_coffee():
#     boil_water()
#     add_grounds()
#     wait(4)
#     pour_into_mug()
#
# # Every morning:
# make_coffee()
# ```
#
# **Functions are Python's recipes.** Write once, use anywhere, change once to fix everywhere.
#
# > 💡 **Jargon alert:** A *function* is a named, reusable block of code that performs a specific task.

# %% [markdown]
# ---
#
# ## 🧠 Core Concepts: The "Why"
#
# The easiest way to read this section is to keep one plain-language question in view: what is The "Why" actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### The DRY Principle — Don't Repeat Yourself
#
# The most important rule in programming: **Don't Repeat Yourself (DRY)**.
#
# Here's the same calculation written **without** functions (bad) and **with** a function (good):

# %%
# ❌ WITHOUT functions — repetitive and error-prone
import math

radius1 = 5
area1 = 3.14159 * radius1 ** 2
print(f"Circle 1 area: {area1:.2f}")

radius2 = 8
area2 = 3.14159 * radius2 ** 2
print(f"Circle 2 area: {area2:.2f}")

radius3 = 12
area3 = 3.14159 * radius3 ** 2
print(f"Circle 3 area: {area3:.2f}")

# If pi is wrong, you have to fix it in THREE places!

# %%
# ✅ WITH a function — write once, use anywhere
import math

def circle_area(radius):
    return math.pi * radius ** 2

# Call it as many times as needed
print(f"Circle 1 area: {circle_area(5):.2f}")
print(f"Circle 2 area: {circle_area(8):.2f}")
print(f"Circle 3 area: {circle_area(12):.2f}")

# If the formula changes, fix it in ONE place!

# %% [markdown]
# **Why functions?**
#
# - ✅ **No repetition** — write logic once
# - ✅ **Easier fixes** — change one place, fixed everywhere
# - ✅ **Readable** — `circle_area(5)` tells you *exactly* what's happening
# - ✅ **Testable** — test each function independently
# - ✅ **Reusable** — call from anywhere, even other files

# %% [markdown]
# ---
#
# ## 🔨 Syntax & First Usage: Defining a Function
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### Anatomy of a Function
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```python
# def greet(name):
#     message = "Hello, " + name + "!"
#     return message
# ```
#
# | Part | What it means |
# |---|---|
# | `def` | **Keyword** — tells Python "a function definition follows" |
# | `greet` | **Function name** — choose something descriptive |
# | `(name)` | **Parameters** — inputs the function accepts (inside parentheses) |
# | `:` | **Colon** — starts the function body (required!) |
# | `    message = ...` | **Body** — indented code that runs when the function is called |
# | `return message` | **Return** — sends a value back to whoever called the function |

# %%
# Step 1: DEFINE the function (nothing runs yet — it's just a recipe)
def greet(name):
    message = "Hello, " + name + "!"
    return message

# Step 2: CALL the function (now the code runs)
result = greet("Alice")
print(result)

# Call it as many times as you like
print(greet("Bob"))
print(greet("Carol"))

# %% [markdown]
# ---
#
# ## 📥 Parameters vs Arguments
#
# These two words are often confused. Here's the clear distinction:
#
# - **Parameter** — the *placeholder variable* in the function **definition** (like a blank on a form)
# - **Argument** — the *actual value* you pass when **calling** the function (filling in the blank)
#
# ```python
# def greet(name):      # 'name' is the PARAMETER — a placeholder
#     ...
#
# greet("Alice")        # "Alice" is the ARGUMENT — the actual value
# ```
#
# > 💡 **Memory trick:** **P**arameters live in the **def**inition. **A**rguments are the **a**ctual values.

# %%
def describe_pet(name, animal_type):
    print(f"I have a {animal_type} named {name}.")

# Two arguments — order matters for positional arguments
describe_pet("Buddy", "dog")
describe_pet("Whiskers", "cat")
describe_pet("Nemo", "fish")

# What if you mix them up?
print()
describe_pet("dog", "Buddy")   # valid Python, but wrong meaning!

# %% [markdown]
# ---
#
# ## 📤 Return Values — Getting Data Back Out
#
# A function can **return** a value to whoever called it. This is how data flows *out* of a function.

# %%
def add(a, b):
    return a + b

result = add(3, 4)
print("3 + 4 =", result)

# Return values work in any expression
print("Double the sum:", add(3, 4) * 2)
print("Chain calls:", add(add(1, 2), 3))

# %% [markdown]
# ### ⚠️ `return` vs `print` — A Critical Distinction
#
# This is one of the most common beginner mistakes. Study this carefully:

# %%
# Function that PRINTS (output goes to screen, nothing returned)
def greet_print(name):
    print(f"Hello, {name}!")
    # no return statement → implicitly returns None

# Function that RETURNS a value
def greet_return(name):
    return f"Hello, {name}!"   # value sent back to caller

# Using the printing version
greet_print("Alice")              # ✅ prints immediately
saved = greet_print("Bob")        # also prints...
print("greet_print returned:", saved)   # ...but saved is None!

print()

# Using the returning version
saved2 = greet_return("Carol")    # nothing printed yet
print("greet_return returned:", saved2)   # ✅ we captured the value
upper = greet_return("David").upper()     # ✅ chain operations on it
print(upper)

# %%
# What does a function return if there is no return statement?
def forgotten_return(x):
    x * 2   # calculated... but thrown away!

result = forgotten_return(5)
print("Result:", result)   # None — the value vanished!

# This causes crashes:
try:
    doubled = result * 2
except TypeError as e:
    print(f"TypeError: {e}")
    print("\n✅ Rule: if you need a value back, ALWAYS use return.")

# %% [markdown]
# ---
#
# ## 🔧 Default Parameters
#
# Give a parameter a default value — the caller can skip it if the default is acceptable:

# %%
def greet(name, greeting="Hello"):
    print(f"{greeting}, {name}!")

# Use the default
greet("Alice")                  # Hello, Alice!

# Override the default
greet("Bob", "Good morning")    # Good morning, Bob!
greet("Carol", "Hola")          # Hola, Carol!

# ⚠️ Rule: parameters with defaults must come AFTER those without
# def broken(greeting="Hello", name):  ← SyntaxError!

# %% [markdown]
# ---
#
# ## 🏷️ Keyword Arguments
#
# When *calling* a function, you can name the arguments explicitly. Benefits:
# 1. Arguments can be in any order
# 2. Code is self-documenting
# 3. Easy to skip optional parameters

# %%
def order_coffee(size, milk, sugar=0, decaf=False):
    style = "decaf " if decaf else ""
    print(f"  {size} {style}coffee, {milk} milk, {sugar} sugar(s)")

print("Positional (order matters):")
order_coffee("large", "oat", 2, False)

print("\nKeyword (order doesn't matter, intent is clear):")
order_coffee(size="large", milk="oat", sugar=2, decaf=False)

print("\nKeyword (skip sugar since default is fine):")
order_coffee(milk="almond", size="small", decaf=True)

# %% [markdown]
# ---
#
# ## ⚔️ vs: Positional vs Keyword Arguments
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# > When should you use keyword arguments? Whenever they make the call **clearer**.

# %%
def send_email(to, subject, body, cc=None, bcc=None, priority="normal"):
    print(f"  To: {to} | Subject: {subject} | Priority: {priority}")
    if cc:  print(f"  CC: {cc}")

# Positional — hard to read without checking the definition
print("Positional:")
send_email("alice@example.com", "Meeting", "3pm today", None, None, "high")

# Keyword — self-documenting, no ambiguity
print("\nKeyword:")
send_email(
    to="alice@example.com",
    subject="Meeting",
    body="3pm today",
    priority="high"       # skipping cc and bcc entirely
)

# %% [markdown]
# **Use keyword arguments when:**
# - A function has many parameters
# - Several parameters share the same type (easy to mix up positions)
# - You want to skip optional parameters
# - You want the call to read like English

# %% [markdown]
# ---
#
# ## 🌊 `*args` — Variable Positional Arguments
#
# What if you don't know in advance how many arguments someone will pass?
#
# The `*` before a parameter name says: "collect **all remaining positional arguments** into a **tuple**."
#
# > 💡 The name `args` is a convention. You could write `*numbers` or `*items`. The `*` is what matters.

# %%
def add_all(*numbers):
    print(f"Received: {numbers}")   # it's a tuple!
    return sum(numbers)

print(add_all(1, 2))              # 2 args
print(add_all(1, 2, 3, 4, 5))    # 5 args
print(add_all(10, 20, 30, 40))    # 4 args — any number works!

# %%
def make_sandwich(bread, *fillings):
    print(f"Bread: {bread}")
    if fillings:
        print(f"Fillings: {', '.join(fillings)}")
    else:
        print("Plain — no fillings!")

make_sandwich("sourdough")
print()
make_sandwich("sourdough", "turkey", "cheese", "lettuce", "tomato")

# %% [markdown]
# ---
#
# ## 🏷️ `**kwargs` — Variable Keyword Arguments
#
# The `**` says: "collect **all extra keyword arguments** into a **dictionary**."
#
# > 💡 The name `kwargs` is a convention. The `**` is what matters.

# %%
def build_profile(name, **details):
    print(f"Name: {name}")
    for key, value in details.items():
        print(f"  {key}: {value}")
    print()

build_profile("Alice", age=28, city="London", job="Engineer")
build_profile("Bob", age=34, hobby="photography", pet="dog", language="Python")

# %%
# All three kinds of parameters together
def everything(required, *args, keyword="default", **kwargs):
    print(f"required : {required}")
    print(f"*args    : {args}")
    print(f"keyword  : {keyword}")
    print(f"**kwargs : {kwargs}")

everything(
    "must have this",
    "extra1", "extra2",        # captured by *args
    keyword="custom",
    foo="bar", baz=42           # captured by **kwargs
)

# %% [markdown]
# ---
#
# ## 🗺️ Scope — Where Variables Live
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### The Analogy
#
# Think of scope like physical spaces:
# - A **local variable** is a sticky note *inside* a function. When the function finishes, the note is thrown away.
# - A **global variable** lives on the *whiteboard in the hallway* — everyone can see it.
#
# ### The LEGB Rule
#
# When Python looks up any variable name, it searches in this order:
#
# ```
# L — Local      : inside the current function
# E — Enclosing  : inside any surrounding (wrapping) functions
# G — Global     : at the top level of the file/module
# B — Built-in   : Python's own names (len, print, range, True...)
# ```

# %%
# LOCAL scope
def my_function():
    local_var = "I only exist inside this function"
    print("Inside:", local_var)    # ✅ visible here

my_function()

try:
    print(local_var)               # ❌ not visible out here
except NameError as e:
    print(f"NameError: {e}")
    print("local_var was thrown away when the function finished.")

# %%
# GLOBAL vs LOCAL — same name, different scope
x = "global x"

def demonstrate():
    x = "local x"      # creates a NEW local variable; global is untouched
    print("Inside function:", x)

demonstrate()
print("Outside function:", x)   # original global unchanged

# %%
# The 'global' keyword — modify a global variable from inside a function
# (use sparingly — global state makes code hard to test and reason about)
counter = 0

def increment():
    global counter    # declare we want to modify the global
    counter += 1

print("Before:", counter)
increment()
increment()
increment()
print("After:", counter)

# ✅ Better pattern: return values instead of mutating globals
def increment_value(n):
    return n + 1

counter2 = 0
counter2 = increment_value(counter2)
counter2 = increment_value(counter2)
print("Counter2:", counter2)

# %% [markdown]
# ---
#
# ## ⚡ Lambda Functions — One-Line Throwaway Functions
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ### The Analogy
#
# A **lambda** is like a sticky note function — a quick, anonymous, one-line function you write for a single use.
#
# ```python
# lambda arguments: expression
# ```
#
# - Can have multiple arguments
# - Can only have **one expression** (the result is automatically returned)
# - No statements allowed (no `if`/`for`/`return` keywords)

# %%
# A full function vs the equivalent lambda
def double(x):
    return x * 2

double_lambda = lambda x: x * 2

print("def   :", double(5))
print("lambda:", double_lambda(5))   # identical result

# %% [markdown]
# ---
#
# ## ⚔️ vs: `def` vs `lambda`
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# Use `def` for anything you'll name and reuse. Use `lambda` for short inline operations — especially as arguments to other functions.

# %%
numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5]

# Sorting with a key: using def
def get_negative(n):
    return -n   # sort by the negative value (i.e., descending)

sorted_def = sorted(numbers, key=get_negative)
print("Sorted descending (def):   ", sorted_def)

# The same, with lambda — much more concise for a one-liner
sorted_lam = sorted(numbers, key=lambda n: -n)
print("Sorted descending (lambda):", sorted_lam)

# map() — apply a function to every item
doubled = list(map(lambda x: x * 2, [1, 2, 3, 4, 5]))
print("\nDoubled:", doubled)

# filter() — keep items where the function returns True
evens = list(filter(lambda x: x % 2 == 0, [1, 2, 3, 4, 5, 6]))
print("Evens:", evens)

# %%
# When NOT to use lambda — complex logic belongs in a named def
# ❌ Unreadable lambda
process = lambda x, y: (x + y) * (x - y) / (x * y) if y != 0 else 0

# ✅ Clear, documented def
def process_values(x, y):
    if y == 0:
        return 0
    return (x + y) * (x - y) / (x * y)

print("lambda:", process(6, 3))
print("def:   ", process_values(6, 3))
print()
print("Rule: if the lambda needs a comment to understand, write a def instead.")

# %% [markdown]
# ---
#
# ## 📦 Modules & Imports — Python's Toolboxes
#
# Architecture material sounds bigger than it is if you read it only as terminology. Start by identifying the responsibility of each part and the reason those responsibilities are separated; the structure usually becomes much clearer from there.
#
# ### The Analogy
#
# A **module** is a toolbox. Python ships with hundreds of toolboxes in its **standard library**. When you write `import math`, you're saying: "Open the math toolbox so I can use its tools."
#
# You can also create your own modules (any `.py` file is a module).
#
# ### Three Ways to Import
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.

# %%
# 1. import module — access tools with module.name prefix
import math

print("pi:          ", math.pi)
print("sqrt(16):    ", math.sqrt(16))
print("ceil(4.3):   ", math.ceil(4.3))
print("floor(4.9):  ", math.floor(4.9))
print("factorial(5):", math.factorial(5))

# %%
# 2. from module import name — import specific tools directly (no prefix)
from math import pi, sqrt, hypot

area = pi * 5 ** 2
print(f"Area of circle r=5: {area:.4f}")
print(f"sqrt(25) = {sqrt(25)}")
print(f"Hypotenuse of 3-4-5 triangle: {hypot(3, 4)}")

# %%
# 3. import module as alias — shorter name for convenience
import math as m

print("Using alias 'm':", m.pi)

# You'll see these common aliases everywhere in data science:
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# %% [markdown]
# ### 🗂️ Useful Standard Library Modules
#
# Python's standard library has batteries included — no `pip install` needed:

# %%
import random

print("Random float [0,1):", random.random())
print("Random int 1-10:   ", random.randint(1, 10))
print("Random choice:     ", random.choice(["rock", "paper", "scissors"]))

deck = list(range(1, 14))
random.shuffle(deck)
print("Shuffled deck:", deck[:7], "...")

# %%
from datetime import datetime, date, timedelta

now = datetime.now()
print("Now:      ", now.strftime("%Y-%m-%d %H:%M:%S"))

today = date.today()
print("Today:    ", today)
print("Tomorrow: ", today + timedelta(days=1))
print("Last week:", today - timedelta(weeks=1))

# %%
import os

print("Working directory:", os.getcwd())

# Build cross-platform file paths (works on Windows, Mac, Linux)
path = os.path.join("python", "chapter5", "notebook.ipynb")
print("Joined path:", path)

# Check if a path exists
print("Does /tmp exist?", os.path.exists("/tmp"))

# %% [markdown]
# ---
#
# ## 🧪 What If? Experimentation
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.

# %% [markdown]
# ### What If #1: What if you call a function before defining it?
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.

# %%
# Python reads files top-to-bottom.
# Calling a function before its 'def' → NameError

try:
    result = square(5)   # called BEFORE the definition below!
except NameError as e:
    print(f"NameError: {e}")
    print("Python hasn't seen 'square' yet — it's defined later.")

# Now define it
def square(x):
    return x ** 2

# Now calling works
print("\nAfter definition: square(5) =", square(5))
print()
print("Rule: define functions before calling them.")
print("(Exception: a function can call ANOTHER function defined later,")
print("as long as the first function isn't called until both are defined.)

# %% [markdown]
# ### What If #2: What if you forget the `return` statement?
#
# If this section feels dense, pause and identify the data structure or model first. Most of the APIs here make more sense once you know what is being stored, queried, or transformed.

# %%
def add_no_return(a, b):
    result = a + b
    # Oops — forgot to return!

def add_with_return(a, b):
    result = a + b
    return result

no_ret   = add_no_return(3, 4)
with_ret = add_with_return(3, 4)

print("Without return:", no_ret)    # None
print("With return:   ", with_ret)  # 7

# The None crash
try:
    doubled = no_ret * 2
except TypeError as e:
    print(f"\nCrash: {e}")
    print("You cannot do math with None!")
    print("\n✅ Fix: add 'return result' to add_no_return")

# %% [markdown]
# ### What If #3: What if two functions have the same name?
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.

# %%
def say_hello():
    print("Version 1 — first definition")

def say_hello():   # same name → silently overwrites the first!
    print("Version 2 — second definition")

say_hello()   # which one runs?

print()
print("The SECOND definition silently overwrites the first.")
print("Python gives NO warning — this is a common source of bugs!")
print()
print("Best practice: use descriptive, specific names:")
print("  send_welcome_email() vs send_password_reset_email()")

# %% [markdown]
# ---
#
# ## 🚀 Real-World Project Link
#
# In our **Simple Calculator** project, each operation will be its own function — making the code modular, testable, and easy to extend:
#
# ```python
# def add(a, b):      return a + b
# def subtract(a, b): return a - b
# def multiply(a, b): return a * b
#
# def divide(a, b):
#     if b == 0:
#         return "Error: division by zero"
#     return a / b
#
# def calculate(a, operator, b):
#     operations = {"+": add, "-": subtract, "*": multiply, "/": divide}
#     if operator not in operations:
#         return f"Unknown operator: {operator}"
#     return operations[operator](a, b)
#
# # Clean, readable, testable
# print(calculate(10, "+", 5))   # 15
# print(calculate(10, "/", 0))   # Error: division by zero
# ```
#
# We'll use `**kwargs` for a configurable display function, `*args` for a multi-number sum, and `import math` for scientific operations.

# %% [markdown]
# ---
#
# ## 📋 Chapter Summary & Cheat Sheet

# %%
# ── DEFINE A FUNCTION ──────────────────────────────────
def function_name(param1, param2="default"):
    result = param1 + param2
    return result

# ── CALL A FUNCTION ─────────────────────────────────────
result = function_name(10, 20)                  # positional
result = function_name(param1=10, param2=20)    # keyword

# ── DEFAULT PARAMETERS ──────────────────────────────────
def greet(name, greeting="Hello"):
    return f"{greeting}, {name}!"

# ── *args — any number of positional args ───────────────
def total(*numbers):
    return sum(numbers)   # numbers is a tuple

# ── **kwargs — any number of keyword args ───────────────
def profile(name, **details):
    pass   # details is a dict

# ── LAMBDA ──────────────────────────────────────────────
square = lambda x: x ** 2
evens  = list(filter(lambda x: x % 2 == 0, range(10)))

# ── SCOPE ───────────────────────────────────────────────
x = "global"
def func():
    x = "local"    # new local variable; global unchanged
# LEGB search order: Local → Enclosing → Global → Built-in

# ── IMPORTS ─────────────────────────────────────────────
import math                    # math.pi, math.sqrt()
from math import pi, sqrt      # pi, sqrt directly
import math as m               # m.pi

print("Cheat sheet ready! ✅")

# %% [markdown]
# ### Key Concepts Summary
#
# | Concept | One-liner |
# |---|---|
# | `def` | Defines a named, reusable function |
# | **parameter** | Placeholder variable in the definition |
# | **argument** | Actual value passed when calling |
# | `return` | Sends a value out — without it, function returns `None` |
# | **default parameter** | `def f(x, y=10):` — caller can omit `y` |
# | **keyword argument** | `f(y=5, x=3)` — name args at call time |
# | `*args` | Collect extra positional args into a tuple |
# | `**kwargs` | Collect extra keyword args into a dictionary |
# | **lambda** | One-line anonymous function |
# | **scope / LEGB** | Where Python searches for variable names |
# | **module** | A `.py` file (or standard library package) you can import |

# %% [markdown]
# ---
#
# ## 💪 Practice Prompts
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### Challenge 1: Simple Calculator 🧮
#
# Build a calculator with individual functions for each operation:
# - `add(a, b)`, `subtract(a, b)`, `multiply(a, b)`, `divide(a, b)`
# - A `calculate(a, operator, b)` function that dispatches to the right one
# - Handle division by zero gracefully
#
# Bonus: add `power(base, exp=2)` with a default exponent of 2, and `sqrt(n)` using `math.sqrt`.
#
# ---
#
# ### Challenge 2: Text Analyzer 📊
#
# Write a function `analyze_text(text)` that returns a **dictionary** with:
# - `word_count`: total words
# - `unique_words`: number of unique words
# - `longest_word`: the longest word
# - `avg_word_length`: average word length, rounded to 2 decimal places
#
# ```python
# result = analyze_text("the quick brown fox jumps over the lazy dog")
# print(result)
# # {'word_count': 9, 'unique_words': 8, 'longest_word': 'jumps', 'avg_word_length': 3.89}
# ```
#
# ---
#
# ### Challenge 3: Grade Book 📚
#
# Build a grade book system using functions:
#
# ```python
# gradebook = {}   # {"Alice": [95, 87, 92], "Bob": [78, 85, 80]}
#
# def add_student(gradebook, name): ...
# def add_grades(gradebook, name, *grades): ...    # *args: add one or many grades at once
# def get_average(gradebook, name): ...
# def get_class_average(gradebook): ...
# def get_top_student(gradebook): ...
# ```
#
# Use `*grades` in `add_grades` so callers can do `add_grades(gb, "Alice", 90, 85, 92)` or `add_grades(gb, "Bob", 78)` — one or many grades in a single call.

# %% [markdown]
# ---
#
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 2em 0 1em 0;'>
#   <a href='4.%20core_data_structures.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Chapter 4: Data Structures</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../3.%20object_oriented_programming/6.%20classes_and_objects.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Chapter 6: Classes & Objects →</a>
# </div>
