# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='17.%20mastering_asyncawait.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../9.%20production_deployment/19.%20containerization.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 18: WebSockets
#
# ## The Big Picture
#
# Normal HTTP works like this:
#
# 1. the client sends one request,
# 2. the server sends one response,
# 3. the connection is finished.
#
# That model is perfect for many APIs. But it is awkward for things that feel live, such as:
#
# - chat apps,
# - live dashboards,
# - multiplayer games,
# - stock tickers,
# - notifications.
#
# WebSockets solve that by creating a **persistent connection**. After the connection is established, both sides can send messages back and forth without opening a brand-new HTTP request every time.
#
# For beginners, the key mental model is this:
#
# > HTTP is like mailing letters.
# > WebSockets are like staying on a phone call.

# %% [markdown]
# ## Core Concepts
#
# ### Persistent connection
# A WebSocket stays open until one side closes it or the network breaks.
#
# ### Full-duplex communication
# **Full-duplex** means both client and server can send messages independently.
#
# ### Accepting a connection
# In FastAPI, a WebSocket route begins with `await websocket.accept()`.
#
# ### Receiving and sending messages
# The server can use methods like:
# - `await websocket.receive_text()`
# - `await websocket.send_text(...)`
#
# ### Connection manager
# In real apps, teams often create a manager object to keep track of connected clients so they can broadcast messages.
#
# ### WebSockets vs SSE
# WebSockets allow two-way messaging. SSE (Server-Sent Events) is one-way: server to client only.
#
# > ❓ **How is WebSocket different from HTTP?** HTTP is request-response: client asks, server replies, connection closes. WebSocket keeps the connection open so *either side* can push a message at any time — essential for chat, live dashboards, or multiplayer games.

# %% [markdown]
# ## Syntax & First Usage
#
# Here is the smallest useful WebSocket example: an **echo server**. Whatever the client sends, the server sends back.

# %%
from fastapi import FastAPI, WebSocket

app = FastAPI()

@app.websocket('/ws')
async def websocket_endpoint(websocket: WebSocket):
    await websocket.accept()

    while True:
        message = await websocket.receive_text()
        await websocket.send_text(f'You said: {message}')

# %% [markdown]
# ## Deep Dive with Code Examples
#
# ### Example 1: The WebSocket lifecycle
#
# A beginner should picture the route in four steps:
#
# 1. client connects,
# 2. server accepts,
# 3. messages move back and forth,
# 4. one side disconnects.

# %%
from fastapi import FastAPI, WebSocket, WebSocketDisconnect

app = FastAPI()

@app.websocket('/lifecycle')
async def lifecycle_socket(websocket: WebSocket):
    await websocket.accept()

    try:
        while True:
            text = await websocket.receive_text()
            await websocket.send_text(f'Server received: {text}')
    except WebSocketDisconnect:
        print('Client disconnected')

# %% [markdown]
# ### Example 2: A simple browser client
#
# WebSockets are not only a server feature. The browser also needs to open the connection.
#
# Notice the URL begins with `ws://` (or `wss://` for secure connections).

# %%
// Browser JavaScript
const socket = new WebSocket('ws://localhost:8000/ws');

socket.onopen = () => {
  console.log('Connected');
  socket.send('Hello from the browser');
};

socket.onmessage = (event) => {
  console.log('Message from server:', event.data);
};

socket.onclose = () => {
  console.log('Connection closed');
};

# %% [markdown]
# ### Example 3: Broadcast pattern with a connection manager
#
# Chat rooms and live notification systems often need the same message to be sent to many connected clients. A connection manager keeps a list of active sockets.

# %%
from fastapi import FastAPI, WebSocket, WebSocketDisconnect

app = FastAPI()

class ConnectionManager:
    def __init__(self):
        self.active_connections: list[WebSocket] = []

    async def connect(self, websocket: WebSocket):
        await websocket.accept()
        self.active_connections.append(websocket)

    def disconnect(self, websocket: WebSocket):
        self.active_connections.remove(websocket)

    async def broadcast(self, message: str):
        for connection in self.active_connections:
            await connection.send_text(message)

manager = ConnectionManager()

@app.websocket('/chat')
async def chat_socket(websocket: WebSocket):
    await manager.connect(websocket)
    try:
        while True:
            text = await websocket.receive_text()
            await manager.broadcast(f'Broadcast: {text}')
    except WebSocketDisconnect:
        manager.disconnect(websocket)

# %% [markdown]
# ### Example 4: Adding user identity
#
# In real projects, you usually want to know **who** sent the message. One beginner-friendly pattern is passing a username or token when connecting, then tagging messages with that identity.

# %%
from fastapi import FastAPI, Query, WebSocket, WebSocketDisconnect

app = FastAPI()

@app.websocket('/room')
async def room_socket(websocket: WebSocket, username: str = Query(...)):
    await websocket.accept()

    try:
        while True:
            text = await websocket.receive_text()
            await websocket.send_text(f'{username} says: {text}')
    except WebSocketDisconnect:
        print(f'{username} left the room')

# %% [markdown]
# ### Example 5: Thinking about limits
#
# WebSockets are powerful, but they introduce new questions:
#
# - What happens if a client disconnects suddenly?
# - What if one slow client delays broadcasts?
# - Where should connection state live if the app runs on many server instances?
#
# These questions are why chat and notification systems often add Redis, message brokers, or dedicated realtime infrastructure as they grow.

# %%
# Pseudocode for a more scalable idea
# 1. WebSocket server receives a message
# 2. Publish message to Redis / broker
# 3. Other app instances receive it
# 4. Each instance broadcasts to its connected clients

architecture = [
    'Client A -> FastAPI instance 1',
    'FastAPI instance 1 -> Redis pub/sub',
    'Redis pub/sub -> FastAPI instance 2',
    'FastAPI instance 2 -> Client B and Client C',
]

for step in architecture:
    print(step)

# %% [markdown]
# ## WebSockets vs SSE
#
# | Feature | WebSockets | SSE |
# |---|---|---|
# | Direction | Two-way | Server → client only |
# | Good for chat? | Yes | Not ideal |
# | Good for live notifications? | Yes | Yes |
# | Browser API complexity | Moderate | Simpler |
# | Uses plain HTTP semantics after connect? | No, upgraded protocol | Yes |
#
# **Rule of thumb:**
#
# - choose **WebSockets** when the client and server both need to talk,
# - choose **SSE** when the server just needs to push updates down to the browser.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# 1. **What if you forget `await websocket.accept()`?**
#    The connection is never properly established.
#
# 2. **What if the client disconnects in the middle of a loop?**
#    Catch `WebSocketDisconnect` and clean up the connection list.
#
# 3. **What if you have multiple FastAPI instances?**
#    A simple in-memory list of connections is no longer enough for global broadcast.
#
# 4. **What if you only need one-way updates?**
#    SSE may be simpler than WebSockets.

# %%
scenarios = {
    'forgot accept()': 'handshake fails',
    'client disconnects': 'catch WebSocketDisconnect',
    'single server broadcast': 'in-memory manager can work',
    'many server instances': 'use shared pub/sub or broker',
    'one-way notifications only': 'consider SSE',
}

for case, result in scenarios.items():
    print(f'{case:<28} -> {result}')

# %% [markdown]
# ## Real-World Project Link
#
# Imagine our project is a **support dashboard**.
#
# - customers submit tickets through normal HTTP routes,
# - support agents watch a live queue in the browser,
# - new tickets appear instantly through a WebSocket broadcast,
# - typing indicators or quick status changes also flow through the same persistent connection.
#
# That is the kind of experience WebSockets are built for.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# - WebSockets create a persistent, two-way connection.
# - Use `@app.websocket(...)` for WebSocket routes in FastAPI.
# - Call `await websocket.accept()` before message exchange.
# - Use `receive_text()` and `send_text()` for simple text messages.
# - A connection manager helps with chat and broadcast patterns.
# - Catch `WebSocketDisconnect` to clean up.
# - WebSockets are best for two-way realtime features; SSE is often enough for one-way streaming.
#
# ### Mini cheat sheet
#
# ```python
# @app.websocket('/ws')
# async def ws(websocket: WebSocket):
#     await websocket.accept()
#     try:
#         while True:
#             message = await websocket.receive_text()
#             await websocket.send_text(message)
#     except WebSocketDisconnect:
#         pass
# ```

# %% [markdown]
# ## Practice Prompts
#
# 1. Build an echo WebSocket that sends back every message in uppercase.
# 2. Add a `ConnectionManager` and broadcast each message to all clients.
# 3. Pass a username in the connection query string and prefix each chat message with it.
# 4. Explain when SSE would be simpler than WebSockets for a dashboard.
# 5. Sketch how you would scale a chat system beyond one FastAPI server instance.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='17.%20mastering_asyncawait.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../9.%20production_deployment/19.%20containerization.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
