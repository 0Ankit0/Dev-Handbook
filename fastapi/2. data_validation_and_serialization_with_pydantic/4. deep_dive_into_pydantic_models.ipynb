# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../1.%20foundations_of_fastapi/3.%20automatic_documentation.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='5.%20advanced_data_handling.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 4: Deep Dive into Pydantic Models
#
# ## The Big Picture
#
# **Pydantic** is the library FastAPI uses to understand data. Think of it like a careful front-desk clerk at a busy hotel: every guest must show the right details before getting a room key. In the same way, Pydantic checks incoming data, converts it into the right Python types when it can, and rejects broken input before bad data spreads through your application.
#
# In this chapter, we will slow down and really understand what a **model** is, how fields work, how to add rules, how to build nested JSON shapes, how special types make your APIs safer, and how custom validators let you enforce business rules.
#
# **By the end of this chapter, you should be able to:**
# - explain what `BaseModel` does in plain English,
# - create fields with types, defaults, and constraints,
# - model real JSON data with nested objects,
# - use special Pydantic types like `EmailStr`, `HttpUrl`, `UUID`, and `datetime`,
# - write validators when built-in rules are not enough.
#
# > ❓ **What does Pydantic do that a plain `dict` doesn't?** Pydantic validates and coerces data at parse time. If a field is `int` but the request sends `"42"` (a string), Pydantic converts it. If it sends `"hello"`, Pydantic raises a clear validation error before your code runs.

# %% [markdown]
# ## Core Concepts
#
# - **Model**: a blueprint that describes what data should look like.
# - **Field**: one named piece of data inside a model, such as `name`, `price`, or `email`.
# - **Type hint**: a Python annotation like `str`, `int`, or `list[str]` that tells Pydantic what kind of data a field should hold.
# - **Validation**: checking whether input follows the rules you defined.
# - **Serialization**: turning Python objects into a format such as a dictionary or JSON so they can be sent in an API response.
# - **Constraint**: an extra rule such as “must be at least 3 characters” or “must be greater than 0”.
# - **Nested model**: a model inside another model. This is how you represent structured JSON such as an order with a customer and shipping address.
# - **Validator**: custom Python logic that runs when you need rules more specific than simple types and constraints.
#
# A helpful mental model: a Pydantic model is like a smart form. It does not only store values. It also checks them, tidies them up, and explains what went wrong.
#
# > ❓ **Why split code into Blueprints?** A single file with hundreds of routes becomes unreadable. Blueprints group related routes (e.g., all auth routes) into pluggable mini-applications that you register on the main app — like separate chapters in a book.

# %% [markdown]
# ## Syntax & First Usage
#
# The most common starting point is `BaseModel`. You create a class that inherits from it, then list fields with type hints.
#
# Why does this matter? Because plain dictionaries are flexible, but sometimes *too* flexible. They let almost anything in. A `BaseModel` gives your data a clear shape.
#
# In beginner terms:
# - `class Book(BaseModel):` means “make a checked data shape called `Book`.”
# - `title: str` means “the `title` field must be text.”
# - `price: float` means “the `price` field must be a number with decimals allowed.”
# - `in_stock: bool = True` means “if no value is given, use `True`.”

# %%
from pydantic import BaseModel


class Book(BaseModel):
    title: str
    price: float
    in_stock: bool = True


book = Book(title="FastAPI for Beginners", price="29.99")

print(book)
print(book.model_dump())
print(type(book.price))

# %% [markdown]
# Notice what happened in the example above:
#
# 1. We passed `price` as a string: `"29.99"`.
# 2. Pydantic recognized that the model expected a `float`.
# 3. It converted the string into a real number.
#
# This automatic conversion is convenient, but it is not magic. If the value cannot sensibly become the required type, Pydantic raises a clear error.
#
# ## Field types and default values
#
# A field type answers the question: **what kind of value belongs here?** A default value answers the question: **what should be used if the caller sends nothing?**
#
# Good defaults reduce repetitive code. They are like sensible starter settings on a new phone: you can change them, but you do not have to configure everything from scratch.

# %%
from pydantic import BaseModel, Field


class Product(BaseModel):
    name: str
    price: float
    quantity: int = 0
    tags: list[str] = Field(default_factory=list)
    description: str | None = None
    is_active: bool = True


product = Product(name="Wireless Mouse", price=24.5)

print(product.model_dump())
print(product.quantity)
print(product.tags)
print(product.description)

# %% [markdown]
# A few important details are hiding in that example:
#
# - `str | None` means the field can be text **or** `None`. `None` is Python's way of saying “no value”.
# - `Field(default_factory=list)` creates a new empty list for each model instance. This is safer than writing `tags: list[str] = []`.
# - `quantity: int = 0` means the field is optional in the input because a default exists.
#
# ## Deep Dive with Code Examples
#
# `Field()` lets you attach extra rules to a field. Think of it like the difference between saying “enter your age” and saying “enter your age, and it must be between 13 and 120.” The second version is much clearer and much safer.
#
# Common beginner-friendly constraints include:
# - `min_length` and `max_length` for text,
# - `ge` for “greater than or equal to”,
# - `gt` for “greater than”,
# - `le` for “less than or equal to”,
# - `pattern` for matching a text format.
#
# > ❓ **Do type hints change how my code runs?** No — Python ignores them at runtime. They exist for you, your editor, and tools like `mypy`. They document intent, catch mistakes early, and enable precise autocomplete.

# %%
from pydantic import BaseModel, Field, ValidationError


class UserSignup(BaseModel):
    username: str = Field(min_length=3, max_length=20, pattern=r"^[a-zA-Z0-9_]+$")
    age: int = Field(ge=13, le=120)
    password: str = Field(min_length=8)


valid_user = UserSignup(username="code_learner", age=18, password="supersecret")
print(valid_user.model_dump())

try:
    UserSignup(username="no spaces", age=10, password="123")
except ValidationError as exc:
    print(exc)

# %% [markdown]
# If you are new to regular expressions, do not worry too much about the `pattern` yet. A **regular expression** is a text pattern used for matching strings. In this example, it means the username may contain letters, numbers, and underscores.
#
# ## Deep Dive with Code Examples
#
# Real APIs rarely deal with flat data only. A shopping order may contain a customer, a shipping address, and a list of items. A blog post may contain an author object and a list of tags. This is where nested models shine.
#
# A nested model is simply a model used as the type of another field. It helps your API mirror real-world structures cleanly.

# %%
from pydantic import BaseModel


class Address(BaseModel):
    street: str
    city: str
    postal_code: str


class Customer(BaseModel):
    name: str
    email: str
    address: Address


class OrderItem(BaseModel):
    name: str
    quantity: int
    price: float


class Order(BaseModel):
    order_id: int
    customer: Customer
    items: list[OrderItem]


order = Order(
    order_id=101,
    customer={
        "name": "Ava",
        "email": "ava@example.com",
        "address": {
            "street": "12 River Road",
            "city": "Pune",
            "postal_code": "411001",
        },
    },
    items=[
        {"name": "Notebook", "quantity": 2, "price": 3.5},
        {"name": "Pen", "quantity": 5, "price": 1.2},
    ],
)

print(order.model_dump())
print(order.customer.address.city)
print(order.items[0].name)

# %% [markdown]
# That example is worth pausing on. We passed nested dictionaries and lists, but Pydantic turned them into structured Python objects that still follow the rules we declared.
#
# This matters because deeply nested JSON can become messy very quickly if you manage it manually. Pydantic gives that structure names and rules.
#
# ## Deep Dive with Code Examples
#
# Some fields represent very specific ideas:
#
# - **Email address**: text that should follow email format rules.
# - **URL**: a web address such as `https://example.com`.
# - **UUID**: a universally unique identifier, which is a long special ID designed to avoid collisions.
# - **datetime**: a date and time together, such as `2025-01-15T09:30:00`.
#
# Using special types makes your model more expressive. It is like labeling boxes in a warehouse with exact categories instead of writing “stuff” on all of them.

# %%
# EmailStr validation requires the optional package: pip install email-validator
from datetime import datetime
from uuid import UUID, uuid4

from pydantic import BaseModel, EmailStr, HttpUrl


class Invitation(BaseModel):
    invite_id: UUID
    email: EmailStr
    meeting_link: HttpUrl
    sent_at: datetime


invitation = Invitation(
    invite_id=uuid4(),
    email="student@example.com",
    meeting_link="https://example.com/meet/intro-fastapi",
    sent_at="2025-01-15T09:30:00",
)

print(invitation.model_dump())
print(type(invitation.invite_id))
print(type(invitation.sent_at))

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Built-in constraints are great, but sometimes your rules depend on your specific business logic.
#
# Example: a username might not be allowed to contain the word `admin`, or an event's `end_time` must come after its `start_time`.
#
# That is when you write a validator.
#
# - A **field validator** checks one field.
# - A **model validator** checks the relationship between multiple fields.
#
# Think of field validation as checking one ingredient, and model validation as checking whether the full recipe makes sense.

# %%
from datetime import datetime

from pydantic import BaseModel, ValidationError, field_validator, model_validator


class EventRegistration(BaseModel):
    attendee_name: str
    ticket_count: int
    start_time: datetime
    end_time: datetime

    @field_validator("attendee_name")
    @classmethod
    def name_must_have_letters(cls, value: str) -> str:
        cleaned = value.strip()
        if len(cleaned) < 2:
            raise ValueError("attendee_name must have at least 2 characters")
        return cleaned.title()

    @field_validator("ticket_count")
    @classmethod
    def ticket_count_must_be_positive(cls, value: int) -> int:
        if value < 1:
            raise ValueError("ticket_count must be at least 1")
        return value

    @model_validator(mode="after")
    def end_must_be_after_start(self):
        if self.end_time <= self.start_time:
            raise ValueError("end_time must be after start_time")
        return self


registration = EventRegistration(
    attendee_name="  ava  ",
    ticket_count=2,
    start_time="2025-02-10T09:00:00",
    end_time="2025-02-10T11:00:00",
)
print(registration.model_dump())

try:
    EventRegistration(
        attendee_name="A",
        ticket_count=0,
        start_time="2025-02-10T11:00:00",
        end_time="2025-02-10T09:00:00",
    )
except ValidationError as exc:
    print(exc)

# %% [markdown]
# ## `BaseModel` vs plain `dict`
#
# Both can hold data, but they solve different problems.
#
# | Tool | Best for | Strength | Weakness |
# | --- | --- | --- | --- |
# | Plain `dict` | quick temporary data | flexible and simple | no automatic validation |
# | `BaseModel` | API input/output and important app data | validation, conversion, documentation | slightly more structure to write |
#
# Use a plain dictionary when you just need a temporary container inside your code. Use `BaseModel` when the data shape matters, especially at the edges of your app where data enters or leaves.

# %%
from pydantic import BaseModel, ValidationError

payload = {"username": "mia", "age": "twenty"}
print("Plain dict accepts anything:", payload)


class Profile(BaseModel):
    username: str
    age: int


try:
    profile = Profile(**payload)
    print(profile)
except ValidationError as exc:
    print("BaseModel catches the problem:")
    print(exc)

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# Try these small changes to build intuition:
#
# 1. Change `price="29.99"` to `price="free"`. What error do you get?
# 2. Remove the `address` field from the nested order input. Which part of the error points to the missing value?
# 3. Set `ticket_count=-1`. How does the custom validator respond?
# 4. Add a new optional field like `coupon_code: str | None = None`. What changes for callers?
# 5. Replace `EmailStr` with plain `str`. What safety do you lose?
#
# This kind of deliberate tinkering is powerful. Small experiments help you build a mental model faster than passive reading.

# %% [markdown]
# ## Real-World Project Link
#
# Imagine you are building an event booking platform:
#
# - `EventCreate` validates new events created by organizers.
# - `AttendeeCreate` checks emails and ticket counts.
# - `Venue` becomes a nested model inside `Event`.
# - `BookingResponse` serializes safe output back to the frontend.
# - Validators enforce business rules such as “booking closes before the event starts.”
#
# This chapter's ideas connect directly to FastAPI route functions. In the next chapters, these models will become request bodies, response models, settings objects, and database-friendly data contracts.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
#
# - `BaseModel` creates structured, validated data shapes.
# - Type hints tell Pydantic what each field should contain.
# - Defaults make fields optional in input.
# - `Field()` adds constraints and metadata.
# - Nested models describe complex JSON cleanly.
# - Special types capture common real-world formats.
# - Validators let you enforce custom business rules.
#
# ### Cheat sheet
#
# ```python
# from pydantic import BaseModel, Field, EmailStr, field_validator, model_validator
#
# class User(BaseModel):
#     username: str = Field(min_length=3, max_length=20)
#     email: EmailStr
#     age: int = Field(ge=13)
#     bio: str | None = None
#
#     @field_validator("username")
#     @classmethod
#     def clean_username(cls, value: str) -> str:
#         return value.strip().lower()
#
#     @model_validator(mode="after")
#     def check_logic(self):
#         return self
# ```
# ### When to use these tools
#
# - Use **basic fields** when your data is simple.
# - Use **constraints** when bad input should be rejected early.
# - Use **nested models** when JSON has objects inside objects.
# - Use **special types** when the format matters.
# - Use **validators** when the rule is specific to your app.

# %% [markdown]
# ## Practice Prompts
#
# 1. Create a `BlogPost` model with `title`, `content`, `author_email`, and `published_at`.
# 2. Add `Field()` constraints so `title` must be between 5 and 100 characters.
# 3. Create a nested `Comment` model and store a list of comments inside `BlogPost`.
# 4. Add a validator that strips spaces from `title`.
# 5. Build a `CheckoutSession` model with `UUID`, nested customer data, and a validator that requires at least one item.
#
# If you can do those exercises without copying the earlier examples line for line, you are building real understanding.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../1. foundations_of_fastapi/3. automatic_documentation.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='5. advanced_data_handling.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
