# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='4.%20deep_dive_into_pydantic_models.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../3.%20core_fastapi_concepts/6.%20dependency_injection_system.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 5: Advanced Data Handling
#
# ## The Big Picture
#
# In Chapter 4, you learned how Pydantic models describe and validate data. Now we move one step further: how to choose the right data tool, how to control exactly what your API sends back, how forms and file uploads fit into FastAPI, and how application settings can be loaded safely from environment variables.
#
# This chapter matters because real applications do more than accept JSON. They also reshape data, hide private fields, accept browser form submissions, upload files, and read configuration such as database URLs and secret keys.
#
# **By the end of this chapter, you should be able to:**
# - explain the difference between `BaseModel` and Python `dataclass`,
# - serialize models with `model_dump()` and `model_dump_json()`,
# - use aliases and include/exclude rules to control output,
# - recognize when to use forms and file uploads instead of JSON,
# - load configuration with `pydantic-settings` in a clean, scalable way.
#
# > ❓ **What does Pydantic do that a plain `dict` doesn't?** Pydantic validates and coerces data at parse time. If a field is `int` but the request sends `"42"` (a string), Pydantic converts it. If it sends `"hello"`, Pydantic raises a clear validation error before your code runs.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# - **Dataclass**: a Python feature that automatically creates helper methods for classes that mainly store data.
# - **Serialization**: converting a Python object into a dictionary or JSON string.
# - **Alias**: an alternate field name, often used when your API wants one name and your Python code prefers another.
# - **Include / exclude**: rules for selecting which fields should appear in output.
# - **Form data**: a request format commonly sent by HTML forms in browsers.
# - **File upload**: sending binary data such as images or PDFs from a client to a server.
# - **Environment variable**: a key-value setting stored outside your code, such as `DATABASE_URL`.
# - **Settings model**: a Pydantic model that reads configuration from the environment.
#
# Analogy time: if Chapter 4 taught you how to inspect packages coming into a warehouse, Chapter 5 teaches you how to label outgoing packages, accept different delivery formats, and read the building's operating instructions.

# %% [markdown]
# ## Syntax & First Usage
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# A `BaseModel` and a `dataclass` can look similar at first glance because both let you define named fields. The difference is in behavior.
#
# - A `dataclass` is lightweight and great for plain Python data containers.
# - A `BaseModel` is stronger when input might be messy because it validates and converts data.
#
# If you are building API request and response models, `BaseModel` is usually the better default choice.

# %%
from dataclasses import dataclass

from pydantic import BaseModel, ValidationError


@dataclass
class PlainUser:
    name: str
    age: int


class ApiUser(BaseModel):
    name: str
    age: int


plain_user = PlainUser(name="Ava", age="20")
print(plain_user)
print(type(plain_user.age))

validated_user = ApiUser(name="Ava", age="20")
print(validated_user)
print(type(validated_user.age))

try:
    ApiUser(name="Ava", age="twenty")
except ValidationError as exc:
    print(exc)

# %% [markdown]
# ## `BaseModel` vs `dataclass`
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# Here is the practical difference:
#
# | Feature | `dataclass` | `BaseModel` |
# | --- | --- | --- |
# | Stores named fields | yes | yes |
# | Runtime validation | no | yes |
# | Automatic type conversion | no | yes |
# | Helpful API error messages | no | yes |
# | Natural fit for FastAPI request/response models | sometimes | yes |
#
# Use a `dataclass` when:
# - data is already trusted,
# - you want a lightweight in-memory structure,
# - you do not need API-style validation.
#
# Use `BaseModel` when:
# - data comes from users, browsers, mobile apps, or external services,
# - bad input should be rejected clearly,
# - FastAPI needs to generate documentation from the model.

# %% [markdown]
# ## Deep Dive with Code Examples
#
# **Serialization** means turning your model into something easy to send over the network. In Pydantic v2, the most common tools are:
#
# - `model_dump()` → returns a Python dictionary,
# - `model_dump_json()` → returns a JSON string.
#
# Why does this matter? Because the shape of your output is part of your API contract. Clients rely on it.

# %%
from datetime import datetime

from pydantic import BaseModel


class OrderSummary(BaseModel):
    order_id: int
    total: float
    coupon_code: str | None = None
    created_at: datetime


summary = OrderSummary(
    order_id=501,
    total=149.99,
    coupon_code=None,
    created_at="2025-03-01T10:15:00",
)

print(summary.model_dump())
print(summary.model_dump(exclude_none=True))
print(summary.model_dump(mode="json"))
print(summary.model_dump_json(indent=2))

# %% [markdown]
# `exclude_none=True` is especially useful when you do not want fields with `None` values to appear in responses. That keeps output cleaner.
#
# ## Deep Dive with Code Examples
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# Sometimes your Python code and your API should use different names. Maybe Python prefers `product_id`, but your frontend expects `productId`. That is where an **alias** helps.
#
# The `include` and `exclude` options act like a camera crop tool. They let you decide exactly which part of the model should be visible.

# %%
from pydantic import BaseModel, ConfigDict, Field


class ProductResponse(BaseModel):
    model_config = ConfigDict(populate_by_name=True)

    product_id: int = Field(alias="productId")
    name: str
    price: float
    internal_notes: str | None = None
    stock_count: int


product = ProductResponse(
    product_id=101,
    name="Mechanical Keyboard",
    price=89.99,
    internal_notes="Discount approved for launch week",
    stock_count=12,
)

print(product.model_dump())
print(product.model_dump(by_alias=True))
print(product.model_dump(exclude={"internal_notes"}))
print(product.model_dump(include={"name", "price"}))

# %% [markdown]
# ## Serialization vs validation
#
# This comparison helps beginners a lot:
#
# - **Validation** is about checking incoming data.
# - **Serialization** is about shaping outgoing data.
#
# Validation answers: “Can this data enter the system?”
#
# Serialization answers: “How should this data leave the system?”
#
# You often use both in the same request-response cycle. A client sends a JSON body, FastAPI validates it with Pydantic, your app does some work, and then Pydantic serializes the response model back out.

# %%
from pydantic import BaseModel, EmailStr, SecretStr


class UserRecord(BaseModel):
    username: str
    email: EmailStr
    password_hash: SecretStr
    is_admin: bool = False


user = UserRecord(
    username="ava",
    email="ava@example.com",
    password_hash="hashed-password-123",
    is_admin=False,
)

print("Validated model:", user)
print("Safe public output:", user.model_dump(exclude={"password_hash"}))

# %% [markdown]
# ## Forms and files overview
#
# So far, most examples used JSON. But browsers often send **form data** instead. A form is the format created when a user fills out inputs on a web page and clicks submit.
#
# File uploads are often sent together with form data using **`multipart/form-data`**, which is a request format that can carry both text fields and files in one package.
#
# Use JSON when:
# - your client is mostly sending structured data,
# - no file is included,
# - the request is API-first.
#
# Use form/file handling when:
# - the request comes from a traditional web form,
# - users upload images, PDFs, or other files,
# - text fields and files need to travel together.

# %%
from typing import Annotated

from fastapi import FastAPI, File, Form, UploadFile
from pydantic import BaseModel

app = FastAPI()


class RegistrationResult(BaseModel):
    username: str
    bio: str | None = None
    avatar_filename: str | None = None


@app.post("/register", response_model=RegistrationResult)
async def register_user(
    username: Annotated[str, Form()],
    password: Annotated[str, Form()],
    bio: Annotated[str | None, Form()] = None,
    avatar: UploadFile | None = File(default=None),
):
    return RegistrationResult(
        username=username,
        bio=bio,
        avatar_filename=avatar.filename if avatar else None,
    )

# %% [markdown]
# A few beginner notes:
#
# - `Form()` tells FastAPI to read a value from form data instead of JSON.
# - `UploadFile` represents an uploaded file in a memory-friendly way.
# - If a request includes files, the body is usually not plain JSON anymore.
#
# ## Deep Dive with Code Examples
#
# Hard-coding configuration is risky. A **configuration value** is a setting that can change between environments, such as development, testing, and production.
#
# Examples:
# - database URL,
# - API key,
# - debug mode,
# - application name.
#
# `pydantic-settings` lets you define configuration as a Pydantic model so your app gets the same benefits you already know: types, defaults, validation, and clarity.

# %%
import os

from pydantic_settings import BaseSettings, SettingsConfigDict

os.environ["BOOKSTORE_APP_NAME"] = "Beginner Bookstore"
os.environ["BOOKSTORE_DEBUG"] = "true"
os.environ["BOOKSTORE_DATABASE_URL"] = "sqlite:///./bookstore.db"


class Settings(BaseSettings):
    model_config = SettingsConfigDict(env_prefix="BOOKSTORE_", extra="ignore")

    app_name: str = "My FastAPI App"
    debug: bool = False
    database_url: str


settings = Settings()
print(settings.model_dump())
print(type(settings.debug))

# %% [markdown]
# That example shows something very useful: environment variables are strings by nature, but `pydantic-settings` can convert them to the right types. Here, `"true"` becomes `True`.
#
# In real projects, this keeps your code cleaner and safer. It also makes deployment easier because the same code can run in different environments with different settings.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# 1. Change `age="20"` to `age="twenty"` in the `BaseModel` example. How is the error different from the dataclass behavior?
# 2. Remove `exclude={"internal_notes"}` and ask yourself: would exposing that field be safe in a real API?
# 3. Add `exclude_none=True` to more serialization calls. Which outputs become cleaner?
# 4. Rename `productId` back to `product_id` with `by_alias=False`. Which output would your frontend prefer?
# 5. Delete `BOOKSTORE_DATABASE_URL` from the environment variables. What error should the settings model raise?
#
# These experiments help you feel the difference between “data exists” and “data is ready for production use.”

# %% [markdown]
# ## Real-World Project Link
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# Imagine a small social app:
#
# - A user updates their profile with form fields and an avatar image.
# - The API returns public profile data but excludes internal moderation notes.
# - The application reads `DATABASE_URL`, `REDIS_URL`, and `SECRET_KEY` from environment variables.
# - An admin dashboard wants camelCase field names, so aliases shape the API output.
#
# This chapter's tools make that workflow practical. Validation protects inputs, serialization shapes outputs, forms/files support the browser, and settings keep configuration out of source code.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
#
# - `dataclass` is lightweight; `BaseModel` validates data.
# - `model_dump()` creates dictionaries; `model_dump_json()` creates JSON strings.
# - `include`, `exclude`, and aliases give you precise control over output.
# - Forms and files use a different request style than plain JSON.
# - `pydantic-settings` turns environment variables into validated config objects.
#
# ### Cheat sheet
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```python
# from pydantic import BaseModel, Field, ConfigDict
# from pydantic_settings import BaseSettings, SettingsConfigDict
#
# class ItemOut(BaseModel):
#     model_config = ConfigDict(populate_by_name=True)
#     item_id: int = Field(alias="itemId")
#     name: str
#
# data = ItemOut(item_id=1, name="Pen")
# data.model_dump(by_alias=True)
# data.model_dump(exclude_none=True)
#
# class Settings(BaseSettings):
#     model_config = SettingsConfigDict(env_prefix="APP_")
#     debug: bool = False
# ```
# ### When to use what
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - Use **`BaseModel`** for API-facing data.
# - Use **`dataclass`** for trusted internal data containers.
# - Use **aliases** when external naming should differ from Python naming.
# - Use **include/exclude** when some fields should stay private.
# - Use **forms/files** for browser submissions and uploads.
# - Use **settings models** for environment-based configuration.

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. Build a `PublicUser` model that hides a `password_hash` field during serialization.
# 2. Compare a `Task` dataclass and a `TaskModel` Pydantic model using messy input.
# 3. Create a `ProductOut` model that serializes `product_id` as `productId`.
# 4. Write a FastAPI endpoint that accepts `title`, `description`, and an uploaded PDF file.
# 5. Create a settings model with `app_name`, `debug`, `database_url`, and `secret_key`.
#
# If you can explain *why* each of those tools is appropriate, not just *how* to write them, you are moving from syntax memorization into real design thinking.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='4. deep_dive_into_pydantic_models.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../3. core_fastapi_concepts/6. dependency_injection_system.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
