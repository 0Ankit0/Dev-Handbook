# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='6.%20dependency_injection_system.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='8.%20response_handling.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 7: Request Handling and Context
#
# FastAPI is famous for turning request data into friendly Python parameters. That is the default path, and usually the best path. But sometimes you need the raw request itself: headers, cookies, client info, uploaded files, or the exact incoming body.
#
# Think of typed parameters as ordering a meal from a menu: clear, structured, and easy. The `Request` object is more like entering the kitchen: powerful, but you should only go there when you really need that extra control.

# %% [markdown]
# ## The Big Picture
#
# An HTTP request carries much more than JSON data.
#
# It can contain:
#
# - path values like `/users/42`,
# - query parameters like `?page=2`,
# - headers like `User-Agent` or `Authorization`,
# - cookies like `session_id`,
# - forms submitted by browsers,
# - uploaded files,
# - low-level metadata like the client IP or full URL.
#
# FastAPI gives you two broad ways to work with that data:
#
# 1. **typed parameters** such as `Header`, `Cookie`, `Form`, and `File`,
# 2. the raw **`Request` object** when you need details beyond the usual typed interface.

# %% [markdown]
# ## Core Concepts
#
# ### `Request`
# `Request` is the full incoming HTTP request. It gives access to the URL, headers, cookies, body, and request metadata.
#
# ### Headers and cookies
# These are small pieces of request information often used for auth, personalization, caching, or tracing.
#
# ### Forms and files
# Browser forms often send `multipart/form-data`, especially when a user uploads a file.
#
# ### Typed access first
# FastAPI can read headers, cookies, forms, and files directly into function parameters. This is beginner-friendly, validated, and documented automatically.
#
# ### Direct request access when needed
# Use `Request` when you need something more flexible, like the raw body, the full URL, client host info, or middleware-style logic.

# %% [markdown]
# ## Syntax & First Usage
#
# Start with the simplest idea: add `request: Request` to a route, and FastAPI gives you the current request object.
#
# Use this when you truly need the full request context. If you only need one header or one cookie, typed parameters are usually cleaner.

# %%
from fastapi import FastAPI, Request

app = FastAPI()


@app.get("/request-info")
async def request_info(request: Request):
    return {
        "method": request.method,
        "path": request.url.path,
        "full_url": str(request.url),
        "user_agent": request.headers.get("user-agent"),
        "cookies": request.cookies,
    }

# %% [markdown]
# ## Deep Dive with Code Examples
#
# We will start with typed access because that is the most readable option for beginners. Then we will look at raw request access, form handling, and file uploads.

# %%
from typing import Annotated

from fastapi import Cookie, FastAPI, Header

app = FastAPI()


@app.get("/dashboard")
def dashboard(
    user_agent: Annotated[str | None, Header()] = None,
    theme: Annotated[str | None, Cookie()] = None,
):
    return {
        "message": "Dashboard loaded",
        "user_agent": user_agent,
        "theme": theme or "light",
    }

# %%
from fastapi import FastAPI, Request

app = FastAPI()


@app.post("/webhook")
async def receive_webhook(request: Request):
    raw_body = await request.body()
    signature = request.headers.get("x-signature")

    return {
        "received_bytes": len(raw_body),
        "signature_present": signature is not None,
        "client_host": request.client.host if request.client else None,
    }

# %%
from typing import Annotated

from fastapi import FastAPI, File, Form, UploadFile

app = FastAPI()


@app.post("/profiles")
async def create_profile(
    username: Annotated[str, Form()],
    bio: Annotated[str, Form()],
    avatar: Annotated[UploadFile | None, File()] = None,
):
    avatar_summary = None
    if avatar is not None:
        avatar_summary = {
            "filename": avatar.filename,
            "content_type": avatar.content_type,
        }
    return {
        "username": username,
        "bio": bio,
        "avatar": avatar_summary,
    }

# %% [markdown]
# ### Notes for browser forms and uploads
#
# - `Form(...)` is for regular browser form fields.
# - `File(...)` / `UploadFile` is for uploaded files.
# - These routes normally require the `python-multipart` package in your environment.
# - `UploadFile` is usually better than plain `bytes` for large uploads because it is designed for file-like access.

# %% [markdown]
# ## Side-by-side decision guide: typed params vs direct `Request`
#
# | Situation | Typed parameters (`Header`, `Cookie`, `Form`, `File`) | Direct `Request` |
# |---|---|---|
# | Need one or two known values | Best choice | Overkill |
# | Automatic docs and validation | Excellent | Limited unless you add it manually |
# | Need raw body bytes | Not ideal | Best choice |
# | Need client IP / full URL / low-level metadata | Limited | Best choice |
# | Beginner readability | Very high | Lower |
# | Best rule | Start here first | Use when the structured tools are not enough |
#
# **Rule of thumb:** ask for the smallest, clearest input shape you can. Only drop down to `Request` when there is a concrete reason.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# ### 1) What if a required header is missing?
# If you declare a required typed header, FastAPI returns a validation error automatically. If you read it manually from `request.headers`, you must decide how to handle the missing value yourself.
#
# ### 2) What if you accept a large upload as `bytes` instead of `UploadFile`?
# The whole file is read into memory at once. That is okay for tiny demos, but risky for larger uploads. `UploadFile` is more scalable.
#
# ### 3) What if you use `Request` for everything?
# Your code becomes more manual, less validated, and less self-documenting. You gain control, but you lose convenience and clarity.

# %% [markdown]
# ## Real-World Project Link
#
# Picture a **customer support portal**:
#
# - the browser sends a session cookie,
# - a custom header carries a trace ID,
# - users submit support forms,
# - screenshots are uploaded as files,
# - a webhook endpoint reads the raw request body to verify a signature.
#
# One FastAPI app can handle all of that cleanly by mixing typed parameters for common cases and `Request` for low-level cases.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
# - Use typed parameters first for headers, cookies, forms, and files.
# - Use `Request` when you need the full HTTP request context.
# - `request.headers`, `request.cookies`, `request.url`, and `request.client` expose low-level details.
# - `Form(...)` handles browser form fields.
# - `UploadFile` is the practical choice for file uploads.
#
# ### Cheat sheet
# ```python
# @app.get("/demo")
# def demo(token: Annotated[str | None, Header()] = None):
#     return {"token": token}
#
# @app.get("/cookie-demo")
# def cookie_demo(theme: Annotated[str | None, Cookie()] = None):
#     return {"theme": theme}
#
# @app.post("/upload")
# async def upload(file: Annotated[UploadFile, File()]):
#     return {"name": file.filename}
#
# @app.post("/raw")
# async def raw(request: Request):
#     body = await request.body()
#     return {"size": len(body)}
# ```

# %% [markdown]
# ## Practice Prompts
#
# 1. Create an endpoint that reads a `User-Agent` header with `Header(...)`.
# 2. Build a route that reads a `session_id` cookie and returns a friendly greeting.
# 3. Add a profile form endpoint with `username`, `bio`, and an optional avatar upload.
# 4. Write a webhook route that uses `Request` to read the raw body and a signature header.
# 5. Explain, in your own words, why typed parameters are usually preferred over `Request`.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='6.%20dependency_injection_system.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='8.%20response_handling.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
