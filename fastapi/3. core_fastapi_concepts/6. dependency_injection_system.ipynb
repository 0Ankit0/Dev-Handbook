# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../2.%20data_validation_and_serialization_with_pydantic/5.%20advanced_data_handling.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='7.%20request_handling_and_context.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 6: Dependency Injection System
#
# Dependency injection sounds like a scary architecture phrase, but the beginner version is simple: **instead of every route building its own tools, FastAPI hands the route the tools it asked for**.
#
# Think of a coffee shop. The cashier should focus on taking orders, not roasting beans, milking cows, and washing cups. In FastAPI, `Depends(...)` lets each route say, "Please hand me a ready-to-use helper." That makes your code smaller, safer, and easier to test.

# %% [markdown]
# ## The Big Picture
#
# Most real APIs keep repeating the same setup work:
#
# - checking the logged-in user,
# - opening a database session,
# - reading shared query parameters,
# - loading tenant settings or feature flags.
#
# If every endpoint repeats that setup manually, your project becomes messy very quickly. Dependency injection solves that by turning shared setup into reusable functions.
#
# The flow is:
#
# 1. your route declares a dependency,
# 2. FastAPI calls that dependency first,
# 3. FastAPI gives the returned value to your route,
# 4. your route focuses on the actual business job.
#
# So the route stops being a giant "do everything" function. It becomes a clean coordinator.

# %% [markdown]
# ## Core Concepts
#
# ### `Depends`
# `Depends(some_function)` tells FastAPI, "Before running this route, call `some_function` and give me the result."
#
# ### Reusable dependencies
# A dependency is usually a normal function that can be shared by many routes. This avoids copy-paste logic.
#
# ### Dependency trees
# A dependency can itself depend on another dependency. That creates a tree. For example:
#
# - route depends on `get_current_user`
# - `get_current_user` depends on `get_token`
# - `get_token` depends on a header value
#
# FastAPI walks that tree for you.
#
# ### `yield` dependencies
# Some helpers need setup **and** cleanup, like opening and closing a database session. A `yield` dependency is like borrowing a library book: FastAPI gives it to the route for a moment, then makes sure it is returned.
#
# ### Overrides for testing
# In tests, you often want a fake database or fake user. FastAPI lets you override a dependency so your tests stay fast and predictable.

# %% [markdown]
# ## Syntax & First Usage
#
# The smallest useful pattern looks like this:
#
# 1. write a helper function,
# 2. return a value from that helper,
# 3. request that value with `Depends(...)`.
#
# Notice the mindset change: your route does **not** call the helper directly. FastAPI does it for you.

# %%
from typing import Annotated

from fastapi import Depends, FastAPI

app = FastAPI()


def get_message() -> str:
    return "Hello from a dependency"


@app.get("/welcome")
def welcome(message: Annotated[str, Depends(get_message)]):
    return {"message": message}

# %% [markdown]
# ## Deep Dive with Code Examples
#
# We will build up the idea step by step.
#
# - **Step 1:** share simple logic.
# - **Step 2:** let one dependency call another.
# - **Step 3:** handle setup and cleanup with `yield`.
# - **Step 4:** swap dependencies during tests.
#
# Read the examples like a story. Each one adds one new idea, not five new ideas at once.

# %%
from typing import Annotated

from fastapi import Depends, FastAPI, Query

app = FastAPI()


def common_pagination(
    page: int = Query(default=1, ge=1),
    page_size: int = Query(default=10, ge=1, le=100),
) -> dict:
    skip = (page - 1) * page_size
    return {"page": page, "page_size": page_size, "skip": skip}


@app.get("/products")
def list_products(paging: Annotated[dict, Depends(common_pagination)]):
    sample_products = ["keyboard", "mouse", "monitor", "laptop"]
    start = paging["skip"]
    end = start + paging["page_size"]
    return {
        "paging": paging,
        "items": sample_products[start:end],
    }


@app.get("/orders")
def list_orders(paging: Annotated[dict, Depends(common_pagination)]):
    sample_orders = [101, 102, 103, 104]
    start = paging["skip"]
    end = start + paging["page_size"]
    return {
        "paging": paging,
        "orders": sample_orders[start:end],
    }

# %% [markdown]
# ### Dependency trees
#
# In a real app, one helper usually needs another helper.
#
# Think of an airport:
#
# - the gate agent needs the boarding pass,
# - the boarding pass depends on a valid booking,
# - the booking depends on the passenger ID.
#
# Your route only asks for the final result, but FastAPI handles the whole chain.

# %%
from typing import Annotated

from fastapi import Depends, FastAPI, Header, HTTPException

app = FastAPI()

fake_tokens = {
    "token-alice": {"id": 1, "name": "Alice", "role": "admin"},
    "token-bob": {"id": 2, "name": "Bob", "role": "reader"},
}


def get_token(authorization: Annotated[str | None, Header()] = None) -> str:
    if not authorization:
        raise HTTPException(status_code=401, detail="Missing Authorization header")
    if not authorization.startswith("Bearer "):
        raise HTTPException(status_code=401, detail="Use the Bearer token format")
    return authorization.removeprefix("Bearer ")


def get_current_user(token: Annotated[str, Depends(get_token)]) -> dict:
    user = fake_tokens.get(token)
    if not user:
        raise HTTPException(status_code=401, detail="Unknown token")
    return user


def require_admin(user: Annotated[dict, Depends(get_current_user)]) -> dict:
    if user["role"] != "admin":
        raise HTTPException(status_code=403, detail="Admins only")
    return user


@app.get("/me")
def read_me(user: Annotated[dict, Depends(get_current_user)]):
    return {"hello": user["name"]}


@app.delete("/admin/reports")
def delete_report(user: Annotated[dict, Depends(require_admin)]):
    return {"message": f"Report deleted by {user['name']}"}

# %% [markdown]
# ### `yield` dependencies
#
# Use `yield` when a dependency must clean up after itself.
#
# Common examples:
#
# - open a database session, then close it,
# - open a file, then close it,
# - start a timer, then log how long the request took.
#
# The code before `yield` is the setup. The code after `yield` is the cleanup.

# %%
from typing import Annotated

from fastapi import Depends, FastAPI

app = FastAPI()


class FakeSession:
    def __init__(self) -> None:
        self.connected = True

    def close(self) -> None:
        self.connected = False


def get_db():
    session = FakeSession()
    print("opening session")
    try:
        yield session
    finally:
        session.close()
        print("closing session")


@app.get("/health/db")
def db_health(db: Annotated[FakeSession, Depends(get_db)]):
    return {"connected": db.connected}

# %% [markdown]
# ### Overrides in testing
#
# The testing superpower of dependencies is this: **you can replace the real helper with a fake one**.
#
# That means your test does not need a real database, a real email service, or a real auth provider.
#
# Instead of testing the whole universe, you test the route behavior.

# %%
from typing import Annotated

from fastapi import Depends, FastAPI
from fastapi.testclient import TestClient

app = FastAPI()


def get_settings() -> dict:
    return {"mode": "production", "feature_x": False}


@app.get("/settings")
def read_settings(settings: Annotated[dict, Depends(get_settings)]):
    return settings


client = TestClient(app)


def fake_settings() -> dict:
    return {"mode": "test", "feature_x": True}


app.dependency_overrides[get_settings] = fake_settings

response = client.get("/settings")
assert response.status_code == 200
assert response.json() == {"mode": "test", "feature_x": True}

app.dependency_overrides.clear()

# %% [markdown]
# ## Side-by-side decision guide: manual helper call vs `Depends`
#
# | Question | Manual helper call inside route | `Depends(...)` |
# |---|---|---|
# | Who runs the helper? | You run it manually | FastAPI runs it automatically |
# | Validation of headers/query params | You wire it up yourself | FastAPI injects and validates inputs |
# | Reuse across routes | Easy to forget or copy-paste | Built for reuse |
# | Dependency trees | You connect each step manually | FastAPI resolves the chain |
# | Testing overrides | Awkward monkey-patching | `app.dependency_overrides` is built-in |
# | Best use | Tiny local helper used once | Shared request-time logic |
#
# **Rule of thumb:** if the logic is part of request processing and should be reused or overridden, make it a dependency.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# ### 1) What if two route parameters use the same dependency?
# FastAPI caches dependency results **per request** by default. If the same dependency is needed multiple times in one request, FastAPI normally reuses the result instead of calling it again.
#
# ### 2) What if a dependency raises `HTTPException`?
# The route stops immediately and FastAPI sends that error response. This is why dependencies are a great place for authentication and permission checks.
#
# ### 3) What if you forget cleanup in a database dependency?
# Small demos may look fine, but real apps can leak connections. `yield` dependencies exist exactly to prevent this kind of silent resource problem.

# %% [markdown]
# ## Real-World Project Link
#
# Imagine a **course platform API**:
#
# - `get_db()` opens a database session,
# - `get_current_user()` reads the logged-in student,
# - `require_instructor()` blocks students from editing lessons,
# - tests override `get_db()` with an in-memory fake.
#
# That one dependency system supports authentication, permissions, tenant settings, and clean testing without stuffing every route with repetitive setup code.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
# - A dependency is a helper FastAPI runs for you during a request.
# - `Depends(...)` is the switch that asks FastAPI for that helper.
# - Dependencies can be reused across many routes.
# - Dependencies can depend on other dependencies, forming a tree.
# - Use `yield` when setup must be followed by cleanup.
# - Use `app.dependency_overrides` to swap real helpers for fake ones in tests.
#
# ### Cheat sheet
# ```python
# # basic
# def get_value():
#     return 123
#
# @app.get("/")
# def home(value: Annotated[int, Depends(get_value)]):
#     return {"value": value}
#
# # setup + cleanup
# def get_db():
#     db = Session()
#     try:
#         yield db
#     finally:
#         db.close()
#
# # test override
# app.dependency_overrides[get_db] = fake_db
# ```

# %% [markdown]
# ## Practice Prompts
#
# 1. Create a `get_language()` dependency that reads a `lang` query parameter and reuse it in two routes.
# 2. Build a dependency tree with `get_token() -> get_current_user() -> require_admin()`.
# 3. Convert a fake `get_db()` dependency from `return` to `yield` and explain why that matters.
# 4. Write a test that overrides `get_current_user()` so an endpoint behaves as if an admin is logged in.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../2.%20data_validation_and_serialization_with_pydantic/5.%20advanced_data_handling.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='7.%20request_handling_and_context.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
