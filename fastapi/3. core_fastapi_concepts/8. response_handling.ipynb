# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='7.%20request_handling_and_context.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../4.%20structuring_large_applications/9.%20project_architecture.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 8: Response Handling
#
# A request is only half of the conversation. Your API also needs to answer clearly. That answer is the response.
#
# Think of a restaurant again: the customer places an order, but the experience is judged by what comes back out of the kitchen. In FastAPI, response handling is about sending the **right content**, with the **right status code**, in the **right format**.

# %% [markdown]
# ## The Big Picture
#
# A response tells the client three big things:
#
# 1. **Did the request succeed or fail?** → status code
# 2. **What data is being returned?** → JSON, HTML, text, file, or stream
# 3. **How should the client handle it?** → headers and media type
#
# Many beginner APIs only return plain dictionaries, and that is fine at first. But real projects often need more control:
#
# - `201 Created` when a new record is made,
# - a file download for reports,
# - a stream for large exports,
# - HTML for a simple landing page,
# - custom text or CSV responses for integrations.

# %% [markdown]
# ## Core Concepts
#
# ### Status codes
# Status codes are short signals for the client. They help browsers, mobile apps, and other services react correctly.
#
# ### `JSONResponse`
# Use it when you want to return JSON with explicit control over status code or headers.
#
# ### `ORJSONResponse`
# This is a faster JSON response class for high-performance cases. It is useful when your app returns lots of JSON and the `orjson` package is installed.
#
# ### `StreamingResponse`
# Sends data gradually instead of building the entire response in memory first.
#
# ### `FileResponse`
# Sends a file from disk with sensible headers.
#
# ### HTML, text, and custom responses
#
# Not every client wants JSON. Sometimes a browser needs HTML, a health tool needs plain text, or a legacy integration needs CSV/XML.

# %% [markdown]
# ## Syntax & First Usage
#
# FastAPI gives you multiple ways to control responses:
#
# - set `status_code=` on the route decorator,
# - use the `Response` object to change status codes or headers,
# - return a specific response class when you need precise control.
#
# > ❓ **What is a decorator?** A decorator is a function that wraps another function to add behaviour before or after it runs. `@app.route('/')` is shorthand for `index = app.route('/')(index)` — it registers your view function with Flask's URL map without any explicit call.

# %%
from fastapi import FastAPI, Response, status

app = FastAPI()


@app.post("/tasks", status_code=status.HTTP_201_CREATED)
def create_task():
    return {"message": "Task created"}


@app.delete("/tasks/{task_id}")
def delete_task(task_id: int, response: Response):
    response.status_code = status.HTTP_204_NO_CONTENT
    return None

# %% [markdown]
# ## Deep Dive with Code Examples
#
# We will start with JSON responses, then move to performance-minded JSON, then streaming and files, and finally non-JSON responses.

# %%
from fastapi import FastAPI
from fastapi.responses import JSONResponse

try:
    from fastapi.responses import ORJSONResponse
except ImportError:  # ORJSONResponse may require the orjson package
    ORJSONResponse = None

app = FastAPI()


@app.get("/reports/default")
def default_json():
    return {"report": "sales", "rows": 3}


@app.get("/reports/explicit")
def explicit_json():
    return JSONResponse(
        status_code=202,
        content={"message": "Report queued"},
        headers={"X-Job-ID": "job-123"},
    )


@app.get("/reports/fast")
def fast_json():
    payload = {"items": [{"id": 1, "name": "Keyboard"}]}
    if ORJSONResponse is None:
        return JSONResponse(content=payload)
    return ORJSONResponse(content=payload)

# %%
from pathlib import Path

from fastapi import FastAPI
from fastapi.responses import FileResponse, StreamingResponse

app = FastAPI()


def generate_lines():
    for number in range(1, 6):
        yield f"line {number}\n"


@app.get("/logs/live")
def stream_logs():
    return StreamingResponse(generate_lines(), media_type="text/plain")


@app.get("/downloads/guide")
def download_guide():
    file_path = Path("downloads/quickstart.txt")
    return FileResponse(file_path, filename="quickstart.txt", media_type="text/plain")

# %%
from fastapi import FastAPI, Response
from fastapi.responses import HTMLResponse, PlainTextResponse

app = FastAPI()


class CSVResponse(Response):
    media_type = "text/csv"


@app.get("/hello-page", response_class=HTMLResponse)
def hello_page():
    return (
        "<html>"
        "<body>"
        "<h1>Hello!</h1>"
        "<p>This response is HTML, not JSON.</p>"
        "</body>"
        "</html>"
    )


@app.get("/health-text", response_class=PlainTextResponse)
def health_text():
    return "ok"


@app.get("/export.csv", response_class=CSVResponse)
def export_csv():
    return "name,score\nAlice,95\nBob,88\n"

# %% [markdown]
# ## Side-by-side decision guide: which response should you choose?
#
# | Need | Good choice | Why |
# |---|---|---|
# | Normal API data | plain `dict` or `JSONResponse` | Simple and standard |
# | JSON with custom status or headers | `JSONResponse` | Explicit control |
# | Faster JSON serialization | `ORJSONResponse` | Performance-focused |
# | Large generated output | `StreamingResponse` | Avoids building everything in memory |
# | Send a file from disk | `FileResponse` | Convenient download behavior |
# | Browser page | `HTMLResponse` | Correct content type |
# | Small plain message | `PlainTextResponse` | Clear text output |
# | Legacy/custom format | custom `Response` subclass | Full control over media type |

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# ### 1) What if you return a body with status code `204 No Content`?
#
# That is confusing because `204` means there should be no response body. Prefer returning `None` and letting the status code speak for itself.
# ### 2) What if a JSON export becomes very large?
# Building one giant response may use a lot of memory. A `StreamingResponse` can send chunks gradually instead.
#
# ### 3) What if you always use `JSONResponse`, even for files or HTML?
# Clients get the wrong content type and may behave incorrectly. Match the response class to the real content being sent.

# %% [markdown]
# ## Real-World Project Link
#
# Think about an **analytics dashboard API**:
#
# - `201 Created` when a report job is created,
# - `JSONResponse` for job metadata,
# - `ORJSONResponse` for heavy JSON endpoints,
# - `StreamingResponse` for live log output,
# - `FileResponse` for downloading finished reports,
# - `HTMLResponse` for a tiny internal status page,
# - `CSVResponse` for spreadsheet imports.
#
# Response handling is where the API starts to feel professional to the client using it.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
# - Status codes explain the outcome of a request.
# - Use `JSONResponse` when you need explicit JSON control.
# - Use `ORJSONResponse` when fast JSON serialization matters.
# - Use `StreamingResponse` for generated or large output.
# - Use `FileResponse` for files on disk.
# - Use HTML, text, or custom response classes when JSON is not the right format.
#
# ### Cheat sheet
#
# ```python
# @app.post("/items", status_code=201)
# def create_item():
#     return {"ok": True}
#
# return JSONResponse(status_code=202, content={"queued": True})
# return StreamingResponse(generator(), media_type="text/plain")
# return FileResponse("report.pdf")
# return PlainTextResponse("ok")
# ```

# %% [markdown]
# ## Practice Prompts
#
# 1. Build a `POST /items` endpoint that returns `201 Created`.
# 2. Return a `JSONResponse` with a custom `X-Request-ID` header.
# 3. Create a `StreamingResponse` that yields five lines of text.
# 4. Add a `FileResponse` endpoint for a sample text file.
# 5. Create a tiny `CSVResponse` subclass and return two rows of CSV data.
# 6. Explain when you would choose `PlainTextResponse` over JSON.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='7. request_handling_and_context.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../4. structuring_large_applications/9. project_architecture.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
