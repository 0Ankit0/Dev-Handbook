# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../9.%20production_deployment/21.%20performance_tuning.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='23.%20graphql.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 22: Error Handling
#
# Errors are part of normal API life. A missing record, bad input, expired token, or broken database connection should not make your app feel mysterious. This chapter introduces beginner-friendly patterns for returning clear errors, shaping them consistently, and logging enough information to debug problems later.

# %% [markdown]
# ## The Big Picture
#
# When an API works, clients get useful data. When an API fails, clients still need a useful answer.
#
# A good error-handling strategy solves four beginner-sized problems:
#
# 1. **Tell the client what went wrong** using the right HTTP status code.
# 2. **Keep responses predictable** so frontend or mobile code knows where to look for error details.
# 3. **Hide internal secrets** so tracebacks and database details do not leak to users.
# 4. **Record enough context in logs** so developers can investigate later.
#
# FastAPI helps with all four. It gives you `HTTPException` for common API errors, exception handlers for global formatting, and easy access to Python's built-in `logging` module.

# %% [markdown]
# ## Core Concepts
#
# - **Happy path**: the normal successful flow.
# - **HTTP status code**: the numeric signal that describes the result, such as `200`, `404`, or `422`.
# - **`HTTPException`**: FastAPI's built-in way to stop execution and return an HTTP error response.
# - **Exception handler**: a function that catches an exception type and turns it into a response.
# - **Error shape**: the structure of your JSON error body. Example: `{"error": {"code": "item_not_found", "message": "..."}}`.
# - **Validation error**: an error raised before your endpoint logic finishes because incoming data does not match the expected schema.
# - **Log entry**: a recorded message that helps you understand what happened inside the app.
# - **Request context**: useful request details such as path, method, and a request ID.
#
# The key idea is simple: **clients need friendly error responses, while developers need detailed logs**. Those are related, but they are not the same job.

# %% [markdown]
# ## Syntax & First Usage
#
# The first problem to solve is: **how do I stop an endpoint and return the right HTTP error?**
#
# Use `HTTPException` when the request is valid HTTP, but the requested action cannot succeed. For example:
#
# - the item does not exist → `404 Not Found`
# - the user is not allowed → `403 Forbidden`
# - the input is semantically wrong → `400 Bad Request`
#
# FastAPI catches `HTTPException` automatically and returns JSON. That means you do not need to build the full error response by hand every time.

# %%
from fastapi import FastAPI, HTTPException

app = FastAPI(title='Error Handling Demo')

ITEMS = {
    '1': {'id': '1', 'name': 'Keyboard'},
    '2': {'id': '2', 'name': 'Mouse'},
}

@app.get('/items/{item_id}')
def read_item(item_id: str):
    item = ITEMS.get(item_id)
    if item is None:
        raise HTTPException(status_code=404, detail='Item not found')
    return item

# %% [markdown]
# ## Deep Dive with Code Examples
#
# `HTTPException` is great for quick, local errors. But bigger apps often want every error response to look similar.
#
# Why? Because clients become easier to write when they can always expect the same JSON structure. For example, a frontend can always read:
#
# - `error.code`
# - `error.message`
# - `error.path`
#
# A custom exception handler lets you convert different failures into one consistent shape.

# %%
import logging
from fastapi import Request
from fastapi.responses import JSONResponse

logger = logging.getLogger('app.errors')

class ItemOutOfStockError(Exception):
    def __init__(self, item_id: str):
        self.item_id = item_id

def error_payload(code: str, message: str, path: str):
    return {
        'error': {
            'code': code,
            'message': message,
            'path': path,
        }
    }

@app.exception_handler(ItemOutOfStockError)
async def item_out_of_stock_handler(request: Request, exc: ItemOutOfStockError):
    logger.warning('Item out of stock', extra={'item_id': exc.item_id, 'path': request.url.path})
    return JSONResponse(
        status_code=409,
        content=error_payload(
            code='item_out_of_stock',
            message=f'Item {exc.item_id} is currently out of stock.',
            path=request.url.path,
        ),
    )

@app.post('/checkout/{item_id}')
def checkout_item(item_id: str):
    if item_id == '2':
        raise ItemOutOfStockError(item_id)
    return {'message': 'Checkout started'}

# %% [markdown]
# ## Logging basics: what to log and what not to expose
#
# Logging solves a different problem from error responses. The client needs a safe message. The developer needs clues.
#
# Beginner-friendly logging rules:
#
# - Log **what happened**: `item_not_found`, `permission_denied`, `database_timeout`.
# - Log **where it happened**: request path, method, route name, or request ID.
# - Log **enough identifiers** to investigate, such as `item_id` or `user_id`.
# - Do **not** send raw stack traces, SQL queries, or secrets back to the client.
# - Use `logger.exception(...)` when you want the traceback in logs for unexpected failures.
#
# A healthy pattern is:
#
# - predictable errors → clear client message + warning/info log
# - unexpected errors → generic client message + detailed error log

# %%
@app.middleware('http')
async def log_requests(request: Request, call_next):
    logger.info('Request started', extra={'method': request.method, 'path': request.url.path})
    response = await call_next(request)
    logger.info('Request finished', extra={'status_code': response.status_code, 'path': request.url.path})
    return response

# %% [markdown]
# ## `HTTPException` vs returning an error dictionary with status `200`
#
# | Approach | What happens | Why it matters |
# | --- | --- | --- |
# | `raise HTTPException(status_code=404, detail='Item not found')` | The HTTP status is truly `404` | Clients, browsers, caches, and monitoring tools understand the failure correctly |
# | `return {'error': 'Item not found'}` with a default success response | The HTTP status is still `200 OK` unless you change it | Clients may think the request succeeded even though the body contains an error message |
#
# In short: **use HTTP semantics honestly**. Error text inside a success status is confusing.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# 1. Change the missing-item case from `404` to `400`. Which status feels more accurate, and why?
# 2. Add a `request_id` field to `error_payload`. How would that help when reading logs?
# 3. Create a handler for `HTTPException` itself so even built-in FastAPI errors follow your custom shape.
# 4. Imagine a database error occurs. What message should the client see, and what extra details should only appear in logs?
# 5. Add a timestamp to your error response. Would that help clients, developers, or both?

# %% [markdown]
# ## Real-World Project Link
#
# A helpful production-oriented reference is the **Full Stack FastAPI Template**:
#
# - https://github.com/fastapi/full-stack-fastapi-template
#
# Study how a larger app separates API routes, security, and infrastructure concerns. Even when its exact error format differs from yours, it shows why consistency and operational logging matter in real systems.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
# Error handling is not just about catching failures. It is about sending the right status code, using a predictable JSON shape, and recording enough context for debugging. `HTTPException` handles common API errors, while custom exception handlers help large apps stay consistent.
#
# ### Cheat sheet
# - Use **`HTTPException`** for common client-facing API errors.
# - Prefer honest status codes like **`404`**, **`403`**, **`409`**, and **`422`**.
# - Keep a **consistent error shape** such as `error.code`, `error.message`, and `error.path`.
# - Log useful context like **path**, **method**, **item_id**, or **user_id**.
# - Show clients safe messages; keep sensitive details in logs.
# - Use `logger.warning(...)` for expected problems and `logger.exception(...)` for unexpected crashes.

# %% [markdown]
# ## Practice Prompts
#
# 1. In plain language, what problem does `HTTPException` solve?
# 2. Why is a consistent error shape helpful for frontend code?
# 3. Give one example of information that belongs in logs but not in the client response.
# 4. Write a custom exception class for `PaymentRequiredError` and choose a suitable status code.
# 5. Explain the difference between a validation error and a business-rule error such as "item out of stock."

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../9.%20production_deployment/21.%20performance_tuning.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='23.%20graphql.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
