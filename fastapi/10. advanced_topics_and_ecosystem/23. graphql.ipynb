# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='22.%20error_handling.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='24.%20advanced_patterns.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 23: GraphQL
#
# GraphQL can feel advanced because it introduces new vocabulary, but the beginner idea is friendly: **let the client ask for exactly the data it needs**. In this chapter, we start from that problem, compare GraphQL with REST, and wire a tiny GraphQL endpoint into FastAPI using Strawberry.

# %% [markdown]
# ## The Big Picture
#
# Traditional REST APIs usually expose many endpoints such as `/users`, `/users/{id}`, and `/users/{id}/posts`. That works well, but sometimes a screen needs a custom combination of fields from several resources.
#
# GraphQL tries to solve that by offering:
#
# - a **schema** that describes available data,
# - a **query language** that lets the client choose fields,
# - and often a **single endpoint** such as `/graphql`.
#
# The promise is not "REST is bad." The promise is "for some read-heavy screens, let clients be more precise."

# %% [markdown]
# ## Core Concepts
#
# - **Schema**: the contract that describes what data can be queried.
# - **Type**: a named shape in the schema, such as `Book` or `User`.
# - **Field**: a single property on a type, such as `name` or `email`.
# - **Resolver**: Python code that returns data for a field.
# - **Query**: a read operation in GraphQL.
# - **Mutation**: a write operation such as create, update, or delete.
# - **Single endpoint**: many GraphQL apps use one HTTP endpoint and put the query inside the request body.
# - **Selection set**: the list of fields the client asks for.
#
# If REST feels like ordering from a fixed menu, GraphQL feels like saying, "I want just these parts of the meal."

# %% [markdown]
# ## Syntax & First Usage
#
# Before writing GraphQL syntax, ask the beginner question: **what problem are we solving?**
#
# Suppose a page only needs a user's name and the titles of their posts. A REST API may require multiple endpoints or may return extra fields the page does not need. GraphQL lets the client request only the exact fields it wants.
#
# One simple way to integrate GraphQL into FastAPI is **Strawberry**, a Python GraphQL library with a FastAPI router.
#
# ```bash
# pip install strawberry-graphql[fastapi]
# ```

# %%
import strawberry
from fastapi import FastAPI
from strawberry.fastapi import GraphQLRouter

@strawberry.type
class Book:
    id: int
    title: str
    author: str

BOOKS = [
    Book(id=1, title='FastAPI for Beginners', author='Ava'),
    Book(id=2, title='Async in Plain English', author='Noah'),
]

@strawberry.type
class Query:
    @strawberry.field
    def books(self) -> list[Book]:
        return BOOKS

    @strawberry.field
    def book_by_id(self, id: int) -> Book | None:
        return next((book for book in BOOKS if book.id == id), None)

schema = strawberry.Schema(query=Query)
graphql_app = GraphQLRouter(schema)

app = FastAPI(title='FastAPI + GraphQL Demo')
app.include_router(graphql_app, prefix='/graphql')

# %% [markdown]
# ## Deep Dive with Code Examples
#
# In a REST app, the URL often decides the shape of the response. In GraphQL, the URL is usually stable and the **query body** decides the shape.
#
# For example, a client can send this request body:
#
# ```graphql
# query {
#   books {
#     title
#     author
#   }
# }
# ```
#
# The schema checks whether `books`, `title`, and `author` are valid. Then the resolver runs and returns only those fields.
#
# This feels unusual at first, but the core idea is straightforward: **the schema defines possibilities; the query chooses from them**.

# %%
graphql_query = '''
query {
  bookById(id: 1) {
    title
    author
  }
}
'''

print(graphql_query)

# %% [markdown]
# ## GraphQL vs REST
#
# | Question | GraphQL | REST |
# | --- | --- | --- |
# | How do clients request data? | By sending a query that lists fields | By calling resource-based endpoints |
# | Typical endpoint style | Often one endpoint such as `/graphql` | Many endpoints such as `/users` and `/posts` |
# | Over-fetching risk | Lower, because clients choose fields | Higher if endpoints return more than a screen needs |
# | Simplicity for beginners | More concepts up front | Usually easier to start with |
# | Browser caching and HTTP semantics | Often needs extra care | Very natural with standard HTTP methods and URLs |
#
# A healthy beginner rule is: **use REST by default, consider GraphQL when client data needs become unusually flexible**.

# %% [markdown]
# ## Deep Dive with Code Examples
#
# GraphQL helps when:
#
# - many frontends need slightly different slices of the same data,
# - mobile apps care about reducing extra payload,
# - nested related data is common.
#
# GraphQL may be unnecessary when:
#
# - your API is small and stable,
# - simple REST routes are already clear,
# - your team is still learning core HTTP ideas.
#
# That is why GraphQL is best understood as **another tool**, not a mandatory upgrade.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# 1. Add a `published_year` field to `Book`. How would clients choose whether to request it?
# 2. Create a mutation named `addBook`. What input fields would it need?
# 3. Imagine one mobile screen only needs `title`. How is that different from a REST endpoint that always returns the whole book object?
# 4. Suppose the schema exposes a field that is expensive to compute. What should you think about before clients request it freely?
# 5. Try explaining GraphQL to a REST-only teammate in one sentence. What would you say?

# %% [markdown]
# ## Real-World Project Link
#
# A useful reference project is the Strawberry repository itself:
#
# - https://github.com/strawberry-graphql/strawberry
#
# Explore its examples and FastAPI integration docs to see how schemas, resolvers, and GraphQL tooling fit together beyond toy demos.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
# GraphQL lets clients request exactly the fields they need through a schema-driven API. In FastAPI, Strawberry provides a gentle integration path with `GraphQLRouter`. REST is still a strong default, but GraphQL becomes attractive when data fetching is flexible and nested.
#
# ### Cheat sheet
# - **Schema** = the contract of allowed queries and types.
# - **Resolver** = Python code that returns data.
# - **Query** = read data.
# - **Mutation** = change data.
# - **Strawberry** integrates with FastAPI through **`GraphQLRouter`**.
# - GraphQL often uses a single endpoint such as **`/graphql`**.
# - Good question to ask first: **Does the client need flexible field selection?**

# %% [markdown]
# ## Practice Prompts
#
# 1. In plain language, what problem does GraphQL solve?
# 2. What is the difference between a GraphQL schema and a resolver?
# 3. Why might REST still be simpler for a small project?
# 4. Write a GraphQL query that asks for only `title` from all books.
# 5. Describe one real screen in an app that could benefit from flexible field selection.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='22.%20error_handling.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='24.%20advanced_patterns.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
