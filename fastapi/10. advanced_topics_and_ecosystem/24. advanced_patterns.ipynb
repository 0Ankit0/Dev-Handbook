# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='23.%20graphql.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='25.%20access_control_using_casbin.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 24: Advanced Patterns
#
# Some FastAPI features solve problems that do not appear in a first CRUD tutorial. This chapter introduces three useful patterns gently: **Server-Sent Events (SSE)** for one-way live updates, **custom OpenAPI** for controlling generated docs, and **mounted sub-applications** for combining multiple ASGI apps under one parent app.

# %% [markdown]
# ## The Big Picture
#
# Most beginner APIs return one JSON response and then the connection ends. But real apps sometimes need different behavior:
#
# - a dashboard wants live updates without refreshing,
# - a company wants the docs page to show custom branding or security metadata,
# - a team wants to host an admin app or legacy service under the same server.
#
# These are not everyday patterns, but they solve very real problems. The important beginner mindset is to ask **which problem each pattern solves** before copying the syntax.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# - **SSE (Server-Sent Events)**: a one-way stream where the server keeps sending text events to the client over normal HTTP.
# - **Streaming response**: a response sent piece by piece instead of all at once.
# - **OpenAPI schema**: the machine-readable description behind `/docs` and `/openapi.json`.
# - **Custom OpenAPI**: changing that schema to add metadata, tags, contact info, or vendor extensions.
# - **Sub-application**: a separate ASGI app mounted under a path such as `/admin`.
# - **Mounting**: attaching one app inside another.
# - **ASGI app**: any application object that follows the ASGI interface, including FastAPI and Starlette apps.
#
# Think of this chapter as a toolbox for special situations, not a list of mandatory features.
#
# > ❓ **Why not just use the development server in production?** The dev server is single-threaded and has no hardening for public traffic. Gunicorn/Uvicorn spawn multiple worker processes to handle concurrent requests and include timeouts, graceful restarts, and proper error logging.

# %% [markdown]
# ## Syntax & First Usage
#
# The first pattern to learn is SSE because its purpose is easy to visualize: **the server keeps pushing updates down to the browser**.
#
# This is useful for notifications, progress updates, live metrics, and activity feeds when the client only needs to receive data, not send messages back continuously.

# %%
import asyncio
from datetime import datetime
from fastapi import FastAPI
from fastapi.responses import StreamingResponse

app = FastAPI(title='Advanced Patterns Demo')

async def event_stream():
    while True:
        message = f"data: The time is {datetime.utcnow().isoformat()}\n\n"
        yield message
        await asyncio.sleep(1)

@app.get('/events')
async def events():
    return StreamingResponse(event_stream(), media_type='text/event-stream')

# %% [markdown]
# ## Deep Dive with Code Examples
#
# FastAPI automatically builds OpenAPI for you, which is wonderful for beginners. But sometimes a team needs a little more control.
#
# Common reasons to customize OpenAPI:
#
# - add a clearer API description,
# - include contact or license information,
# - attach a company logo or custom extension,
# - group routes more intentionally.
#
# The good news is that you usually **start with the default schema and then modify it**, rather than building everything from scratch.

# %%
from fastapi.openapi.utils import get_openapi

def custom_openapi():
    if app.openapi_schema:
        return app.openapi_schema

    openapi_schema = get_openapi(
        title='Advanced Patterns Demo',
        version='1.0.0',
        description='Demo API showing SSE and mounted applications.',
        routes=app.routes,
    )
    openapi_schema['info']['x-logo'] = {
        'url': 'https://fastapi.tiangolo.com/img/logo-margin/logo-teal.png'
    }
    app.openapi_schema = openapi_schema
    return app.openapi_schema

app.openapi = custom_openapi

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Mounting helps when one path section should behave like its own mini-site. For example:
#
# - `/admin` for internal admin pages,
# - `/legacy` for an older ASGI app,
# - `/static` for static files,
# - `/metrics` for monitoring tools.
#
# The parent app stays in control of the overall server, while the sub-app owns its specific path prefix.

# %%
main_app = FastAPI(title='Main App')
admin_app = FastAPI(title='Admin App')

@main_app.get('/')
def read_home():
    return {'message': 'Public API root'}

@admin_app.get('/dashboard')
def read_dashboard():
    return {'message': 'Admin dashboard'}

main_app.mount('/admin', admin_app)

# %% [markdown]
# ## SSE vs WebSockets
#
# Sections like this become clearer when you separate capabilities from tradeoffs. As you read, ask what each option is optimized for and what complexity you accept in exchange.
#
# | Question | SSE | WebSockets |
# | --- | --- | --- |
# | Direction | Server → client only | Two-way communication |
# | Transport style | Standard HTTP streaming | Persistent socket connection |
# | Good for | Live notifications, progress, feeds | Chat, multiplayer, collaborative editing |
# | Beginner complexity | Usually lower | Higher |
#
# If the browser only needs to **listen**, SSE is often the simpler tool. If both sides need to **talk constantly**, WebSockets are a better fit.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# 1. Change the SSE interval from 1 second to 5 seconds. What user experience changes?
# 2. Add a `tag` field to your custom OpenAPI schema. Where would it appear in `/docs`?
# 3. Imagine you mount an admin app at `/admin`. How does that help keep public routes and internal routes mentally separate?
# 4. When would `APIRouter` be enough, and when would a fully mounted sub-application be better?
# 5. Suppose the client must send live typing updates back to the server. Why would SSE stop being enough?

# %% [markdown]
# ## Real-World Project Link
#
# A practical reference for broader FastAPI architecture is:
#
# - https://github.com/fastapi/full-stack-fastapi-template
#
# Even if it does not use every pattern exactly as shown here, it is a good project for seeing where documentation, app structure, and deployment-friendly organization start to matter.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
# Advanced patterns are useful when your app grows beyond simple request-response JSON. SSE handles one-way live updates, custom OpenAPI helps you shape generated documentation, and mounted sub-applications let one server host multiple ASGI apps cleanly.
#
# ### Cheat sheet
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - **SSE** = one-way live updates over HTTP.
# - Use **`StreamingResponse(..., media_type='text/event-stream')`** for a simple SSE approach.
# - **Custom OpenAPI** starts with `get_openapi(...)` and then tweaks the returned schema.
# - **`app.mount('/prefix', sub_app)`** attaches another ASGI app.
# - Ask first: **Do I need streaming, docs customization, or a separate mini-app?**
# - Do not use advanced patterns just because they sound powerful.

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. In plain language, what problem does SSE solve?
# 2. What is the difference between `APIRouter` and a mounted sub-application?
# 3. Why is it usually better to modify the generated OpenAPI schema than to rebuild it from scratch?
# 4. Give one example where SSE is simpler than WebSockets.
# 5. Design a tiny app that uses all three patterns in a realistic way.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='23.%20graphql.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='25.%20access_control_using_casbin.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
