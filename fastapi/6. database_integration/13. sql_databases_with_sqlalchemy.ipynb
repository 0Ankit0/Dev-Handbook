# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../5.%20security_and_authentication/12.%20oauth2_and_jwt.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='14.%20nosql_and_orms.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 13: SQL Databases with SQLAlchemy
#
# If you are brand new to databases, this chapter is for you. We will start with the plain-English idea of what a database is, then move into SQL, and only then introduce SQLAlchemy and FastAPI patterns.

# %% [markdown]
# ## The Big Picture
#
# A **database** is a place where your program stores information so it can survive after the app stops running.
#
# Without a database, an API only remembers data while the Python process is alive. The moment you restart the server, your users, tasks, orders, or blog posts disappear. A database gives your app long-term memory.
#
# For beginners, it helps to picture a relational database as a set of connected spreadsheets:
#
# - a **table** stores one kind of thing, such as users or products,
# - a **row** is one record,
# - a **column** is one field, such as `name` or `price`.
#
# In this chapter you will learn three layers of thinking:
#
# 1. **SQL basics**: the language databases understand,
# 2. **SQLAlchemy**: a Python toolkit that helps you work with SQL databases,
# 3. **FastAPI integration**: how to give each request a safe database session.
#
# > 💡 **Encouragement:** You do **not** need to memorize database theory before building useful APIs. Start with the mental model, then learn the tools one step at a time.
#
# > ❓ **Why use an ORM instead of raw SQL?** An ORM (Object-Relational Mapper) lets you work with database rows as Python objects, so you write Python instead of SQL strings. It also prevents SQL injection by default and makes switching databases straightforward later.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### What is SQL?
#
# **SQL** stands for **Structured Query Language**. It is the language used to create tables, insert data, read data, update data, and delete data in relational databases such as SQLite, PostgreSQL, and MySQL.
#
# ### Why do relational databases exist?
#
# Relational databases are great when your data has clear structure and relationships:
#
# - one user can have many orders,
# - one blog post can have many comments,
# - one course can belong to one instructor.
#
# They help you keep data consistent with rules such as types, required fields, and foreign keys.
#
# ### Why does an ORM exist?
#
# A useful beginner mental model here is to separate the shape of the data from the operations performed on it. Once you know what is being represented and who depends on that representation, the rules become easier to predict.
#
# An **ORM** (**Object-Relational Mapper**) lets you work with database rows using Python classes and objects. Instead of writing raw SQL for every operation, you can often write Python code like `Task(title='Buy milk')` or `select(User)`.
#
# An ORM does **not** replace database understanding. It simply gives you a nicer bridge between Python code and SQL tables.
# ### Engine, session, and dependency
#
# When people first meet SQLAlchemy, three words matter most:
#
# - **engine**: knows how to connect to the database,
# - **session**: your temporary workspace for database operations,
# - **dependency**: the FastAPI function that creates and cleans up a session for each request.
#
# ### Why async here?
#
# FastAPI supports asynchronous request handling. SQLAlchemy's async tools let your app wait for database work without blocking the whole server. That matters more as your app grows or handles many users at once.

# %% [markdown]
# ## Syntax & First Usage
#
# Before using SQLAlchemy, let's see what a database feels like at the most basic level. SQLite is included with Python, so it is a friendly place to learn the flow: create a table, insert rows, and query them.

# %%
import sqlite3

connection = sqlite3.connect(':memory:')
cursor = connection.cursor()

cursor.execute('''
CREATE TABLE users (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    email TEXT UNIQUE NOT NULL
)
''')

cursor.execute('INSERT INTO users (name, email) VALUES (?, ?)', ('Alice', 'alice@example.com'))
cursor.execute('INSERT INTO users (name, email) VALUES (?, ?)', ('Bob', 'bob@example.com'))
connection.commit()

cursor.execute('SELECT id, name, email FROM users ORDER BY id')
rows = cursor.fetchall()

for row in rows:
    print(row)

connection.close()

# %% [markdown]
# ### Reading that SQL slowly
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - `CREATE TABLE` defines the structure.
# - `INSERT INTO` adds rows.
# - `SELECT` reads rows.
# - `commit()` saves the changes.
#
# That is the heart of database work, even when higher-level libraries help you.
#
# Now let's move from raw SQL to SQLAlchemy's async setup.

# %%
from sqlalchemy.ext.asyncio import AsyncSession, async_sessionmaker, create_async_engine
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column

DATABASE_URL = 'sqlite+aiosqlite:///./app.db'

engine = create_async_engine(DATABASE_URL, echo=True)
SessionLocal = async_sessionmaker(bind=engine, class_=AsyncSession, expire_on_commit=False)

class Base(DeclarativeBase):
    pass

class User(Base):
    __tablename__ = 'users'

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str]
    email: Mapped[str] = mapped_column(unique=True)

# %% [markdown]
# ### What just happened?
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - `create_async_engine(...)` creates the connection layer.
# - `async_sessionmaker(...)` is a factory that can make sessions when requests arrive.
# - `DeclarativeBase` lets us define tables as Python classes.
# - `mapped_column(...)` describes how class fields map to database columns.
#
# You still need real SQL knowledge, but now you can express your schema in Python too.

# %% [markdown]
# ## Deep Dive with Code Examples
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### Session dependency in FastAPI
#
# A session should usually be created per request and then cleaned up automatically. FastAPI's `yield` dependencies are perfect for this pattern.
#
# > ❓ **Why use a generator instead of returning a list?** A generator computes values *on demand* and never holds the whole sequence in memory at once. Processing millions of database rows with a generator uses kilobytes; building a list first could exhaust your RAM.

# %%
from collections.abc import AsyncGenerator

from fastapi import Depends, FastAPI
from sqlalchemy.ext.asyncio import AsyncSession, async_sessionmaker, create_async_engine

app = FastAPI()
engine = create_async_engine('sqlite+aiosqlite:///./app.db')
SessionLocal = async_sessionmaker(engine, expire_on_commit=False)

async def get_session() -> AsyncGenerator[AsyncSession, None]:
    async with SessionLocal() as session:
        yield session

@app.get('/health/db')
async def db_healthcheck(session: AsyncSession = Depends(get_session)):
    return {'message': 'Session dependency was created successfully'}

# %% [markdown]
# ### CRUD with SQLAlchemy sessions
#
# **CRUD** stands for **Create, Read, Update, Delete**. These are the four basic operations almost every API performs.
#
# The pattern is simple:
#
# - build or query an object,
# - add or modify it in the session,
# - commit the session,
# - refresh if you want the newest database state.

# %%
from fastapi import Depends, FastAPI, HTTPException, status
from pydantic import BaseModel
from sqlalchemy import select
from sqlalchemy.ext.asyncio import AsyncSession
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column

app = FastAPI()

class Base(DeclarativeBase):
    pass

class Task(Base):
    __tablename__ = 'tasks'

    id: Mapped[int] = mapped_column(primary_key=True)
    title: Mapped[str]
    done: Mapped[bool] = mapped_column(default=False)

class TaskCreate(BaseModel):
    title: str

@app.post('/tasks', status_code=status.HTTP_201_CREATED)
async def create_task(payload: TaskCreate, session: AsyncSession = Depends(get_session)):
    task = Task(title=payload.title)
    session.add(task)
    await session.commit()
    await session.refresh(task)
    return task

@app.get('/tasks')
async def list_tasks(session: AsyncSession = Depends(get_session)):
    result = await session.execute(select(Task).order_by(Task.id))
    return result.scalars().all()

@app.patch('/tasks/{task_id}')
async def mark_done(task_id: int, session: AsyncSession = Depends(get_session)):
    task = await session.get(Task, task_id)
    if task is None:
        raise HTTPException(status_code=404, detail='Task not found')
    task.done = True
    await session.commit()
    await session.refresh(task)
    return task

@app.delete('/tasks/{task_id}', status_code=status.HTTP_204_NO_CONTENT)
async def delete_task(task_id: int, session: AsyncSession = Depends(get_session)):
    task = await session.get(Task, task_id)
    if task is None:
        raise HTTPException(status_code=404, detail='Task not found')
    await session.delete(task)
    await session.commit()

# %% [markdown]
# ### Relationships
#
# A **relationship** connects tables. This is where relational databases really shine.
#
# Examples:
#
# - one user has many tasks,
# - one author has many posts,
# - one post has many comments.
#
# Usually that connection is stored with a **foreign key** such as `task.owner_id -> users.id`.
#
# In SQLAlchemy, you often define both:
#
# - a foreign-key column, and
# - a Python relationship on each side.

# %%
from sqlalchemy import ForeignKey, select
from sqlalchemy.orm import Mapped, relationship, selectinload

class User(Base):
    __tablename__ = 'users'

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str]
    tasks: Mapped[list['Task']] = relationship(back_populates='owner')

class Task(Base):
    __tablename__ = 'tasks'

    id: Mapped[int] = mapped_column(primary_key=True)
    title: Mapped[str]
    owner_id: Mapped[int] = mapped_column(ForeignKey('users.id'))
    owner: Mapped[User] = relationship(back_populates='tasks')

async def list_users_with_tasks(session: AsyncSession):
    statement = select(User).options(selectinload(User.tasks)).order_by(User.id)
    result = await session.execute(statement)
    return result.scalars().all()

# %% [markdown]
# ### Why ORMs exist
#
# ORMS exist because application code often wants to talk in terms of **objects** and **relationships**, while databases talk in terms of **tables**, **rows**, and **joins**.
#
# An ORM helps with:
#
# - mapping Python classes to tables,
# - reusing schema definitions,
# - organizing complex queries,
# - reducing repetitive SQL for common tasks.
#
# But ORMs are not magic. You still need to understand transactions, constraints, and query performance. That is why learning basic SQL first is so valuable.

# %% [markdown]
# ## ⚖️ Raw SQL vs ORM
#
# Both approaches are valid. Strong developers usually know a bit of both.
#
# | Raw SQL | ORM |
# | --- | --- |
# | Very explicit | More Python-friendly |
# | Easy to compare with database docs | Easier to reuse model definitions |
# | Great for learning and special queries | Great for common CRUD and relationships |
# | More manual string writing | More abstraction to learn |
#
# > 💡 **Practical rule:** Use the ORM for everyday application code, but stay comfortable reading and writing SQL when debugging or optimizing.

# %%
raw_sql = '''
SELECT id, title
FROM tasks
WHERE done = false
ORDER BY id
'''

orm_version = '''
statement = select(Task).where(Task.done.is_(False)).order_by(Task.id)
result = await session.execute(statement)
tasks = result.scalars().all()
'''

print('Raw SQL example:\n', raw_sql)
print('ORM example:\n', orm_version)

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# 1. **What if you forget `await session.commit()`?**
#    Your Python object may look updated, but the database will not actually save the change.
#
# 2. **What if every route creates a session but never closes it?**
#    Connections can pile up, waste resources, and eventually hurt performance.
#
# 3. **What if you delete a user who still has related tasks?**
#    Your database rules and relationship settings decide whether that is blocked, cascaded, or leaves broken links.
#
# 4. **What if you only learn ORM syntax and ignore SQL basics?**
#    You will struggle when queries get complicated or slow.
#
# 5. **What if your API needs to list users and their tasks efficiently?**
#    You may need relationship loading tools like `selectinload` to avoid too many queries.

# %% [markdown]
# ## Real-World Project Link
#
# Try applying this chapter to a **team task manager API**:
#
# - `users` table for team members,
# - `projects` table for workspaces,
# - `tasks` table linked to users and projects,
# - CRUD endpoints for creating and completing tasks,
# - relationship queries for dashboards such as "show all tasks assigned to Alice."
#
# Helpful references:
#
# - [FastAPI SQL databases tutorial](https://fastapi.tiangolo.com/tutorial/sql-databases/)
# - [SQLAlchemy async documentation](https://docs.sqlalchemy.org/en/20/orm/extensions/asyncio.html)

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
#
# - A database gives your app memory that survives restarts.
# - SQL is the core language for relational databases.
# - SQLAlchemy lets you map Python classes to database tables.
# - The async engine handles connections; the session handles work for one request.
# - FastAPI dependencies are a clean way to provide a session per request.
# - CRUD and relationships are the foundation of most API data layers.
#
# ### Cheat sheet
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# Keep this mental sentence nearby:
#
# **engine connects, session works, dependency cleans up.**

# %%
from collections.abc import AsyncGenerator

from sqlalchemy import ForeignKey, select
from sqlalchemy.ext.asyncio import AsyncSession, async_sessionmaker, create_async_engine
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column, relationship

engine = create_async_engine('sqlite+aiosqlite:///./app.db')
SessionLocal = async_sessionmaker(engine, expire_on_commit=False)

class Base(DeclarativeBase):
    pass

class User(Base):
    __tablename__ = 'users'
    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str]

class Task(Base):
    __tablename__ = 'tasks'
    id: Mapped[int] = mapped_column(primary_key=True)
    title: Mapped[str]
    owner_id: Mapped[int] = mapped_column(ForeignKey('users.id'))
    owner: Mapped[User] = relationship()

async def get_session() -> AsyncGenerator[AsyncSession, None]:
    async with SessionLocal() as session:
        yield session

async def list_tasks(session: AsyncSession):
    result = await session.execute(select(Task))
    return result.scalars().all()

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. In your own words, explain the difference between a table, a row, and a column.
# 2. Write SQL that creates a `products` table with `id`, `name`, and `price`.
# 3. Build a `get_session()` dependency and explain why `yield` is useful.
# 4. Create CRUD endpoints for a `Note` model.
# 5. Add a `User` → `Post` relationship and describe which field becomes the foreign key.
# 6. Compare one raw SQL query with its ORM version.
# 7. Explain why an ORM helps, but does not remove the need to learn SQL.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../5. security_and_authentication/12. oauth2_and_jwt.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='14. nosql_and_orms.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
