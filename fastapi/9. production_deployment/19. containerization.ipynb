# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../8.%20asynchronous_programming/18.%20websockets.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='20.%20deployment_strategies.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 19: Containerization
#
# ## The Big Picture
# If deployment feels mysterious, containers make it easier to reason about. Instead of asking, "What exact packages were installed on that server?" you describe your app, dependencies, and startup command once in a Docker image. Then you can run that same image on your laptop, in CI, or in the cloud.
#
# For a beginner, the main win is confidence: a container is a repeatable box for your FastAPI app. You still need networking, environment variables, and a database, but Docker turns those moving pieces into something you can start, stop, rebuild, and share with predictable behavior.
#
# > ❓ **What problem does Docker solve?** "It works on my machine." Docker packages your app *and* its exact environment (OS libraries, Python version, config) into a container image that runs identically on any machine or cloud provider.

# %% [markdown]
# ## Core Concepts
#
# - **Docker image**: a read-only blueprint. Think of it like a recipe or snapshot of your app plus its dependencies.
# - **Container**: a running instance of an image. If the image is the recipe, the container is the actual meal on the table.
# - **Dockerfile**: the step-by-step instructions Docker uses to build an image.
# - **Port mapping**: connects a port on your machine or server to a port inside the container, such as `8000:8000`.
# - **Environment variables**: values like database URLs or secrets that should be injected at runtime, not hard-coded.
# - **Volumes**: folders or named storage that survive container restarts, useful for databases and local development.
# - **Docker Compose**: one file that starts multiple services together, such as your FastAPI app, PostgreSQL, and Redis.
#
# A good mental model is this: **build once, run many times**. You build an image from a Dockerfile, then create containers from that image wherever you need them.
#
# > ❓ **Why split code into Blueprints?** A single file with hundreds of routes becomes unreadable. Blueprints group related routes (e.g., all auth routes) into pluggable mini-applications that you register on the main app — like separate chapters in a book.

# %% [markdown]
# ## Syntax & First Usage
# A minimal beginner workflow looks like this:
#
# 1. Write a `Dockerfile`.
# 2. Build an image with `docker build`.
# 3. Run a container with `docker run`.
# 4. Open the API in the browser or call it with `curl`.
#
# Useful first commands:
# - `docker build -t fastapi-demo .`
# - `docker run --rm -p 8000:8000 fastapi-demo`
# - `docker ps`
# - `docker logs <container-id>`
# - `docker compose up --build`
#
# Notice the progression: **Dockerfile -> image -> container**. That sequence removes a lot of deployment confusion.

# %%
# Dockerfile
FROM python:3.11-slim

WORKDIR /app

COPY requirements.txt .
RUN pip install --no-cache-dir -r requirements.txt

COPY . .

CMD ["uvicorn", "app.main:app", "--host", "0.0.0.0", "--port", "8000"]

# %% [markdown]
# ## Deep Dive with Code Examples
#
# The base image `python:3.11-slim` gives you Linux plus Python. `WORKDIR /app` says, "treat `/app` as the project's home." Copying `requirements.txt` first helps Docker cache dependency installation, so future rebuilds are faster when only your source code changes.
#
# `CMD` starts Uvicorn and binds to `0.0.0.0`. That address matters. If you bind to `127.0.0.1`, the server listens only inside the container and outside traffic cannot reach it.
#
# For real projects, your API is rarely alone. It often needs:
# - a **database** for persistent data,
# - a **Redis** instance for caching or background tasks,
# - and sometimes a **worker** service for jobs.
#
# That is where Docker Compose becomes beginner-friendly. Instead of memorizing long `docker run` commands, you describe the whole mini-system in one file.

# %%
# compose.yaml
services:
  app:
    build: .
    command: uvicorn app.main:app --host 0.0.0.0 --port 8000 --reload
    ports:
      - "8000:8000"
    environment:
      DATABASE_URL: postgresql+psycopg://postgres:postgres@db:5432/appdb
      REDIS_URL: redis://redis:6379/0
    depends_on:
      - db
      - redis
    volumes:
      - .:/app

  db:
    image: postgres:16
    environment:
      POSTGRES_DB: appdb
      POSTGRES_USER: postgres
      POSTGRES_PASSWORD: postgres
    ports:
      - "5432:5432"
    volumes:
      - postgres_data:/var/lib/postgresql/data

  redis:
    image: redis:7-alpine
    ports:
      - "6379:6379"

volumes:
  postgres_data:

# %% [markdown]
# ## Docker image vs container, and `docker run` vs Compose
#
# ### Image vs container
#
# - **Image** = packaged blueprint.
# - **Container** = live running process created from that blueprint.
#
# You can create many containers from one image. For example, one image might power three API containers behind a load balancer.
# ### `docker run` vs `docker compose`
#
# - Use **`docker run`** when learning, debugging, or starting a single container.
# - Use **Docker Compose** when your app needs multiple services that should start together.
#
# For beginners, Compose is usually easier once a database enters the picture because it makes the whole stack visible in one place.

# %% [markdown]
# ## The "What If?" Experimentation Section
# Try these small experiments to remove the mystery:
#
# 1. **Change the app port** from `8000` to `9000` in Compose. What else must change for your browser to still reach the API?
# 2. **Delete the `volumes` entry** for Postgres, then restart the stack. What happens to stored data?
# 3. **Break `DATABASE_URL` on purpose** by using the wrong host. How does the error message help you understand container networking?
# 4. **Remove `--host 0.0.0.0`** and rebuild. Why does the container appear healthy but the API is unreachable from outside?
# 5. **Edit source code while using the bind mount** (`.:/app`). What changes happen immediately, and which ones require a rebuild?

# %% [markdown]
# ## Real-World Project Link
# A useful example to explore is **Full Stack FastAPI Template** by the FastAPI community:
#
# - https://github.com/fastapi/full-stack-fastapi-template
#
# It shows how Docker, a database, background services, and deployment-friendly configuration fit together in a real application instead of a toy example.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
# ### Summary
# Containerization gives you a repeatable way to package and run your API. The big idea is not just "put it in Docker"; it is **reduce surprises between development and production**.
#
# ### Cheat sheet
#
# - **Dockerfile**: instructions to build an image.
# - **Image**: packaged app snapshot.
# - **Container**: running image.
# - **`docker build -t name .`**: build image.
# - **`docker run -p 8000:8000 name`**: run one container.
# - **`docker compose up --build`**: start multi-service app.
# - **Use `0.0.0.0`** inside containers so outside traffic can reach the app.
# - **Use volumes** for persistent database data.
# - **Use environment variables** for connection strings and secrets.
# - **Use Compose** when app + db + redis should act like one local environment.

# %% [markdown]
# ## Practice Prompts
#
# 1. Explain the difference between a Docker image and a Docker container in plain English.
# 2. Write a small `Dockerfile` for a FastAPI app that starts Uvicorn on port 8000.
# 3. Add a Postgres and Redis service to a Compose file and describe what each service is responsible for.
# 4. Describe why `0.0.0.0` matters inside a container.
# 5. Imagine your API works locally but not in Docker. List three things you would check first.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../8. asynchronous_programming/18. websockets.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='20. deployment_strategies.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
