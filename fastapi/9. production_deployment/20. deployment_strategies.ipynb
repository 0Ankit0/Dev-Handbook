# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='19.%20containerization.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='21.%20performance_tuning.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 20: Deployment Strategies
#
# ## The Big Picture
# A container gives you a package. Deployment strategy answers the next questions: **how should the package run, what should sit in front of it, where should it live, and how does new code reach production safely?**
#
# For beginners, the hardest part is that deployment sounds like many unrelated buzzwords: Gunicorn, Uvicorn, reverse proxy, cloud platform, CI/CD. They do connect. Together they form the path from a Git commit to a running API that users can reliably reach.
#
# > ❓ **Why not just use the development server in production?** The dev server is single-threaded and has no hardening for public traffic. Gunicorn/Uvicorn spawn multiple worker processes to handle concurrent requests and include timeouts, graceful restarts, and proper error logging.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# - **Uvicorn**: an ASGI server that can run a FastAPI app.
# - **Gunicorn**: a process manager that can start and supervise multiple worker processes.
# - **Uvicorn worker**: a Gunicorn worker type that knows how to serve ASGI apps like FastAPI.
# - **Worker**: one running process handling requests. More workers can improve throughput, up to a point.
# - **Reverse proxy**: a server such as Nginx or a cloud load balancer that sits in front of your app and forwards requests to it.
# - **Managed platform**: a service like Render, Railway, or Fly.io that hides most server setup.
# - **Self-managed deployment**: a VPS, VM, or Kubernetes setup that gives more control but more responsibility.
# - **CI/CD**: automated steps that test, build, and deploy your application when code changes.
#
# A simple mental picture is: **internet -> reverse proxy/load balancer -> Gunicorn/Uvicorn workers -> FastAPI app**.

# %% [markdown]
# ## Syntax & First Usage
# For a small production deployment, a very common command is Gunicorn managing Uvicorn workers:
#
# - `gunicorn app.main:app -k uvicorn.workers.UvicornWorker --workers 2 --bind 0.0.0.0:8000`
#
# This says:
# - load the FastAPI app from `app.main:app`,
# - use Uvicorn-compatible workers,
# - start 2 worker processes,
# - and listen on port 8000.
#
# You can run only Uvicorn in simple cases, but Gunicorn becomes helpful when you want multiple workers and cleaner process management.

# %%
# Start FastAPI in production with Gunicorn + Uvicorn workers

gunicorn app.main:app \
  -k uvicorn.workers.UvicornWorker \
  --workers 2 \
  --bind 0.0.0.0:8000 \
  --timeout 60 \
  --access-logfile -

# %% [markdown]
# ## Deep Dive with Code Examples
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### Why a reverse proxy exists
# A reverse proxy is the front desk for your API. Clients talk to the proxy first, not directly to your Python process. The proxy can:
# - terminate HTTPS,
# - route traffic to the right service,
# - buffer slow clients,
# - serve static files,
# - and spread requests across multiple app instances.
#
# Even if you never install Nginx yourself, many cloud platforms give you this layer automatically.
#
# ### Cloud deployment options
#
# Production-oriented material makes more sense when you see it as reliability work. The tools and steps here exist to make behavior repeatable, observable, and safer to change.
#
# 1. **Managed app platforms** such as Render, Railway, and Fly.io: fastest to start, great for beginners.
# 2. **Virtual machines or VPS providers** such as DigitalOcean or AWS EC2: more control, but you manage OS updates, firewall rules, and process setup.
# 3. **Containers on cloud services** such as AWS ECS, Google Cloud Run, or Azure Container Apps: a middle ground where you deploy images and let the platform handle part of the infrastructure.
# 4. **Kubernetes**: powerful for large teams and complex systems, but usually too much for a first deployment.
# ### CI/CD overview
# A beginner-friendly pipeline usually does four things:
# 1. runs tests,
# 2. builds the Docker image,
# 3. pushes the image to a registry,
# 4. triggers deployment to the chosen platform.
#
# That turns deployment from a manual ritual into a repeatable process.
#
# > ❓ **What problem does Docker solve?** "It works on my machine." Docker packages your app *and* its exact environment (OS libraries, Python version, config) into a container image that runs identically on any machine or cloud provider.

# %%
# Example GitHub Actions workflow idea
name: deploy

on:
  push:
    branches: [main]

jobs:
  build-and-deploy:
    runs-on: ubuntu-latest
    steps:
      - uses: actions/checkout@v4
      - uses: actions/setup-python@v5
        with:
          python-version: '3.11'
      - run: pip install -r requirements.txt
      - run: pytest
      - run: docker build -t my-registry/fastapi-app:${{ github.sha }} .
      - run: docker push my-registry/fastapi-app:${{ github.sha }}
      # platform-specific deploy step goes here

# %% [markdown]
# ## `uvicorn` alone vs Gunicorn + Uvicorn workers
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# ### `uvicorn` alone
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - simpler command,
# - fine for demos, local testing, and some lightweight deployments,
# - fewer moving parts to understand.
# ### Gunicorn + Uvicorn workers
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - better process supervision,
# - easier multi-worker setup,
# - common in Linux server deployments.
#
# For beginners, a good rule is: **start simple, but know why teams often add Gunicorn in production**.
# ## Managed platform vs self-managed server
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# - **Managed platform**: easier, faster, safer for first deployments.
# - **Self-managed server**: more flexible, but you must handle security patches, process restarts, logs, and networking yourself.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# 1. Start with **1 worker**, then imagine traffic doubles. What problem is the extra worker solving?
# 2. Remove the reverse proxy layer in your mental model. Where would HTTPS termination and load balancing happen?
# 3. Compare deploying to **Render** vs a **raw VM**. Which tasks disappear on the managed platform, and which remain your responsibility?
# 4. Imagine your CI pipeline tests successfully but deploys the wrong image tag. What part of the pipeline should you inspect first?
# 5. Increase Gunicorn workers from 2 to 8 on a tiny server. Why might performance get worse instead of better?

# %% [markdown]
# ## Real-World Project Link
# A practical reference is the **Full Stack FastAPI Template** deployment setup:
#
# - https://github.com/fastapi/full-stack-fastapi-template
#
# It is helpful because it shows the bigger deployment story: application code, containers, environment configuration, and infrastructure decisions living together.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
# ### Summary
# Deployment strategy is the bridge between "my code runs" and "real users can rely on it." Gunicorn/Uvicorn workers run the app, a reverse proxy or platform front end receives traffic, cloud services provide the infrastructure, and CI/CD keeps releases repeatable.
#
# ### Cheat sheet
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - **Uvicorn**: ASGI server for FastAPI.
# - **Gunicorn**: manages worker processes.
# - **Reverse proxy**: fronts your app and forwards traffic.
# - **Managed platform**: easiest beginner path.
# - **VM/VPS**: more control, more ops work.
# - **CI/CD**: test -> build -> push -> deploy.
# - Good first production command:
#   - `gunicorn app.main:app -k uvicorn.workers.UvicornWorker --workers 2 --bind 0.0.0.0:8000`

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. Explain what Gunicorn does that plain Uvicorn does not.
# 2. Describe a reverse proxy using a real-world analogy.
# 3. Choose one beginner-friendly cloud option and explain why it is a good first deployment target.
# 4. Write out the four basic stages of a simple CI/CD pipeline for a FastAPI app.
# 5. If HTTPS, load balancing, and static file serving are needed, where might those responsibilities live?

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='19. containerization.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='21. performance_tuning.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
