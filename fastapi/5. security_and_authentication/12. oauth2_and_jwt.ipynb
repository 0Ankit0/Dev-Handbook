# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='11.%20security_fundamentals.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../6.%20database_integration/13.%20sql_databases_with_sqlalchemy.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 12: OAuth2 and JWT
#
# In Chapter 11, we learned the basic questions of security:
#
# - Who is calling the API?
# - What are they allowed to do?
#
# Now we are ready for the pattern you will see in many real FastAPI projects:
#
# 1. A user sends login credentials.
# 2. The server verifies them.
# 3. The server creates a token.
# 4. The client sends that token on future requests.
#
# This chapter introduces **OAuth2 password flow**, **JWTs**, and the **current user dependency pattern**. These names can sound advanced, but the core idea is simple: once a user proves their identity, the server hands them a temporary access pass.
#
# > ❓ **Is a JWT the same as a password?** No — a JWT is a *signed token* the server issues after login. On each request the client sends it back, and the server verifies the signature without touching the database. Treat it like a password though: anyone holding it can impersonate the user.

# %% [markdown]
# ## The Big Picture
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# Imagine a music festival:
#
# - At the gate, you show your ID and ticket once.
# - The staff gives you a wristband.
# - For the rest of the day, you show the wristband instead of repeating the full check.
#
# In many APIs:
#
# - the **username and password** are used at login,
# - the **token** is the wristband,
# - protected routes check the token before serving the request.
#
# OAuth2 gives us a standard way to talk about this flow, and JWT gives us a common token format.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### OAuth2 password flow
#
# The password flow is a login pattern where:
#
# 1. the user sends a username and password to a token endpoint,
# 2. the server validates them,
# 3. the server returns an access token.
#
# In FastAPI tutorials, that token endpoint is often `/token`.
#
# ### What is a JWT?
#
# JWT stands for **JSON Web Token**. It is a compact string with three parts:
#
# ```text
# header.payload.signature
# ```
#
# - **Header**: says what algorithm and token type are used.
# - **Payload**: stores claims, such as the username or scopes.
# - **Signature**: helps detect tampering.
#
# ### Protected route
#
# A protected route is simply a route that depends on a function that checks the incoming token.
#
# ### Current user pattern
#
# Instead of repeating token validation in every route, we create one dependency like `get_current_user()` and reuse it everywhere.

# %% [markdown]
# ## Syntax & First Usage
#
# The first FastAPI tool many people meet in token-based auth is `OAuth2PasswordBearer`.
#
# Its job is not to log users in by itself. Its job is to say:
#
# > "For this route, expect a bearer token, and document that token flow in OpenAPI."
#
# Then you use `Depends(oauth2_scheme)` to read the token string from the `Authorization: Bearer ...` header.
#
# > ❓ **Why use dependency injection?** Instead of creating shared objects (like a DB session) inside every route, you declare them as dependencies. The framework creates, injects, and cleans them up — keeping routes small and making them easy to test with mock replacements.

# %%
from fastapi import Depends, FastAPI
from fastapi.security import OAuth2PasswordBearer

app = FastAPI()
oauth2_scheme = OAuth2PasswordBearer(tokenUrl="token")


@app.get("/profile")
def read_profile(token: str = Depends(oauth2_scheme)):
    return {"received_token": token}

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Here is the beginner-friendly version of the flow:
#
# 1. The client sends `username` and `password` to `/token`.
# 2. Your app checks the password against the stored password hash.
# 3. If valid, your app creates a token.
# 4. The client stores the token.
# 5. The client sends `Authorization: Bearer <token>` on future requests.
# 6. Your app validates the token before allowing access.
#
# This is better than sending the password on every request.
# The password is used only at login, while the token becomes the temporary proof of access.
#
# > ❓ **Why hash passwords instead of encrypting them?** Encryption is reversible — if someone steals the key, they get all passwords. Hashing is one-way: you store the hash and on login compare hashes. Even if your database leaks, attackers get only hashes, not the original passwords.

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Think of a JWT like a sealed note inside a wristband:
#
# - the **header** says what kind of wristband it is,
# - the **payload** says information about the wearer,
# - the **signature** proves the note was issued by your server and not edited by a random stranger.
#
# Important beginner note: the payload is usually **encoded**, not magically hidden from the world. Do not put sensitive secrets inside a JWT just because it looks scrambled.
#
# ### JWT vs server-side session
#
# Sections like this become clearer when you separate capabilities from tradeoffs. As you read, ask what each option is optimized for and what complexity you accept in exchange.
#
# | JWT-based access | Server-side session |
# | --- | --- |
# | Token often stores claims directly | Server keeps session data in server storage |
# | Great for APIs and distributed systems | Common in traditional web apps |
# | Client sends token each request | Client often sends a session cookie |

# %%
from datetime import datetime, timedelta, timezone
from jose import JWTError, jwt

SECRET_KEY = "change-this-in-real-projects"
ALGORITHM = "HS256"


def create_access_token(data: dict, expires_delta: timedelta | None = None):
    to_encode = data.copy()
    expire = datetime.now(timezone.utc) + (expires_delta or timedelta(minutes=30))
    to_encode.update({"exp": expire})
    return jwt.encode(to_encode, SECRET_KEY, algorithm=ALGORITHM)


def decode_access_token(token: str):
    try:
        payload = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
        return payload
    except JWTError:
        return None


token = create_access_token({"sub": "alice", "scope": "profile:read"})
print(token)
print(decode_access_token(token))

# %% [markdown]
# ## Deep Dive with Code Examples
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# FastAPI commonly uses `OAuth2PasswordRequestForm` for the `/token` endpoint.
# The client submits form data, not JSON, because that matches the OAuth2 password-flow convention.
#
# This example keeps the database fake so you can focus on the flow.

# %%
from datetime import datetime, timedelta, timezone

from fastapi import Depends, FastAPI, HTTPException, status
from fastapi.security import OAuth2PasswordRequestForm
from jose import JWTError, jwt
from passlib.context import CryptContext

app = FastAPI()

SECRET_KEY = "change-this-in-real-projects"
ALGORITHM = "HS256"
ACCESS_TOKEN_EXPIRE_MINUTES = 30
pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

fake_users_db = {
    "alice": {
        "username": "alice",
        "hashed_password": pwd_context.hash("wonderland"),
        "role": "admin",
    }
}


def verify_password(plain_password: str, hashed_password: str) -> bool:
    return pwd_context.verify(plain_password, hashed_password)


def authenticate_user(username: str, password: str):
    user = fake_users_db.get(username)
    if not user:
        return None
    if not verify_password(password, user["hashed_password"]):
        return None
    return user


def create_access_token(data: dict, expires_delta: timedelta | None = None):
    to_encode = data.copy()
    expire = datetime.now(timezone.utc) + (expires_delta or timedelta(minutes=15))
    to_encode.update({"exp": expire})
    return jwt.encode(to_encode, SECRET_KEY, algorithm=ALGORITHM)


@app.post("/token")
def login(form_data: OAuth2PasswordRequestForm = Depends()):
    user = authenticate_user(form_data.username, form_data.password)
    if not user:
        raise HTTPException(
            status_code=status.HTTP_401_UNAUTHORIZED,
            detail="Incorrect username or password",
        )

    access_token = create_access_token(
        data={"sub": user["username"], "role": user["role"]},
        expires_delta=timedelta(minutes=ACCESS_TOKEN_EXPIRE_MINUTES),
    )
    return {"access_token": access_token, "token_type": "bearer"}

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Now we will reuse the token with dependencies.
#
# This is the beautiful FastAPI idea:
#
# - one dependency extracts the token,
# - another validates and decodes it,
# - routes receive a ready-to-use user object.
#
# That keeps route functions focused on business logic instead of security plumbing.

# %%
from fastapi import Depends, FastAPI, HTTPException, status
from fastapi.security import OAuth2PasswordBearer
from jose import JWTError, jwt

app = FastAPI()
oauth2_scheme = OAuth2PasswordBearer(tokenUrl="token")

SECRET_KEY = "change-this-in-real-projects"
ALGORITHM = "HS256"

fake_users_db = {
    "alice": {"username": "alice", "full_name": "Alice Brown", "role": "admin"},
    "bob": {"username": "bob", "full_name": "Bob Green", "role": "member"},
}


def get_current_user(token: str = Depends(oauth2_scheme)):
    credentials_exception = HTTPException(
        status_code=status.HTTP_401_UNAUTHORIZED,
        detail="Could not validate credentials",
        headers={"WWW-Authenticate": "Bearer"},
    )

    try:
        payload = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
        username = payload.get("sub")
        if username is None:
            raise credentials_exception
    except JWTError:
        raise credentials_exception

    user = fake_users_db.get(username)
    if user is None:
        raise credentials_exception
    return user


@app.get("/users/me")
def read_users_me(current_user: dict = Depends(get_current_user)):
    return current_user


def require_admin(current_user: dict = Depends(get_current_user)):
    if current_user["role"] != "admin":
        raise HTTPException(status_code=403, detail="Admins only")
    return current_user


@app.get("/admin/dashboard")
def read_admin_dashboard(current_user: dict = Depends(require_admin)):
    return {"message": f"Welcome, {current_user['username']}"}

# %% [markdown]
# ## Current user pattern explained slowly
#
# If you are new to dependencies, here is the mental model:
#
# - `oauth2_scheme` reads the raw token string.
# - `get_current_user()` decodes the token and finds the matching user.
# - route functions receive `current_user` as trusted input.
#
# So instead of every route repeating "decode token, extract username, find user, handle errors," you write that once and reuse it.
#
# This pattern makes code easier to read, easier to test, and less likely to drift into inconsistent security behavior.

# %% [markdown]
# ## Scopes and RBAC basics
#
# Two common permission ideas are **scopes** and **roles**.
#
# - **Scope** = a specific permission, such as `items:read` or `items:write`
# - **Role** = a bundle of permissions, such as `admin`, `editor`, or `viewer`
#
# ### Scopes vs roles
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# | Scopes | Roles |
# | --- | --- |
# | Fine-grained permissions | Higher-level labels |
# | Example: `orders:read` | Example: `manager` |
# | Good when permissions vary a lot | Good when teams understand named job functions |
#
# RBAC means **Role-Based Access Control**. It is the idea of assigning permissions based on a role.
# Many real systems mix both: a role determines common permissions, while scopes express the exact actions available inside the token.

# %%
from fastapi import Depends, FastAPI, HTTPException, status
from fastapi.security import OAuth2PasswordBearer, SecurityScopes
from jose import JWTError, jwt

app = FastAPI()

oauth2_scheme = OAuth2PasswordBearer(
    tokenUrl="token",
    scopes={
        "items:read": "Read items",
        "items:write": "Create or update items",
    },
)

SECRET_KEY = "change-this-in-real-projects"
ALGORITHM = "HS256"


def get_current_user_with_scopes(
    security_scopes: SecurityScopes,
    token: str = Depends(oauth2_scheme),
):
    credentials_exception = HTTPException(
        status_code=status.HTTP_401_UNAUTHORIZED,
        detail="Not enough permissions",
        headers={"WWW-Authenticate": f'Bearer scope="{security_scopes.scope_str}"'},
    )

    try:
        payload = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
        token_scopes = payload.get("scopes", [])
    except JWTError:
        raise credentials_exception

    for scope in security_scopes.scopes:
        if scope not in token_scopes:
            raise credentials_exception

    return payload

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# 1. **What if the token is expired?**
#    Validation should fail, and the user should log in again.
#
# 2. **What if someone changes the payload of a JWT by hand?**
#    The signature check should fail, so the token is rejected.
#
# 3. **What if the token contains a username that no longer exists in the database?**
#    `get_current_user()` should reject the request.
#
# 4. **What if a valid logged-in user lacks the required scope?**
#    Authentication succeeds, but authorization should fail.
#
# 5. **What if you put sensitive secrets inside the JWT payload?**
#    That is a bad idea, because payload data can often be decoded and inspected.

# %% [markdown]
# ## Real-World Project Link
#
# Try applying this chapter to a **task manager API**:
#
# - `/token` logs users in,
# - `/users/me` returns the current user,
# - `/tasks` is available to logged-in users,
# - `/admin/reports` is restricted to admins,
# - write scopes like `tasks:read` and `tasks:write` for finer control.
#
# Helpful references:
#
# - [FastAPI OAuth2 with JWT tutorial](https://fastapi.tiangolo.com/tutorial/security/oauth2-jwt/)
# - [JWT introduction on jwt.io](https://jwt.io/introduction)

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
#
# - **OAuth2 password flow** uses username/password once to get a token.
# - **JWT** has three parts: header, payload, and signature.
# - Use `OAuth2PasswordBearer` to read bearer tokens in FastAPI.
# - Create a reusable `get_current_user()` dependency for protected routes.
# - **Scopes** and **roles** help express authorization rules.
#
# ### Cheat sheet
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```python
# from fastapi.security import OAuth2PasswordBearer, OAuth2PasswordRequestForm
# from fastapi import Depends
# from jose import jwt
#
# oauth2_scheme = OAuth2PasswordBearer(tokenUrl="token")
#
# token = jwt.encode({"sub": "alice"}, SECRET_KEY, algorithm="HS256")
# payload = jwt.decode(token, SECRET_KEY, algorithms=["HS256"])
#
# @app.get("/users/me")
# def read_me(current_user=Depends(get_current_user)):
#     return current_user
# ```
# ### Memory hook
#
# Remember this sentence:
# **"Log in once with a password, then travel with a token, and let dependencies check the token for each protected route."**

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. Explain OAuth2 password flow using the festival wristband analogy.
# 2. Create a `/token` endpoint that returns a JWT with a `sub` claim.
# 3. Write a `get_current_user()` dependency that reads the bearer token.
# 4. Protect `/users/me` with `Depends(get_current_user)`.
# 5. Add a `role` claim and block non-admin users from an `/admin` route.
# 6. Add a `scopes` list to the token payload and require `items:write` for one route.
# 7. Compare JWT-based auth with server-side sessions in your own words.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='11. security_fundamentals.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../6. database_integration/13. sql_databases_with_sqlalchemy.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
