# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../4.%20structuring_large_applications/10.%20middleware_and_events.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='12.%20oauth2_and_jwt.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 11: Security Fundamentals
#
# Security can feel scary because it is often explained with dense words like *credential exchange*, *threat model*, and *attack surface*.
# For a beginner, it is easier to think about security the way you think about a building:
#
# - **Authentication** answers: *Who are you?*
# - **Authorization** answers: *What are you allowed to do once you are inside?*
# - **Password hashing** answers: *How do we store secrets without leaving the vault door open?*
#
# In this chapter, we will move slowly. We will start with the idea of identity, then look at simple FastAPI tools such as API keys and HTTP Basic, and finally learn why plain text passwords are dangerous and why hashing is a must.
#
# > ❓ **Why hash passwords instead of encrypting them?** Encryption is reversible — if someone steals the key, they get all passwords. Hashing is one-way: you store the hash and on login compare hashes. Even if your database leaks, attackers get only hashes, not the original passwords.

# %% [markdown]
# ## The Big Picture
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# Imagine a small office:
#
# - The **front desk** checks whether you belong there.
# - Different rooms have different **permission levels**.
# - The office should never keep a sticky note containing everybody's real password.
#
# FastAPI gives you building blocks for all three ideas.
#
# 1. **API keys** are like a shared badge or secret code.
# 2. **HTTP Basic** is like saying your username and password directly to the receptionist on every visit.
# 3. **Password hashing** is like storing a locked fingerprint of a password instead of the password itself.
#
# These tools are not the final word in security, but they are excellent starting points because they teach the core mental model behind safer APIs.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### Authentication vs authorization
#
# Sections like this become clearer when you separate capabilities from tradeoffs. As you read, ask what each option is optimized for and what complexity you accept in exchange.
#
# | Idea | Plain-English question | Everyday analogy | FastAPI example |
# | --- | --- | --- | --- |
# | **Authentication** | "Who are you?" | Showing your ID badge | Verifying username/password, API key, or token |
# | **Authorization** | "What may you do?" | Door access after your badge is accepted | Allowing only admins to delete data |
#
# A user may be **authenticated but not authorized**. For example, a normal customer can log in, but that does not mean they should be able to view every user's billing data.
# ### Why plain text passwords are dangerous
#
# If you store passwords exactly as users typed them, anyone who can read the database can immediately impersonate users.
#
# That means:
#
# - a database leak becomes an account leak,
# - employees with database access can see real passwords,
# - users who reuse passwords on other sites are at risk far beyond your app.
#
# So instead of storing the real password, we store a **hash**.
#
# ### What is a hash?
#
# A hash is a one-way transformation. You give it a password, and it gives back a scrambled result.
#
# - You can compare a new login attempt against the stored hash.
# - You should not be able to reverse the hash back into the original password.
# - Good password hashing tools also make guessing attacks slower.

# %% [markdown]
# ## Syntax & First Usage
#
# FastAPI includes ready-made security helpers in `fastapi.security`.
#
# A very small API key example looks like this:
#
# 1. Create a security object, such as `APIKeyHeader(name="x-api-key")`.
# 2. Ask FastAPI for the value with `Depends(...)`.
# 3. Compare the provided secret with the value your server expects.
#
# Notice the pattern: the security tool is not magic. It is a helper that reads a credential from the request, and **you** decide what to do with it.
#
# > ❓ **Why use dependency injection?** Instead of creating shared objects (like a DB session) inside every route, you declare them as dependencies. The framework creates, injects, and cleans them up — keeping routes small and making them easy to test with mock replacements.

# %%
from fastapi import Depends, FastAPI, HTTPException, status
from fastapi.security import APIKeyHeader

app = FastAPI()

api_key_header = APIKeyHeader(name="x-api-key")
EXPECTED_API_KEY = "super-secret-demo-key"


def require_api_key(api_key: str = Depends(api_key_header)):
    if api_key != EXPECTED_API_KEY:
        raise HTTPException(
            status_code=status.HTTP_403_FORBIDDEN,
            detail="Invalid or missing API key",
        )
    return api_key


@app.get("/internal-report")
def read_internal_report(api_key: str = Depends(require_api_key)):
    return {"message": "Access granted", "key_used": api_key}

# %% [markdown]
# ## Deep Dive with Code Examples
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# API keys are often used when:
#
# - one service talks to another service,
# - a simple internal dashboard needs protection,
# - you are securing a prototype before adding full user accounts.
#
# Think of an API key as a **shared secret key for a storage room**. Anyone holding the key can usually open the same door, so API keys are better for app-to-app access than for individual user identities.
# ### API keys vs user login
#
# Sections like this become clearer when you separate capabilities from tradeoffs. As you read, ask what each option is optimized for and what complexity you accept in exchange.
#
# | API keys | User login |
# | --- | --- |
# | Usually identify an application or client | Usually identify a person |
# | Often one key is shared by a service | Each user should have their own credentials |
# | Simpler to set up | Better when actions must be tied to a specific user |
#
# API keys are useful, but they have limits:
#
# - they do not naturally answer "which human user is this?"
# - they are hard to revoke per person if many people share one key
# - if pasted into client-side JavaScript, they can leak

# %%
from fastapi import Depends, FastAPI, HTTPException, status
from fastapi.security import APIKeyHeader, APIKeyQuery

app = FastAPI()

header_scheme = APIKeyHeader(name="x-api-key", auto_error=False)
query_scheme = APIKeyQuery(name="api_key", auto_error=False)
VALID_KEYS = {"alpha-demo-key", "beta-demo-key"}


def get_api_key(
    header_key: str | None = Depends(header_scheme),
    query_key: str | None = Depends(query_scheme),
) -> str:
    provided_key = header_key or query_key

    if not provided_key:
        raise HTTPException(
            status_code=status.HTTP_401_UNAUTHORIZED,
            detail="Please send an API key in the header or query string.",
        )

    if provided_key not in VALID_KEYS:
        raise HTTPException(
            status_code=status.HTTP_403_FORBIDDEN,
            detail="That API key is not recognized.",
        )

    return provided_key


@app.get("/inventory")
def read_inventory(api_key: str = Depends(get_api_key)):
    return {"message": "You can view inventory.", "api_key": api_key}

# %% [markdown]
# ## Deep Dive with Code Examples
#
# HTTP Basic is one of the simplest authentication schemes on the web.
#
# The browser or client sends a username and password in a special `Authorization` header.
# The credentials are **encoded**, not safely encrypted by Basic Auth itself, so you should only use it over **HTTPS**.
#
# ### How to think about HTTP Basic
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# - It is easy to understand.
# - It is easy to demo.
# - It is usually too limited for modern user-facing apps.
#
# It is like telling the receptionist your name and password every single time you walk in. That works, but it is not very elegant.
# ### HTTP Basic vs API keys
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# | HTTP Basic | API keys |
# | --- | --- |
# | Usually username + password | Usually one secret value |
# | Better fit for simple human login demos | Better fit for service-to-service access |
# | Often replaced later by tokens | Often rotated and managed as application secrets |

# %%
import secrets

from fastapi import Depends, FastAPI, HTTPException, status
from fastapi.security import HTTPBasic, HTTPBasicCredentials

app = FastAPI()
security = HTTPBasic()


def verify_basic_user(credentials: HTTPBasicCredentials = Depends(security)):
    expected_username = "alice"
    expected_password = "wonderland"

    username_ok = secrets.compare_digest(credentials.username, expected_username)
    password_ok = secrets.compare_digest(credentials.password, expected_password)

    if not (username_ok and password_ok):
        raise HTTPException(
            status_code=status.HTTP_401_UNAUTHORIZED,
            detail="Incorrect username or password",
            headers={"WWW-Authenticate": "Basic"},
        )

    return credentials.username


@app.get("/basic-profile")
def read_basic_profile(username: str = Depends(verify_basic_user)):
    return {"message": f"Welcome, {username}!"}

# %% [markdown]
# ## Deep Dive with Code Examples
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# Here is the key beginner idea:
#
# - During **registration**, hash the password and store the hash.
# - During **login**, hash the newly entered password in a safe verification process and compare it against the stored hash.
#
# You never need to recover the original password.
# ### Plain text vs hashed passwords
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# | Plain text storage | Hashed storage |
# | --- | --- |
# | Database reveals real passwords immediately | Database reveals only password hashes |
# | Easy for attackers to abuse | Much safer when modern hashing is used |
# | Teaches bad habits | Matches real security practice |
#
# Good password hashing libraries also add **salt** and use slower algorithms such as bcrypt so attackers cannot guess millions of passwords cheaply.

# %%
from passlib.context import CryptContext

pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

plain_password = "my-dog-loves-apples"
hashed_password = pwd_context.hash(plain_password)

print("Stored in database:", hashed_password)
print("Correct password?", pwd_context.verify("my-dog-loves-apples", hashed_password))
print("Wrong password?", pwd_context.verify("not-the-right-password", hashed_password))

# %% [markdown]
# ## Putting the ideas together
#
# A beginner-friendly login system often follows this flow:
#
# 1. A user registers with a username and password.
# 2. Your app hashes the password and stores the hash.
# 3. The user later logs in.
# 4. Your app verifies the entered password against the stored hash.
# 5. If the identity is confirmed, your app decides what that user is allowed to access.
#
# Step 4 is **authentication**.
# Step 5 is **authorization**.
#
# That separation matters because it keeps your design clean. One part proves identity. Another part checks permissions.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# Try mentally predicting what happens in each case before you test it:
#
# 1. **What if an API key is missing?**
#    You should return an error such as `401 Unauthorized` or `403 Forbidden`, depending on your design.
#
# 2. **What if two services share the same API key?**
#    You can allow access, but you cannot easily tell which specific human triggered the action.
#
# 3. **What if you store plain text passwords and the database leaks?**
#    Attackers instantly know the passwords. There is no protective layer.
#
# 4. **What if you use HTTP Basic without HTTPS?**
#    The credentials can be intercepted much more easily because Basic Auth alone is not enough protection.
#
# 5. **What if an authenticated user tries an admin-only route?**
#    Authentication can succeed while authorization should still deny access.

# %% [markdown]
# ## Real-World Project Link
#
# A good beginner project is a **private team notes API**:
#
# - protect internal endpoints with an API key,
# - add a simple admin route behind HTTP Basic for quick demos,
# - store team member passwords as hashes,
# - later upgrade the project to token-based login in the next chapter.
#
# Helpful references:
#
# - [FastAPI security tools overview](https://fastapi.tiangolo.com/tutorial/security/)
# - [OWASP Password Storage Cheat Sheet](https://cheatsheetseries.owasp.org/cheatsheets/Password_Storage_Cheat_Sheet.html)

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Summary
#
# - **Authentication** proves identity.
# - **Authorization** decides permissions.
# - **API keys** are simple shared secrets, often for service-to-service access.
# - **HTTP Basic** is easy to learn but should be used with HTTPS and is usually not the final design.
# - **Passwords must be hashed**, not stored in plain text.
#
# ### Cheat sheet
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```python
# from fastapi.security import APIKeyHeader, HTTPBasic
# from fastapi import Depends
# from passlib.context import CryptContext
#
# api_key_scheme = APIKeyHeader(name="x-api-key")
# basic_scheme = HTTPBasic()
# pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")
#
# hashed = pwd_context.hash("secret")
# ok = pwd_context.verify("secret", hashed)
# ```
# ### Memory hook
#
# If you only remember one sentence, remember this:
# **"First prove who the caller is, then check what the caller may do, and never store raw passwords."**

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. Explain authentication and authorization to a friend using a library card analogy.
# 2. Build a FastAPI route that accepts an API key in the `x-api-key` header.
# 3. Modify the API key example so different keys map to different client names.
# 4. Create an HTTP Basic protected route called `/admin`.
# 5. Hash the password `coffee123` and verify it with `passlib`.
# 6. Write one paragraph about why plain text password storage is dangerous.
# 7. Decide which is a better fit for each case: API key, HTTP Basic, or a future token-based system.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../4. structuring_large_applications/10. middleware_and_events.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='12. oauth2_and_jwt.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
