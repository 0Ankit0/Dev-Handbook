# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='15.%20testing_strategies.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../8.%20asynchronous_programming/17.%20mastering_asyncawait.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 16: Code Quality
#
# ## The Big Picture
#
# Code quality tools do not make your app smarter. They make your team **safer, faster, and more consistent**.
#
# Beginners sometimes ask, *"If my code already runs, why should I care about linting or type checking?"* The answer is simple: teams want problems caught **before** they become bugs, review comments, or production incidents.
#
# Think of the tools in this chapter as different kinds of assistants:
#
# - a **linter** points out suspicious code,
# - a **formatter** keeps style consistent,
# - a **type checker** catches mismatch mistakes early,
# - **pre-commit** runs checks automatically before code is committed.
#
# FastAPI projects especially benefit because they often contain request models, response models, settings, async code, and many dependencies that are easier to maintain when the codebase stays clean.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### Linting
# A linter looks for code that is suspicious, inconsistent, or likely to cause mistakes.
#
# Common examples:
# - unused imports,
# - variables that are created but never used,
# - risky patterns,
# - style issues teams want to keep consistent.
#
# ### Formatting
# A formatter rewrites code into a consistent shape automatically. It answers questions like:
# - How many blank lines?
# - Where should line breaks go?
# - Should strings use single or double quotes?
#
# ### Type checking
# A type checker reads type hints and asks, *"Are you using values in a way that matches their declared types?"*
#
# ### Pre-commit
# `pre-commit` runs tools before each git commit so humans do not have to remember every command.
#
# ### Why teams use them
# Teams use these tools because they reduce argument, reduce review noise, and catch simple issues earlier than manual review.

# %% [markdown]
# ## Syntax & First Usage
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# A beginner-friendly workflow is:
#
# 1. write code,
# 2. run the linter,
# 3. auto-format the file,
# 4. run the type checker,
# 5. let `pre-commit` automate the routine.
#
# Here are the commands you will see often in FastAPI teams.

# %%
# Install common tools
pip install ruff black mypy pre-commit

# Linting
ruff check .

# Formatting
black .

# Type checking
mypy app

# Pre-commit setup
pre-commit install
pre-commit run --all-files

# %% [markdown]
# ## Deep Dive with Code Examples
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### Example 1: Linting with Ruff
#
# `ruff` is popular because it is fast and can replace several older tools in one package. Teams often use it to catch simple problems before code review.

# %%
# messy_example.py
from fastapi import FastAPI
import json

app = FastAPI()

@app.get('/hello')
def hello():
    message = 'hello'
    return {'message': 'hi'}

# Possible lint findings:
# - json is imported but unused
# - message is assigned but unused
# - spacing and blank lines may not match project rules

# %% [markdown]
# ### Example 2: Formatting with Black
#
# Formatters are not about correctness; they are about consistency. That sounds small, but it matters. If every file follows the same shape, code reviews can focus on logic instead of commas, spaces, and line wrapping.

# %%
# before formatting
def build_response(name:str,age:int,city:str): return {'name':name,'age':age,'city':city}

# after running black
def build_response(name: str, age: int, city: str):
    return {'name': name, 'age': age, 'city': city}

# %% [markdown]
# ### Example 3: Type checking with Mypy
#
# FastAPI encourages clear data models. Type checkers shine when one part of the app expects one type but receives another.

# %%
from pydantic import BaseModel

class UserOut(BaseModel):
    id: int
    username: str

def get_user_id(user: UserOut) -> int:
    return user.id

def broken_example() -> int:
    user = UserOut(id=1, username='sam')
    return user.username  # mypy should complain: str is not int

# %% [markdown]
# ### Example 4: Project configuration
#
# Modern Python teams usually keep tool settings in `pyproject.toml` so the project has one central place for quality rules.

# %%
# pyproject.toml
[tool.ruff]
line-length = 100

[tool.black]
line-length = 100

[tool.mypy]
python_version = '3.11'
warn_return_any = true
warn_unused_configs = true
disallow_untyped_defs = true

# %% [markdown]
# ### Example 5: Automate with pre-commit
#
# `pre-commit` is not a linter by itself. It is a runner that executes tools automatically before a commit is created.
#
# Teams love this because it moves small quality checks earlier in the workflow. Instead of finding formatting problems in CI, developers fix them locally in seconds.

# %%
# .pre-commit-config.yaml
repos:
  - repo: https://github.com/astral-sh/ruff-pre-commit
    rev: v0.6.9
    hooks:
      - id: ruff
        args: [--fix]
      - id: ruff-format

  - repo: https://github.com/psf/black
    rev: 24.8.0
    hooks:
      - id: black

  - repo: https://github.com/pre-commit/mirrors-mypy
    rev: v1.11.2
    hooks:
      - id: mypy

# %% [markdown]
# ## Linting vs Formatting
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# | Tool type | Main job | Example question it answers |
# |---|---|---|
# | Linter | Find suspicious or undesirable code | "Why is this import unused?" |
# | Formatter | Re-shape code automatically | "How should this line wrap?" |
# | Type checker | Verify type-hint consistency | "Can this function really return `int`?" |
# | Pre-commit | Run tools automatically before commit | "Did we remember to run the checks?" |
#
# Another useful comparison:
#
# - **Linting** is about *quality signals*.
# - **Formatting** is about *consistent appearance*.
#
# They work well together, but they are not the same thing.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# 1. **What if you skip formatting?**
#    Your app might still run, but code reviews become noisier and style drifts across files.
#
# 2. **What if you skip type checking?**
#    A function may say it returns `dict[str, int]` while actually returning strings, and you might not notice until much later.
#
# 3. **What if you only rely on CI?**
#    You wait longer for feedback and fix simple issues after pushing instead of before committing.
#
# 4. **What if tools disagree?**
#    Teams usually standardize on one formatter and one linter configuration so the rules are clear.

# %%
# Mini experiment: a type mismatch that may run but is still wrong
def add_tax(price: float) -> float:
    return price * 1.2

total = add_tax('9.99')  # Python will fail at runtime; mypy can warn earlier
print(total)

# %% [markdown]
# ## Real-World Project Link
#
# Imagine our FastAPI project is an **online bookstore API**.
#
# A quality workflow for that team could look like this:
#
# - `ruff` catches unused imports and obvious mistakes,
# - `black` keeps every file formatted the same way,
# - `mypy` checks service-layer functions and Pydantic models,
# - `pre-commit` runs all of them before each commit,
# - CI runs the same checks again on GitHub for extra safety.
#
# This does not replace human review. It makes human review more valuable.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# - **Linting** finds suspicious code patterns.
# - **Formatting** keeps style consistent automatically.
# - **Type checking** uses hints to catch mismatches before runtime.
# - **Pre-commit** runs tools automatically before commits.
# - Teams use these tools to save time, reduce style debates, and catch problems earlier.
#
# ### Mini cheat sheet
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```bash
# ruff check .
# black .
# mypy app
# pre-commit install
# pre-commit run --all-files
# ```
# ### Beginner rule of thumb
#
# If a tool can fix style automatically, let it. Save your brainpower for API design and business logic.

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. Create a small `pyproject.toml` for a FastAPI app using Ruff, Black, and Mypy.
# 2. Write a file with an unused import and run a linter to see the warning.
# 3. Add type hints to one route helper and intentionally return the wrong type. What does Mypy report?
# 4. Install `pre-commit` and configure it to run at least Ruff and Mypy.
# 5. Explain, in your own words, why linting and formatting solve different problems.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='15. testing_strategies.ipynb' style='font-weight:bold; font-size:1.05em;'>&larr; Previous</a>
#   <a href='../TOC.md' style='font-weight:bold; font-size:1.05em; text-align:center;'>Table of Contents</a>
#   <a href='../8. asynchronous_programming/17. mastering_asyncawait.ipynb' style='font-weight:bold; font-size:1.05em;'>Next &rarr;</a>
# </div>
