# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../6.%20database_integration/14.%20nosql_and_orms.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='16.%20code_quality.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 15: Testing Strategies
#
# ## The Big Picture
#
# When you test a FastAPI app, you are checking one small promise at a time: **if a request comes in, does the app respond the way we expect?**
#
# For beginners, tests can feel like extra work. In real teams, they are the opposite: they are a safety net. They let you rename code, add features, or fix bugs without wondering, *"Did I accidentally break login?"*
#
# In this chapter, think of tests as **tiny robot users**. Each robot sends a request, reads the response, and complains if something looks wrong.
#
# By the end of this chapter, you should be comfortable with:
#
# - using `TestClient` to call your API without starting a real server,
# - organizing test cases with `pytest`,
# - testing authentication and protected routes,
# - overriding dependencies so tests stay predictable,
# - understanding the first step from sync tests to async tests.
#
# > ❓ **Why use a fake client instead of a real browser?** The test client sends requests directly to your app in memory — no network, no server startup. Tests run in milliseconds and work in CI without any extra infrastructure.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### 1. `TestClient`
# `TestClient` lets you call your FastAPI app like a browser or API client would, but entirely inside Python.
#
# ### 2. Test cases
# A **test case** is one focused check. Good tests usually follow **Arrange → Act → Assert**:
#
# - **Arrange**: create data or setup state,
# - **Act**: send a request,
# - **Assert**: verify the result.
#
# ### 3. Fixtures
# In `pytest`, fixtures are reusable setup helpers. Teams use them for common things like a client, a test database, or a logged-in user.
#
# ### 4. Authentication tests
# Protected endpoints are only useful if they reject the wrong user and accept the right one. That means testing **both success and failure paths**.
#
# ### 5. Dependency overrides
# FastAPI dependencies are powerful because you can swap them during tests. For example, you can replace:
#
# - a real database with a fake one,
# - a real payment service with a stub,
# - a real current-user dependency with a test user.
#
# ### 6. Async testing basics
# Many FastAPI apps contain async code. Beginners should know this rule:
#
# > `TestClient` is great for most endpoint tests.
# > Use async tests when you need to directly await async functions or use async clients/libraries.

# %% [markdown]
# ## Syntax & First Usage
#
# Here is the smallest useful FastAPI test. Notice what is happening:
#
# 1. create the app,
# 2. wrap it in `TestClient`,
# 3. send a request,
# 4. check the response.

# %%
from fastapi import FastAPI
from fastapi.testclient import TestClient

app = FastAPI()

@app.get('/health')
def health_check():
    return {'status': 'ok'}

client = TestClient(app)

def test_health_check():
    response = client.get('/health')

    assert response.status_code == 200
    assert response.json() == {'status': 'ok'}

# %% [markdown]
# ## Deep Dive with Code Examples
#
# We will build confidence step by step.
#
# ### Example 1: Test a simple endpoint
# Start with something small and deterministic. If the endpoint always returns the same shape, your first test should check that shape.

# %%
from fastapi import FastAPI
from fastapi.testclient import TestClient

app = FastAPI()

@app.get('/hello/{name}')
def hello(name: str):
    return {'message': f'Hello, {name}!'}

client = TestClient(app)

def test_hello_endpoint():
    response = client.get('/hello/Ada')

    assert response.status_code == 200
    assert response.json()['message'] == 'Hello, Ada!'

# %% [markdown]
# ### Example 2: Test validation and business rules
#
# Real APIs accept input. A good test suite checks **valid input** and **invalid input**.
#
# In FastAPI, validation errors usually return status code `422` when the request body does not match the schema.

# %%
from fastapi import FastAPI
from fastapi.testclient import TestClient
from pydantic import BaseModel

app = FastAPI()

class UserCreate(BaseModel):
    username: str
    age: int

@app.post('/users')
def create_user(user: UserCreate):
    return {'username': user.username, 'age': user.age}

client = TestClient(app)

def test_create_user_success():
    response = client.post('/users', json={'username': 'maya', 'age': 22})

    assert response.status_code == 200
    assert response.json()['username'] == 'maya'

def test_create_user_rejects_bad_age():
    response = client.post('/users', json={'username': 'maya', 'age': 'not-a-number'})

    assert response.status_code == 422

# %% [markdown]
# ### Example 3: Test authentication
#
# Authentication tests usually have three parts:
#
# - create or fake a user,
# - obtain credentials or a token,
# - call a protected endpoint.
#
# Just as important: test the **wrong token** case too.

# %%
from fastapi import Depends, FastAPI, Header, HTTPException
from fastapi.testclient import TestClient

app = FastAPI()

def get_current_user(authorization: str | None = Header(default=None)):
    if authorization != 'Bearer test-token':
        raise HTTPException(status_code=401, detail='Unauthorized')
    return {'username': 'demo-user'}

@app.get('/me')
def read_me(current_user = Depends(get_current_user)):
    return current_user

client = TestClient(app)

def test_protected_route_with_valid_token():
    response = client.get('/me', headers={'Authorization': 'Bearer test-token'})

    assert response.status_code == 200
    assert response.json()['username'] == 'demo-user'

def test_protected_route_with_missing_token():
    response = client.get('/me')

    assert response.status_code == 401

# %% [markdown]
# ### Example 4: Override dependencies
#
# This is one of FastAPI's best testing features.
#
# Suppose your route depends on `get_db()` or `get_current_user()`. In tests, you often do **not** want to hit the real database or the real auth system. Instead, you replace the dependency with a simpler version.

# %%
from fastapi import Depends, FastAPI
from fastapi.testclient import TestClient

app = FastAPI()

def get_db():
    return {'source': 'real database'}

@app.get('/debug-db')
def debug_db(db = Depends(get_db)):
    return db

def override_get_db():
    return {'source': 'fake test database'}

app.dependency_overrides[get_db] = override_get_db

client = TestClient(app)

def test_dependency_override():
    response = client.get('/debug-db')

    assert response.status_code == 200
    assert response.json()['source'] == 'fake test database'

# Important cleanup after tests in a real suite:
app.dependency_overrides.clear()

# %% [markdown]
# ### Example 5: Async testing basics
#
# `TestClient` is synchronous on purpose. It hides event-loop details so beginners can focus on behavior.
#
# Sometimes, though, you need an async test:
#
# - you want to call an async helper directly,
# - you are using an async database layer,
# - you want an async HTTP client for finer control.
#
# A modern pattern is `httpx.AsyncClient` with `ASGITransport`.

# %%
import pytest
from httpx import ASGITransport, AsyncClient
from fastapi import FastAPI

app = FastAPI()

@app.get('/async-health')
async def async_health():
    return {'status': 'async-ok'}

@pytest.mark.anyio
async def test_async_health():
    transport = ASGITransport(app=app)

    async with AsyncClient(transport=transport, base_url='http://test') as client:
        response = await client.get('/async-health')

    assert response.status_code == 200
    assert response.json() == {'status': 'async-ok'}

# %% [markdown]
# ## `TestClient` vs Async Client
#
# Sections like this become clearer when you separate capabilities from tradeoffs. As you read, ask what each option is optimized for and what complexity you accept in exchange.
#
# | Question | `TestClient` | `AsyncClient` |
# |---|---|---|
# | Best for beginners? | Yes | Not usually first choice |
# | Test syntax | Normal `def test_...` | `async def test_...` |
# | Need event-loop knowledge? | Very little | More |
# | Good for most endpoint tests? | Yes | Yes |
# | Good for testing async helpers directly? | No | Yes |
#
# **Rule of thumb:** start with `TestClient`, then move to async tests when the code under test is truly async end-to-end.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# Try these on purpose so the failure messages stop feeling mysterious:
#
# 1. **What if you forget the auth header?**
#    Expect `401 Unauthorized`.
#
# 2. **What if your request body is missing a required field?**
#    Expect `422 Unprocessable Entity`.
#
# 3. **What if you forget to clear dependency overrides?**
#    One test can accidentally affect the next test.
#
# 4. **What if you use the real database in unit tests?**
#    Your tests become slower, harder to reset, and less predictable.

# %%
# Small checklist you can adapt into real tests

def test_missing_field_returns_422(client):
    response = client.post('/users', json={'username': 'only-name'})
    assert response.status_code == 422

def test_wrong_token_returns_401(client):
    response = client.get('/me', headers={'Authorization': 'Bearer wrong-token'})
    assert response.status_code == 401

# Common cleanup pattern in pytest fixtures:
# app.dependency_overrides.clear()

# %% [markdown]
# ## Real-World Project Link
#
# Imagine our handbook project is a **task-tracking API** with login, projects, and comments.
#
# A practical test suite for that app would include:
#
# - `test_auth.py` for login, refresh, and protected routes,
# - `test_projects.py` for creating and listing projects,
# - `test_permissions.py` to ensure one user cannot edit another user's data,
# - dependency overrides so each test uses a small fake database or isolated test database.
#
# This matters because teams ship changes constantly. A strong test suite turns fear into feedback.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# - `TestClient(app)` lets you test FastAPI routes without running Uvicorn.
# - Good tests are small and focused: **Arrange → Act → Assert**.
# - Test both **success** and **failure** paths.
# - Use `headers={...}` to test tokens and authenticated endpoints.
# - Use `app.dependency_overrides[...] = ...` to replace real dependencies in tests.
# - Clear overrides after the test so they do not leak into later tests.
# - Use async tests when you need to await async code directly.
#
# ### Mini cheat sheet
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# ```python
# from fastapi.testclient import TestClient
# client = TestClient(app)
#
# response = client.get('/items')
# assert response.status_code == 200
#
# app.dependency_overrides[get_db] = override_get_db
# app.dependency_overrides.clear()
# ```

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. Write a test for `GET /items/{item_id}` that checks both an existing item and a missing item.
# 2. Create a fixture named `client` so you do not repeat `TestClient(app)` in every file.
# 3. Build a fake `get_current_user()` dependency and test a protected `/dashboard` route.
# 4. Convert one `TestClient` example into an async test with `AsyncClient`.
# 5. Add a test that proves invalid input returns `422` for a Pydantic model.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../6.%20database_integration/14.%20nosql_and_orms.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='16.%20code_quality.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
