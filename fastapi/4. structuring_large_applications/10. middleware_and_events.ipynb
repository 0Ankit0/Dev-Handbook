# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='9.%20project_architecture.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../5.%20security_and_authentication/11.%20security_fundamentals.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 10: Middleware and Events
#
# Once your API has more than a few endpoints, you will notice that some tasks repeat everywhere:
#
# - logging requests,
# - adding security headers,
# - allowing frontend apps to call your API,
# - compressing large responses,
# - preparing shared resources when the app starts,
# - closing those resources cleanly when the app shuts down.
#
# FastAPI gives you two powerful tools for this:
#
# - **middleware**, which wraps every request and response,
# - **lifespan**, which handles startup and shutdown work.
#
# In this chapter, we will keep both ideas beginner-friendly and practical.
#
# > ❓ **What is middleware exactly?** Middleware sits between the server and your route handlers. Every request passes *through* it (and every response passes back through it on the way out). Common uses: logging, auth checks, CORS headers, request timing.

# %% [markdown]
# ## The Big Picture
#
# Imagine your API is a building.
#
# - **Routes** are individual rooms where specific work happens.
# - **Middleware** is the front desk and security gate that every visitor passes through.
# - **Lifespan** is what staff do when opening the building in the morning and locking it up at night.
#
# That is why middleware is great for **cross-cutting behavior**: tasks that should happen for many or all requests, not just one endpoint.
#
# Lifespan is different. It is not about each request. It is about the app itself starting and stopping.

# %% [markdown]
# ## Core Concepts
#
# ### 1. Middleware intercepts requests and responses
# Code before `call_next(request)` runs **before** the endpoint.
# Code after it runs **after** the endpoint.
#
# ### 2. Middleware is global by nature
# If a behavior should apply to almost every request, middleware is often a better fit than repeating code in many routes.
#
# ### 3. Built-in middleware solves common web concerns
# FastAPI and Starlette give you ready-made middleware for:
# - **CORS**
# - **GZip compression**
# - **Trusted host checks**
# - **HTTPS redirect**
#
# ### 4. Order matters
# Middleware wraps other middleware. The order you add it affects the order in which requests enter and responses leave.
#
# ### 5. Lifespan manages app-wide resources
# Use lifespan for things like:
# - opening a database connection pool,
# - loading a machine learning model,
# - warming a cache,
# - closing resources cleanly at shutdown.

# %% [markdown]
# ## Syntax & First Usage
#
# Here is the smallest useful custom middleware: measure how long each request takes and place that information in a response header.

# %%
import time

from fastapi import FastAPI, Request, Response

app = FastAPI()


@app.middleware("http")
async def add_process_time_header(request: Request, call_next) -> Response:
    start = time.perf_counter()
    response = await call_next(request)
    duration = time.perf_counter() - start
    response.headers["X-Process-Time"] = f"{duration:.4f}s"
    return response


@app.get("/health")
async def health_check():
    return {"status": "ok"}

# %% [markdown]
# ### Why this is a good first example
#
# This middleware is simple, safe, and teaches the core shape:
#
# 1. receive the request,
# 2. do something before the route if needed,
# 3. call `await call_next(request)`,
# 4. optionally adjust the response,
# 5. return the response.
#
# If you forget step 3, your endpoint never runs.

# %% [markdown]
# ## Deep Dive with Code Examples
#
# ### Built-in middleware you will see often
#
# #### CORS middleware
# Use this when a frontend running on another origin, such as `http://localhost:3000`, needs to call your API.
#
# #### GZip middleware
# Use this to compress larger responses. It can reduce bandwidth usage, especially for large JSON payloads.
#
# #### TrustedHost middleware
# Use this when you want to reject requests with unexpected host headers. This is a protective measure in deployed environments.
#
# #### HTTPSRedirect middleware
# Use this when you want plain HTTP traffic redirected to HTTPS.
#
# ### Lifespan in plain language
#
# Some setup should happen once, not on every request. Lifespan is the right home for that work.
#
# Examples:
# - create a shared HTTP client,
# - connect to Redis,
# - load environment-dependent resources,
# - close them during shutdown.

# %%
from contextlib import asynccontextmanager

from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware
from fastapi.middleware.gzip import GZipMiddleware
from fastapi.middleware.httpsredirect import HTTPSRedirectMiddleware
from fastapi.middleware.trustedhost import TrustedHostMiddleware


@asynccontextmanager
async def lifespan(app: FastAPI):
    app.state.cache = {"status": "warm"}
    app.state.message = "Shared resource created at startup"
    print("Starting application resources...")
    yield
    print("Closing application resources...")
    app.state.cache.clear()


app = FastAPI(lifespan=lifespan)

app.add_middleware(
    CORSMiddleware,
    allow_origins=["http://localhost:3000"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)
app.add_middleware(GZipMiddleware, minimum_size=500)
app.add_middleware(TrustedHostMiddleware, allowed_hosts=["localhost", "127.0.0.1", "api.example.com"])
app.add_middleware(HTTPSRedirectMiddleware)


@app.get("/info")
async def read_info():
    return {
        "message": app.state.message,
        "cache_status": app.state.cache["status"],
    }

# %% [markdown]
# ### When to choose each pattern
#
# - Choose **middleware** when the behavior is about the HTTP request/response cycle.
#   - logging,
#   - timing,
#   - adding headers,
#   - origin checks,
#   - redirects.
#
# - Choose **lifespan** when the behavior is about the application process itself.
#   - preparing shared resources,
#   - cleaning up on shutdown.
#
# - Choose **route logic or dependencies** when the behavior is specific to certain endpoints, not all of them.
#
# This distinction prevents you from putting everything into middleware just because it feels "advanced."

# %% [markdown]
# ## VS comparison: middleware vs dependencies
#
# | Middleware | Dependency |
# |---|---|
# | Runs around many or all requests | Runs only where you declare it |
# | Great for cross-cutting HTTP behavior | Great for endpoint-specific validation or shared objects |
# | Can inspect and modify responses | Usually focused on supplying data or checks before route logic |
# | Best for logging, headers, CORS, timing | Best for auth checks, DB sessions, current user loading |
#
# ### Which should you pick?
#
# Pick **middleware** when you need the same HTTP-level behavior almost everywhere.
#
# Pick a **dependency** when you only need logic on selected endpoints or routers.
#
# Another helpful comparison:
#
# ### Middleware vs route code
#
# - Put code in **routes** when it is clearly local to one endpoint.
# - Put code in **middleware** when you catch yourself repeating the same request/response behavior again and again.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# 1. **What if I forget `await call_next(request)`?**
#    - The request stops in middleware and the endpoint never produces a response.
#
# 2. **What if I allow every origin in CORS during development?**
#    - Convenient locally, but risky if copied into production carelessly.
#
# 3. **What if I put expensive setup inside every route instead of lifespan?**
#    - You waste time on every request and make performance worse.
#
# 4. **What if I add middleware in the wrong order?**
#    - Behavior can become confusing because wrappers execute in layers.
#
# 5. **What if I use middleware for business rules like "only managers can delete invoices"?**
#    - That usually belongs in dependencies or service logic, because it is endpoint-specific domain behavior rather than global HTTP behavior.

# %% [markdown]
# ## Real-World Project Link
#
# Explore the **FastAPI Full Stack Template** when you want to see how a larger project handles API startup and web concerns:
#
# - https://github.com/fastapi/full-stack-fastapi-template
#
# As you browse it, look specifically for:
# - where the application object is created,
# - where configuration is loaded,
# - where cross-cutting behavior is centralized.
#
# You do not need to understand every file yet. The main lesson is that mature projects avoid scattering setup code everywhere.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Quick summary
# - Middleware wraps requests and responses.
# - Built-in middleware handles common web tasks.
# - Custom middleware is useful for logging, timing, and headers.
# - Lifespan handles startup and shutdown work.
# - Middleware is for global HTTP concerns; dependencies and services handle more local or domain-specific logic.
#
# ### Mini cheat sheet
#
# ```python
# @app.middleware("http")
# async def example(request, call_next):
#     response = await call_next(request)
#     return response
# ```
# Basic shape of HTTP middleware.
#
# ```python
# app.add_middleware(CORSMiddleware, allow_origins=["http://localhost:3000"])
# ```
# Lets a frontend from another origin call the API.
#
# ```python
# app.add_middleware(GZipMiddleware, minimum_size=500)
# ```
# Compresses larger responses.
#
# ```python
# app = FastAPI(lifespan=lifespan)
# ```
# Registers startup and shutdown behavior.
#
# ### Simple decision guide
# - **Need logging or headers everywhere?** Middleware.
# - **Need frontend access from another origin?** CORS middleware.
# - **Need one-time startup setup?** Lifespan.
# - **Need route-specific auth or validation?** Dependency or service layer.

# %% [markdown]
# ## Practice Prompts
#
# 1. Write middleware that adds an `X-App-Version` header to every response.
# 2. Add `CORSMiddleware` for a frontend running at `http://localhost:5173`.
# 3. Explain why GZip middleware should usually target larger responses instead of every tiny payload.
# 4. Create a lifespan function that loads a mock dictionary at startup and clears it at shutdown.
# 5. Decide whether each task belongs in middleware, lifespan, a dependency, or a route:
#    - logging request duration,
#    - loading the current user,
#    - opening a shared Redis client,
#    - checking if a task belongs to the logged-in user.
#
# If you can tell **why** something belongs in middleware or lifespan, you are building real backend intuition.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='9.%20project_architecture.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../5.%20security_and_authentication/11.%20security_fundamentals.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
