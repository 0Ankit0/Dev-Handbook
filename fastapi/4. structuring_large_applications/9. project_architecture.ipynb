# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../3.%20core_fastapi_concepts/8.%20response_handling.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='10.%20middleware_and_events.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 9: Project Architecture
#
# Welcome to the point where your FastAPI app stops feeling like a tutorial toy and starts feeling like a real project.
#
# In the early chapters, putting everything in one file was helpful because it reduced distractions. But once your API has users, authentication, database access, validation, and multiple teams touching the code, a single `main.py` quickly becomes stressful to navigate.
#
# In this chapter, we will build a gentle mental model for **how to organize a FastAPI project** so that it stays understandable as it grows.
#
# **You will learn to:**
# - use `APIRouter` to split endpoints into focused modules,
# - choose a beginner-friendly folder layout,
# - understand services and repositories in plain language,
# - centralize settings and configuration,
# - decide when structure is helping and when it is becoming over-engineering.

# %% [markdown]
# ## The Big Picture
#
# Think of project architecture like organizing a kitchen.
#
# - If every tool, ingredient, and recipe sits in one giant drawer, you *can* cook, but it gets slower and messier every day.
# - If knives, pans, spices, and recipes each have a place, you can work faster, teach other people the system, and change one part without disturbing everything else.
#
# A growing FastAPI app is similar:
#
# - **routers** group related endpoints,
# - **schemas** describe input and output data,
# - **services** hold business rules,
# - **repositories** talk to the database,
# - **settings** keep environment-specific values in one place.
#
# The goal is not to create the fanciest folder tree. The goal is to make future changes less scary.

# %% [markdown]
# ## Core Concepts
#
# ### 1. `APIRouter` lets you split endpoints by feature
# When all routes live in `main.py`, every new endpoint makes that file heavier. `APIRouter` helps you move related routes into files like `users.py`, `items.py`, or `auth.py`.
#
# ### 2. A modular layout gives each job a home
# A clean project often separates:
# - **API layer**: receives requests and returns responses,
# - **business layer**: decides *what should happen*,
# - **data layer**: reads and writes data,
# - **configuration layer**: stores settings like URLs and secrets.
#
# ### 3. Services explain the app's rules
# A **service** is just a place for logic such as:
# - "a user email must be unique,"
# - "an order cannot be paid twice,"
# - "inactive users cannot create projects."
#
# Put simply: **services answer "what should the app do?"**
#
# ### 4. Repositories explain how data is fetched or stored
# A **repository** is a small wrapper around database operations.
#
# Put simply: **repositories answer "how do we get or save the data?"**
#
# ### 5. Centralized settings prevent scattered configuration
# If your database URL, app name, debug flag, and CORS settings are hardcoded in random files, changing environments becomes painful. A settings module gives those values one obvious home.
#
# ### 6. Structure should match app size
# A tiny demo app does **not** need ten folders and six layers. A serious API with multiple features usually does benefit from structure.

# %% [markdown]
# ## Syntax & First Usage
#
# Let's start with the smallest useful architecture improvement: moving routes into routers.

# %%
from fastapi import APIRouter, FastAPI

users_router = APIRouter(prefix="/users", tags=["users"])


@users_router.get("/")
async def list_users():
    return [{"id": 1, "name": "Ava"}]


@users_router.get("/{user_id}")
async def get_user(user_id: int):
    return {"id": user_id, "name": "Ava"}


app = FastAPI(title="Starter API")
app.include_router(users_router)

# %% [markdown]
# ### Why this first step matters
#
# This is still a very small app, but it already gives you two wins:
#
# 1. `main.py` stays focused on app creation.
# 2. User-related routes can grow without mixing with unrelated topics.
#
# A very common beginner path is:
#
# - start with one file,
# - add `APIRouter` when routes begin to feel crowded,
# - add service and repository modules when logic starts repeating,
# - add more structure only when the codebase genuinely needs it.

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Here is a beginner-friendly layout for a first serious API project:
#
# ```text
# app/
# ├── main.py
# ├── core/
# │   └── config.py
# ├── api/
# │   ├── deps.py
# │   └── routes/
# │       ├── users.py
# │       └── projects.py
# ├── schemas/
# │   ├── user.py
# │   └── project.py
# ├── services/
# │   ├── user_service.py
# │   └── project_service.py
# ├── repositories/
# │   ├── user_repository.py
# │   └── project_repository.py
# └── db/
#     └── session.py
# ```
#
# ### What each area is responsible for
#
# #### `main.py`
# Usually creates the FastAPI app, includes routers, and registers middleware or lifespan behavior.
#
# #### `api/routes/`
# Holds endpoint functions. These should stay thin:
# - read inputs,
# - call a service,
# - return the result.
#
# #### `services/`
# Holds business logic. This is where you decide what is allowed, what should be rejected, and what steps must happen in which order.
#
# #### `repositories/`
# Holds database access logic. If two endpoints both need "find user by email," that query should not be rewritten in multiple route files.
#
# #### `core/config.py`
# Holds settings such as app name, environment, secret keys, database URL, and allowed origins.
#
# ### A simple mental flow
#
# ```text
# Request -> Router -> Service -> Repository -> Database
#                          |
#                          -> business decisions happen here
# ```
#
# That flow is helpful because each layer has a simpler job.

# %%
from functools import lru_cache

from fastapi import APIRouter, Depends, HTTPException
from pydantic import BaseModel
from pydantic_settings import BaseSettings, SettingsConfigDict


class Settings(BaseSettings):
    model_config = SettingsConfigDict(env_file=".env", extra="ignore")

    app_name: str = "Project Hub API"
    database_url: str = "sqlite:///./project_hub.db"
    admin_email: str = "admin@example.com"


@lru_cache
def get_settings() -> Settings:
    return Settings()


class UserCreate(BaseModel):
    email: str
    full_name: str


class UserRepository:
    def __init__(self):
        self._users = []

    def get_by_email(self, email: str):
        return next((user for user in self._users if user["email"] == email), None)

    def create(self, data: dict):
        user = {"id": len(self._users) + 1, **data}
        self._users.append(user)
        return user


class UserService:
    def __init__(self, repository: UserRepository):
        self.repository = repository

    def register_user(self, payload: UserCreate):
        existing = self.repository.get_by_email(payload.email)
        if existing:
            raise HTTPException(status_code=400, detail="Email already registered")
        return self.repository.create(payload.model_dump())


router = APIRouter(prefix="/users", tags=["users"])
repository = UserRepository()
service = UserService(repository)


@router.post("/")
async def create_user(payload: UserCreate, settings: Settings = Depends(get_settings)):
    user = service.register_user(payload)
    return {
        "app": settings.app_name,
        "admin_contact": settings.admin_email,
        "user": user,
    }

# %% [markdown]
# ### Choosing patterns gently
#
# You do **not** need a repository layer on day one just because a blog post said so.
#
# A practical beginner rule is:
#
# - **Use direct database access in routes** for very small demos.
# - **Introduce a service** when route logic starts getting longer than the request/response handling.
# - **Introduce a repository** when the same queries or persistence steps appear in multiple places.
#
# This keeps your architecture useful instead of decorative.

# %% [markdown]
# ## VS comparison: one big file vs modular project
#
# | One big `main.py` | Modular project |
# |---|---|
# | Fast to start | Fast to maintain |
# | Easy for 2-3 endpoints | Easier for 20-50 endpoints |
# | Logic, routes, and config mix together | Each concern gets a clearer home |
# | Harder to test pieces in isolation | Easier to test services and repositories separately |
# | New teammates must scan one large file | New teammates can navigate by feature |
#
# ### Which one should you choose?
#
# - Choose **one file** for experiments, tutorials, and tiny prototypes.
# - Choose a **modular structure** when your app has multiple resources, authentication, database logic, or more than one developer.
#
# Another useful comparison:
#
# ### Service layer vs route-heavy logic
#
# - Put logic **in the route** when it is short and unlikely to be reused.
# - Put logic **in a service** when it contains rules, branching, validation steps, or coordination across multiple repositories.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# Try answering these before you code:
#
# 1. **What if every route directly opens the database and writes SQL?**
#    - It may work at first, but repeated queries become hard to update consistently.
#
# 2. **What if I skip services completely?**
#    - Fine for a tiny app. Less fine once business rules appear in many endpoints.
#
# 3. **What if settings are scattered across files?**
#    - Changing environments becomes risky because you cannot easily see what values matter.
#
# 4. **What if two routers need the same helper logic?**
#    - That is usually a sign the logic belongs in a shared service, dependency, or utility module.
#
# 5. **What if I create too many layers too early?**
#    - You may slow yourself down. Good architecture should reduce confusion, not increase it.
#
# A healthy architecture is one that feels boring in a good way: easy to find, easy to change, easy to explain.

# %% [markdown]
# ## Real-World Project Link
#
# A useful real project to explore later is the **FastAPI Full Stack Template**:
#
# - https://github.com/fastapi/full-stack-fastapi-template
#
# Why it is worth looking at:
# - it separates application concerns clearly,
# - it centralizes configuration,
# - it shows how structure supports bigger teams and production deployment.
#
# Why you should explore it **later, not blindly copy it now**:
# - it is more advanced than a first API project,
# - some patterns make more sense after you have built a smaller app yourself.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### Quick summary
# - `APIRouter` helps split endpoints into feature-based modules.
# - Services hold business rules.
# - Repositories hold data-access details.
# - Settings centralize environment-based values.
# - A good structure helps more as the app grows.
#
# ### Mini cheat sheet
#
# ```python
# app.include_router(users_router)
# ```
# Use when you want to mount routes from another file.
#
# ```python
# class Settings(BaseSettings):
#     database_url: str
# ```
# Use when you want config loaded from environment variables.
#
# ```python
# class UserService:
#     def register_user(self, payload):
#         ...
# ```
# Use when route functions are becoming too smart.
#
# ```python
# class UserRepository:
#     def get_by_email(self, email):
#         ...
# ```
# Use when database access is repeating.
#
# ### Simple decision guide
# - **Tiny app?** Keep it simple.
# - **Growing app?** Add routers first.
# - **Repeated rules?** Add services.
# - **Repeated queries?** Add repositories.
# - **Multiple environments?** Centralize settings early.

# %% [markdown]
# ## Practice Prompts
#
# 1. Create a small folder plan for an API with `users`, `tasks`, and `auth` features.
# 2. Move one pair of endpoints from `main.py` into an `APIRouter`.
# 3. Write a `TaskService` with one rule: completed tasks cannot be edited.
# 4. Write a `TaskRepository` method called `get_by_owner(owner_id: int)`.
# 5. List three settings you would want in `core/config.py` for a blog API.
# 6. Explain, in your own words, the difference between a service and a repository.
#
# If you can explain **why** a piece of code belongs in a certain layer, you are learning architecture the right way.

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='../3.%20core_fastapi_concepts/8.%20response_handling.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='10.%20middleware_and_events.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
