# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='2.%20routing_and_basic_path_operations.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../2.%20data_validation_and_serialization_with_pydantic/4.%20deep_dive_into_pydantic_models.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 3: Automatic Documentation
#
# One of FastAPI's most beginner-friendly superpowers is that it creates API documentation for you. Instead of building docs from scratch, you get interactive pages almost immediately.

# %% [markdown]
# ## The Big Picture
#
# Documentation explains what your API can do, what data it expects, and what it returns. In many frameworks, beginners have to write much of that manually. FastAPI helps by generating docs from the code you already write.
#
# The main pieces are:
#
# - **`/docs`**: an interactive page powered by Swagger UI
# - **`/redoc`**: a cleaner, more reading-focused page powered by ReDoc
# - **OpenAPI schema**: a machine-readable description of your API, usually available at `/openapi.json`
#
# A **schema** is a structured description of data or behavior. Think of it like a blueprint. Humans can read the docs pages, and tools can read the OpenAPI schema.
#
# > ❓ **Why split code into Blueprints?** A single file with hundreds of routes becomes unreadable. Blueprints group related routes (e.g., all auth routes) into pluggable mini-applications that you register on the main app — like separate chapters in a book.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### Why does automatic documentation matter?
# Because APIs are only useful when people know how to use them. That includes:
#
# - future you
# - teammates
# - frontend developers
# - testing tools
# - deployment tools
#
# ### Why are docs generated from code?
# Because duplicated information goes out of date. If you manually write docs in one place and route code in another, they can drift apart. FastAPI reduces that problem by using your route definitions, type hints, and models as the source of truth.
#
# ### Why have both `/docs` and `/redoc`?
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# They serve different moods:
#
# - `/docs` is great for trying requests interactively.
# - `/redoc` is great for reading the API structure in a clean layout.

# %% [markdown]
# ## Syntax & First Usage
#
# Here is a tiny FastAPI app that automatically creates documentation:
#
# ```python
# from fastapi import FastAPI
# from pydantic import BaseModel
#
# app = FastAPI(title='Library API')
#
# class Book(BaseModel):
#     title: str
#     author: str
#
# @app.post('/books', response_model=Book, tags=['Books'])
# def create_book(book: Book):
#     return book
# ```
#
# If you run this app and open these URLs, you will see generated docs:
#
# - `http://127.0.0.1:8000/docs`
# - `http://127.0.0.1:8000/redoc`
# - `http://127.0.0.1:8000/openapi.json`
#
# The important idea is this: your code is now describing both behavior *and* documentation.
#
# > ❓ **What is a decorator?** A decorator is a function that wraps another function to add behaviour before or after it runs. `@app.route('/')` is shorthand for `index = app.route('/')(index)` — it registers your view function with Flask's URL map without any explicit call.

# %%
from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI(title='Library API', version='1.0.0', description='A tiny API for learning docs.')

class Book(BaseModel):
    title: str
    author: str

@app.post('/books', response_model=Book, tags=['Books'])
def create_book(book: Book):
    return book

schema = app.openapi()
print(schema['info']['title'])
print(list(schema['paths'].keys()))

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Swagger UI, which powers `/docs`, gives you buttons and forms for testing the API in the browser.
#
# Beginners often love this because it turns an abstract API into something clickable. You can:
#
# - inspect routes
# - see parameters and request bodies
# - try requests without writing frontend code
# - view responses and status codes
#
# It is like getting a built-in playground for your API.

# %%
docs_urls = {
    'Swagger UI': '/docs',
    'ReDoc': '/redoc',
    'OpenAPI JSON': '/openapi.json',
}

for label, url in docs_urls.items():
    print(f'{label}: {url}')

# %% [markdown]
# ## Deep Dive with Code Examples
#
# The **OpenAPI schema** is a JSON document that describes your API in a standard format. Standards are shared conventions. They help different tools cooperate.
#
# Why is that useful?
#
# - documentation pages can be generated from it
# - testing tools can read it
# - client SDK generators can read it
# - teams can agree on API behavior more clearly
#
# In other words, OpenAPI is not just a nice extra. It is a bridge between your code and the broader software ecosystem.

# %%
openapi_info = {
    'title': schema['info']['title'],
    'version': schema['info']['version'],
    'book_post_summary': schema['paths']['/books']['post'].get('summary'),
}

print(openapi_info)

# %% [markdown]
# ## Deep Dive with Code Examples
#
# FastAPI lets you improve the generated docs by adding metadata such as:
#
# - `title`
# - `description`
# - `version`
# - `tags`
# - route summaries and descriptions
#
# This matters because clear docs are not only about correctness. They are also about readability.

# %%
from fastapi import FastAPI

custom_app = FastAPI(
    title='Study Tracker API',
    description='Track study sessions and topics.',
    version='0.1.0'
)

@custom_app.get('/sessions', tags=['Sessions'], summary='List study sessions')
def list_sessions():
    return [{'topic': 'FastAPI', 'minutes': 30}]

custom_schema = custom_app.openapi()
operation = custom_schema['paths']['/sessions']['get']
print(custom_schema['info'])
print(operation['tags'])
print(operation['summary'])

# %% [markdown]
# ## `/docs` vs `/redoc`
#
# The hard part here is usually not the syntax but the boundary between similar ideas. Keep comparing the job each option does best, the tradeoff it introduces, and the clues that tell you which one fits the situation in front of you.
#
# | Option | Best for | What it feels like |
# | --- | --- | --- |
# | `/docs` | Trying requests and exploring interactively | A hands-on control panel |
# | `/redoc` | Reading the API structure more calmly | A polished reference guide |
#
# They show the same underlying API information in different styles. If you like clicking buttons and sending test requests, `/docs` will probably be your first stop.

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Sometimes you want a route to exist but not show up in public docs. FastAPI allows that with `include_in_schema=False`.
#
# Example:
#
# ```python
# @app.get('/internal-health', include_in_schema=False)
# def internal_health():
#     return {'ok': True}
# ```
#
# This route still exists, but it will not appear in the OpenAPI schema or generated docs.
#
# That can be useful for internal-only endpoints, though beginners should still document important routes clearly whenever possible.

# %%
hidden_app = FastAPI(title='Hidden Route Demo')

@hidden_app.get('/public')
def public_route():
    return {'visible': True}

@hidden_app.get('/internal-health', include_in_schema=False)
def internal_health():
    return {'ok': True}

hidden_schema = hidden_app.openapi()
print('Paths visible in schema:', list(hidden_schema['paths'].keys()))
print('Hidden route exists in Python:', any(getattr(route, 'path', '') == '/internal-health' for route in hidden_app.routes))

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### Experiment 1: Change the app title and description
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# Update the `FastAPI(...)` constructor and refresh `/docs`. Notice how the docs page becomes more descriptive.
# ### Experiment 2: Add tags to routes
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# Put related routes under tags such as `['Books']` or `['Users']`. This groups operations visually in the docs.
# ### Experiment 3: Hide one endpoint from the schema
#
# A useful beginner mental model here is to separate the shape of the data from the operations performed on it. Once you know what is being represented and who depends on that representation, the rules become easier to predict.
#
# Use `include_in_schema=False` on a route and compare `/docs` before and after. This shows that the schema controls what documentation tools can see.

# %%
tagged_app = FastAPI(title='Tag Demo')

@tagged_app.get('/books', tags=['Books'])
def get_books():
    return []

@tagged_app.get('/authors', tags=['Authors'])
def get_authors():
    return []

tagged_schema = tagged_app.openapi()
print(tagged_schema['paths']['/books']['get']['tags'])
print(tagged_schema['paths']['/authors']['get']['tags'])

# %% [markdown]
# ## Real-World Project Link
#
# **Mini project:** Build a "Classroom Tasks API" and make the documentation pleasant to use.
#
# Suggested goals:
#
# - create routes for tasks and students
# - add tags such as `Tasks` and `Students`
# - write short summaries for each route
# - visit `/docs` and `/redoc`
# - inspect `/openapi.json` and identify where your route names appear
#
# This project helps you see documentation as part of development, not something you do at the very end.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### What you learned
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# - FastAPI automatically generates docs at `/docs` and `/redoc`.
# - The OpenAPI schema is usually available at `/openapi.json`.
# - Type hints, models, and route metadata feed the docs system.
# - Tags, summaries, titles, and descriptions improve clarity.
# - `include_in_schema=False` hides a route from generated docs.
# ### Cheat sheet
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```python
# app = FastAPI(
#     title='My API',
#     description='An API for practice',
#     version='1.0.0'
# )
#
# @app.get('/items', tags=['Items'], summary='List items')
# def list_items():
#     return []
# ```
#
# ```text
# /docs
# /redoc
# /openapi.json
# ```

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. What problem does automatic documentation solve for API teams?
# 2. When might you prefer `/docs` over `/redoc`?
# 3. What is the role of `/openapi.json`?
# 4. Add a `summary` and `tags` value to a route in your own practice app.
# 5. Why might `include_in_schema=False` be useful for some routes?

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='2.%20routing_and_basic_path_operations.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='../2.%20data_validation_and_serialization_with_pydantic/4.%20deep_dive_into_pydantic_models.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
