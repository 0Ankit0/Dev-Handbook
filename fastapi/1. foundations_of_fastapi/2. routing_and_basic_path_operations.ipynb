# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='1.%20setting_up_the_development_environment.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='3.%20automatic_documentation.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>

# %% [markdown]
# # Chapter 2: Routing and Basic Path Operations
#
# Now that your app can run, it is time to teach it how to respond to different URLs and different kinds of requests. This is where FastAPI starts to feel powerful very quickly.

# %% [markdown]
# ## The Big Picture
#
# A web API is made of **path operations**. That phrase sounds formal, but it simply means:
#
# - a **path** such as `/items` or `/users/5`
# - plus an **operation** such as GET, POST, PUT, or DELETE
#
# Together, they describe one action your API can perform.
#
# Example:
#
# - `GET /items` → read items
# - `POST /items` → create items
#
# Think of a path as a street address and the HTTP method as what you want done at that address.
#
# > ❓ **What makes an API "RESTful"?** REST uses HTTP verbs semantically: `GET` reads, `POST` creates, `PUT`/`PATCH` updates, `DELETE` removes. Each URL represents a *resource* (e.g., `/users/42`), and the server keeps no state between requests.

# %% [markdown]
# ## Core Concepts
#
# The easiest way to read this section is to keep one plain-language question in view: what is Core Concepts actually responsible for? Once that job is clear, the terminology stops feeling arbitrary and the details start to line up.
#
# ### Why does FastAPI use decorators like `@app.get()`?
# A **decorator** is a Python feature that attaches extra meaning to a function. In FastAPI, the decorator tells the framework, "This function should run for this kind of request."
#
# ### Why do types matter here?
# When you write `item_id: int`, FastAPI uses that type hint to validate input. Validation means checking whether data is in an acceptable form.
#
# ### Why separate path parameters, query parameters, and request bodies?
# Because they answer different questions:
#
# - **Path parameters** identify *which thing* you want, like `/items/7`.
# - **Query parameters** adjust *how* you want it, like `/items?limit=10`.
# - **Request body** sends the actual data, usually when creating or updating something.
#
# FastAPI keeps these ideas separate so your code stays readable.
#
# > ❓ **What is a decorator?** A decorator is a function that wraps another function to add behaviour before or after it runs. `@app.route('/')` is shorthand for `index = app.route('/')(index)` — it registers your view function with Flask's URL map without any explicit call.

# %% [markdown]
# ## Syntax & First Usage
#
# Here are the four path operation decorators you will see all the time:
#
# ```python
# @app.get('/items')
# @app.post('/items')
# @app.put('/items/{item_id}')
# @app.delete('/items/{item_id}')
# ```
#
# A beginner-friendly example:
#
# ```python
# from fastapi import FastAPI
#
# app = FastAPI()
#
# @app.get('/hello')
# def say_hello(name: str = 'friend'):
#     return {'message': f'Hello, {name}!'}
# ```
#
# If the user visits `/hello?name=Ava`, the response changes. That `name` value is a **query parameter** because it appears after a question mark in the URL.

# %%
from fastapi import FastAPI
from fastapi.routing import APIRoute

app = FastAPI(title='Routing Demo')

@app.get('/hello')
def say_hello(name: str = 'friend'):
    return {'message': f'Hello, {name}!'}

route = next(route for route in app.routes if isinstance(route, APIRoute))
print(route.path)
print(sorted(route.methods))
print(route.endpoint(name='Ava'))

# %% [markdown]
# ## Deep Dive with Code Examples
#
# A **path parameter** is a value inside the URL path itself.
#
# ```python
# @app.get('/items/{item_id}')
# def read_item(item_id: int):
#     return {'item_id': item_id}
# ```
#
# If someone visits `/items/42`, FastAPI passes `42` into the function.
#
# Notice the type hint `int`. If the user tries `/items/banana`, FastAPI knows that does not fit and returns a validation error automatically. That is one of the reasons beginners often enjoy FastAPI: it catches mistakes early.

# %%
def read_item(item_id: int):
    return {'item_id': item_id}

print(read_item(42))
print(type(read_item(42)['item_id']).__name__)

# %% [markdown]
# ## Deep Dive with Code Examples
#
# Query parameters are optional pieces of information added to the URL.
#
# Example URL:
#
# ```text
# /search?term=fastapi&limit=5
# ```
#
# In FastAPI, you can write:
#
# ```python
# @app.get('/search')
# def search(term: str, limit: int = 10):
#     return {'term': term, 'limit': limit}
# ```
#
# Here:
#
# - `term` is required because it has no default value.
# - `limit` is optional because it has a default value of `10`.

# %%
def search(term: str, limit: int = 10):
    return {'term': term, 'limit': limit}

print(search('fastapi'))
print(search('fastapi', limit=3))

# %% [markdown]
# ## Deep Dive with Code Examples
#
# When a client sends JSON data to your API, that data usually goes into the **request body**.
#
# FastAPI commonly uses **Pydantic models** to describe that shape. A model is a structured template for data.
#
# ```python
# from pydantic import BaseModel
#
# class Item(BaseModel):
#     name: str
#     price: float
#     in_stock: bool = True
# ```
#
# This model says:
#
# - every item needs a `name`
# - every item needs a `price`
# - `in_stock` defaults to `True` unless another value is sent

# %%
from pydantic import BaseModel

class Item(BaseModel):
    name: str
    price: float
    in_stock: bool = True

example_item = Item(name='Notebook', price=12.5)
print(example_item.model_dump())

# %% [markdown]
# ## Deep Dive with Code Examples
#
# A **response model** tells FastAPI what the returned data should look like. This improves consistency and documentation.
#
# ```python
# from pydantic import BaseModel
#
# class ItemCreate(BaseModel):
#     name: str
#     price: float
#
# class ItemResponse(BaseModel):
#     name: str
#     price: float
#     message: str
#
# @app.post('/items', response_model=ItemResponse)
# def create_item(item: ItemCreate):
#     return {
#         'name': item.name,
#         'price': item.price,
#         'message': 'Item created successfully'
#     }
# ```
#
# This does two helpful things:
#
# 1. it makes your code easier to understand
# 2. it limits the response to the fields you declared

# %%
from pydantic import BaseModel

class ItemCreate(BaseModel):
    name: str
    price: float

class ItemResponse(BaseModel):
    name: str
    price: float
    message: str

def create_item(item: ItemCreate) -> ItemResponse:
    return ItemResponse(
        name=item.name,
        price=item.price,
        message='Item created successfully'
    )

created = create_item(ItemCreate(name='Pen', price=1.99))
print(created.model_dump())

# %% [markdown]
# ## Path Parameters vs Query Parameters
#
# This comparison helps many beginners:
#
# | Feature | Path parameter | Query parameter |
# | --- | --- | --- |
# | Example | `/items/7` | `/items?limit=7` |
# | Main purpose | Identify a specific resource | Filter, sort, search, or tweak the request |
# | Usually required? | Yes | Often optional |
# | Feels like | "which thing?" | "with what options?" |
#
# A quick rule of thumb:
#
# - If the value points to a specific thing, it is often a **path parameter**.
# - If the value changes how you search or display results, it is often a **query parameter**.

# %% [markdown]
# ## The "What If?" Experimentation Section
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ### Experiment 1: Make a query parameter required
#
# If this section feels dense, pause and identify the data structure or model first. Most of the APIs here make more sense once you know what is being stored, queried, or transformed.
#
# Remove the default value from `name: str = 'friend'` so it becomes `name: str`. Now the client must provide `?name=...`.
# ### Experiment 2: Change the path parameter type
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# Change `item_id: int` to `item_id: str`. Now `/items/banana` is allowed because you told FastAPI to expect text instead of a number.
# ### Experiment 3: Add a hidden internal field
# Return extra data from your function, then use a response model that leaves it out. This shows how response models can protect your public output.

# %%
from pydantic import BaseModel

class PublicItem(BaseModel):
    name: str
    price: float

raw_data = {
    'name': 'Desk Lamp',
    'price': 24.99,
    'internal_code': 'LAMP-SECRET-01'
}

public_view = PublicItem.model_validate(raw_data)
print('Raw data:', raw_data)
print('Public response:', public_view.model_dump())

# %% [markdown]
# ## Real-World Project Link
#
# **Mini project:** Build a simple "Book Notes API."
#
# Suggested routes:
#
# - `GET /books` → list books
# - `GET /books/{book_id}` → read one book by id
# - `POST /books` → create a new book from JSON
# - `PUT /books/{book_id}` → update a book
# - `DELETE /books/{book_id}` → remove a book
#
# Add query parameters such as `?limit=5` or `?author=...` to practice filtering.

# %% [markdown]
# ## Chapter Summary & Cheat Sheet
#
# ### What you learned
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# - A **path operation** combines a URL path and an HTTP method.
# - Decorators such as `@app.get()` connect routes to Python functions.
# - **Path parameters** live inside the URL path.
# - **Query parameters** live after `?` in the URL.
# - **Request bodies** usually carry JSON data.
# - **Pydantic models** describe and validate structured data.
# - **Response models** shape the data your API sends back.
# ### Cheat sheet
#
# A first read goes better when you connect every new idea to a concrete responsibility and a concrete use case. Once those anchors are in place, the terminology in this section becomes much easier to reuse accurately.
#
# ```python
# @app.get('/items/{item_id}')
# def read_item(item_id: int, details: bool = False):
#     return {'item_id': item_id, 'details': details}
# ```
#
# ```python
# class Item(BaseModel):
#     name: str
#     price: float
#
# @app.post('/items', response_model=Item)
# def create_item(item: Item):
#     return item
# ```

# %% [markdown]
# ## Practice Prompts
#
# If this topic is new, keep translating each new term into a simple question: what job does it do, when would you reach for it, and what would you confuse it with if you were moving too quickly? That habit makes the section easier to retain.
#
# 1. Explain the difference between a path parameter and a query parameter in your own words.
# 2. Write a route that accepts `/users/{user_id}` where `user_id` must be an integer.
# 3. Create a query parameter named `page` with a default value of `1`.
# 4. Define a Pydantic model for a `Movie` with `title`, `year`, and `rating`.
# 5. Why might a response model be safer than returning raw data directly?

# %% [markdown]
# <div style='width:100%; display:flex; justify-content:space-between; align-items:center; margin: 1em 0;'>
#   <a href='1.%20setting_up_the_development_environment.ipynb' style='padding:6px 14px; background:#007bff; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>← Previous</a>
#   <a href='../TOC.md' style='padding:6px 14px; background:#6c757d; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>📚 Table of Contents</a>
#   <a href='3.%20automatic_documentation.ipynb' style='padding:6px 14px; background:#28a745; color:white; border-radius:4px; text-decoration:none; font-weight:bold;'>Next →</a>
# </div>
